# %% [markdown]
# <a href="https://colab.research.google.com/github/ifeLight/ml-bot/blob/main/binance-multi-timeframe-grade-review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas-ta
# !pip install backtrader[plotting]
# !pip install plotly
# !pip install --upgrade firebase-admin
# Out:
# Collecting pandas-ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from pandas-ta) (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas-ta) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas-ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas-ta) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas-ta) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->pandas-ta) (1.17.0)
# Building wheels for collected packages: pandas-ta
#   Building wheel for pandas-ta (setup.py) ... done
#   Created wheel for pandas-ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218909 sha256=0f7af34cd4114ff7edc7112271db61bbb8bb3c41b5b464f98deefb567d975acd
#   Stored in directory: /root/.cache/pip/wheels/7f/33/8b/50b245c5c65433cd8f5cb24ac15d97e5a3db2d41a8b6ae957d
# Successfully built pandas-ta
# Installing collected packages: pandas-ta
# Successfully installed pandas-ta-0.3.14b0
# Collecting backtrader[plotting]
#   Downloading backtrader-1.9.78.123-py2.py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from backtrader[plotting]) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->backtrader[plotting]) (1.17.0)
# Downloading backtrader-1.9.78.123-py2.py3-none-any.whl (419 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 4.5 MB/s eta 0:00:00
# Installing collected packages: backtrader
# Successfully installed backtrader-1.9.78.123
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)
# Requirement already satisfied: firebase-admin in /usr/local/lib/python3.11/dist-packages (6.6.0)
# Collecting firebase-admin
#   Downloading firebase_admin-6.7.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: cachecontrol>=0.12.14 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (0.14.2)
# Requirement already satisfied: google-api-python-client>=1.7.8 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (2.160.0)
# Requirement already satisfied: google-cloud-storage>=1.37.1 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (2.19.0)
# Requirement already satisfied: pyjwt>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (2.10.1)
# Requirement already satisfied: google-api-core<3.0.0dev,>=1.22.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.24.2)
# Requirement already satisfied: google-cloud-firestore>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (2.20.1)
# Requirement already satisfied: requests>=2.16.0 in /usr/local/lib/python3.11/dist-packages (from cachecontrol>=0.12.14->firebase-admin) (2.32.3)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in /usr/local/lib/python3.11/dist-packages (from cachecontrol>=0.12.14->firebase-admin) (1.1.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.69.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (4.25.6)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.38.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.62.3)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (4.1.1)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from google-cloud-firestore>=2.19.0->firebase-admin) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage>=1.37.1->firebase-admin) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage>=1.37.1->firebase-admin) (1.6.0)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (1.17.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client>=1.7.8->firebase-admin) (3.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (2025.1.31)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.6.1)
# Downloading firebase_admin-6.7.0-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.0/134.0 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: firebase-admin
#   Attempting uninstall: firebase-admin
#     Found existing installation: firebase-admin 6.6.0
#     Uninstalling firebase-admin-6.6.0:
#       Successfully uninstalled firebase-admin-6.6.0
# Successfully installed firebase-admin-6.7.0

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import datetime
import requests
import json
import os
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.losses import mse, mae
import backtrader as bt
import pandas_ta as ta
from imblearn.over_sampling import SMOTE
import subprocess
import firebase_admin
from firebase_admin import firestore
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
from google.colab import auth
import google.auth
import itertools
import hashlib
import re

# %%
auth.authenticate_user()
#Configure Google cloud project
project_id = 'ifelight'
# !gcloud config set project {project_id}
# Out:
# Updated property [core/project].

# %%
# Working GCP Bucket name
bucket_name = 'ife-storage'
# Working on Firestore name
firestore_collection_name = 'trade-models'

# %%
binance_base_url = 'https://52on3577u3.execute-api.eu-central-1.amazonaws.com'

def get_binance_candles(symbol: str, interval='1h', limit: int = 50, **kwargs):
    url = f'{binance_base_url}/api/v3/uiKlines?symbol={symbol}&interval={interval}&limit={limit}'
    for key, value in kwargs.items():
        url += f'&{key}={value}'
    response = requests.get(url)
    result = json.loads(response.text)
    # print(result)
    def map_result(x):
        return {
            'Date': x[0],
            'Open': x[1],
            'High': x[2],
            'Low': x[3],
            'Close': x[4],
            'Volume': x[5],
        }
    mappeded_result = []
    for x in result:
        mappeded_result.append(map_result(x))
    return mappeded_result


def candles_to_df(data):
    df =  pd.DataFrame(data)
    df['Date'] = pd.to_datetime(df['Date'], unit='ms')
    df['Open'] = df['Open'].astype(float)
    df['High'] = df['High'].astype(float)
    df['Low'] = df['Low'].astype(float)
    df['Close'] = df['Close'].astype(float)
    df['Volume'] = df['Volume'].astype(float)
    df.set_index('Date', inplace=True)
    return df

def get_all_binance_candles(symbol: str, interval='1h', start_date=None, end_date=None, limit=1000):
  try:
    return load_candles_from_cloud_storage(symbol, interval, start_date, end_date)
  except FileNotFoundError:
    pass
  result = []
  raw_start_date = start_date
  raw_end_date = end_date
  start_date = pd.to_datetime(start_date) if start_date else pd.to_datetime('2015-01-01')
  end_date = pd.to_datetime(end_date) if end_date else pd.to_datetime('today')
  while True:
    candles = get_binance_candles(symbol, interval, limit, startTime=int(start_date.timestamp() * 1000), endTime=int(end_date.timestamp() * 1000))
    if len(candles) <= 1:
      break;
    result += candles
    start_date = pd.to_datetime(datetime.datetime.fromtimestamp(candles[-1]['Date'] / 1000))
  candles_df = candles_to_df(result)
  save_candles_to_cloud_storage(candles_df, symbol, interval, raw_start_date, raw_end_date)
  return candles_df

def candles_storage_file_name(symbol: str, interval='1h', start_date=None, end_date=None):
  file_name = f'binance_{symbol}_{interval}_{start_date}_{end_date}.csv'
  return file_name

def load_candles_from_cloud_storage(symbol: str, interval: str, start_date=None, end_date=None):
  file_name = candles_storage_file_name(symbol, interval, start_date, end_date)
  try:
    # Download the file from cloud storage.
    subprocess.run(['gsutil', 'cp', f'gs://{bucket_name}/trade/candles/{file_name}', f'/tmp/{file_name}'], check=True)

    # Load the data into a Pandas DataFrame.
    with open(f'/tmp/{file_name}', 'r') as f:
      return pd.read_csv(f, index_col=0, parse_dates=True)
  except subprocess.CalledProcessError:
    # Raise a FileNotFoundError if the file is not found in cloud storage.
    raise FileNotFoundError(f"File not found: gs://{bucket_name}/trade/candles/{file_name}")

def save_candles_to_cloud_storage(df: pd.DataFrame, symbol: str, interval: str, start_date, end_date):
  file_name = candles_storage_file_name(symbol, interval, start_date, end_date)
  df.to_csv(f'/tmp/{file_name}')
  # !gsutil cp /tmp/{file_name} gs://{bucket_name}/trade/candles/{file_name}

# %%
def add_scaled_rsi(df, window=14, prefix = '', features_columns=[]):
  series = ta.rsi(df['Close'], length=window)
  column_name = f"{prefix}RSI_{window}"
  df[column_name] = series / 100
  if(column_name not in features_columns):
    features_columns.append(column_name)
  return df

def add_scaled_ema(df, window=50, prefix = '', features_columns=[]):
  series = ta.ema(df['Close'], length=window)
  column_name = f"{prefix}EMA_{window}"
  df[column_name] = series / df['Close']
  if column_name not in features_columns:
    features_columns.append(column_name)
  return df

def add_scaled_sma(df, window=50, prefix = '', features_columns=[]):
  series = ta.sma(df['Close'], length=window)
  column_name = f"{prefix}SMA_{window}"
  df[column_name] = series / df['Close']
  if column_name not in features_columns:
    features_columns.append(column_name)
  return df

def add_scaled_macd(df, prefix= '', features_columns=[], fast = 12, slow = 26, signal=9):
  macd_df = ta.macd(df['Close'], fast=fast, slow=slow, signal=signal)
  suffix = f"{fast}_{slow}_{signal}"
  macd_column_name = f"{prefix}MACD_{suffix}"
  macds_column_name = f"{prefix}MACDs_{suffix}"
  macdh_column_name = f"{prefix}MACDh_{suffix}"
  df[macd_column_name] = macd_df[macd_df.columns[0]] / df['Close']
  df[macds_column_name] = macd_df[macd_df.columns[2]] / df['Close']
  df[macdh_column_name] = macd_df[macd_df.columns[1]] / df['Close']
  if macd_column_name not in features_columns:
    features_columns.append(macd_column_name)
  if macds_column_name not in features_columns:
    features_columns.append(macds_column_name)
  if macdh_column_name not in features_columns:
    features_columns.append(macdh_column_name)
  return df

def add_scaled_bbands(df, window=20, std=2.0, prefix= '', features_columns=[]):
  bbands_df = ta.bbands(df['Close'], length=window, std=std)
  suffix = f"{window}_{std}"
  bbl_column_name = f"{prefix}BBL_{suffix}"
  bbm_column_name = f"{prefix}BBM_{suffix}"
  bbu_column_name = f"{prefix}BBU_{suffix}"
  bbb_column_name = f"{prefix}BBB_{suffix}"
  bbp_column_name = f"{prefix}BBP_{suffix}"
  df[bbl_column_name] = bbands_df[bbands_df.columns[0]] / df['Close']
  df[bbm_column_name] = bbands_df[bbands_df.columns[1]] / df['Close']
  df[bbu_column_name] = bbands_df[bbands_df.columns[2]] / df['Close']
  df[bbb_column_name] = bbands_df[bbands_df.columns[3]]
  df[bbp_column_name] = bbands_df[bbands_df.columns[4]]
  if bbl_column_name not in features_columns: features_columns.append(bbl_column_name)
  if bbm_column_name not in features_columns: features_columns.append(bbm_column_name)
  if bbu_column_name not in features_columns: features_columns.append(bbu_column_name)
  if bbb_column_name not in features_columns: features_columns.append(bbb_column_name)
  if bbp_column_name not in features_columns: features_columns.append(bbp_column_name)
  return df

# %%
def merge_candlesticks_data(df1, df2):
  """
  Merges two candlestick DataFrames with forward fill, handling different timeframes,
  and prevents duplicate OHLCV columns.
  Ensure both DataFrames have a datetime index.
  And ensure the second DataFrame is the larger timeframe

  Args:
      df1: First candlestick DataFrame with datetime index.
      df2: Second candlestick DataFrame with datetime index.

  Returns:
      Merged DataFrame with forward-filled values, and no duplicate OHLCV columns.
  """
  # Ensure both DataFrames have a datetime index
  if not isinstance(df1.index, pd.DatetimeIndex) or not isinstance(df2.index, pd.DatetimeIndex):
      raise ValueError("DataFrames must have a datetime index.")
  # Identify OHLCV columns
  ohlcv_cols = ['open', 'high', 'low', 'close', 'volume']

  # Rename columns in df2 that conflict with df1's OHLCV columns
  for col in df2.columns:
    if col.lower() in ohlcv_cols and col.lower() in df1.columns.str.lower():
      del df2[col]

  # Merge the DataFrames using outer join, which preserves all dates
  merged_df = pd.merge(df1, df2, how='outer', left_index=True, right_index=True, suffixes=('_df1', '_df2'))

  # Forward fill the missing values for each column
  for col in merged_df.columns:
    merged_df[col] = merged_df[col].ffill()

  return merged_df

# %%
def resample_candles(df, interval='1h'):
    return df.resample(interval).agg({'Open': 'first', 'High': 'max', 'Low': 'min', 'Close': 'last', 'Volume': 'sum'}).ffill()

# %%
def predict_in_batches(model, test_data, features_columns, seq_length, batch_size=128):
    """
    Predicts in batches to speed up inference.
    """
    num_samples = len(test_data) - seq_length
    feature_array = test_data[features_columns].values
    predicted_values = np.full(len(test_data), np.nan)

    for start_idx in range(0, num_samples, batch_size):
        end_idx = min(start_idx + batch_size, num_samples)
        batch_indices = range(start_idx + seq_length, end_idx + seq_length)
        batch_input = np.array([feature_array[i - seq_length:i] for i in batch_indices])

        if len(batch_input) > 0 :
            predictions = model.predict(batch_input, verbose=0)
            predicted_values[batch_indices] = predictions.flatten() #Flatten to 1d array.

    test_data['Predicted_Value'] = predicted_values
    return test_data

# %%
class PredictedValueStrategy(bt.Strategy):
    params = (
        ('buy_threshold', 0.6),
        ('sell_threshold', 0.6),
        ('leverage', 1),  # Leverage ratio
        ('margin', 1000),
        ('log', True)
    )

    def __init__(self):
        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None

        # Add the Predicted_Value as a data feed
        self.predicted_value = self.datas[0].predicted_value

    def next(self):
        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return
         # # Check if we are in the market
        if not self.position:
          cash = self.broker.getcash()
          position_size = (self.params.margin * self.params.leverage) / self.data.close[0]
          # Long signal
          if self.predicted_value[0] > self.params.buy_threshold:
            self.log('LONG POSITION CREATED, %.2f' % self.datas[0].close[0])
            self.order = self.buy(size=position_size)

          # Short signal
          elif self.predicted_value[0] < self.params.sell_threshold:
            self.log('SHORT POSITION CREATED, %.2f' % self.datas[0].close[0])
            self.order = self.sell(size=position_size)

        else:
          if self.predicted_value[0] > self.params.buy_threshold and self.position.size < 0:
            self.log('CLOSE SHORT POSITION CREATED, %.2f' % self.datas[0].close[0])
            self.order = self.close()
          elif self.predicted_value[0] < self.params.sell_threshold and self.position.size > 0:
            self.log('CLOSE LONG POSITION CREATED, %.2f' % self.datas[0].close[0])
            self.order = self.close()

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return
        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY EXECUTED, %.2f' % order.executed.price)
            elif order.issell():
                self.log('SELL EXECUTED, %.2f' % order.executed.price)
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            if order.status == order.Canceled:
                self.log('Order Canceled')
            elif order.status == order.Margin:
                self.log(f'Order Margin Not Enough - Available cash: {self.broker.getcash()}')
            elif order.status == order.Rejected:
                self.log('Order Rejected')

        # Write down: no pending order
        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        self.log(f'TRADE COMPLETED, GROSS {trade.pnl:.2f}, NET {trade.pnlcomm:.2f}, Available Cash {self.broker.getcash():.2f}')

    def log(self, txt, dt=None):
        if not self.params.log:
          return
        dt = dt or self.datas[0].datetime.date(0)
        time = self.datas[0].datetime.time()
        print(f'{dt.isoformat()} {time.isoformat()}, {txt}')

# %%
# Extend PandasData to include the custom column
class CustomPandasData(bt.feeds.PandasData):
    # Add custom columns
    lines = ('predicted_value',)  # Add the custom line
    params = (
        ('predicted_value', 'Predicted_Value'),  # Map the column name
    )

# %%
def get_model_cloud_storage_path(bucket_name, local_file_name):
    """
    Returns the cloud storage path for a given model name.

    Parameters:
        local_file_name (str): The name of the model.

    Returns:
        str: The cloud storage path. (e.g., gs://<bucket_name>/trade/models/<model_name>.h5).
    """
    return f'gs://{bucket_name}/trade/models/{local_file_name}'

def save_model_to_cloud_storage(model: tf.keras.Model, model_name: str, bucket_name: str):
    """
    Saves a TensorFlow model to Google Cloud Storage and returns the cloud storage file path.

    Parameters:
        model (tf.keras.Model): The TensorFlow model to save.
        model_name (str): The name of the model (used to create the file name).
        bucket_name (str): The name of the Google Cloud Storage bucket.

    Returns:
        str: The cloud storage file path (e.g., gs://<bucket_name>/trade/models/<model_name>.h5).
    """
    # Define the local and cloud storage file paths
    local_file_name = f'{model_name}.h5'
    local_file_path = f'/tmp/{local_file_name}'
    cloud_file_path = get_model_cloud_storage_path(bucket_name, local_file_name)

    # Save the model locally
    model.save(local_file_path)

    try:
        # Upload the model to Google Cloud Storage
        subprocess.run(['gsutil', 'cp', local_file_path, cloud_file_path], check=True)
        print(f"Model saved to {cloud_file_path}")
    except subprocess.CalledProcessError as e:
        # Handle errors during the upload process
        raise RuntimeError(f"Failed to upload model to Google Cloud Storage: {e}")
    finally:
        # Clean up the local file
        if os.path.exists(local_file_path):
            os.remove(local_file_path)
    return cloud_file_path

def load_model_from_cloud_storage(model_name: str, bucket_name: str, custom_objects=None):
    """
    Loads a TensorFlow model from Google Cloud Storage.

    Parameters:
        model_name (str): The name of the model (used to create the file name).
        bucket_name (str): The name of the Google Cloud Storage bucket.

    Returns:
        tf.keras.Model: The loaded TensorFlow model.
    """
    # Define the local and cloud storage file paths
    local_file_name = f'{model_name}.h5'
    local_file_path = f'/tmp/{local_file_name}'
    cloud_file_path = get_model_cloud_storage_path(bucket_name, local_file_name)

    try:
        # Download the model from Google Cloud Storage
        subprocess.run(['gsutil', 'cp', cloud_file_path, local_file_path], check=True)

        # Load the model
        model = tf.keras.models.load_model(local_file_path, custom_objects=custom_objects)
        print(f"Model loaded from {cloud_file_path}")
        return model
    except subprocess.CalledProcessError as e:
        raise FileNotFoundError(f"Model not found in Google Cloud Storage: {e}")
    finally:
        # Clean up the local file
        if os.path.exists(local_file_path):
            os.remove(local_file_path)

# %%
def initialize_firestore(project_id):
    """
    Initialize the Firestore client using the service account key.

    Parameters:
        project_id (str): The Google Cloud project ID.

    Returns:
        firestore.Client: Initialized Firestore client.
    """
    if not firebase_admin._apps:
        # cred = credentials.Certificate(service_account_key_path)
        cred = firebase_admin.credentials.ApplicationDefault()
        cred._project_id = project_id  # Add this line
        os.environ["GOOGLE_CLOUD_PROJECT"] = project_id
        firebase_admin.initialize_app(cred, {'projectId': project_id})
    return firestore.client()


def save_to_firestore(project_id, collection_name, data):
    """
    Save data to a Firestore collection.

    Parameters:
        project_id (str): The Google Cloud project ID.
        service_account_key_path (str): Path to the Firebase service account key JSON file.
        collection_name (str): Name of the Firestore collection.
        data (dict): Data to save in the document.

    Returns:
        None
    """
    # Initialize Firestore client
    db = initialize_firestore(project_id)

    # Save data to Firestore
    doc_ref = db.collection(collection_name).document()
    doc_ref.set(data)
    print(f"Data saved to Firestore: Collection={collection_name}, Document ID={doc_ref.id}")

# %%
def get_nested_value(data, keys):
    """
    Retrieves a deeply nested value from a dictionary or list.

    Args:
        data: The dictionary or list to traverse.
        keys: A list of keys or indices to access the nested value.

    Returns:
        The nested value if found, otherwise None.
    """
    try:
        current_value = data
        for key in keys:
            if isinstance(current_value, dict):
                current_value = current_value.get(key)
            elif isinstance(current_value, list):
                if isinstance(key, int) and 0 <= key < len(current_value):
                    current_value = current_value[key]
                else:
                    return None #invalid index
            else:
                return None #not a dict or list
            if current_value is None:
                return None  # Early exit if any key is missing
        return current_value
    except (TypeError, IndexError, AttributeError, KeyError):
        return None

# %%
def add_indicators_and_normalize(df, indicators, default_timeframe='15m'):
    """
    Adds technical indicators to the DataFrame based on the provided list of indicators.
    Handles higher timeframes by resampling the DataFrame and merging results.

    Parameters:
    df (pd.DataFrame): The candlestick DataFrame with columns like 'Open', 'High', 'Low', 'Close', 'Volume'.
    indicators (list): A list of indicator strings in the format 'TIMEFRAME_INDICATOR_PARAMS' or 'INDICATOR_PARAMS'.
    default_timeframe (str): The default timeframe to use if not specified in the indicator string (e.g., '15m').

    Returns:
    pd.DataFrame: The DataFrame with the added indicator columns.
    """
    # Dictionary to store resampled DataFrames for higher timeframes
    resampled_dfs = {}

    # Ensure indicators are unique
    indicators = list(set(indicators))

    # Drop duplicates
    df = df.drop_duplicates(keep='first')

    # timeframe regex patter
    timeframe_pattern = re.compile(r'^\d+[mhdw]$')

    def apply_indicator(target_df, indicator_name, params, full_indicator_name):
        """
        Applies the specified indicator to the target DataFrame.
        """
        if target_df.columns.str.contains(full_indicator_name).any():
          del target_df[full_indicator_name]
        if indicator_name == 'RSI':
            target_df[full_indicator_name] = ta.rsi(target_df['Close'], length=params[0]) / 100
        elif indicator_name == 'EMA':
            target_df[full_indicator_name] = ta.ema(target_df['Close'], length=params[0]) / target_df['Close']
        elif indicator_name == 'SMA':
            target_df[full_indicator_name] = ta.sma(target_df['Close'], length=params[0]) / target_df['Close']
        elif indicator_name == 'MACD':
            macd = ta.macd(target_df['Close'], fast=params[0], slow=params[1], signal=params[2])
            target_df[full_indicator_name] = macd[macd.columns[0]] / target_df['Close']
        elif indicator_name == 'MACDs':
            macd = ta.macd(target_df['Close'], fast=params[0], slow=params[1], signal=params[2])
            target_df[full_indicator_name] = macd[macd.columns[1]] / target_df['Close']
        elif indicator_name == 'MACDh':
            macd = ta.macd(target_df['Close'], fast=params[0], slow=params[1], signal=params[2])
            target_df[full_indicator_name] = macd[macd.columns[2]] / target_df['Close']
        elif indicator_name == 'BBL':
            bb = ta.bbands(target_df['Close'], length=params[0], std=params[1])
            target_df[full_indicator_name] = bb[bb.columns[0]] / target_df['Close']
        elif indicator_name == 'BBM':
            bb = ta.bbands(target_df['Close'], length=params[0], std=params[1])
            target_df[full_indicator_name] = bb[bb.columns[1]] / target_df['Close']
        elif indicator_name == 'BBU':
            bb = ta.bbands(target_df['Close'], length=params[0], std=params[1])
            target_df[full_indicator_name] = bb[bb.columns[2]] / target_df['Close']
        elif indicator_name == 'BBB':
            bb = ta.bbands(target_df['Close'], length=params[0], std=params[1])
            target_df[full_indicator_name] = bb[bb.columns[3]]
        elif indicator_name == 'BBP':
            bb = ta.bbands(target_df['Close'], length=params[0], std=params[1])
            target_df[full_indicator_name] = bb[bb.columns[4]]
        else:
            raise ValueError(f"Unsupported indicator: {indicator_name}")

    for indicator in indicators:
        # Split the indicator string into components
        parts = indicator.split('_')

        # Check if the first part is a timeframe (e.g., '15m', '1h', '4h')
        if timeframe_pattern.match(parts[0]):
            timeframe = parts[0]
            indicator_name = parts[1]
            params = parts[2:]
        else:
            # If no timeframe is specified, use the default timeframe
            timeframe = default_timeframe
            indicator_name = parts[0]
            params = parts[1:]

        # Convert parameters to appropriate types
        params = [float(p) if '.' in p else int(p) for p in params]

        # Construct the full indicator name with timeframe
        full_indicator_name = f"{timeframe}_{indicator_name}_{'_'.join(map(str, params))}"

        # Check if the timeframe is higher than the default timeframe
        if timeframe != default_timeframe:
            # Resample the DataFrame to the higher timeframe
            if timeframe not in resampled_dfs:
                resample_rule = timeframe
                resampled_df = df.resample(resample_rule).agg({
                    'Open': 'first',
                    'High': 'max',
                    'Low': 'min',
                    'Close': 'last',
                    'Volume': 'sum'
                }).dropna()
                resampled_dfs[timeframe] = resampled_df
            else:
                # resampled_df =
                pass

            # Apply the indicator to the resampled DataFrame
            apply_indicator(resampled_dfs[timeframe], indicator_name, params, full_indicator_name)

            # Merge the resampled DataFrame back into the original DataFrame
            if full_indicator_name in df.columns:
                del df[full_indicator_name]
            df = df.merge(resampled_dfs[timeframe][[full_indicator_name]], how='left', left_index=True, right_index=True)
        else:
            # Apply the indicator to the original DataFrame
            apply_indicator(df, indicator_name, params, full_indicator_name)
    df.ffill(inplace=True)
    return df

# %%
def plot_pyfolio_results(results):
    """
    Extracts PyFolio analyzer results from Backtrader and generates interactive plots using Plotly.

    Parameters:
        results (list): The results object returned by Backtrader's cerebro.run().

    Plots:
        1. Cumulative Returns
        2. Drawdowns
        3. Daily Returns
        4. Rolling Sharpe Ratio (252-day)
    """
    # Extract the PyFolio analyzer results
    pyfoliozer = results[0].analyzers.getbyname('pyfolio')
    returns, positions, transactions, gross_lev = pyfoliozer.get_pf_items()

    # Ensure returns is a pandas Series with a datetime index
    if not isinstance(returns, pd.Series):
        returns = pd.Series(returns, index=pd.date_range(start='2020-01-01', periods=len(returns)))

    # Plot cumulative returns
    cumulative_returns = (1 + returns).cumprod()
    fig = px.line(cumulative_returns, title='Cumulative Returns', labels={'value': 'Cumulative Returns', 'index': 'Date'})
    fig.show()

    # Plot drawdowns
    drawdown = returns / (1 + returns).cumprod() - 1
    fig = px.area(drawdown, title='Drawdowns', labels={'value': 'Drawdown', 'index': 'Date'})
    fig.show()

    # Plot daily returns
    fig = px.bar(returns, title='Daily Returns', labels={'value': 'Daily Returns', 'index': 'Date'})
    fig.show()

# %%
def simulate_strategy(model_series):
  # TODO
  model_name = model_series['model_name']
  features_columns = model_series['features_columns']
  symbol = model_series['symbol']
  timeframe = model_series['timeframe']
  start_date = model_series['test_data_start_date']
  end_date = model_series['test_data_end_date']
  leverage = model_series['trade_leverage']
  buy_threshold = model_series['trade_buy_threshold']
  sell_threshold = model_series['trade_sell_threshold']
  trade_margin = model_series['trade_margin']
  broker_commision = model_series['broker_commision']

  data = get_all_binance_candles(symbol, timeframe, start_date, end_date)
  model = load_model_from_cloud_storage(model_name, bucket_name, custom_objects={'mse': mse, 'mae': mae})
  data = add_indicators_and_normalize(data, features_columns, timeframe)


  data = predict_in_batches(model, data, features_columns, 1024)
  data.dropna(inplace=True)

  # Load your data into a Pandas DataFrame
  backtest_data = CustomPandasData(
      dataname=data,
      datetime=None,  # Use the index as the datetime
      open='Open',         # Column index for Open
      high='High',         # Column index for High
      low='Low',          # Column index for Low
      close='Close',        # Column index for Close
      volume='Volume',       # Column index for Volume
      openinterest=None,# No open interest column
      predicted_value='Predicted_Value'  # Column index for Predicted_Value
  )
  cerebro = bt.Cerebro()

  # Add the strategy
  cerebro.addstrategy(
      PredictedValueStrategy,
      buy_threshold=buy_threshold,
      sell_threshold=sell_threshold,
      leverage=leverage,
      margin=trade_margin
    )

  # Add the data feed
  cerebro.adddata(backtest_data)

  # Set the initial cash
  cerebro.broker.set_cash(10000.0)

  # Set the commission
  cerebro.broker.setcommission(commission=broker_commision / 100)

  # Add analyzers
  cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='sharpe')
  cerebro.addanalyzer(bt.analyzers.DrawDown, _name='drawdown')
  cerebro.addanalyzer(bt.analyzers.TradeAnalyzer, _name='tradeanalyzer')
  cerebro.addanalyzer(bt.analyzers.Returns, _name='returns')
  cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')

  # Run the backtest
  # Run the backtest
  starting_portfolio_value = cerebro.broker.getvalue()
  print('Starting Portfolio Value: %.2f' % starting_portfolio_value)
  backtest_result = cerebro.run()
  final_portfolio_value = cerebro.broker.getvalue()
  print('Final Portfolio Value: %.2f' % final_portfolio_value)
  plot_pyfolio_results(backtest_result)
  return backtest_result

# %%
trade_models = []
db = initialize_firestore(project_id)
trade_moldel_ref = db.collection('trade-models')
trade_models_stream = (
    trade_moldel_ref.where('version', '==', 'v1_0_2')
    .where('symbol', '==', 'BTCUSDT')
    .where('exchange', '==', 'binance')
    .where('timeframe', '==', '15m')
    .stream()
)
for model in trade_models_stream:
    trade_models.append(model.to_dict())
trade_models
# Out:
# /usr/local/lib/python3.11/dist-packages/google/cloud/firestore_v1/base_collection.py:303: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   return query.where(field_path, op_string, value)
# <ipython-input-18-a89e5ac8c19e>:6: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   .where('symbol', '==', 'BTCUSDT')
# <ipython-input-18-a89e5ac8c19e>:7: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   .where('exchange', '==', 'binance')
# <ipython-input-18-a89e5ac8c19e>:8: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   .where('timeframe', '==', '15m')
# [{'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff.h5',
#   'val_mae': 0.41148462891578674,
#   'training_data_end_date': DatetimeWithNanoseconds(2023, 9, 8, 6, 30, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.5,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 2},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 20,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 12, 22, 17, 52, 66459, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_2',
#   'train_mae': 0.3990473449230194,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff',
#   'test_data_end_date': DatetimeWithNanoseconds(2025, 3, 12, 15, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24998442828655243,
#   'drawdown_analysis': {'len': 2,
#    'drawdown': 0,
#    'max': {'len': 850, 'drawdown': 6, 'moneydown': 1806},
#    'moneydown': 4},
#   'end_date': '30-12-2025',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 426,
#     'pnl': {'average': 258,
#      'total': 109320,
#      'won': {'total': 124866, 'average': 344, 'max': 2136},
#      'lost': {'total': -15546, 'average': -246, 'max': -872}},
#     'won': 364,
#     'lost': 64},
#    'total': {'total': 792, 'open': 0, 'closed': 792},
#    'won': {'total': 680,
#     'pnl': {'average': 374, 'total': 253278, 'max': 2370}},
#    'len': {'short': {'max': 564,
#      'average': 46,
#      'total': 19148,
#      'won': {'total': 14132, 'average': 40, 'min': 4, 'max': 564},
#      'min': 4,
#      'lost': {'total': 5016, 'average': 80, 'min': 22, 'max': 242}},
#     'total': 42420,
#     'average': 54,
#     'won': {'average': 48, 'total': 32118, 'max': 564, 'min': 4},
#     'min': 4,
#     'long': {'max': 394,
#      'average': 64,
#      'total': 23274,
#      'won': {'total': 17986, 'average': 58, 'min': 8, 'max': 320},
#      'min': 8,
#      'lost': {'total': 5288, 'average': 108, 'min': 34, 'max': 394}},
#     'max': 564,
#     'lost': {'average': 92, 'total': 10304, 'max': 394, 'min': 22}},
#    'long': {'total': 366,
#     'pnl': {'average': 320,
#      'total': 116564,
#      'won': {'total': 128410, 'average': 406, 'max': 2370},
#      'lost': {'total': -11846, 'average': -242, 'max': -898}},
#     'won': 316,
#     'lost': 50},
#    'pnl': {'gross': {'average': 294, 'total': 232214},
#     'net': {'average': 286, 'total': 225884}},
#    'streak': {'won': {'longest': 22, 'current': 8},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 112,
#     'pnl': {'average': -244, 'total': -27392, 'max': -898}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 9, 9, 7, 45, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.6,
#   'train_loss': 0.239034965634346,
#   'start_date': '01-01-2017',
#   'final_portfolio_value': 235883.67928449414,
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff.h5',
#   'val_mae': 0.41148462891578674,
#   'training_data_end_date': DatetimeWithNanoseconds(2023, 9, 8, 6, 30, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.6,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 2},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 30,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 12, 22, 21, 1, 126826, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_2',
#   'train_mae': 0.3990473449230194,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff',
#   'test_data_end_date': DatetimeWithNanoseconds(2025, 3, 12, 15, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24998442828655243,
#   'drawdown_analysis': {'len': 0,
#    'drawdown': 0,
#    'max': {'len': 5750, 'drawdown': 38, 'moneydown': 4866},
#    'moneydown': 0},
#   'end_date': '30-12-2025',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 430,
#     'pnl': {'average': 256,
#      'total': 109424,
#      'won': {'total': 178782, 'average': 616, 'max': 3672},
#      'lost': {'total': -69356, 'average': -498, 'max': -2990}},
#     'won': 290,
#     'lost': 140},
#    'total': {'total': 634, 'open': 2, 'closed': 632},
#    'won': {'total': 482,
#     'pnl': {'average': 538, 'total': 258762, 'max': 3672}},
#    'len': {'short': {'max': 758,
#      'average': 102,
#      'total': 43764,
#      'won': {'total': 26560, 'average': 92, 'min': 8, 'max': 758},
#      'min': 4,
#      'lost': {'total': 17204, 'average': 124, 'min': 4, 'max': 494}},
#     'total': 47394,
#     'average': 76,
#     'won': {'average': 62, 'total': 29688, 'max': 758, 'min': 2},
#     'min': 2,
#     'long': {'max': 94,
#      'average': 18,
#      'total': 3630,
#      'won': {'total': 3128, 'average': 16, 'min': 2, 'max': 72},
#      'min': 2,
#      'lost': {'total': 504, 'average': 42, 'min': 14, 'max': 94}},
#     'max': 758,
#     'lost': {'average': 118, 'total': 17708, 'max': 494, 'min': 4}},
#    'long': {'total': 204,
#     'pnl': {'average': 380,
#      'total': 77046,
#      'won': {'total': 79982, 'average': 420, 'max': 1520},
#      'lost': {'total': -2934, 'average': -244, 'max': -904}},
#     'won': 192,
#     'lost': 12},
#    'pnl': {'gross': {'average': 308, 'total': 194048},
#     'net': {'average': 296, 'total': 186470}},
#    'streak': {'won': {'longest': 20, 'current': 4},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 152,
#     'pnl': {'average': -478, 'total': -72292, 'max': -2990}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 9, 9, 7, 45, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.4,
#   'train_loss': 0.239034965634346,
#   'start_date': '01-01-2017',
#   'final_portfolio_value': 197193.8230090526,
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff.h5',
#   'val_mae': 0.41148462891578674,
#   'training_data_end_date': DatetimeWithNanoseconds(2023, 9, 8, 6, 30, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.5,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 2},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 25,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 12, 22, 13, 53, 533356, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_2',
#   'train_mae': 0.3990473449230194,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff',
#   'test_data_end_date': DatetimeWithNanoseconds(2025, 3, 12, 15, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24998442828655243,
#   'drawdown_analysis': {'len': 2,
#    'drawdown': 0,
#    'max': {'len': 2564, 'drawdown': 28, 'moneydown': 3776},
#    'moneydown': 6},
#   'end_date': '30-12-2025',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 796,
#     'pnl': {'average': 162,
#      'total': 128812,
#      'won': {'total': 197602, 'average': 348, 'max': 2676},
#      'lost': {'total': -68788, 'average': -304, 'max': -2536}},
#     'won': 570,
#     'lost': 226},
#    'total': {'total': 1284, 'open': 0, 'closed': 1284},
#    'won': {'total': 1014,
#     'pnl': {'average': 308, 'total': 311772, 'max': 2676}},
#    'len': {'short': {'max': 572,
#      'average': 50,
#      'total': 40074,
#      'won': {'total': 25088, 'average': 44, 'min': 4, 'max': 572},
#      'min': 4,
#      'lost': {'total': 14986, 'average': 66, 'min': 4, 'max': 246}},
#     'total': 46694,
#     'average': 36,
#     'won': {'average': 30, 'total': 30706, 'max': 572, 'min': 2},
#     'min': 2,
#     'long': {'max': 66,
#      'average': 14,
#      'total': 6622,
#      'won': {'total': 5618, 'average': 14, 'min': 2, 'max': 60},
#      'min': 2,
#      'lost': {'total': 1004, 'average': 22, 'min': 4, 'max': 66}},
#     'max': 572,
#     'lost': {'average': 60, 'total': 15990, 'max': 246, 'min': 4}},
#    'long': {'total': 490,
#     'pnl': {'average': 222,
#      'total': 108636,
#      'won': {'total': 114170, 'average': 258, 'max': 1204},
#      'lost': {'total': -5536, 'average': -122, 'max': -826}},
#     'won': 444,
#     'lost': 46},
#    'pnl': {'gross': {'average': 196, 'total': 250282},
#     'net': {'average': 186, 'total': 237448}},
#    'streak': {'won': {'longest': 32, 'current': 4},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 272,
#     'pnl': {'average': -274, 'total': -74324, 'max': -2536}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 9, 9, 7, 45, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.3,
#   'train_loss': 0.239034965634346,
#   'start_date': '01-01-2017',
#   'final_portfolio_value': 247446.60130025042,
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff.h5',
#   'val_mae': 0.41148462891578674,
#   'training_data_end_date': DatetimeWithNanoseconds(2023, 9, 8, 6, 30, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.4,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 2},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 10,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 12, 22, 10, 21, 950247, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_2',
#   'train_mae': 0.3990473449230194,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff',
#   'test_data_end_date': DatetimeWithNanoseconds(2025, 3, 12, 15, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24998442828655243,
#   'drawdown_analysis': {'len': 2,
#    'drawdown': 0,
#    'max': {'len': 494, 'drawdown': 4, 'moneydown': 1046},
#    'moneydown': 2},
#   'end_date': '30-12-2025',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 746,
#     'pnl': {'average': 82,
#      'total': 61374,
#      'won': {'total': 73028, 'average': 120, 'max': 840},
#      'lost': {'total': -11654, 'average': -88, 'max': -448}},
#     'won': 616,
#     'lost': 132},
#    'total': {'total': 1496, 'open': 0, 'closed': 1496},
#    'won': {'total': 1256,
#     'pnl': {'average': 126, 'total': 157864, 'max': 968}},
#    'len': {'short': {'max': 312,
#      'average': 28,
#      'total': 20466,
#      'won': {'total': 14314, 'average': 24, 'min': 2, 'max': 312},
#      'min': 2,
#      'lost': {'total': 6154, 'average': 48, 'min': 6, 'max': 188}},
#     'total': 46612,
#     'average': 32,
#     'won': {'average': 28, 'total': 34740, 'max': 312, 'min': 2},
#     'min': 2,
#     'long': {'max': 204,
#      'average': 36,
#      'total': 26146,
#      'won': {'total': 20428, 'average': 32, 'min': 4, 'max': 204},
#      'min': 4,
#      'lost': {'total': 5718, 'average': 52, 'min': 4, 'max': 142}},
#     'max': 312,
#     'lost': {'average': 50, 'total': 11872, 'max': 188, 'min': 4}},
#    'long': {'total': 750,
#     'pnl': {'average': 102,
#      'total': 76410,
#      'won': {'total': 84836, 'average': 134, 'max': 968},
#      'lost': {'total': -8426, 'average': -76, 'max': -438}},
#     'won': 640,
#     'lost': 110},
#    'pnl': {'gross': {'average': 96, 'total': 143770},
#     'net': {'average': 92, 'total': 137784}},
#    'streak': {'won': {'longest': 28, 'current': 4},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 242,
#     'pnl': {'average': -82, 'total': -20080, 'max': -448}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 9, 9, 7, 45, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.5,
#   'train_loss': 0.239034965634346,
#   'start_date': '01-01-2017',
#   'final_portfolio_value': 147782.847520898,
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff.h5',
#   'val_mae': 0.41148462891578674,
#   'training_data_end_date': DatetimeWithNanoseconds(2023, 9, 8, 6, 30, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.3,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 2},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 15,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 12, 22, 6, 16, 604116, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_2',
#   'train_mae': 0.3990473449230194,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff',
#   'test_data_end_date': DatetimeWithNanoseconds(2025, 3, 12, 15, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24998442828655243,
#   'drawdown_analysis': {'len': 2,
#    'drawdown': 0,
#    'max': {'len': 680, 'drawdown': 4, 'moneydown': 1516},
#    'moneydown': 4},
#   'end_date': '30-12-2025',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 530,
#     'pnl': {'average': 140,
#      'total': 74294,
#      'won': {'total': 79440, 'average': 164, 'max': 792},
#      'lost': {'total': -5144, 'average': -124, 'max': -756}},
#     'won': 488,
#     'lost': 42},
#    'total': {'total': 1096, 'open': 0, 'closed': 1096},
#    'won': {'total': 938,
#     'pnl': {'average': 212, 'total': 198460, 'max': 1706}},
#    'len': {'short': {'max': 80,
#      'average': 16,
#      'total': 7886,
#      'won': {'total': 6548, 'average': 14, 'min': 2, 'max': 64},
#      'min': 2,
#      'lost': {'total': 1340, 'average': 34, 'min': 4, 'max': 80}},
#     'total': 44694,
#     'average': 42,
#     'won': {'average': 36, 'total': 32590, 'max': 358, 'min': 2},
#     'min': 2,
#     'long': {'max': 396,
#      'average': 66,
#      'total': 36808,
#      'won': {'total': 26044, 'average': 58, 'min': 4, 'max': 358},
#      'min': 4,
#      'lost': {'total': 10764, 'average': 92, 'min': 10, 'max': 396}},
#     'max': 396,
#     'lost': {'average': 78, 'total': 12104, 'max': 396, 'min': 4}},
#    'long': {'total': 566,
#     'pnl': {'average': 172,
#      'total': 97428,
#      'won': {'total': 119020, 'average': 266, 'max': 1706},
#      'lost': {'total': -21592, 'average': -184, 'max': -820}},
#     'won': 450,
#     'lost': 118},
#    'pnl': {'gross': {'average': 164, 'total': 178298},
#     'net': {'average': 158, 'total': 171722}},
#    'streak': {'won': {'longest': 32, 'current': 10},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 158,
#     'pnl': {'average': -168, 'total': -26736, 'max': -820}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 9, 9, 7, 45, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.6,
#   'train_loss': 0.239034965634346,
#   'start_date': '01-01-2017',
#   'final_portfolio_value': 181722.1791688295,
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff.h5',
#   'val_mae': 0.41148462891578674,
#   'training_data_end_date': DatetimeWithNanoseconds(2023, 9, 8, 6, 30, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.6,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 2},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 15,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 12, 22, 18, 59, 780459, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_2',
#   'train_mae': 0.3990473449230194,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff',
#   'test_data_end_date': DatetimeWithNanoseconds(2025, 3, 12, 15, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24998442828655243,
#   'drawdown_analysis': {'len': 0,
#    'drawdown': 0,
#    'max': {'len': 7338, 'drawdown': 24, 'moneydown': 2750},
#    'moneydown': 0},
#   'end_date': '30-12-2025',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 448,
#     'pnl': {'average': 114,
#      'total': 50670,
#      'won': {'total': 88998, 'average': 306, 'max': 1736},
#      'lost': {'total': -38328, 'average': -246, 'max': -1520}},
#     'won': 292,
#     'lost': 156},
#    'total': {'total': 690, 'open': 2, 'closed': 690},
#    'won': {'total': 524,
#     'pnl': {'average': 250, 'total': 130548, 'max': 1736}},
#    'len': {'short': {'max': 760,
#      'average': 104,
#      'total': 46184,
#      'won': {'total': 26998, 'average': 92, 'min': 6, 'max': 760},
#      'min': 4,
#      'lost': {'total': 19186, 'average': 124, 'min': 4, 'max': 500}},
#     'total': 49152,
#     'average': 72,
#     'won': {'average': 58, 'total': 29680, 'max': 760, 'min': 2},
#     'min': 2,
#     'long': {'max': 64,
#      'average': 12,
#      'total': 2968,
#      'won': {'total': 2682, 'average': 12, 'min': 2, 'max': 52},
#      'min': 2,
#      'lost': {'total': 288, 'average': 32, 'min': 12, 'max': 64}},
#     'max': 760,
#     'lost': {'average': 118, 'total': 19474, 'max': 500, 'min': 4}},
#    'long': {'total': 242,
#     'pnl': {'average': 170,
#      'total': 40680,
#      'won': {'total': 41552, 'average': 180, 'max': 734},
#      'lost': {'total': -870, 'average': -96, 'max': -268}},
#     'won': 232,
#     'lost': 10},
#    'pnl': {'gross': {'average': 140, 'total': 95480},
#     'net': {'average': 134, 'total': 91350}},
#    'streak': {'won': {'longest': 20, 'current': 4},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 166,
#     'pnl': {'average': -238, 'total': -39198, 'max': -1520}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 9, 9, 7, 45, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.3,
#   'train_loss': 0.239034965634346,
#   'start_date': '01-01-2017',
#   'final_portfolio_value': 101665.03615322812,
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff.h5',
#   'val_mae': 0.41148462891578674,
#   'training_data_end_date': DatetimeWithNanoseconds(2023, 9, 8, 6, 30, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.6,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 2},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 30,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 12, 22, 22, 21, 822350, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_2',
#   'train_mae': 0.3990473449230194,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff',
#   'test_data_end_date': DatetimeWithNanoseconds(2025, 3, 12, 15, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24998442828655243,
#   'drawdown_analysis': {'len': 0,
#    'drawdown': 0,
#    'max': {'len': 2112, 'drawdown': 28, 'moneydown': 4118},
#    'moneydown': 0},
#   'end_date': '30-12-2025',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 386,
#     'pnl': {'average': 330,
#      'total': 126658,
#      'won': {'total': 178556, 'average': 634, 'max': 3672},
#      'lost': {'total': -51900, 'average': -504, 'max': -2686}},
#     'won': 282,
#     'lost': 104},
#    'total': {'total': 614, 'open': 2, 'closed': 614},
#    'won': {'total': 498,
#     'pnl': {'average': 580, 'total': 288226, 'max': 3672}},
#    'len': {'short': {'max': 752,
#      'average': 100,
#      'total': 38500,
#      'won': {'total': 25218, 'average': 90, 'min': 4, 'max': 752},
#      'min': 4,
#      'lost': {'total': 13284, 'average': 130, 'min': 16, 'max': 492}},
#     'total': 45406,
#     'average': 74,
#     'won': {'average': 64, 'total': 31336, 'max': 752, 'min': 4},
#     'min': 4,
#     'long': {'max': 186,
#      'average': 30,
#      'total': 6906,
#      'won': {'total': 6118, 'average': 28, 'min': 4, 'max': 186},
#      'min': 4,
#      'lost': {'total': 788, 'average': 66, 'min': 28, 'max': 138}},
#     'max': 752,
#     'lost': {'average': 122, 'total': 14070, 'max': 492, 'min': 16}},
#    'long': {'total': 228,
#     'pnl': {'average': 464,
#      'total': 105742,
#      'won': {'total': 109668, 'average': 508, 'max': 2934},
#      'lost': {'total': -3926, 'average': -326, 'max': -1218}},
#     'won': 216,
#     'lost': 12},
#    'pnl': {'gross': {'average': 392, 'total': 239750},
#     'net': {'average': 380, 'total': 232398}},
#    'streak': {'won': {'longest': 20, 'current': 10},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 116,
#     'pnl': {'average': -484, 'total': -55826, 'max': -2686}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 9, 9, 7, 45, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.5,
#   'train_loss': 0.239034965634346,
#   'start_date': '01-01-2017',
#   'final_portfolio_value': 243121.70270337426,
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff.h5',
#   'val_mae': 0.41148462891578674,
#   'training_data_end_date': DatetimeWithNanoseconds(2023, 9, 8, 6, 30, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.4,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 2},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 25,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 12, 22, 12, 28, 834029, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_2',
#   'train_mae': 0.3990473449230194,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff',
#   'test_data_end_date': DatetimeWithNanoseconds(2025, 3, 12, 15, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24998442828655243,
#   'drawdown_analysis': {'len': 2,
#    'drawdown': 0,
#    'max': {'len': 686, 'drawdown': 8, 'moneydown': 2616},
#    'moneydown': 6},
#   'end_date': '30-12-2025',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 492,
#     'pnl': {'average': 282,
#      'total': 137894,
#      'won': {'total': 149524, 'average': 340, 'max': 2102},
#      'lost': {'total': -11630, 'average': -232, 'max': -1072}},
#     'won': 442,
#     'lost': 50},
#    'total': {'total': 956, 'open': 0, 'closed': 956},
#    'won': {'total': 826,
#     'pnl': {'average': 400, 'total': 328838, 'max': 2972}},
#    'len': {'short': {'max': 312,
#      'average': 26,
#      'total': 12306,
#      'won': {'total': 9612, 'average': 22, 'min': 2, 'max': 312},
#      'min': 2,
#      'lost': {'total': 2696, 'average': 54, 'min': 12, 'max': 188}},
#     'total': 42278,
#     'average': 44,
#     'won': {'average': 38, 'total': 31572, 'max': 386, 'min': 2},
#     'min': 2,
#     'long': {'max': 394,
#      'average': 66,
#      'total': 29972,
#      'won': {'total': 21960, 'average': 58, 'min': 4, 'max': 386},
#      'min': 4,
#      'lost': {'total': 8012, 'average': 100, 'min': 18, 'max': 394}},
#     'max': 394,
#     'lost': {'average': 82, 'total': 10708, 'max': 394, 'min': 12}},
#    'long': {'total': 464,
#     'pnl': {'average': 334,
#      'total': 154720,
#      'won': {'total': 179314, 'average': 468, 'max': 2972},
#      'lost': {'total': -24594, 'average': -306, 'max': -1124}},
#     'won': 384,
#     'lost': 80},
#    'pnl': {'gross': {'average': 316, 'total': 302166},
#     'net': {'average': 306, 'total': 292614}},
#    'streak': {'won': {'longest': 30, 'current': 10},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 130,
#     'pnl': {'average': -278, 'total': -36224, 'max': -1124}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 9, 9, 7, 45, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.6,
#   'train_loss': 0.239034965634346,
#   'start_date': '01-01-2017',
#   'final_portfolio_value': 302612.74100244907,
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff.h5',
#   'val_mae': 0.41148462891578674,
#   'training_data_end_date': DatetimeWithNanoseconds(2023, 9, 8, 6, 30, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.3,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 2},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 10,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 12, 22, 6, 2, 442800, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_2',
#   'train_mae': 0.3990473449230194,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff',
#   'test_data_end_date': DatetimeWithNanoseconds(2025, 3, 12, 15, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24998442828655243,
#   'drawdown_analysis': {'len': 2,
#    'drawdown': 0,
#    'max': {'len': 680, 'drawdown': 4, 'moneydown': 1010},
#    'moneydown': 2},
#   'end_date': '30-12-2025',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 522,
#     'pnl': {'average': 94,
#      'total': 49304,
#      'won': {'total': 52680, 'average': 110, 'max': 528},
#      'lost': {'total': -3374, 'average': -84, 'max': -504}},
#     'won': 482,
#     'lost': 40},
#    'total': {'total': 1130, 'open': 0, 'closed': 1130},
#    'won': {'total': 966,
#     'pnl': {'average': 144, 'total': 138662, 'max': 1138}},
#    'len': {'short': {'max': 80,
#      'average': 16,
#      'total': 7724,
#      'won': {'total': 6410, 'average': 14, 'min': 2, 'max': 64},
#      'min': 2,
#      'lost': {'total': 1314, 'average': 34, 'min': 4, 'max': 80}},
#     'total': 48746,
#     'average': 44,
#     'won': {'average': 38, 'total': 35826, 'max': 358, 'min': 2},
#     'min': 2,
#     'long': {'max': 396,
#      'average': 68,
#      'total': 41024,
#      'won': {'total': 29416, 'average': 62, 'min': 4, 'max': 358},
#      'min': 4,
#      'lost': {'total': 11608, 'average': 94, 'min': 10, 'max': 396}},
#     'max': 396,
#     'lost': {'average': 80, 'total': 12922, 'max': 396, 'min': 4}},
#    'long': {'total': 608,
#     'pnl': {'average': 118,
#      'total': 71058,
#      'won': {'total': 85982, 'average': 178, 'max': 1138},
#      'lost': {'total': -14924, 'average': -120, 'max': -546}},
#     'won': 484,
#     'lost': 124},
#    'pnl': {'gross': {'average': 112, 'total': 124886},
#     'net': {'average': 108, 'total': 120362}},
#    'streak': {'won': {'longest': 32, 'current': 10},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 164,
#     'pnl': {'average': -112, 'total': -18300, 'max': -546}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 9, 9, 7, 45, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.6,
#   'train_loss': 0.239034965634346,
#   'start_date': '01-01-2017',
#   'final_portfolio_value': 130361.08579615387,
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff.h5',
#   'val_mae': 0.41148462891578674,
#   'training_data_end_date': DatetimeWithNanoseconds(2023, 9, 8, 6, 30, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.6,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 2},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 7,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 12, 22, 18, 32, 966162, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_2',
#   'train_mae': 0.3990473449230194,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff',
#   'test_data_end_date': DatetimeWithNanoseconds(2025, 3, 12, 15, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24998442828655243,
#   'drawdown_analysis': {'len': 0,
#    'drawdown': 0,
#    'max': {'len': 1750, 'drawdown': 8, 'moneydown': 1108},
#    'moneydown': 0},
#   'end_date': '30-12-2025',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 448,
#     'pnl': {'average': 54,
#      'total': 24176,
#      'won': {'total': 41912, 'average': 144, 'max': 810},
#      'lost': {'total': -17736, 'average': -114, 'max': -702}},
#     'won': 292,
#     'lost': 156},
#    'total': {'total': 756, 'open': 2, 'closed': 754},
#    'won': {'total': 584, 'pnl': {'average': 112, 'total': 65568, 'max': 810}},
#    'len': {'short': {'max': 760,
#      'average': 104,
#      'total': 46044,
#      'won': {'total': 26876, 'average': 92, 'min': 6, 'max': 760},
#      'min': 4,
#      'lost': {'total': 19170, 'average': 124, 'min': 4, 'max': 498}},
#     'total': 49928,
#     'average': 66,
#     'won': {'average': 52, 'total': 30338, 'max': 760, 'min': 2},
#     'min': 2,
#     'long': {'max': 64,
#      'average': 14,
#      'total': 3884,
#      'won': {'total': 3464, 'average': 12, 'min': 2, 'max': 60},
#      'min': 2,
#      'lost': {'total': 420, 'average': 30, 'min': 10, 'max': 64}},
#     'max': 760,
#     'lost': {'average': 116, 'total': 19590, 'max': 498, 'min': 4}},
#    'long': {'total': 306,
#     'pnl': {'average': 76,
#      'total': 23176,
#      'won': {'total': 23656, 'average': 82, 'max': 344},
#      'lost': {'total': -478, 'average': -34, 'max': -124}},
#     'won': 292,
#     'lost': 14},
#    'pnl': {'gross': {'average': 66, 'total': 49464},
#     'net': {'average': 64, 'total': 47354}},
#    'streak': {'won': {'longest': 20, 'current': 4},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 170,
#     'pnl': {'average': -106, 'total': -18214, 'max': -702}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 9, 9, 7, 45, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.3,
#   'train_loss': 0.239034965634346,
#   'start_date': '01-01-2017',
#   'final_portfolio_value': 57500.4292752476,
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff.h5',
#   'val_mae': 0.41148462891578674,
#   'training_data_end_date': DatetimeWithNanoseconds(2023, 9, 8, 6, 30, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.4,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 2},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 7,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 12, 22, 7, 13, 154117, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_2',
#   'train_mae': 0.3990473449230194,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff',
#   'test_data_end_date': DatetimeWithNanoseconds(2025, 3, 12, 15, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24998442828655243,
#   'drawdown_analysis': {'len': 2,
#    'drawdown': 0,
#    'max': {'len': 556, 'drawdown': 6, 'moneydown': 906},
#    'moneydown': 2},
#   'end_date': '30-12-2025',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 1106,
#     'pnl': {'average': 38,
#      'total': 42224,
#      'won': {'total': 60962, 'average': 74, 'max': 590},
#      'lost': {'total': -18736, 'average': -68, 'max': -728}},
#     'won': 830,
#     'lost': 276},
#    'total': {'total': 2092, 'open': 0, 'closed': 2092},
#    'won': {'total': 1696, 'pnl': {'average': 66, 'total': 112288, 'max': 590}},
#    'len': {'short': {'max': 314,
#      'average': 30,
#      'total': 33514,
#      'won': {'total': 20494, 'average': 26, 'min': 2, 'max': 314},
#      'min': 2,
#      'lost': {'total': 13020, 'average': 48, 'min': 2, 'max': 194}},
#     'total': 47862,
#     'average': 24,
#     'won': {'average': 20, 'total': 31972, 'max': 314, 'min': 2},
#     'min': 2,
#     'long': {'max': 66,
#      'average': 16,
#      'total': 14348,
#      'won': {'total': 11478, 'average': 14, 'min': 2, 'max': 62},
#      'min': 2,
#      'lost': {'total': 2870, 'average': 24, 'min': 2, 'max': 66}},
#     'max': 314,
#     'lost': {'average': 40, 'total': 15890, 'max': 194, 'min': 2}},
#    'long': {'total': 986,
#     'pnl': {'average': 48,
#      'total': 46652,
#      'won': {'total': 51328, 'average': 60, 'max': 390},
#      'lost': {'total': -4674, 'average': -38, 'max': -316}},
#     'won': 866,
#     'lost': 120},
#    'pnl': {'gross': {'average': 46, 'total': 94732},
#     'net': {'average': 44, 'total': 88876}},
#    'streak': {'won': {'longest': 26, 'current': 4},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 396,
#     'pnl': {'average': -58, 'total': -23412, 'max': -728}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 9, 9, 7, 45, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.3,
#   'train_loss': 0.239034965634346,
#   'start_date': '01-01-2017',
#   'final_portfolio_value': 98876.02764767363,
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff.h5',
#   'val_mae': 0.41148462891578674,
#   'training_data_end_date': DatetimeWithNanoseconds(2023, 9, 8, 6, 30, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.3,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 2},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 15,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 12, 22, 3, 23, 324030, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_2',
#   'train_mae': 0.3990473449230194,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff',
#   'test_data_end_date': DatetimeWithNanoseconds(2025, 3, 12, 15, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24998442828655243,
#   'drawdown_analysis': {'len': 2,
#    'drawdown': 0,
#    'max': {'len': 1238, 'drawdown': 14, 'moneydown': 1934},
#    'moneydown': 4},
#   'end_date': '30-12-2025',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 1150,
#     'pnl': {'average': 80,
#      'total': 91356,
#      'won': {'total': 119856, 'average': 130, 'max': 948},
#      'lost': {'total': -28500, 'average': -126, 'max': -1550}},
#     'won': 926,
#     'lost': 224},
#    'total': {'total': 2182, 'open': 0, 'closed': 2182},
#    'won': {'total': 1774,
#     'pnl': {'average': 138, 'total': 244152, 'max': 1038}},
#    'len': {'short': {'max': 238,
#      'average': 20,
#      'total': 22328,
#      'won': {'total': 14880, 'average': 16, 'min': 2, 'max': 238},
#      'min': 2,
#      'lost': {'total': 7448, 'average': 34, 'min': 2, 'max': 108}},
#     'total': 45164,
#     'average': 22,
#     'won': {'average': 18, 'total': 31540, 'max': 238, 'min': 2},
#     'min': 2,
#     'long': {'max': 100,
#      'average': 22,
#      'total': 22838,
#      'won': {'total': 16660, 'average': 20, 'min': 2, 'max': 86},
#      'min': 2,
#      'lost': {'total': 6178, 'average': 34, 'min': 2, 'max': 100}},
#     'max': 238,
#     'lost': {'average': 34, 'total': 13626, 'max': 108, 'min': 2}},
#    'long': {'total': 1034,
#     'pnl': {'average': 102,
#      'total': 104224,
#      'won': {'total': 124296, 'average': 146, 'max': 1038},
#      'lost': {'total': -20072, 'average': -108, 'max': -836}},
#     'won': 850,
#     'lost': 184},
#    'pnl': {'gross': {'average': 96, 'total': 208674},
#     'net': {'average': 90, 'total': 195580}},
#    'streak': {'won': {'longest': 26, 'current': 4},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 408,
#     'pnl': {'average': -118, 'total': -48572, 'max': -1550}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 9, 9, 7, 45, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.4,
#   'train_loss': 0.239034965634346,
#   'start_date': '01-01-2017',
#   'final_portfolio_value': 205578.5695698862,
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff.h5',
#   'val_mae': 0.41148462891578674,
#   'training_data_end_date': DatetimeWithNanoseconds(2023, 9, 8, 6, 30, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.6,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 2},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 15,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 12, 22, 20, 20, 856252, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_2',
#   'train_mae': 0.3990473449230194,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff',
#   'test_data_end_date': DatetimeWithNanoseconds(2025, 3, 12, 15, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24998442828655243,
#   'drawdown_analysis': {'len': 0,
#    'drawdown': 0,
#    'max': {'len': 5750, 'drawdown': 22, 'moneydown': 2432},
#    'moneydown': 0},
#   'end_date': '30-12-2025',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 430,
#     'pnl': {'average': 130,
#      'total': 55932,
#      'won': {'total': 89698, 'average': 308, 'max': 1836},
#      'lost': {'total': -33766, 'average': -246, 'max': -1494}},
#     'won': 292,
#     'lost': 138},
#    'total': {'total': 674, 'open': 2, 'closed': 674},
#    'won': {'total': 524,
#     'pnl': {'average': 266, 'total': 138928, 'max': 1836}},
#    'len': {'short': {'max': 758,
#      'average': 102,
#      'total': 43606,
#      'won': {'total': 26678, 'average': 92, 'min': 8, 'max': 758},
#      'min': 4,
#      'lost': {'total': 16930, 'average': 124, 'min': 4, 'max': 494}},
#     'total': 47900,
#     'average': 72,
#     'won': {'average': 58, 'total': 30468, 'max': 758, 'min': 2},
#     'min': 2,
#     'long': {'max': 94,
#      'average': 18,
#      'total': 4294,
#      'won': {'total': 3792, 'average': 16, 'min': 2, 'max': 72},
#      'min': 2,
#      'lost': {'total': 504, 'average': 42, 'min': 14, 'max': 94}},
#     'max': 758,
#     'lost': {'average': 118, 'total': 17432, 'max': 494, 'min': 4}},
#    'long': {'total': 244,
#     'pnl': {'average': 196,
#      'total': 47762,
#      'won': {'total': 49230, 'average': 212, 'max': 874},
# ...
#      'min': 2,
#      'lost': {'total': 504, 'average': 42, 'min': 14, 'max': 94}},
#     'max': 758,
#     'lost': {'average': 118, 'total': 17706, 'max': 494, 'min': 4}},
#    'long': {'total': 204,
#     'pnl': {'average': 316,
#      'total': 64484,
#      'won': {'total': 66930, 'average': 350, 'max': 1266},
#      'lost': {'total': -2446, 'average': -204, 'max': -752}},
#     'won': 192,
#     'lost': 12},
#    'pnl': {'gross': {'average': 256, 'total': 162132},
#     'net': {'average': 246, 'total': 155808}},
#    'streak': {'won': {'longest': 20, 'current': 4},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 152,
#     'pnl': {'average': -398, 'total': -60106, 'max': -2492}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 9, 9, 7, 45, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.4,
#   'train_loss': 0.239034965634346,
#   'start_date': '01-01-2017',
#   'final_portfolio_value': 166411.39802726352,
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff.h5',
#   'val_mae': 0.41148462891578674,
#   'training_data_end_date': DatetimeWithNanoseconds(2023, 9, 8, 6, 30, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.3,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 2},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 25,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 12, 22, 2, 23, 331911, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_2',
#   'train_mae': 0.3990473449230194,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff',
#   'test_data_end_date': DatetimeWithNanoseconds(2025, 3, 12, 15, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24998442828655243,
#   'drawdown_analysis': {'len': 2,
#    'drawdown': 0,
#    'max': {'len': 1502, 'drawdown': 20, 'moneydown': 3416},
#    'moneydown': 6},
#   'end_date': '30-12-2025',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 1390,
#     'pnl': {'average': 108,
#      'total': 149256,
#      'won': {'total': 214244, 'average': 198, 'max': 1298},
#      'lost': {'total': -64988, 'average': -210, 'max': -2628}},
#     'won': 1080,
#     'lost': 310},
#    'total': {'total': 2470, 'open': 0, 'closed': 2470},
#    'won': {'total': 1984,
#     'pnl': {'average': 200, 'total': 397608, 'max': 1298}},
#    'len': {'short': {'max': 238,
#      'average': 20,
#      'total': 28206,
#      'won': {'total': 17754, 'average': 16, 'min': 2, 'max': 238},
#      'min': 2,
#      'lost': {'total': 10452, 'average': 34, 'min': 2, 'max': 110}},
#     'total': 44446,
#     'average': 18,
#     'won': {'average': 16, 'total': 29834, 'max': 238, 'min': 2},
#     'min': 2,
#     'long': {'max': 78,
#      'average': 16,
#      'total': 16242,
#      'won': {'total': 12080, 'average': 14, 'min': 2, 'max': 62},
#      'min': 2,
#      'lost': {'total': 4162, 'average': 24, 'min': 2, 'max': 78}},
#     'max': 238,
#     'lost': {'average': 30, 'total': 14614, 'max': 110, 'min': 2}},
#    'long': {'total': 1082,
#     'pnl': {'average': 144,
#      'total': 155426,
#      'won': {'total': 183366, 'average': 204, 'max': 1278},
#      'lost': {'total': -27938, 'average': -158, 'max': -1246}},
#     'won': 904,
#     'lost': 178},
#    'pnl': {'gross': {'average': 134, 'total': 329382},
#     'net': {'average': 124, 'total': 304680}},
#    'streak': {'won': {'longest': 26, 'current': 4},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 486,
#     'pnl': {'average': -190, 'total': -92928, 'max': -2628}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 9, 9, 7, 45, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.3,
#   'train_loss': 0.239034965634346,
#   'start_date': '01-01-2017',
#   'final_portfolio_value': 314680.3349075981,
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff.h5',
#   'val_mae': 0.41148462891578674,
#   'training_data_end_date': DatetimeWithNanoseconds(2023, 9, 8, 6, 30, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.3,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 2},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 25,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 12, 22, 5, 20, 716344, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_2',
#   'train_mae': 0.3990473449230194,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff',
#   'test_data_end_date': DatetimeWithNanoseconds(2025, 3, 12, 15, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24998442828655243,
#   'drawdown_analysis': {'len': 2,
#    'drawdown': 0,
#    'max': {'len': 906, 'drawdown': 18, 'moneydown': 3162},
#    'moneydown': 6},
#   'end_date': '30-12-2025',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 864,
#     'pnl': {'average': 164,
#      'total': 140536,
#      'won': {'total': 168356, 'average': 232, 'max': 1420},
#      'lost': {'total': -27820, 'average': -202, 'max': -2330}},
#     'won': 728,
#     'lost': 138},
#    'total': {'total': 1622, 'open': 0, 'closed': 1622},
#    'won': {'total': 1340,
#     'pnl': {'average': 274, 'total': 365200, 'max': 2438}},
#    'len': {'short': {'max': 212,
#      'average': 18,
#      'total': 15650,
#      'won': {'total': 11206, 'average': 16, 'min': 2, 'max': 212},
#      'min': 2,
#      'lost': {'total': 4444, 'average': 32, 'min': 2, 'max': 96}},
#     'total': 42522,
#     'average': 26,
#     'won': {'average': 24, 'total': 30810, 'max': 276, 'min': 2},
#     'min': 2,
#     'long': {'max': 276,
#      'average': 36,
#      'total': 26872,
#      'won': {'total': 19604, 'average': 32, 'min': 2, 'max': 276},
#      'min': 2,
#      'lost': {'total': 7270, 'average': 50, 'min': 4, 'max': 146}},
#     'max': 276,
#     'lost': {'average': 42, 'total': 11714, 'max': 146, 'min': 2}},
#    'long': {'total': 758,
#     'pnl': {'average': 218,
#      'total': 164236,
#      'won': {'total': 196846, 'average': 322, 'max': 2438},
#      'lost': {'total': -32608, 'average': -222, 'max': -1396}},
#     'won': 612,
#     'lost': 146},
#    'pnl': {'gross': {'average': 198, 'total': 320996},
#     'net': {'average': 188, 'total': 304770}},
#    'streak': {'won': {'longest': 22, 'current': 4},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 284,
#     'pnl': {'average': -214, 'total': -60430, 'max': -2330}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 9, 9, 7, 45, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.5,
#   'train_loss': 0.239034965634346,
#   'start_date': '01-01-2017',
#   'final_portfolio_value': 314770.0881700641,
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff.h5',
#   'val_mae': 0.41148462891578674,
#   'training_data_end_date': DatetimeWithNanoseconds(2023, 9, 8, 6, 30, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.6,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 2},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 10,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 12, 22, 21, 28, 217115, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_2',
#   'train_mae': 0.3990473449230194,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff',
#   'test_data_end_date': DatetimeWithNanoseconds(2025, 3, 12, 15, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24998442828655243,
#   'drawdown_analysis': {'len': 0,
#    'drawdown': 0,
#    'max': {'len': 1618, 'drawdown': 8, 'moneydown': 1372},
#    'moneydown': 0},
#   'end_date': '30-12-2025',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 384,
#     'pnl': {'average': 114,
#      'total': 43480,
#      'won': {'total': 59924, 'average': 210, 'max': 1224},
#      'lost': {'total': -16444, 'average': -166, 'max': -684}},
#     'won': 286,
#     'lost': 100},
#    'total': {'total': 676, 'open': 2, 'closed': 676},
#    'won': {'total': 560,
#     'pnl': {'average': 190, 'total': 105866, 'max': 1224}},
#    'len': {'short': {'max': 752,
#      'average': 100,
#      'total': 38196,
#      'won': {'total': 25068, 'average': 88, 'min': 4, 'max': 752},
#      'min': 4,
#      'lost': {'total': 13128, 'average': 134, 'min': 16, 'max': 492}},
#     'total': 47300,
#     'average': 70,
#     'won': {'average': 60, 'total': 33082, 'max': 752, 'min': 4},
#     'min': 4,
#     'long': {'max': 186,
#      'average': 32,
#      'total': 9104,
#      'won': {'total': 8014, 'average': 30, 'min': 4, 'max': 186},
#      'min': 4,
#      'lost': {'total': 1092, 'average': 64, 'min': 28, 'max': 138}},
#     'max': 752,
#     'lost': {'average': 124, 'total': 14218, 'max': 492, 'min': 16}},
#    'long': {'total': 292,
#     'pnl': {'average': 152,
#      'total': 44254,
#      'won': {'total': 45942, 'average': 168, 'max': 978},
#      'lost': {'total': -1688, 'average': -98, 'max': -406}},
#     'won': 274,
#     'lost': 18},
#    'pnl': {'gross': {'average': 134, 'total': 90434},
#     'net': {'average': 130, 'total': 87734}},
#    'streak': {'won': {'longest': 22, 'current': 10},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 116,
#     'pnl': {'average': -156, 'total': -18132, 'max': -684}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 9, 9, 7, 45, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.5,
#   'train_loss': 0.239034965634346,
#   'start_date': '01-01-2017',
#   'final_portfolio_value': 97974.9727635846,
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff.h5',
#   'val_mae': 0.41148462891578674,
#   'training_data_end_date': DatetimeWithNanoseconds(2023, 9, 8, 6, 30, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.4,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 2},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 7,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 12, 22, 8, 40, 886652, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_2',
#   'train_mae': 0.3990473449230194,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_2_15m_01-01-2017_30-12-2025_d3dd27ff',
#   'test_data_end_date': DatetimeWithNanoseconds(2025, 3, 12, 15, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24998442828655243,
#   'drawdown_analysis': {'len': 2,
#    'drawdown': 0,
#    'max': {'len': 640, 'drawdown': 6, 'moneydown': 902},
#    'moneydown': 2},
#   'end_date': '30-12-2025',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 958,
#     'pnl': {'average': 48,
#      'total': 44882,
#      'won': {'total': 58802, 'average': 80, 'max': 590},
#      'lost': {'total': -13920, 'average': -66, 'max': -718}},
#     'won': 748,
#     'lost': 210},
#    'total': {'total': 1848, 'open': 0, 'closed': 1848},
#    'won': {'total': 1516, 'pnl': {'average': 76, 'total': 114130, 'max': 590}},
#    'len': {'short': {'max': 312,
#      'average': 30,
#      'total': 27876,
#      'won': {'total': 17910, 'average': 24, 'min': 2, 'max': 312},
#      'min': 2,
#      'lost': {'total': 9966, 'average': 48, 'min': 2, 'max': 190}},
#     'total': 46862,
#     'average': 26,
#     'won': {'average': 22, 'total': 32284, 'max': 312, 'min': 2},
#     'min': 2,
#     'long': {'max': 96,
#      'average': 22,
#      'total': 18986,
#      'won': {'total': 14374, 'average': 20, 'min': 2, 'max': 84},
#      'min': 2,
#      'lost': {'total': 4614, 'average': 38, 'min': 4, 'max': 96}},
#     'max': 312,
#     'lost': {'average': 44, 'total': 14578, 'max': 190, 'min': 2}},
#    'long': {'total': 892,
#     'pnl': {'average': 56,
#      'total': 49704,
#      'won': {'total': 55328, 'average': 72, 'max': 518},
#      'lost': {'total': -5624, 'average': -46, 'max': -262}},
#     'won': 768,
#     'lost': 124},
#    'pnl': {'gross': {'average': 54, 'total': 99760},
#     'net': {'average': 52, 'total': 94584}},
#    'streak': {'won': {'longest': 24, 'current': 4},
#     'lost': {'longest': 6, 'current': 0}},
#    'lost': {'total': 334,
#     'pnl': {'average': -58, 'total': -19546, 'max': -718}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 9, 9, 7, 45, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.4,
#   'train_loss': 0.239034965634346,
#   'start_date': '01-01-2017',
#   'final_portfolio_value': 104584.49062625215,
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc)}]

# %%
data = pd.DataFrame(trade_models)
data
# Out:
#                                            model_path   val_mae  \
# 0   gs://ife-storage/trade/models/binance_mtf_v1_0...  0.411485
# 1   gs://ife-storage/trade/models/binance_mtf_v1_0...  0.411485
# 2   gs://ife-storage/trade/models/binance_mtf_v1_0...  0.411485
# 3   gs://ife-storage/trade/models/binance_mtf_v1_0...  0.411485
# 4   gs://ife-storage/trade/models/binance_mtf_v1_0...  0.411485
# ..                                                ...       ...
# 91  gs://ife-storage/trade/models/binance_mtf_v1_0...  0.411485
# 92  gs://ife-storage/trade/models/binance_mtf_v1_0...  0.411485
# 93  gs://ife-storage/trade/models/binance_mtf_v1_0...  0.411485
# 94  gs://ife-storage/trade/models/binance_mtf_v1_0...  0.411485
# 95  gs://ife-storage/trade/models/binance_mtf_v1_0...  0.411485
#
#       training_data_end_date  trade_buy_threshold  \
# 0  2023-09-08 06:30:00+00:00                  0.5
# 1  2023-09-08 06:30:00+00:00                  0.6
# 2  2023-09-08 06:30:00+00:00                  0.5
# 3  2023-09-08 06:30:00+00:00                  0.4
# 4  2023-09-08 06:30:00+00:00                  0.3
# ..                       ...                  ...
# 91 2023-09-08 06:30:00+00:00                  0.6
# 92 2023-09-08 06:30:00+00:00                  0.3
# 93 2023-09-08 06:30:00+00:00                  0.3
# 94 2023-09-08 06:30:00+00:00                  0.6
# 95 2023-09-08 06:30:00+00:00                  0.4
#
#                                      features_columns  training_data_ratio  \
# 0   _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 1   _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 2   _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 3   _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 4   _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# ..                                                ...                  ...
# 91  _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 92  _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 93  _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 94  _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 95  _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
#
#        sharpe_analysis model_input_shape  epochs  trade_leverage  ...  \
# 0   {'sharperatio': 2}         [100, 29]      20              20  ...
# 1   {'sharperatio': 2}         [100, 29]      20              30  ...
# 2   {'sharperatio': 2}         [100, 29]      20              25  ...
# 3   {'sharperatio': 2}         [100, 29]      20              10  ...
# 4   {'sharperatio': 2}         [100, 29]      20              15  ...
# ..                 ...               ...     ...             ...  ...
# 91  {'sharperatio': 2}         [100, 29]      20              25  ...
# 92  {'sharperatio': 2}         [100, 29]      20              25  ...
# 93  {'sharperatio': 2}         [100, 29]      20              25  ...
# 94  {'sharperatio': 2}         [100, 29]      20              10  ...
# 95  {'sharperatio': 2}         [100, 29]      20               7  ...
#
#    exchange starting_portfolio_value   symbol      test_data_start_date  \
# 0   binance                  10000.0  BTCUSDT 2023-09-09 07:45:00+00:00
# 1   binance                  10000.0  BTCUSDT 2023-09-09 07:45:00+00:00
# 2   binance                  10000.0  BTCUSDT 2023-09-09 07:45:00+00:00
# 3   binance                  10000.0  BTCUSDT 2023-09-09 07:45:00+00:00
# 4   binance                  10000.0  BTCUSDT 2023-09-09 07:45:00+00:00
# ..      ...                      ...      ...                       ...
# 91  binance                  10000.0  BTCUSDT 2023-09-09 07:45:00+00:00
# 92  binance                  10000.0  BTCUSDT 2023-09-09 07:45:00+00:00
# 93  binance                  10000.0  BTCUSDT 2023-09-09 07:45:00+00:00
# 94  binance                  10000.0  BTCUSDT 2023-09-09 07:45:00+00:00
# 95  binance                  10000.0  BTCUSDT 2023-09-09 07:45:00+00:00
#
#    middle_timeframe  trade_sell_threshold train_loss  start_date  \
# 0                1h                  -0.6   0.239035  01-01-2017
# 1                1h                  -0.4   0.239035  01-01-2017
# 2                1h                  -0.3   0.239035  01-01-2017
# 3                1h                  -0.5   0.239035  01-01-2017
# 4                1h                  -0.6   0.239035  01-01-2017
# ..              ...                   ...        ...         ...
# 91               1h                  -0.4   0.239035  01-01-2017
# 92               1h                  -0.3   0.239035  01-01-2017
# 93               1h                  -0.5   0.239035  01-01-2017
# 94               1h                  -0.5   0.239035  01-01-2017
# 95               1h                  -0.4   0.239035  01-01-2017
#
#    final_portfolio_value  training_data_start_date
# 0          235883.679284 2017-08-20 12:00:00+00:00
# 1          197193.823009 2017-08-20 12:00:00+00:00
# 2          247446.601300 2017-08-20 12:00:00+00:00
# 3          147782.847521 2017-08-20 12:00:00+00:00
# 4          181722.179169 2017-08-20 12:00:00+00:00
# ..                   ...                       ...
# 91         166411.398027 2017-08-20 12:00:00+00:00
# 92         314680.334908 2017-08-20 12:00:00+00:00
# 93         314770.088170 2017-08-20 12:00:00+00:00
# 94          97974.972764 2017-08-20 12:00:00+00:00
# 95         104584.490626 2017-08-20 12:00:00+00:00
#
# [96 rows x 36 columns]

# %%
sorted(data.columns)
# Out:
# ['broker_commision',
#  'created_at',
#  'drawdown_analysis',
#  'end_date',
#  'epochs',
#  'exchange',
#  'features_columns',
#  'final_epoch',
#  'final_portfolio_value',
#  'higher_timeframe',
#  'lower_timeframe',
#  'middle_timeframe',
#  'model_input_shape',
#  'model_name',
#  'model_path',
#  'seq_length',
#  'sharpe_analysis',
#  'start_date',
#  'starting_portfolio_value',
#  'symbol',
#  'test_data_end_date',
#  'test_data_start_date',
#  'timeframe',
#  'trade_analysis',
#  'trade_buy_threshold',
#  'trade_leverage',
#  'trade_margin',
#  'trade_sell_threshold',
#  'train_loss',
#  'train_mae',
#  'training_data_end_date',
#  'training_data_ratio',
#  'training_data_start_date',
#  'val_loss',
#  'val_mae',
#  'version']

# %%
performing_model = data[['start_date', 'end_date', 'final_portfolio_value', 'trade_buy_threshold', 'trade_sell_threshold', 'trade_leverage', 'val_loss', 'val_mae', 'test_data_start_date', 'test_data_end_date']].sort_values(by='final_portfolio_value', ascending=False).head(20)
performing_model
# Out:
#     start_date    end_date  final_portfolio_value  trade_buy_threshold  \
# 37  01-01-2017  30-12-2025          386127.064512                  0.4
# 19  01-01-2017  30-12-2025          382489.577728                  0.3
# 46  01-01-2017  30-12-2025          381768.230982                  0.4
# 42  01-01-2017  30-12-2025          374783.692354                  0.3
# 18  01-01-2017  30-12-2025          374231.539454                  0.3
# 34  01-01-2017  30-12-2025          359918.778656                  0.4
# 27  01-01-2017  30-12-2025          358065.101090                  0.4
# 25  01-01-2017  30-12-2025          342466.275412                  0.5
# 36  01-01-2017  30-12-2025          342272.750257                  0.5
# 45  01-01-2017  30-12-2025          339102.624180                  0.3
# 30  01-01-2017  30-12-2025          325511.399987                  0.4
# 80  01-01-2017  30-12-2025          323278.805046                  0.3
# 86  01-01-2017  30-12-2025          321329.703417                  0.5
# 49  01-01-2017  30-12-2025          320244.610303                  0.4
# 93  01-01-2017  30-12-2025          314770.088170                  0.3
# 92  01-01-2017  30-12-2025          314680.334908                  0.3
# 55  01-01-2017  30-12-2025          303376.886405                  0.4
# 7   01-01-2017  30-12-2025          302612.741002                  0.4
# 59  01-01-2017  30-12-2025          294362.720199                  0.5
# 47  01-01-2017  30-12-2025          289486.796518                  0.5
#
#     trade_sell_threshold  trade_leverage  val_loss   val_mae  \
# 37                  -0.5              30  0.249984  0.411485
# 19                  -0.4              30  0.249984  0.411485
# 46                  -0.4              30  0.249984  0.411485
# 42                  -0.5              30  0.249984  0.411485
# 18                  -0.3              30  0.249984  0.411485
# 34                  -0.3              30  0.249984  0.411485
# 27                  -0.6              30  0.249984  0.411485
# 25                  -0.5              30  0.249984  0.411485
# 36                  -0.6              30  0.249984  0.411485
# 45                  -0.6              30  0.249984  0.411485
# 30                  -0.5              25  0.249984  0.411485
# 80                  -0.4              25  0.249984  0.411485
# 86                  -0.4              30  0.249984  0.411485
# 49                  -0.4              25  0.249984  0.411485
# 93                  -0.5              25  0.249984  0.411485
# 92                  -0.3              25  0.249984  0.411485
# 55                  -0.3              25  0.249984  0.411485
# 7                   -0.6              25  0.249984  0.411485
# 59                  -0.3              30  0.249984  0.411485
# 47                  -0.5              25  0.249984  0.411485
#
#         test_data_start_date        test_data_end_date
# 37 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00
# 19 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00
# 46 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00
# 42 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00
# 18 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00
# 34 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00
# 27 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00
# 25 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00
# 36 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00
# 45 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00
# 30 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00
# 80 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00
# 86 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00
# 49 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00
# 93 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00
# 92 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00
# 55 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00
# 7  2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00
# 59 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00
# 47 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00

# %%
data.loc[37]['sharpe_analysis']
# Out:
# {'sharperatio': 2}

# %%
get_nested_value(data.loc[37]['trade_analysis'], ['streak', 'won', 'longest'])
# Out:
# 28

# %%
def get_trade_analysis_overview(df):
  selected_columns = [
      'start_date', 'end_date', 'final_portfolio_value', 'trade_buy_threshold',
      'trade_sell_threshold', 'trade_leverage', 'val_loss', 'val_mae',
      'test_data_start_date', 'test_data_end_date', 'trade_analysis', 'drawdown_analysis'
  ]
  df = df[selected_columns].copy().sort_values(by='final_portfolio_value', ascending=False)
  df['total_trade'] = df['trade_analysis'].apply(lambda x: x['total']['total'])
  df['longest_won_streak'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['streak', 'won', 'longest']))
  df['longest_lost_streak'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['streak', 'lost', 'longest']))
  df['total_pnl'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['pnl', 'net', 'total']))
  df['avg_pnl'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['pnl', 'net', 'average']))
  df['total_win_trade'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['won', 'total']))
  df['total_won_amount'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['won', 'pnl', 'total']))
  df['max_won_amount'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['won', 'pnl', 'max']))
  df['avg_won_amount'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['won', 'pnl', 'average']))
  df['total_loss_trade'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['lost', 'total']))
  df['total_lost_amount'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['lost', 'pnl', 'total']))
  df['max_lost_amount'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['lost', 'pnl', 'max']))
  df['avg_lost_amount'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['lost', 'pnl', 'average']))
  df['max_drawdown_percent'] = df['drawdown_analysis'].apply(lambda x: get_nested_value(x, ['max', 'drawdown']))
  df['max_drawdown_value'] = df['drawdown_analysis'].apply(lambda x: get_nested_value(x, ['max', 'moneydown']))
  df['max_drawdown_len'] = df['drawdown_analysis'].apply(lambda x: get_nested_value(x, ['max', 'len']))
  del df['trade_analysis']
  del df['drawdown_analysis']
  return df

# %%
trade_data = get_trade_analysis_overview(data)
trade_data
# Out:
#     start_date    end_date  final_portfolio_value  trade_buy_threshold  \
# 37  01-01-2017  30-12-2025          386127.064512                  0.4
# 19  01-01-2017  30-12-2025          382489.577728                  0.3
# 46  01-01-2017  30-12-2025          381768.230982                  0.4
# 42  01-01-2017  30-12-2025          374783.692354                  0.3
# 18  01-01-2017  30-12-2025          374231.539454                  0.3
# ..         ...         ...                    ...                  ...
# 76  01-01-2017  30-12-2025           77594.765512                  0.6
# 29  01-01-2017  30-12-2025           77446.559404                  0.6
# 16  01-01-2017  30-12-2025           71756.145360                  0.6
# 69  01-01-2017  30-12-2025           63150.215288                  0.6
# 9   01-01-2017  30-12-2025           57500.429275                  0.6
#
#     trade_sell_threshold  trade_leverage  val_loss   val_mae  \
# 37                  -0.5              30  0.249984  0.411485
# 19                  -0.4              30  0.249984  0.411485
# 46                  -0.4              30  0.249984  0.411485
# 42                  -0.5              30  0.249984  0.411485
# 18                  -0.3              30  0.249984  0.411485
# ..                   ...             ...       ...       ...
# 76                  -0.3              10  0.249984  0.411485
# 29                  -0.6               7  0.249984  0.411485
# 16                  -0.5               7  0.249984  0.411485
# 69                  -0.4               7  0.249984  0.411485
# 9                   -0.3               7  0.249984  0.411485
#
#         test_data_start_date        test_data_end_date  ...  total_won_amount  \
# 37 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00  ...            437150
# 19 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00  ...            467380
# 46 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00  ...            454638
# 42 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00  ...            437084
# 18 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00  ...            476084
# ..                       ...                       ...  ...               ...
# 76 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00  ...             93404
# 29 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00  ...             75726
# 16 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00  ...             74294
# 69 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00  ...             69244
# 9  2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00  ...             65568
#
#     max_won_amount  avg_won_amount  total_loss_trade  total_lost_amount  \
# 37            2906             380               226             -61022
# 19            2076             278               398             -94888
# 46            2530             330               316             -82868
# 42            2924             328               282             -72300
# 18            1558             242               484            -111850
# ..             ...             ...               ...                ...
# 76            1158             162               170             -26020
# 29             852             160                86              -8504
# 16             858             132               116             -12706
# 69             858             120               154             -16260
# 9              810             112               170             -18214
#
#     max_lost_amount  avg_lost_amount  max_drawdown_percent  \
# 37            -2796             -270                    20
# 19            -3102             -238                    22
# 46            -3102             -262                    24
# 42            -2796             -256                    20
# 18            -3154             -230                    22
# ..              ...              ...                   ...
# 76            -1004             -152                    12
# 29             -320              -98                     4
# 16             -478             -110                     6
# 69             -692             -106                     8
# 9              -702             -106                     8
#
#     max_drawdown_value  max_drawdown_len
# 37                3794              1098
# 19                3866              1238
# 46                4154              1814
# 42                3794               906
# 18                4100              1502
# ..                 ...               ...
# 76                1584              1930
# 29                 778              1066
# 16                 962              1262
# 69                 998              1446
# 9                 1108              1750
#
# [96 rows x 26 columns]

# %%
trade_data.columns
# Out:
# Index(['start_date', 'end_date', 'final_portfolio_value',
#        'trade_buy_threshold', 'trade_sell_threshold', 'trade_leverage',
#        'val_loss', 'val_mae', 'test_data_start_date', 'test_data_end_date',
#        'total_trade', 'longest_won_streak', 'longest_lost_streak', 'total_pnl',
#        'avg_pnl', 'total_win_trade', 'total_won_amount', 'max_won_amount',
#        'avg_won_amount', 'total_loss_trade', 'total_lost_amount',
#        'max_lost_amount', 'avg_lost_amount', 'max_drawdown_percent',
#        'max_drawdown_value', 'max_drawdown_len'],
#       dtype='object')

# %%
trade_data.query('max_drawdown_percent < 40 and final_portfolio_value > 50000')
# Out:
#     start_date    end_date  final_portfolio_value  trade_buy_threshold  \
# 37  01-01-2017  30-12-2025          386127.064512                  0.4
# 19  01-01-2017  30-12-2025          382489.577728                  0.3
# 46  01-01-2017  30-12-2025          381768.230982                  0.4
# 42  01-01-2017  30-12-2025          374783.692354                  0.3
# 18  01-01-2017  30-12-2025          374231.539454                  0.3
# ..         ...         ...                    ...                  ...
# 76  01-01-2017  30-12-2025           77594.765512                  0.6
# 29  01-01-2017  30-12-2025           77446.559404                  0.6
# 16  01-01-2017  30-12-2025           71756.145360                  0.6
# 69  01-01-2017  30-12-2025           63150.215288                  0.6
# 9   01-01-2017  30-12-2025           57500.429275                  0.6
#
#     trade_sell_threshold  trade_leverage  val_loss   val_mae  \
# 37                  -0.5              30  0.249984  0.411485
# 19                  -0.4              30  0.249984  0.411485
# 46                  -0.4              30  0.249984  0.411485
# 42                  -0.5              30  0.249984  0.411485
# 18                  -0.3              30  0.249984  0.411485
# ..                   ...             ...       ...       ...
# 76                  -0.3              10  0.249984  0.411485
# 29                  -0.6               7  0.249984  0.411485
# 16                  -0.5               7  0.249984  0.411485
# 69                  -0.4               7  0.249984  0.411485
# 9                   -0.3               7  0.249984  0.411485
#
#         test_data_start_date        test_data_end_date  ...  total_won_amount  \
# 37 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00  ...            437150
# 19 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00  ...            467380
# 46 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00  ...            454638
# 42 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00  ...            437084
# 18 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00  ...            476084
# ..                       ...                       ...  ...               ...
# 76 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00  ...             93404
# 29 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00  ...             75726
# 16 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00  ...             74294
# 69 2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00  ...             69244
# 9  2023-09-09 07:45:00+00:00 2025-03-12 15:00:00+00:00  ...             65568
#
#     max_won_amount  avg_won_amount  total_loss_trade  total_lost_amount  \
# 37            2906             380               226             -61022
# 19            2076             278               398             -94888
# 46            2530             330               316             -82868
# 42            2924             328               282             -72300
# 18            1558             242               484            -111850
# ..             ...             ...               ...                ...
# 76            1158             162               170             -26020
# 29             852             160                86              -8504
# 16             858             132               116             -12706
# 69             858             120               154             -16260
# 9              810             112               170             -18214
#
#     max_lost_amount  avg_lost_amount  max_drawdown_percent  \
# 37            -2796             -270                    20
# 19            -3102             -238                    22
# 46            -3102             -262                    24
# 42            -2796             -256                    20
# 18            -3154             -230                    22
# ..              ...              ...                   ...
# 76            -1004             -152                    12
# 29             -320              -98                     4
# 16             -478             -110                     6
# 69             -692             -106                     8
# 9              -702             -106                     8
#
#     max_drawdown_value  max_drawdown_len
# 37                3794              1098
# 19                3866              1238
# 46                4154              1814
# 42                3794               906
# 18                4100              1502
# ..                 ...               ...
# 76                1584              1930
# 29                 778              1066
# 16                 962              1262
# 69                 998              1446
# 9                 1108              1750
#
# [95 rows x 26 columns]

# %%
top_performing_param = trade_data.groupby(['trade_buy_threshold', 'trade_sell_threshold', 'trade_leverage']).agg({
    'final_portfolio_value': 'mean',
    'total_trade': 'mean',
    'total_pnl': 'sum',
    'longest_won_streak': 'mean',
    'longest_lost_streak': 'max',
    'max_drawdown_percent': 'max',
    'max_drawdown_value': 'max',
    'max_drawdown_len': 'max',
    'avg_lost_amount': 'mean',
    'max_lost_amount': 'max'
}).sort_values(by='final_portfolio_value', ascending=False).head(30)
top_performing_param
# Out:
#                                                          final_portfolio_value  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.5                 30                      386127.064512
# 0.3                 -0.4                 30                      382489.577728
# 0.4                 -0.4                 30                      381768.230982
# 0.3                 -0.5                 30                      374783.692354
#                     -0.3                 30                      374231.539454
# 0.4                 -0.3                 30                      359918.778656
#                     -0.6                 30                      358065.101090
# 0.5                 -0.5                 30                      342466.275412
#                     -0.6                 30                      342272.750257
# 0.3                 -0.6                 30                      339102.624180
# 0.4                 -0.5                 25                      325511.399987
# 0.3                 -0.4                 25                      323278.805046
# 0.5                 -0.4                 30                      321329.703417
# 0.4                 -0.4                 25                      320244.610303
# 0.3                 -0.5                 25                      314770.088170
#                     -0.3                 25                      314680.334908
# 0.4                 -0.3                 25                      303376.886405
#                     -0.6                 25                      302612.741002
# 0.5                 -0.3                 30                      294362.720199
#                     -0.5                 25                      289486.796518
#                     -0.6                 25                      288416.753363
# 0.3                 -0.6                 25                      285781.209057
# 0.5                 -0.4                 25                      269441.419514
# 0.6                 -0.6                 30                      266820.601861
# 0.3                 -0.4                 20                      265596.178094
# 0.4                 -0.5                 20                      264150.769817
# 0.3                 -0.5                 20                      261438.903050
#                     -0.3                 20                      260515.716435
# 0.4                 -0.4                 20                      260190.588094
#                     -0.6                 20                      248108.376408
#
#                                                          total_trade  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.5                 30                   1378.0
# 0.3                 -0.4                 30                   2088.0
# 0.4                 -0.4                 30                   1696.0
# 0.3                 -0.5                 30                   1618.0
#                     -0.3                 30                   2456.0
# 0.4                 -0.3                 30                   1910.0
#                     -0.6                 30                    948.0
# 0.5                 -0.5                 30                   1020.0
#                     -0.6                 30                    778.0
# 0.3                 -0.6                 30                   1060.0
# 0.4                 -0.5                 25                   1390.0
# 0.3                 -0.4                 25                   2106.0
# 0.5                 -0.4                 30                   1188.0
# 0.4                 -0.4                 25                   1702.0
# 0.3                 -0.5                 25                   1622.0
#                     -0.3                 25                   2470.0
# 0.4                 -0.3                 25                   1920.0
#                     -0.6                 25                    956.0
# 0.5                 -0.3                 30                   1284.0
#                     -0.5                 25                   1024.0
#                     -0.6                 25                    786.0
# 0.3                 -0.6                 25                   1068.0
# 0.5                 -0.4                 25                   1188.0
# 0.6                 -0.6                 30                    514.0
# 0.3                 -0.4                 20                   2142.0
# 0.4                 -0.5                 20                   1398.0
# 0.3                 -0.5                 20                   1662.0
#                     -0.3                 20                   2534.0
# 0.4                 -0.4                 20                   1720.0
#                     -0.6                 20                    966.0
#
#                                                          total_pnl  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.5                 30                 376128
# 0.3                 -0.4                 30                 372490
# 0.4                 -0.4                 30                 371768
# 0.3                 -0.5                 30                 364784
#                     -0.3                 30                 364232
# 0.4                 -0.3                 30                 349920
#                     -0.6                 30                 348066
# 0.5                 -0.5                 30                 332466
#                     -0.6                 30                 332274
# 0.3                 -0.6                 30                 329104
# 0.4                 -0.5                 25                 315512
# 0.3                 -0.4                 25                 313280
# 0.5                 -0.4                 30                 311330
# 0.4                 -0.4                 25                 310246
# 0.3                 -0.5                 25                 304770
#                     -0.3                 25                 304680
# 0.4                 -0.3                 25                 293378
#                     -0.6                 25                 292614
# 0.5                 -0.3                 30                 284364
#                     -0.5                 25                 279488
#                     -0.6                 25                 278418
# 0.3                 -0.6                 25                 275782
# 0.5                 -0.4                 25                 259442
# 0.6                 -0.6                 30                 255858
# 0.3                 -0.4                 20                 255596
# 0.4                 -0.5                 20                 254152
# 0.3                 -0.5                 20                 251440
#                     -0.3                 20                 250516
# 0.4                 -0.4                 20                 250192
#                     -0.6                 20                 238108
#
#                                                          longest_won_streak  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.5                 30                            28.0
# 0.3                 -0.4                 30                            26.0
# 0.4                 -0.4                 30                            24.0
# 0.3                 -0.5                 30                            22.0
#                     -0.3                 30                            26.0
# 0.4                 -0.3                 30                            26.0
#                     -0.6                 30                            30.0
# 0.5                 -0.5                 30                            26.0
#                     -0.6                 30                            22.0
# 0.3                 -0.6                 30                            32.0
# 0.4                 -0.5                 25                            28.0
# 0.3                 -0.4                 25                            26.0
# 0.5                 -0.4                 30                            30.0
# 0.4                 -0.4                 25                            24.0
# 0.3                 -0.5                 25                            22.0
#                     -0.3                 25                            26.0
# 0.4                 -0.3                 25                            26.0
#                     -0.6                 25                            30.0
# 0.5                 -0.3                 30                            32.0
#                     -0.5                 25                            26.0
#                     -0.6                 25                            22.0
# 0.3                 -0.6                 25                            32.0
# 0.5                 -0.4                 25                            30.0
# 0.6                 -0.6                 30                            26.0
# 0.3                 -0.4                 20                            26.0
# 0.4                 -0.5                 20                            28.0
# 0.3                 -0.5                 20                            22.0
#                     -0.3                 20                            26.0
# 0.4                 -0.4                 20                            24.0
#                     -0.6                 20                            30.0
#
#                                                          longest_lost_streak  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.5                 30                                4
# 0.3                 -0.4                 30                                4
# 0.4                 -0.4                 30                                4
# 0.3                 -0.5                 30                                4
#                     -0.3                 30                                4
# 0.4                 -0.3                 30                                4
#                     -0.6                 30                                4
# 0.5                 -0.5                 30                                2
#                     -0.6                 30                                2
# 0.3                 -0.6                 30                                4
# 0.4                 -0.5                 25                                4
# 0.3                 -0.4                 25                                4
# 0.5                 -0.4                 30                                4
# 0.4                 -0.4                 25                                4
# 0.3                 -0.5                 25                                4
#                     -0.3                 25                                4
# 0.4                 -0.3                 25                                4
#                     -0.6                 25                                4
# 0.5                 -0.3                 30                                4
#                     -0.5                 25                                2
#                     -0.6                 25                                4
# 0.3                 -0.6                 25                                4
# 0.5                 -0.4                 25                                4
# 0.6                 -0.6                 30                                4
# 0.3                 -0.4                 20                                4
# 0.4                 -0.5                 20                                4
# 0.3                 -0.5                 20                                4
#                     -0.3                 20                                4
# 0.4                 -0.4                 20                                4
#                     -0.6                 20                                4
#
#                                                          max_drawdown_percent  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.5                 30                                20
# 0.3                 -0.4                 30                                22
# 0.4                 -0.4                 30                                24
# 0.3                 -0.5                 30                                20
#                     -0.3                 30                                22
# 0.4                 -0.3                 30                                26
#                     -0.6                 30                                 8
# 0.5                 -0.5                 30                                22
#                     -0.6                 30                                 8
# 0.3                 -0.6                 30                                 6
# 0.4                 -0.5                 25                                18
# 0.3                 -0.4                 25                                20
# 0.5                 -0.4                 30                                28
# 0.4                 -0.4                 25                                22
# 0.3                 -0.5                 25                                18
#                     -0.3                 25                                20
# 0.4                 -0.3                 25                                24
#                     -0.6                 25                                 8
# 0.5                 -0.3                 30                                30
#                     -0.5                 25                                20
#                     -0.6                 25                                 8
# 0.3                 -0.6                 25                                 6
# 0.5                 -0.4                 25                                24
# 0.6                 -0.6                 30                                18
# 0.3                 -0.4                 20                                16
# 0.4                 -0.5                 20                                16
# 0.3                 -0.5                 20                                16
#                     -0.3                 20                                18
# 0.4                 -0.4                 20                                18
#                     -0.6                 20                                 6
#
#                                                          max_drawdown_value  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.5                 30                            3794
# 0.3                 -0.4                 30                            3866
# 0.4                 -0.4                 30                            4154
# 0.3                 -0.5                 30                            3794
#                     -0.3                 30                            4100
# 0.4                 -0.3                 30                            4422
#                     -0.6                 30                            3140
# 0.5                 -0.5                 30                            3794
#                     -0.6                 30                            2710
# 0.3                 -0.6                 30                            3032
# 0.4                 -0.5                 25                            3162
# 0.3                 -0.4                 25                            3222
# 0.5                 -0.4                 30                            4304
# 0.4                 -0.4                 25                            3462
# 0.3                 -0.5                 25                            3162
#                     -0.3                 25                            3416
# 0.4                 -0.3                 25                            3686
#                     -0.6                 25                            2616
# 0.5                 -0.3                 30                            4532
#                     -0.5                 25                            3162
#                     -0.6                 25                            2258
# 0.3                 -0.6                 25                            2526
# 0.5                 -0.4                 25                            3586
# 0.6                 -0.6                 30                            3332
# 0.3                 -0.4                 20                            2578
# 0.4                 -0.5                 20                            2530
# 0.3                 -0.5                 20                            2530
#                     -0.3                 20                            2734
# 0.4                 -0.4                 20                            2770
#                     -0.6                 20                            2094
#
#                                                          max_drawdown_len  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.5                 30                          1098
# 0.3                 -0.4                 30                          1238
# 0.4                 -0.4                 30                          1814
# 0.3                 -0.5                 30                           906
#                     -0.3                 30                          1502
# 0.4                 -0.3                 30                          1802
#                     -0.6                 30                           686
# 0.5                 -0.5                 30                          1454
#                     -0.6                 30                           782
# 0.3                 -0.6                 30                           680
# 0.4                 -0.5                 25                          1098
# 0.3                 -0.4                 25                          1238
# 0.5                 -0.4                 30                          2562
# 0.4                 -0.4                 25                          1814
# 0.3                 -0.5                 25                           906
#                     -0.3                 25                          1502
# 0.4                 -0.3                 25                          1802
#                     -0.6                 25                           686
# 0.5                 -0.3                 30                          2564
#                     -0.5                 25                          1454
#                     -0.6                 25                           850
# 0.3                 -0.6                 25                           680
# 0.5                 -0.4                 25                          2562
# 0.6                 -0.6                 30                          2000
# 0.3                 -0.4                 20                          1238
# 0.4                 -0.5                 20                          1098
# 0.3                 -0.5                 20                           906
#                     -0.3                 20                          1502
# 0.4                 -0.4                 20                          1814
#                     -0.6                 20                           686
#
#                                                          avg_lost_amount  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.5                 30                       -270.0
# 0.3                 -0.4                 30                       -238.0
# 0.4                 -0.4                 30                       -262.0
# 0.3                 -0.5                 30                       -256.0
#                     -0.3                 30                       -230.0
# 0.4                 -0.3                 30                       -262.0
#                     -0.6                 30                       -340.0
# 0.5                 -0.5                 30                       -354.0
#                     -0.6                 30                       -370.0
# 0.3                 -0.6                 30                       -344.0
# 0.4                 -0.5                 25                       -224.0
# 0.3                 -0.4                 25                       -198.0
# 0.5                 -0.4                 30                       -348.0
# 0.4                 -0.4                 25                       -218.0
# 0.3                 -0.5                 25                       -214.0
#                     -0.3                 25                       -190.0
# 0.4                 -0.3                 25                       -218.0
#                     -0.6                 25                       -278.0
# 0.5                 -0.3                 30                       -328.0
#                     -0.5                 25                       -294.0
#                     -0.6                 25                       -304.0
# 0.3                 -0.6                 25                       -284.0
# 0.5                 -0.4                 25                       -290.0
# 0.6                 -0.6                 30                       -444.0
# 0.3                 -0.4                 20                       -158.0
# 0.4                 -0.5                 20                       -180.0
# 0.3                 -0.5                 20                       -172.0
#                     -0.3                 20                       -150.0
# 0.4                 -0.4                 20                       -174.0
#                     -0.6                 20                       -220.0
#
#                                                          max_lost_amount
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.5                 30                        -2796
# 0.3                 -0.4                 30                        -3102
# 0.4                 -0.4                 30                        -3102
# 0.3                 -0.5                 30                        -2796
#                     -0.3                 30                        -3154
# 0.4                 -0.3                 30                        -3154
#                     -0.6                 30                        -1348
# 0.5                 -0.5                 30                        -2686
#                     -0.6                 30                        -1348
# 0.3                 -0.6                 30                        -1640
# 0.4                 -0.5                 25                        -2330
# 0.3                 -0.4                 25                        -2584
# 0.5                 -0.4                 30                        -2990
# 0.4                 -0.4                 25                        -2584
# 0.3                 -0.5                 25                        -2330
#                     -0.3                 25                        -2628
# 0.4                 -0.3                 25                        -2628
#                     -0.6                 25                        -1124
# 0.5                 -0.3                 30                        -3042
#                     -0.5                 25                        -2238
#                     -0.6                 25                        -1124
# 0.3                 -0.6                 25                        -1366
# 0.5                 -0.4                 25                        -2492
# 0.6                 -0.6                 30                        -1370
# 0.3                 -0.4                 20                        -2068
# 0.4                 -0.5                 20                        -1864
# 0.3                 -0.5                 20                        -1864
#                     -0.3                 20                        -2102
# 0.4                 -0.4                 20                        -2068
#                     -0.6                 20                         -898

# %%
top_performing_param.sort_values(by='max_drawdown_value', ascending=True) # lesser drawdown
# Out:
#                                                          final_portfolio_value  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.6                 20                      248108.376408
# 0.5                 -0.6                 25                      288416.753363
# 0.3                 -0.6                 25                      285781.209057
#                     -0.5                 20                      261438.903050
# 0.4                 -0.5                 20                      264150.769817
# 0.3                 -0.4                 20                      265596.178094
# 0.4                 -0.6                 25                      302612.741002
# 0.5                 -0.6                 30                      342272.750257
# 0.3                 -0.3                 20                      260515.716435
# 0.4                 -0.4                 20                      260190.588094
# 0.3                 -0.6                 30                      339102.624180
# 0.4                 -0.6                 30                      358065.101090
# 0.5                 -0.5                 25                      289486.796518
# 0.3                 -0.5                 25                      314770.088170
# 0.4                 -0.5                 25                      325511.399987
# 0.3                 -0.4                 25                      323278.805046
# 0.6                 -0.6                 30                      266820.601861
# 0.3                 -0.3                 25                      314680.334908
# 0.4                 -0.4                 25                      320244.610303
# 0.5                 -0.4                 25                      269441.419514
# 0.4                 -0.3                 25                      303376.886405
# 0.5                 -0.5                 30                      342466.275412
# 0.3                 -0.5                 30                      374783.692354
# 0.4                 -0.5                 30                      386127.064512
# 0.3                 -0.4                 30                      382489.577728
#                     -0.3                 30                      374231.539454
# 0.4                 -0.4                 30                      381768.230982
# 0.5                 -0.4                 30                      321329.703417
# 0.4                 -0.3                 30                      359918.778656
# 0.5                 -0.3                 30                      294362.720199
#
#                                                          total_trade  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.6                 20                    966.0
# 0.5                 -0.6                 25                    786.0
# 0.3                 -0.6                 25                   1068.0
#                     -0.5                 20                   1662.0
# 0.4                 -0.5                 20                   1398.0
# 0.3                 -0.4                 20                   2142.0
# 0.4                 -0.6                 25                    956.0
# 0.5                 -0.6                 30                    778.0
# 0.3                 -0.3                 20                   2534.0
# 0.4                 -0.4                 20                   1720.0
# 0.3                 -0.6                 30                   1060.0
# 0.4                 -0.6                 30                    948.0
# 0.5                 -0.5                 25                   1024.0
# 0.3                 -0.5                 25                   1622.0
# 0.4                 -0.5                 25                   1390.0
# 0.3                 -0.4                 25                   2106.0
# 0.6                 -0.6                 30                    514.0
# 0.3                 -0.3                 25                   2470.0
# 0.4                 -0.4                 25                   1702.0
# 0.5                 -0.4                 25                   1188.0
# 0.4                 -0.3                 25                   1920.0
# 0.5                 -0.5                 30                   1020.0
# 0.3                 -0.5                 30                   1618.0
# 0.4                 -0.5                 30                   1378.0
# 0.3                 -0.4                 30                   2088.0
#                     -0.3                 30                   2456.0
# 0.4                 -0.4                 30                   1696.0
# 0.5                 -0.4                 30                   1188.0
# 0.4                 -0.3                 30                   1910.0
# 0.5                 -0.3                 30                   1284.0
#
#                                                          total_pnl  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.6                 20                 238108
# 0.5                 -0.6                 25                 278418
# 0.3                 -0.6                 25                 275782
#                     -0.5                 20                 251440
# 0.4                 -0.5                 20                 254152
# 0.3                 -0.4                 20                 255596
# 0.4                 -0.6                 25                 292614
# 0.5                 -0.6                 30                 332274
# 0.3                 -0.3                 20                 250516
# 0.4                 -0.4                 20                 250192
# 0.3                 -0.6                 30                 329104
# 0.4                 -0.6                 30                 348066
# 0.5                 -0.5                 25                 279488
# 0.3                 -0.5                 25                 304770
# 0.4                 -0.5                 25                 315512
# 0.3                 -0.4                 25                 313280
# 0.6                 -0.6                 30                 255858
# 0.3                 -0.3                 25                 304680
# 0.4                 -0.4                 25                 310246
# 0.5                 -0.4                 25                 259442
# 0.4                 -0.3                 25                 293378
# 0.5                 -0.5                 30                 332466
# 0.3                 -0.5                 30                 364784
# 0.4                 -0.5                 30                 376128
# 0.3                 -0.4                 30                 372490
#                     -0.3                 30                 364232
# 0.4                 -0.4                 30                 371768
# 0.5                 -0.4                 30                 311330
# 0.4                 -0.3                 30                 349920
# 0.5                 -0.3                 30                 284364
#
#                                                          longest_won_streak  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.6                 20                            30.0
# 0.5                 -0.6                 25                            22.0
# 0.3                 -0.6                 25                            32.0
#                     -0.5                 20                            22.0
# 0.4                 -0.5                 20                            28.0
# 0.3                 -0.4                 20                            26.0
# 0.4                 -0.6                 25                            30.0
# 0.5                 -0.6                 30                            22.0
# 0.3                 -0.3                 20                            26.0
# 0.4                 -0.4                 20                            24.0
# 0.3                 -0.6                 30                            32.0
# 0.4                 -0.6                 30                            30.0
# 0.5                 -0.5                 25                            26.0
# 0.3                 -0.5                 25                            22.0
# 0.4                 -0.5                 25                            28.0
# 0.3                 -0.4                 25                            26.0
# 0.6                 -0.6                 30                            26.0
# 0.3                 -0.3                 25                            26.0
# 0.4                 -0.4                 25                            24.0
# 0.5                 -0.4                 25                            30.0
# 0.4                 -0.3                 25                            26.0
# 0.5                 -0.5                 30                            26.0
# 0.3                 -0.5                 30                            22.0
# 0.4                 -0.5                 30                            28.0
# 0.3                 -0.4                 30                            26.0
#                     -0.3                 30                            26.0
# 0.4                 -0.4                 30                            24.0
# 0.5                 -0.4                 30                            30.0
# 0.4                 -0.3                 30                            26.0
# 0.5                 -0.3                 30                            32.0
#
#                                                          longest_lost_streak  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.6                 20                                4
# 0.5                 -0.6                 25                                4
# 0.3                 -0.6                 25                                4
#                     -0.5                 20                                4
# 0.4                 -0.5                 20                                4
# 0.3                 -0.4                 20                                4
# 0.4                 -0.6                 25                                4
# 0.5                 -0.6                 30                                2
# 0.3                 -0.3                 20                                4
# 0.4                 -0.4                 20                                4
# 0.3                 -0.6                 30                                4
# 0.4                 -0.6                 30                                4
# 0.5                 -0.5                 25                                2
# 0.3                 -0.5                 25                                4
# 0.4                 -0.5                 25                                4
# 0.3                 -0.4                 25                                4
# 0.6                 -0.6                 30                                4
# 0.3                 -0.3                 25                                4
# 0.4                 -0.4                 25                                4
# 0.5                 -0.4                 25                                4
# 0.4                 -0.3                 25                                4
# 0.5                 -0.5                 30                                2
# 0.3                 -0.5                 30                                4
# 0.4                 -0.5                 30                                4
# 0.3                 -0.4                 30                                4
#                     -0.3                 30                                4
# 0.4                 -0.4                 30                                4
# 0.5                 -0.4                 30                                4
# 0.4                 -0.3                 30                                4
# 0.5                 -0.3                 30                                4
#
#                                                          max_drawdown_percent  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.6                 20                                 6
# 0.5                 -0.6                 25                                 8
# 0.3                 -0.6                 25                                 6
#                     -0.5                 20                                16
# 0.4                 -0.5                 20                                16
# 0.3                 -0.4                 20                                16
# 0.4                 -0.6                 25                                 8
# 0.5                 -0.6                 30                                 8
# 0.3                 -0.3                 20                                18
# 0.4                 -0.4                 20                                18
# 0.3                 -0.6                 30                                 6
# 0.4                 -0.6                 30                                 8
# 0.5                 -0.5                 25                                20
# 0.3                 -0.5                 25                                18
# 0.4                 -0.5                 25                                18
# 0.3                 -0.4                 25                                20
# 0.6                 -0.6                 30                                18
# 0.3                 -0.3                 25                                20
# 0.4                 -0.4                 25                                22
# 0.5                 -0.4                 25                                24
# 0.4                 -0.3                 25                                24
# 0.5                 -0.5                 30                                22
# 0.3                 -0.5                 30                                20
# 0.4                 -0.5                 30                                20
# 0.3                 -0.4                 30                                22
#                     -0.3                 30                                22
# 0.4                 -0.4                 30                                24
# 0.5                 -0.4                 30                                28
# 0.4                 -0.3                 30                                26
# 0.5                 -0.3                 30                                30
#
#                                                          max_drawdown_value  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.6                 20                            2094
# 0.5                 -0.6                 25                            2258
# 0.3                 -0.6                 25                            2526
#                     -0.5                 20                            2530
# 0.4                 -0.5                 20                            2530
# 0.3                 -0.4                 20                            2578
# 0.4                 -0.6                 25                            2616
# 0.5                 -0.6                 30                            2710
# 0.3                 -0.3                 20                            2734
# 0.4                 -0.4                 20                            2770
# 0.3                 -0.6                 30                            3032
# 0.4                 -0.6                 30                            3140
# 0.5                 -0.5                 25                            3162
# 0.3                 -0.5                 25                            3162
# 0.4                 -0.5                 25                            3162
# 0.3                 -0.4                 25                            3222
# 0.6                 -0.6                 30                            3332
# 0.3                 -0.3                 25                            3416
# 0.4                 -0.4                 25                            3462
# 0.5                 -0.4                 25                            3586
# 0.4                 -0.3                 25                            3686
# 0.5                 -0.5                 30                            3794
# 0.3                 -0.5                 30                            3794
# 0.4                 -0.5                 30                            3794
# 0.3                 -0.4                 30                            3866
#                     -0.3                 30                            4100
# 0.4                 -0.4                 30                            4154
# 0.5                 -0.4                 30                            4304
# 0.4                 -0.3                 30                            4422
# 0.5                 -0.3                 30                            4532
#
#                                                          max_drawdown_len  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.6                 20                           686
# 0.5                 -0.6                 25                           850
# 0.3                 -0.6                 25                           680
#                     -0.5                 20                           906
# 0.4                 -0.5                 20                          1098
# 0.3                 -0.4                 20                          1238
# 0.4                 -0.6                 25                           686
# 0.5                 -0.6                 30                           782
# 0.3                 -0.3                 20                          1502
# 0.4                 -0.4                 20                          1814
# 0.3                 -0.6                 30                           680
# 0.4                 -0.6                 30                           686
# 0.5                 -0.5                 25                          1454
# 0.3                 -0.5                 25                           906
# 0.4                 -0.5                 25                          1098
# 0.3                 -0.4                 25                          1238
# 0.6                 -0.6                 30                          2000
# 0.3                 -0.3                 25                          1502
# 0.4                 -0.4                 25                          1814
# 0.5                 -0.4                 25                          2562
# 0.4                 -0.3                 25                          1802
# 0.5                 -0.5                 30                          1454
# 0.3                 -0.5                 30                           906
# 0.4                 -0.5                 30                          1098
# 0.3                 -0.4                 30                          1238
#                     -0.3                 30                          1502
# 0.4                 -0.4                 30                          1814
# 0.5                 -0.4                 30                          2562
# 0.4                 -0.3                 30                          1802
# 0.5                 -0.3                 30                          2564
#
#                                                          avg_lost_amount  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.6                 20                       -220.0
# 0.5                 -0.6                 25                       -304.0
# 0.3                 -0.6                 25                       -284.0
#                     -0.5                 20                       -172.0
# 0.4                 -0.5                 20                       -180.0
# 0.3                 -0.4                 20                       -158.0
# 0.4                 -0.6                 25                       -278.0
# 0.5                 -0.6                 30                       -370.0
# 0.3                 -0.3                 20                       -150.0
# 0.4                 -0.4                 20                       -174.0
# 0.3                 -0.6                 30                       -344.0
# 0.4                 -0.6                 30                       -340.0
# 0.5                 -0.5                 25                       -294.0
# 0.3                 -0.5                 25                       -214.0
# 0.4                 -0.5                 25                       -224.0
# 0.3                 -0.4                 25                       -198.0
# 0.6                 -0.6                 30                       -444.0
# 0.3                 -0.3                 25                       -190.0
# 0.4                 -0.4                 25                       -218.0
# 0.5                 -0.4                 25                       -290.0
# 0.4                 -0.3                 25                       -218.0
# 0.5                 -0.5                 30                       -354.0
# 0.3                 -0.5                 30                       -256.0
# 0.4                 -0.5                 30                       -270.0
# 0.3                 -0.4                 30                       -238.0
#                     -0.3                 30                       -230.0
# 0.4                 -0.4                 30                       -262.0
# 0.5                 -0.4                 30                       -348.0
# 0.4                 -0.3                 30                       -262.0
# 0.5                 -0.3                 30                       -328.0
#
#                                                          max_lost_amount
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.6                 20                         -898
# 0.5                 -0.6                 25                        -1124
# 0.3                 -0.6                 25                        -1366
#                     -0.5                 20                        -1864
# 0.4                 -0.5                 20                        -1864
# 0.3                 -0.4                 20                        -2068
# 0.4                 -0.6                 25                        -1124
# 0.5                 -0.6                 30                        -1348
# 0.3                 -0.3                 20                        -2102
# 0.4                 -0.4                 20                        -2068
# 0.3                 -0.6                 30                        -1640
# 0.4                 -0.6                 30                        -1348
# 0.5                 -0.5                 25                        -2238
# 0.3                 -0.5                 25                        -2330
# 0.4                 -0.5                 25                        -2330
# 0.3                 -0.4                 25                        -2584
# 0.6                 -0.6                 30                        -1370
# 0.3                 -0.3                 25                        -2628
# 0.4                 -0.4                 25                        -2584
# 0.5                 -0.4                 25                        -2492
# 0.4                 -0.3                 25                        -2628
# 0.5                 -0.5                 30                        -2686
# 0.3                 -0.5                 30                        -2796
# 0.4                 -0.5                 30                        -2796
# 0.3                 -0.4                 30                        -3102
#                     -0.3                 30                        -3154
# 0.4                 -0.4                 30                        -3102
# 0.5                 -0.4                 30                        -2990
# 0.4                 -0.3                 30                        -3154
# 0.5                 -0.3                 30                        -3042

# %%
htmap = data.groupby(['trade_buy_threshold', 'trade_sell_threshold']).agg({
    'final_portfolio_value': 'mean'
}).pivot_table(index=['trade_buy_threshold'], columns='trade_sell_threshold', values='final_portfolio_value')
sns.heatmap(htmap)
plt.show()

# %%
simulate_strategy(data.loc[37])
# Out:
# CommandException: No URLs matched: /tmp/binance_BTCUSDT_15m_2023-09-09
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# <ipython-input-15-81e937b76d41>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   