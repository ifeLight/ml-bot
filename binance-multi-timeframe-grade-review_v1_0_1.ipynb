# %% [markdown]
# <a href="https://colab.research.google.com/github/ifeLight/ml-bot/blob/main/binance-multi-timeframe-grade-review_v1_0_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas-ta
# !pip install backtrader[plotting]
# !pip install plotly
# !pip install --upgrade firebase-admin
# Out:
# Collecting pandas-ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from pandas-ta) (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas-ta) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas-ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas-ta) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas-ta) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->pandas-ta) (1.17.0)
# Building wheels for collected packages: pandas-ta
#   Building wheel for pandas-ta (setup.py) ... done
#   Created wheel for pandas-ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218909 sha256=8d2cd997994680f23624def8c16ce7fdb4342bd54f7e10bdc6347d5316c8249a
#   Stored in directory: /root/.cache/pip/wheels/7f/33/8b/50b245c5c65433cd8f5cb24ac15d97e5a3db2d41a8b6ae957d
# Successfully built pandas-ta
# Installing collected packages: pandas-ta
# Successfully installed pandas-ta-0.3.14b0
# Collecting backtrader[plotting]
#   Downloading backtrader-1.9.78.123-py2.py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from backtrader[plotting]) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->backtrader[plotting]) (1.17.0)
# Downloading backtrader-1.9.78.123-py2.py3-none-any.whl (419 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 6.5 MB/s eta 0:00:00
# Installing collected packages: backtrader
# Successfully installed backtrader-1.9.78.123
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)
# Requirement already satisfied: firebase-admin in /usr/local/lib/python3.11/dist-packages (6.6.0)
# Requirement already satisfied: cachecontrol>=0.12.14 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (0.14.2)
# Requirement already satisfied: google-api-python-client>=1.7.8 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (2.160.0)
# Requirement already satisfied: google-cloud-storage>=1.37.1 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (2.19.0)
# Requirement already satisfied: pyjwt>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (2.10.1)
# Requirement already satisfied: google-api-core<3.0.0dev,>=1.22.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.24.1)
# Requirement already satisfied: google-cloud-firestore>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (2.20.1)
# Requirement already satisfied: requests>=2.16.0 in /usr/local/lib/python3.11/dist-packages (from cachecontrol>=0.12.14->firebase-admin) (2.32.3)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in /usr/local/lib/python3.11/dist-packages (from cachecontrol>=0.12.14->firebase-admin) (1.1.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.69.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (4.25.6)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.26.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.38.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.62.3)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (4.1.1)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from google-cloud-firestore>=2.19.0->firebase-admin) (2.4.2)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage>=1.37.1->firebase-admin) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage>=1.37.1->firebase-admin) (1.6.0)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (1.17.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client>=1.7.8->firebase-admin) (3.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (2025.1.31)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.6.1)

# %%
import numpy as np
import pandas as pd
import datetime
import requests
import json
import os
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import backtrader as bt
import pandas_ta as ta
from imblearn.over_sampling import SMOTE
import subprocess
import firebase_admin
from firebase_admin import firestore
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
from google.colab import auth
import google.auth
import itertools
import hashlib

# %%
auth.authenticate_user()
#Configure Google cloud project
project_id = 'ifelight'
# !gcloud config set project {project_id}
# Out:
# Updated property [core/project].

# %%
# Working GCP Bucket name
bucket_name = 'ife-storage'
# Working on Firestore name
firestore_collection_name = 'trade-models'

# %%
binance_base_url = 'https://52on3577u3.execute-api.eu-central-1.amazonaws.com'

def get_binance_candles(symbol: str, interval='1h', limit: int = 50, **kwargs):
    url = f'{binance_base_url}/api/v3/uiKlines?symbol={symbol}&interval={interval}&limit={limit}'
    for key, value in kwargs.items():
        url += f'&{key}={value}'
    response = requests.get(url)
    result = json.loads(response.text)
    # print(result)
    def map_result(x):
        return {
            'Date': x[0],
            'Open': x[1],
            'High': x[2],
            'Low': x[3],
            'Close': x[4],
            'Volume': x[5],
        }
    mappeded_result = []
    for x in result:
        mappeded_result.append(map_result(x))
    return mappeded_result


def candles_to_df(data):
    df =  pd.DataFrame(data)
    df['Date'] = pd.to_datetime(df['Date'], unit='ms')
    df['Open'] = df['Open'].astype(float)
    df['High'] = df['High'].astype(float)
    df['Low'] = df['Low'].astype(float)
    df['Close'] = df['Close'].astype(float)
    df['Volume'] = df['Volume'].astype(float)
    df.set_index('Date', inplace=True)
    return df

def get_all_binance_candles(symbol: str, interval='1h', start_date=None, end_date=None, limit=1000):
  try:
    return load_candles_from_cloud_storage(symbol, interval, start_date, end_date)
  except FileNotFoundError:
    pass
  result = []
  raw_start_date = start_date
  raw_end_date = end_date
  start_date = pd.to_datetime(start_date) if start_date else pd.to_datetime('2015-01-01')
  end_date = pd.to_datetime(end_date) if end_date else pd.to_datetime('today')
  while True:
    candles = get_binance_candles(symbol, interval, limit, startTime=int(start_date.timestamp() * 1000), endTime=int(end_date.timestamp() * 1000))
    if len(candles) <= 1:
      break;
    result += candles
    start_date = pd.to_datetime(datetime.datetime.fromtimestamp(candles[-1]['Date'] / 1000))
  candles_df = candles_to_df(result)
  save_candles_to_cloud_storage(candles_df, symbol, interval, raw_start_date, raw_end_date)
  return candles_df

def candles_storage_file_name(symbol: str, interval='1h', start_date=None, end_date=None):
  file_name = f'binance_{symbol}_{interval}_{start_date}_{end_date}.csv'
  return file_name

def load_candles_from_cloud_storage(symbol: str, interval: str, start_date=None, end_date=None):
  file_name = candles_storage_file_name(symbol, interval, start_date, end_date)
  try:
    # Download the file from cloud storage.
    subprocess.run(['gsutil', 'cp', f'gs://{bucket_name}/trade/candles/{file_name}', f'/tmp/{file_name}'], check=True)

    # Load the data into a Pandas DataFrame.
    with open(f'/tmp/{file_name}', 'r') as f:
      return pd.read_csv(f, index_col=0, parse_dates=True)
  except subprocess.CalledProcessError:
    # Raise a FileNotFoundError if the file is not found in cloud storage.
    raise FileNotFoundError(f"File not found: gs://{bucket_name}/trade/candles/{file_name}")

def save_candles_to_cloud_storage(df: pd.DataFrame, symbol: str, interval: str, start_date, end_date):
  file_name = candles_storage_file_name(symbol, interval, start_date, end_date)
  df.to_csv(f'/tmp/{file_name}')
  # !gsutil cp /tmp/{file_name} gs://{bucket_name}/trade/candles/{file_name}

# %%
def add_scaled_rsi(df, window=14, prefix = '', features_columns=[]):
  series = ta.rsi(df['Close'], length=window)
  column_name = f"{prefix}RSI_{window}"
  df[column_name] = series / 100
  if(column_name not in features_columns):
    features_columns.append(column_name)
  return df

def add_scaled_ema(df, window=50, prefix = '', features_columns=[]):
  series = ta.ema(df['Close'], length=window)
  column_name = f"{prefix}EMA_{window}"
  df[column_name] = series / df['Close']
  if column_name not in features_columns:
    features_columns.append(column_name)
  return df

def add_scaled_sma(df, window=50, prefix = '', features_columns=[]):
  series = ta.sma(df['Close'], length=window)
  column_name = f"{prefix}SMA_{window}"
  df[column_name] = series / df['Close']
  if column_name not in features_columns:
    features_columns.append(column_name)
  return df

def add_scaled_macd(df, prefix= '', features_columns=[], fast = 12, slow = 26, signal=9):
  macd_df = ta.macd(df['Close'], fast=fast, slow=slow, signal=signal)
  suffix = f"{fast}_{slow}_{signal}"
  macd_column_name = f"{prefix}MACD_{suffix}"
  macds_column_name = f"{prefix}MACDs_{suffix}"
  macdh_column_name = f"{prefix}MACDh_{suffix}"
  df[macd_column_name] = macd_df[macd_df.columns[0]] / df['Close']
  df[macds_column_name] = macd_df[macd_df.columns[2]] / df['Close']
  df[macdh_column_name] = macd_df[macd_df.columns[1]] / df['Close']
  if macd_column_name not in features_columns:
    features_columns.append(macd_column_name)
  if macds_column_name not in features_columns:
    features_columns.append(macds_column_name)
  if macdh_column_name not in features_columns:
    features_columns.append(macdh_column_name)
  return df

def add_scaled_bbands(df, window=20, std=2.0, prefix= '', features_columns=[]):
  bbands_df = ta.bbands(df['Close'], length=window, std=std)
  suffix = f"{window}_{std}"
  bbl_column_name = f"{prefix}BBL_{suffix}"
  bbm_column_name = f"{prefix}BBM_{suffix}"
  bbu_column_name = f"{prefix}BBU_{suffix}"
  bbb_column_name = f"{prefix}BBB_{suffix}"
  bbp_column_name = f"{prefix}BBP_{suffix}"
  df[bbl_column_name] = bbands_df[bbands_df.columns[0]] / df['Close']
  df[bbm_column_name] = bbands_df[bbands_df.columns[1]] / df['Close']
  df[bbu_column_name] = bbands_df[bbands_df.columns[2]] / df['Close']
  df[bbb_column_name] = bbands_df[bbands_df.columns[3]]
  df[bbp_column_name] = bbands_df[bbands_df.columns[4]]
  if bbl_column_name not in features_columns: features_columns.append(bbl_column_name)
  if bbm_column_name not in features_columns: features_columns.append(bbm_column_name)
  if bbu_column_name not in features_columns: features_columns.append(bbu_column_name)
  if bbb_column_name not in features_columns: features_columns.append(bbb_column_name)
  if bbp_column_name not in features_columns: features_columns.append(bbp_column_name)
  return df

# %%
def merge_candlesticks_data(df1, df2):
  """
  Merges two candlestick DataFrames with forward fill, handling different timeframes,
  and prevents duplicate OHLCV columns.
  Ensure both DataFrames have a datetime index.
  And ensure the second DataFrame is the larger timeframe

  Args:
      df1: First candlestick DataFrame with datetime index.
      df2: Second candlestick DataFrame with datetime index.

  Returns:
      Merged DataFrame with forward-filled values, and no duplicate OHLCV columns.
  """
  # Ensure both DataFrames have a datetime index
  if not isinstance(df1.index, pd.DatetimeIndex) or not isinstance(df2.index, pd.DatetimeIndex):
      raise ValueError("DataFrames must have a datetime index.")
  # Identify OHLCV columns
  ohlcv_cols = ['open', 'high', 'low', 'close', 'volume']

  # Rename columns in df2 that conflict with df1's OHLCV columns
  for col in df2.columns:
    if col.lower() in ohlcv_cols and col.lower() in df1.columns.str.lower():
      del df2[col]

  # Merge the DataFrames using outer join, which preserves all dates
  merged_df = pd.merge(df1, df2, how='outer', left_index=True, right_index=True, suffixes=('_df1', '_df2'))

  # Forward fill the missing values for each column
  for col in merged_df.columns:
    merged_df[col] = merged_df[col].ffill()

  return merged_df

# %%
def resample_candles(df, interval='1h'):
    return df.resample(interval).agg({'Open': 'first', 'High': 'max', 'Low': 'min', 'Close': 'last', 'Volume': 'sum'}).ffill()

# %%
def predict_in_batches(model, test_data, features_columns, seq_length, batch_size=128):
    """
    Predicts in batches to speed up inference.
    """
    num_samples = len(test_data) - seq_length
    feature_array = test_data[features_columns].values
    predicted_values = np.full(len(test_data), np.nan)

    for start_idx in range(0, num_samples, batch_size):
        end_idx = min(start_idx + batch_size, num_samples)
        batch_indices = range(start_idx + seq_length, end_idx + seq_length)
        batch_input = np.array([feature_array[i - seq_length:i] for i in batch_indices])

        if len(batch_input) > 0 :
            predictions = model.predict(batch_input, verbose=0)
            predicted_values[batch_indices] = predictions.flatten() #Flatten to 1d array.

    test_data['Predicted_Value'] = predicted_values
    return test_data

# %%
class PredictedValueStrategy(bt.Strategy):
    params = (
        ('buy_threshold', 0.6),
        ('sell_threshold', 0.6),
        ('leverage', 1),  # Leverage ratio
        ('margin', 1000),
        ('log', True)
    )

    def __init__(self):
        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None

        # Add the Predicted_Value as a data feed
        self.predicted_value = self.datas[0].predicted_value

    def next(self):
        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return
         # # Check if we are in the market
        if not self.position:
          cash = self.broker.getcash()
          position_size = (self.params.margin * self.params.leverage) / self.data.close[0]
          # Long signal
          if self.predicted_value[0] > self.params.buy_threshold:
            self.log('LONG POSITION CREATED, %.2f' % self.datas[0].close[0])
            self.order = self.buy(size=position_size)

          # Short signal
          elif self.predicted_value[0] < self.params.sell_threshold:
            self.log('SHORT POSITION CREATED, %.2f' % self.datas[0].close[0])
            self.order = self.sell(size=position_size)

        else:
          if self.predicted_value[0] > self.params.buy_threshold and self.position.size < 0:
            self.log('CLOSE SHORT POSITION CREATED, %.2f' % self.datas[0].close[0])
            self.order = self.close()
          elif self.predicted_value[0] < self.params.sell_threshold and self.position.size > 0:
            self.log('CLOSE LONG POSITION CREATED, %.2f' % self.datas[0].close[0])
            self.order = self.close()

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return
        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY EXECUTED, %.2f' % order.executed.price)
            elif order.issell():
                self.log('SELL EXECUTED, %.2f' % order.executed.price)
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            if order.status == order.Canceled:
                self.log('Order Canceled')
            elif order.status == order.Margin:
                self.log(f'Order Margin Not Enough - Available cash: {self.broker.getcash()}')
            elif order.status == order.Rejected:
                self.log('Order Rejected')

        # Write down: no pending order
        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        self.log(f'TRADE COMPLETED, GROSS {trade.pnl:.2f}, NET {trade.pnlcomm:.2f}, Available Cash {self.broker.getcash():.2f}')

    def log(self, txt, dt=None):
        if not self.params.log:
          return
        dt = dt or self.datas[0].datetime.date(0)
        time = self.datas[0].datetime.time()
        print(f'{dt.isoformat()} {time.isoformat()}, {txt}')

# %%
# Extend PandasData to include the custom column
class CustomPandasData(bt.feeds.PandasData):
    # Add custom columns
    lines = ('predicted_value',)  # Add the custom line
    params = (
        ('predicted_value', 'Predicted_Value'),  # Map the column name
    )

# %%
def get_model_cloud_storage_path(bucket_name, local_file_name):
    """
    Returns the cloud storage path for a given model name.

    Parameters:
        local_file_name (str): The name of the model.

    Returns:
        str: The cloud storage path. (e.g., gs://<bucket_name>/trade/models/<model_name>.h5).
    """
    return f'gs://{bucket_name}/trade/models/{local_file_name}'

def save_model_to_cloud_storage(model: tf.keras.Model, model_name: str, bucket_name: str):
    """
    Saves a TensorFlow model to Google Cloud Storage and returns the cloud storage file path.

    Parameters:
        model (tf.keras.Model): The TensorFlow model to save.
        model_name (str): The name of the model (used to create the file name).
        bucket_name (str): The name of the Google Cloud Storage bucket.

    Returns:
        str: The cloud storage file path (e.g., gs://<bucket_name>/trade/models/<model_name>.h5).
    """
    # Define the local and cloud storage file paths
    local_file_name = f'{model_name}.h5'
    local_file_path = f'/tmp/{local_file_name}'
    cloud_file_path = get_model_cloud_storage_path(bucket_name, local_file_name)

    # Save the model locally
    model.save(local_file_path)

    try:
        # Upload the model to Google Cloud Storage
        subprocess.run(['gsutil', 'cp', local_file_path, cloud_file_path], check=True)
        print(f"Model saved to {cloud_file_path}")
    except subprocess.CalledProcessError as e:
        # Handle errors during the upload process
        raise RuntimeError(f"Failed to upload model to Google Cloud Storage: {e}")
    finally:
        # Clean up the local file
        if os.path.exists(local_file_path):
            os.remove(local_file_path)
    return cloud_file_path

def load_model_from_cloud_storage(model_name: str, bucket_name: str):
    """
    Loads a TensorFlow model from Google Cloud Storage.

    Parameters:
        model_name (str): The name of the model (used to create the file name).
        bucket_name (str): The name of the Google Cloud Storage bucket.

    Returns:
        tf.keras.Model: The loaded TensorFlow model.
    """
    # Define the local and cloud storage file paths
    local_file_name = f'{model_name}.h5'
    local_file_path = f'/tmp/{local_file_name}'
    cloud_file_path = get_model_cloud_storage_path(bucket_name, local_file_name)

    try:
        # Download the model from Google Cloud Storage
        subprocess.run(['gsutil', 'cp', cloud_file_path, local_file_path], check=True)

        # Load the model
        model = tf.keras.models.load_model(local_file_path)
        print(f"Model loaded from {cloud_file_path}")
        return model
    except subprocess.CalledProcessError as e:
        raise FileNotFoundError(f"Model not found in Google Cloud Storage: {e}")
    finally:
        # Clean up the local file
        if os.path.exists(local_file_path):
            os.remove(local_file_path)

# %%
def initialize_firestore(project_id):
    """
    Initialize the Firestore client using the service account key.

    Parameters:
        project_id (str): The Google Cloud project ID.

    Returns:
        firestore.Client: Initialized Firestore client.
    """
    if not firebase_admin._apps:
        # cred = credentials.Certificate(service_account_key_path)
        cred = firebase_admin.credentials.ApplicationDefault()
        cred._project_id = project_id  # Add this line
        os.environ["GOOGLE_CLOUD_PROJECT"] = project_id
        firebase_admin.initialize_app(cred, {'projectId': project_id})
    return firestore.client()


def save_to_firestore(project_id, collection_name, data):
    """
    Save data to a Firestore collection.

    Parameters:
        project_id (str): The Google Cloud project ID.
        service_account_key_path (str): Path to the Firebase service account key JSON file.
        collection_name (str): Name of the Firestore collection.
        data (dict): Data to save in the document.

    Returns:
        None
    """
    # Initialize Firestore client
    db = initialize_firestore(project_id)

    # Save data to Firestore
    doc_ref = db.collection(collection_name).document()
    doc_ref.set(data)
    print(f"Data saved to Firestore: Collection={collection_name}, Document ID={doc_ref.id}")

# %%
def get_nested_value(data, keys):
    """
    Retrieves a deeply nested value from a dictionary or list.

    Args:
        data: The dictionary or list to traverse.
        keys: A list of keys or indices to access the nested value.

    Returns:
        The nested value if found, otherwise None.
    """
    try:
        current_value = data
        for key in keys:
            if isinstance(current_value, dict):
                current_value = current_value.get(key)
            elif isinstance(current_value, list):
                if isinstance(key, int) and 0 <= key < len(current_value):
                    current_value = current_value[key]
                else:
                    return None #invalid index
            else:
                return None #not a dict or list
            if current_value is None:
                return None  # Early exit if any key is missing
        return current_value
    except (TypeError, IndexError, AttributeError, KeyError):
        return None

# %%
trade_models = []
db = initialize_firestore(project_id)
trade_moldel_ref = db.collection('trade-models')
trade_models_stream = (
    trade_moldel_ref.where('version', '==', 'v1_0_1')
    .where('symbol', '==', 'BTCUSDT')
    .where('exchange', '==', 'binance')
    .where('timeframe', '==', '15m')
    .stream()
)
for model in trade_models_stream:
    trade_models.append(model.to_dict())
trade_models
# Out:
# /usr/local/lib/python3.11/dist-packages/google/cloud/firestore_v1/base_collection.py:303: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   return query.where(field_path, op_string, value)
# <ipython-input-15-ac03e80f4af4>:6: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   .where('symbol', '==', 'BTCUSDT')
# <ipython-input-15-ac03e80f4af4>:7: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   .where('exchange', '==', 'binance')
# <ipython-input-15-ac03e80f4af4>:8: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   .where('timeframe', '==', '15m')
# [{'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2019_31-12-2023_09e4f70d.h5',
#   'val_mae': 0.40847355127334595,
#   'training_data_end_date': DatetimeWithNanoseconds(2022, 12, 31, 19, 45, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.6,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 0},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 20,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 14, 41, 20, 581498, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_1',
#   'train_mae': 0.4116671085357666,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_1_15m_01-01-2019_31-12-2023_09e4f70d',
#   'test_data_end_date': DatetimeWithNanoseconds(2023, 12, 30, 17, 30, tzinfo=datetime.timezone.utc),
#   'final_epoch': 6,
#   'val_loss': 0.24270614981651306,
#   'drawdown_analysis': {'len': 32,
#    'drawdown': 2,
#    'max': {'len': 1714, 'drawdown': 24, 'moneydown': 2620},
#    'moneydown': 440},
#   'end_date': '31-12-2023',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 124,
#     'pnl': {'average': 306,
#      'total': 37572,
#      'won': {'total': 46096, 'average': 424, 'max': 1932},
#      'lost': {'total': -8522, 'average': -608, 'max': -1842}},
#     'won': 110,
#     'lost': 14},
#    'total': {'total': 194, 'open': 2, 'closed': 194},
#    'won': {'total': 174, 'pnl': {'average': 432, 'total': 74914, 'max': 3062}},
#    'len': {'short': {'max': 768,
#      'average': 136,
#      'total': 16660,
#      'won': {'total': 14296, 'average': 132, 'min': 10, 'max': 768},
#      'min': 10,
#      'lost': {'total': 2366, 'average': 170, 'min': 48, 'max': 614}},
#     'total': 24088,
#     'average': 126,
#     'won': {'average': 120, 'total': 20800, 'max': 768, 'min': 10},
#     'min': 10,
#     'long': {'max': 574,
#      'average': 106,
#      'total': 7428,
#      'won': {'total': 6506, 'average': 100, 'min': 10, 'max': 574},
#      'min': 10,
#      'lost': {'total': 922, 'average': 184, 'min': 112, 'max': 256}},
#     'max': 768,
#     'lost': {'average': 174, 'total': 3288, 'max': 614, 'min': 48}},
#    'long': {'total': 70,
#     'pnl': {'average': 408,
#      'total': 28460,
#      'won': {'total': 28818, 'average': 444, 'max': 3062},
#      'lost': {'total': -358, 'average': -72, 'max': -140}},
#     'won': 66,
#     'lost': 6},
#    'pnl': {'gross': {'average': 350, 'total': 67574},
#     'net': {'average': 342, 'total': 66032}},
#    'streak': {'won': {'longest': 36, 'current': 6},
#     'lost': {'longest': 2, 'current': 0}},
#    'lost': {'total': 20,
#     'pnl': {'average': -466, 'total': -8882, 'max': -1842}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 1, 1, 21, 0, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.5,
#   'train_loss': 0.2505199909210205,
#   'start_date': '01-01-2019',
#   'final_portfolio_value': 76166.75296276694,
#   'training_data_start_date': DatetimeWithNanoseconds(2019, 1, 4, 8, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2020_30-12-2024_4cc8bc32.h5',
#   'val_mae': 0.4036828577518463,
#   'training_data_end_date': DatetimeWithNanoseconds(2023, 12, 31, 19, 0, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.7,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 0},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 25,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 15, 15, 3, 278650, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_1',
#   'train_mae': 0.3972854018211365,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_1_15m_01-01-2020_30-12-2024_4cc8bc32',
#   'test_data_end_date': DatetimeWithNanoseconds(2024, 12, 29, 21, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24077270925045013,
#   'drawdown_analysis': {'len': 580,
#    'drawdown': 2,
#    'max': {'len': 8018, 'drawdown': 60, 'moneydown': 9008},
#    'moneydown': 302},
#   'end_date': '30-12-2024',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 100,
#     'pnl': {'average': 156,
#      'total': 15488,
#      'won': {'total': 57080, 'average': 866, 'max': 3514},
#      'lost': {'total': -41592, 'average': -1260, 'max': -3032}},
#     'won': 66,
#     'lost': 34},
#    'total': {'total': 126, 'open': 2, 'closed': 126},
#    'won': {'total': 92, 'pnl': {'average': 748, 'total': 68822, 'max': 3514}},
#    'len': {'short': {'max': 1732,
#      'average': 326,
#      'total': 32284,
#      'won': {'total': 19208, 'average': 292, 'min': 8, 'max': 1732},
#      'min': 8,
#      'lost': {'total': 13076, 'average': 396, 'min': 40, 'max': 1252}},
#     'total': 32664,
#     'average': 262,
#     'won': {'average': 214, 'total': 19588, 'max': 1732, 'min': 8},
#     'min': 8,
#     'long': {'max': 42,
#      'average': 16,
#      'total': 380,
#      'won': {'total': 380, 'average': 16, 'min': 8, 'max': 42},
#      'min': 8,
#      'lost': {'total': 0, 'average': 0, 'min': 0, 'max': 0}},
#     'max': 1732,
#     'lost': {'average': 396, 'total': 13076, 'max': 1252, 'min': 40}},
#    'long': {'total': 26,
#     'pnl': {'average': 452,
#      'total': 11744,
#      'won': {'total': 11744, 'average': 452, 'max': 2128},
#      'lost': {'total': 0, 'average': 0, 'max': 0}},
#     'won': 26,
#     'lost': 0},
#    'pnl': {'gross': {'average': 228, 'total': 28480},
#     'net': {'average': 218, 'total': 27230}},
#    'streak': {'won': {'longest': 10, 'current': 6},
#     'lost': {'longest': 2, 'current': 0}},
#    'lost': {'total': 34,
#     'pnl': {'average': -1260, 'total': -41592, 'max': -3032}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2024, 1, 1, 20, 15, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.4,
#   'train_loss': 0.236819788813591,
#   'start_date': '01-01-2020',
#   'final_portfolio_value': 37899.47505871862,
#   'training_data_start_date': DatetimeWithNanoseconds(2020, 1, 4, 8, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d.h5',
#   'val_mae': 0.4045906066894531,
#   'training_data_end_date': DatetimeWithNanoseconds(2021, 2, 15, 13, 30, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.6,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 0},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 25,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 13, 44, 3, 828082, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_1',
#   'train_mae': 0.41433656215667725,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d',
#   'test_data_end_date': DatetimeWithNanoseconds(2021, 12, 30, 19, 30, tzinfo=datetime.timezone.utc),
#   'final_epoch': 7,
#   'val_loss': 0.24152757227420807,
#   'drawdown_analysis': {'len': 272,
#    'drawdown': 0,
#    'max': {'len': 1580, 'drawdown': 30, 'moneydown': 4704},
#    'moneydown': 842},
#   'end_date': '31-12-2021',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 252,
#     'pnl': {'average': 404,
#      'total': 101372,
#      'won': {'total': 145324, 'average': 774, 'max': 3274},
#      'lost': {'total': -43952, 'average': -698, 'max': -3174}},
#     'won': 188,
#     'lost': 64},
#    'total': {'total': 394, 'open': 2, 'closed': 394},
#    'won': {'total': 318,
#     'pnl': {'average': 694, 'total': 219998, 'max': 5500}},
#    'len': {'short': {'max': 390,
#      'average': 88,
#      'total': 21748,
#      'won': {'total': 14554, 'average': 78, 'min': 8, 'max': 390},
#      'min': 8,
#      'lost': {'total': 7194, 'average': 114, 'min': 22, 'max': 358}},
#     'total': 25656,
#     'average': 66,
#     'won': {'average': 56, 'total': 17550, 'max': 390, 'min': 6},
#     'min': 6,
#     'long': {'max': 142,
#      'average': 28,
#      'total': 3908,
#      'won': {'total': 2996, 'average': 24, 'min': 6, 'max': 142},
#      'min': 6,
#      'lost': {'total': 914, 'average': 70, 'min': 48, 'max': 102}},
#     'max': 390,
#     'lost': {'average': 108, 'total': 8108, 'max': 358, 'min': 22}},
#    'long': {'total': 142,
#     'pnl': {'average': 454,
#      'total': 64338,
#      'won': {'total': 74676, 'average': 580, 'max': 5500},
#      'lost': {'total': -10338, 'average': -794, 'max': -2506}},
#     'won': 130,
#     'lost': 14},
#    'pnl': {'gross': {'average': 432, 'total': 169630},
#     'net': {'average': 422, 'total': 165708}},
#    'streak': {'won': {'longest': 22, 'current': 2},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 76,
#     'pnl': {'average': -714, 'total': -54290, 'max': -3174}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2021, 2, 16, 14, 45, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.5,
#   'train_loss': 0.2532379627227783,
#   'start_date': '01-01-2017',
#   'final_portfolio_value': 175261.68436290903,
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d.h5',
#   'val_mae': 0.4045906066894531,
#   'training_data_end_date': DatetimeWithNanoseconds(2021, 2, 15, 13, 30, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.6,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 0},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 10,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 13, 43, 4, 552005, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_1',
#   'train_mae': 0.41433656215667725,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d',
#   'test_data_end_date': DatetimeWithNanoseconds(2021, 12, 30, 19, 30, tzinfo=datetime.timezone.utc),
#   'final_epoch': 7,
#   'val_loss': 0.24152757227420807,
#   'drawdown_analysis': {'len': 78,
#    'drawdown': 0,
#    'max': {'len': 1272, 'drawdown': 10, 'moneydown': 2158},
#    'moneydown': 322},
#   'end_date': '31-12-2021',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 272,
#     'pnl': {'average': 140,
#      'total': 37656,
#      'won': {'total': 58972, 'average': 304, 'max': 1364},
#      'lost': {'total': -21316, 'average': -276, 'max': -1238}},
#     'won': 194,
#     'lost': 78},
#    'total': {'total': 464, 'open': 2, 'closed': 462},
#    'won': {'total': 374, 'pnl': {'average': 254, 'total': 94230, 'max': 2200}},
#    'len': {'short': {'max': 390,
#      'average': 90,
#      'total': 24202,
#      'won': {'total': 15704, 'average': 82, 'min': 8, 'max': 390},
#      'min': 8,
#      'lost': {'total': 8500, 'average': 110, 'min': 20, 'max': 358}},
#     'total': 27654,
#     'average': 60,
#     'won': {'average': 50, 'total': 18500, 'max': 390, 'min': 4},
#     'min': 4,
#     'long': {'max': 100,
#      'average': 18,
#      'total': 3452,
#      'won': {'total': 2798, 'average': 16, 'min': 4, 'max': 88},
#      'min': 4,
#      'lost': {'total': 656, 'average': 56, 'min': 16, 'max': 100}},
#     'max': 390,
#     'lost': {'average': 104, 'total': 9154, 'max': 358, 'min': 16}},
#    'long': {'total': 192,
#     'pnl': {'average': 164,
#      'total': 31146,
#      'won': {'total': 35258, 'average': 198, 'max': 2200},
#      'lost': {'total': -4110, 'average': -342, 'max': -1190}},
#     'won': 180,
#     'lost': 12},
#    'pnl': {'gross': {'average': 154, 'total': 70648},
#     'net': {'average': 150, 'total': 68802}},
#    'streak': {'won': {'longest': 22, 'current': 2},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 90,
#     'pnl': {'average': -286, 'total': -25426, 'max': -1238}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2021, 2, 16, 14, 45, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.4,
#   'train_loss': 0.2532379627227783,
#   'start_date': '01-01-2017',
#   'final_portfolio_value': 78813.93311269842,
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d.h5',
#   'val_mae': 0.4045906066894531,
#   'training_data_end_date': DatetimeWithNanoseconds(2021, 2, 15, 13, 30, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.6,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 0},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 25,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 13, 43, 26, 823252, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_1',
#   'train_mae': 0.41433656215667725,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d',
#   'test_data_end_date': DatetimeWithNanoseconds(2021, 12, 30, 19, 30, tzinfo=datetime.timezone.utc),
#   'final_epoch': 7,
#   'val_loss': 0.24152757227420807,
#   'drawdown_analysis': {'len': 78,
#    'drawdown': 0,
#    'max': {'len': 1272, 'drawdown': 24, 'moneydown': 5394},
#    'moneydown': 804},
#   'end_date': '31-12-2021',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 274,
#     'pnl': {'average': 344,
#      'total': 93972,
#      'won': {'total': 147724, 'average': 758, 'max': 3410},
#      'lost': {'total': -53750, 'average': -688, 'max': -3094}},
#     'won': 196,
#     'lost': 78},
#    'total': {'total': 418, 'open': 2, 'closed': 416},
#    'won': {'total': 328,
#     'pnl': {'average': 658, 'total': 214882, 'max': 5500}},
#    'len': {'short': {'max': 390,
#      'average': 90,
#      'total': 24390,
#      'won': {'total': 15572, 'average': 80, 'min': 10, 'max': 390},
#      'min': 10,
#      'lost': {'total': 8818, 'average': 114, 'min': 24, 'max': 358}},
#     'total': 27090,
#     'average': 66,
#     'won': {'average': 54, 'total': 17656, 'max': 390, 'min': 4},
#     'min': 4,
#     'long': {'max': 100,
#      'average': 20,
#      'total': 2700,
#      'won': {'total': 2084, 'average': 16, 'min': 4, 'max': 88},
#      'min': 4,
#      'lost': {'total': 616, 'average': 56, 'min': 16, 'max': 100}},
#     'max': 390,
#     'lost': {'average': 106, 'total': 9434, 'max': 358, 'min': 16}},
#    'long': {'total': 144,
#     'pnl': {'average': 400,
#      'total': 57186,
#      'won': {'total': 67158, 'average': 510, 'max': 5500},
#      'lost': {'total': -9972, 'average': -906, 'max': -2976}},
#     'won': 132,
#     'lost': 12},
#    'pnl': {'gross': {'average': 374, 'total': 155310},
#     'net': {'average': 364, 'total': 151158}},
#    'streak': {'won': {'longest': 20, 'current': 2},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 90,
#     'pnl': {'average': -716, 'total': -63724, 'max': -3094}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2021, 2, 16, 14, 45, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.4,
#   'train_loss': 0.2532379627227783,
#   'start_date': '01-01-2017',
#   'final_portfolio_value': 161189.0367508367,
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2018_31-12-2022_3dbe3a81.h5',
#   'val_mae': 0.39963728189468384,
#   'training_data_end_date': DatetimeWithNanoseconds(2022, 1, 1, 8, 45, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.6,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 0},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 30,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 14, 13, 31, 98273, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_1',
#   'train_mae': 0.39900368452072144,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_1_15m_01-01-2018_31-12-2022_3dbe3a81',
#   'test_data_end_date': DatetimeWithNanoseconds(2022, 12, 30, 21, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 12,
#   'val_loss': 0.23427772521972656,
#   'drawdown_analysis': {'len': 26,
#    'drawdown': 0,
#    'max': {'len': 864, 'drawdown': 16, 'moneydown': 4834},
#    'moneydown': 344},
#   'end_date': '31-12-2022',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 270,
#     'pnl': {'average': 516,
#      'total': 138750,
#      'won': {'total': 175926, 'average': 830, 'max': 4158},
#      'lost': {'total': -37176, 'average': -652, 'max': -2298}},
#     'won': 212,
#     'lost': 58},
#    'total': {'total': 446, 'open': 2, 'closed': 446},
#    'won': {'total': 376,
#     'pnl': {'average': 698, 'total': 262488, 'max': 4158}},
#    'len': {'short': {'max': 714,
#      'average': 106,
#      'total': 28434,
#      'won': {'total': 22032, 'average': 104, 'min': 6, 'max': 714},
#      'min': 6,
#      'lost': {'total': 6402, 'average': 112, 'min': 12, 'max': 590}},
#     'total': 31502,
#     'average': 72,
#     'won': {'average': 66, 'total': 24636, 'max': 714, 'min': 4},
#     'min': 4,
#     'long': {'max': 70,
#      'average': 18,
#      'total': 3070,
#      'won': {'total': 2604, 'average': 16, 'min': 4, 'max': 66},
#      'min': 4,
#      'lost': {'total': 466, 'average': 40, 'min': 16, 'max': 70}},
#     'max': 714,
#     'lost': {'average': 100, 'total': 6868, 'max': 590, 'min': 12}},
#    'long': {'total': 176,
#     'pnl': {'average': 458,
#      'total': 80632,
#      'won': {'total': 86564, 'average': 528, 'max': 2002},
#      'lost': {'total': -5932, 'average': -494, 'max': -3448}},
#     'won': 164,
#     'lost': 12},
#    'pnl': {'gross': {'average': 506, 'total': 224708},
#     'net': {'average': 494, 'total': 219380}},
#    'streak': {'won': {'longest': 20, 'current': 2},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 70,
#     'pnl': {'average': -624, 'total': -43108, 'max': -3448}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2022, 1, 2, 10, 0, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.3,
#   'train_loss': 0.23926624655723572,
#   'start_date': '01-01-2018',
#   'final_portfolio_value': 229823.9203026925,
#   'training_data_start_date': DatetimeWithNanoseconds(2018, 1, 4, 8, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d.h5',
#   'val_mae': 0.4045906066894531,
#   'training_data_end_date': DatetimeWithNanoseconds(2021, 2, 15, 13, 30, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.7,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 0},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 20,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 13, 45, 44, 937702, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_1',
#   'train_mae': 0.41433656215667725,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d',
#   'test_data_end_date': DatetimeWithNanoseconds(2021, 12, 30, 19, 30, tzinfo=datetime.timezone.utc),
#   'final_epoch': 7,
#   'val_loss': 0.24152757227420807,
#   'drawdown_analysis': {'len': 78,
#    'drawdown': 2,
#    'max': {'len': 6666, 'drawdown': 34, 'moneydown': 6826},
#    'moneydown': 644},
#   'end_date': '31-12-2021',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 86,
#     'pnl': {'average': 342,
#      'total': 29286,
#      'won': {'total': 56108, 'average': 1002, 'max': 4734},
#      'lost': {'total': -26822, 'average': -894, 'max': -3172}},
#     'won': 56,
#     'lost': 30},
#    'total': {'total': 124, 'open': 2, 'closed': 122},
#    'won': {'total': 92, 'pnl': {'average': 792, 'total': 72820, 'max': 4734}},
#    'len': {'short': {'max': 1240,
#      'average': 342,
#      'total': 29318,
#      'won': {'total': 20572, 'average': 368, 'min': 16, 'max': 1240},
#      'min': 16,
#      'lost': {'total': 8748, 'average': 292, 'min': 84, 'max': 968}},
#     'total': 29632,
#     'average': 244,
#     'won': {'average': 228, 'total': 20886, 'max': 1240, 'min': 2},
#     'min': 2,
#     'long': {'max': 30,
#      'average': 10,
#      'total': 314,
#      'won': {'total': 314, 'average': 10, 'min': 2, 'max': 30},
#      'min': 2,
#      'lost': {'total': 0, 'average': 0, 'min': 0, 'max': 0}},
#     'max': 1240,
#     'lost': {'average': 292, 'total': 8748, 'max': 968, 'min': 84}},
#    'long': {'total': 36,
#     'pnl': {'average': 464,
#      'total': 16712,
#      'won': {'total': 16712, 'average': 464, 'max': 1192},
#      'lost': {'total': 0, 'average': 0, 'max': 0}},
#     'won': 36,
#     'lost': 0},
#    'pnl': {'gross': {'average': 386, 'total': 46970},
#     'net': {'average': 378, 'total': 45996}},
#    'streak': {'won': {'longest': 10, 'current': 2},
#     'lost': {'longest': 2, 'current': 0}},
#    'lost': {'total': 30,
#     'pnl': {'average': -894, 'total': -26822, 'max': -3172}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2021, 2, 16, 14, 45, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.3,
#   'train_loss': 0.2532379627227783,
#   'start_date': '01-01-2017',
#   'final_portfolio_value': 55992.44294680418,
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2018_31-12-2022_3dbe3a81.h5',
#   'val_mae': 0.39963728189468384,
#   'training_data_end_date': DatetimeWithNanoseconds(2022, 1, 1, 8, 45, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.7,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 0},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 20,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 14, 16, 37, 452969, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_1',
#   'train_mae': 0.39900368452072144,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_1_15m_01-01-2018_31-12-2022_3dbe3a81',
#   'test_data_end_date': DatetimeWithNanoseconds(2022, 12, 30, 21, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 12,
#   'val_loss': 0.23427772521972656,
#   'drawdown_analysis': {'len': 26,
#    'drawdown': 0,
#    'max': {'len': 2654, 'drawdown': 20, 'moneydown': 4276},
#    'moneydown': 228},
#   'end_date': '31-12-2022',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 88,
#     'pnl': {'average': 628,
#      'total': 55242,
#      'won': {'total': 67530, 'average': 1146, 'max': 5052},
#      'lost': {'total': -12288, 'average': -424, 'max': -1440}},
#     'won': 60,
#     'lost': 30},
#    'total': {'total': 138, 'open': 2, 'closed': 136},
#    'won': {'total': 106, 'pnl': {'average': 860, 'total': 91128, 'max': 5052}},
#    'len': {'short': {'max': 2978,
#      'average': 374,
#      'total': 32798,
#      'won': {'total': 22608, 'average': 384, 'min': 8, 'max': 2978},
#      'min': 8,
#      'lost': {'total': 10190, 'average': 352, 'min': 38, 'max': 2838}},
#     'total': 33464,
#     'average': 246,
#     'won': {'average': 220, 'total': 23208, 'max': 2978, 'min': 4},
#     'min': 4,
#     'long': {'max': 66,
#      'average': 14,
#      'total': 666,
#      'won': {'total': 602, 'average': 14, 'min': 4, 'max': 34},
#      'min': 4,
#      'lost': {'total': 66, 'average': 66, 'min': 66, 'max': 66}},
#     'max': 2978,
#     'lost': {'average': 342, 'total': 10256, 'max': 2838, 'min': 38}},
#    'long': {'total': 48,
#     'pnl': {'average': 450,
#      'total': 21546,
#      'won': {'total': 23598, 'average': 502, 'max': 1746},
#      'lost': {'total': -2052, 'average': -2052, 'max': -2052}},
#     'won': 48,
#     'lost': 2},
#    'pnl': {'gross': {'average': 574, 'total': 77868},
#     'net': {'average': 566, 'total': 76786}},
#    'streak': {'won': {'longest': 18, 'current': 2},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 30,
#     'pnl': {'average': -478, 'total': -14340, 'max': -2052}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2022, 1, 2, 10, 0, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.3,
#   'train_loss': 0.23926624655723572,
#   'start_date': '01-01-2018',
#   'final_portfolio_value': 87082.22010714236,
#   'training_data_start_date': DatetimeWithNanoseconds(2018, 1, 4, 8, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2019_31-12-2023_09e4f70d.h5',
#   'val_mae': 0.40847355127334595,
#   'training_data_end_date': DatetimeWithNanoseconds(2022, 12, 31, 19, 45, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.6,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 0},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 15,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 14, 41, 12, 533081, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_1',
#   'train_mae': 0.4116671085357666,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_1_15m_01-01-2019_31-12-2023_09e4f70d',
#   'test_data_end_date': DatetimeWithNanoseconds(2023, 12, 30, 17, 30, tzinfo=datetime.timezone.utc),
#   'final_epoch': 6,
#   'val_loss': 0.24270614981651306,
#   'drawdown_analysis': {'len': 32,
#    'drawdown': 2,
#    'max': {'len': 1714, 'drawdown': 18, 'moneydown': 1892},
#    'moneydown': 330},
#   'end_date': '31-12-2023',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 122,
#     'pnl': {'average': 232,
#      'total': 28184,
#      'won': {'total': 33818, 'average': 314, 'max': 1448},
#      'lost': {'total': -5634, 'average': -402, 'max': -1188}},
#     'won': 108,
#     'lost': 14},
#    'total': {'total': 206, 'open': 2, 'closed': 204},
#    'won': {'total': 184, 'pnl': {'average': 330, 'total': 60130, 'max': 2296}},
#    'len': {'short': {'max': 768,
#      'average': 134,
#      'total': 16358,
#      'won': {'total': 14074, 'average': 130, 'min': 10, 'max': 768},
#      'min': 10,
#      'lost': {'total': 2286, 'average': 164, 'min': 48, 'max': 614}},
#     'total': 25060,
#     'average': 124,
#     'won': {'average': 118, 'total': 21556, 'max': 768, 'min': 10},
#     'min': 10,
#     'long': {'max': 574,
#      'average': 106,
#      'total': 8702,
#      'won': {'total': 7482, 'average': 100, 'min': 10, 'max': 574},
#      'min': 10,
#      'lost': {'total': 1220, 'average': 174, 'min': 112, 'max': 256}},
#     'max': 768,
#     'lost': {'average': 168, 'total': 3506, 'max': 614, 'min': 48}},
#    'long': {'total': 82,
#     'pnl': {'average': 314,
#      'total': 25750,
#      'won': {'total': 26314, 'average': 352, 'max': 2296},
#      'lost': {'total': -564, 'average': -80, 'max': -168}},
#     'won': 76,
#     'lost': 8},
#    'pnl': {'gross': {'average': 270, 'total': 55156},
#     'net': {'average': 264, 'total': 53934}},
#    'streak': {'won': {'longest': 36, 'current': 6},
#     'lost': {'longest': 2, 'current': 0}},
#    'lost': {'total': 22,
#     'pnl': {'average': -294, 'total': -6196, 'max': -1188}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 1, 1, 21, 0, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.5,
#   'train_loss': 0.2505199909210205,
#   'start_date': '01-01-2019',
#   'final_portfolio_value': 64034.053776684494,
#   'training_data_start_date': DatetimeWithNanoseconds(2019, 1, 4, 8, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d.h5',
#   'val_mae': 0.4045906066894531,
#   'training_data_end_date': DatetimeWithNanoseconds(2021, 2, 15, 13, 30, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.7,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 0},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 25,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 13, 46, 27, 698346, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_1',
#   'train_mae': 0.41433656215667725,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d',
#   'test_data_end_date': DatetimeWithNanoseconds(2021, 12, 30, 19, 30, tzinfo=datetime.timezone.utc),
#   'final_epoch': 7,
#   'val_loss': 0.24152757227420807,
#   'drawdown_analysis': {'len': 78,
#    'drawdown': 2,
#    'max': {'len': 5996, 'drawdown': 38, 'moneydown': 7590},
#    'moneydown': 804},
#   'end_date': '31-12-2021',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 86,
#     'pnl': {'average': 476,
#      'total': 40898,
#      'won': {'total': 72144, 'average': 1266, 'max': 5918},
#      'lost': {'total': -31246, 'average': -1076, 'max': -3736}},
#     'won': 58,
#     'lost': 30},
#    'total': {'total': 124, 'open': 2, 'closed': 122},
#    'won': {'total': 94, 'pnl': {'average': 1038, 'total': 96488, 'max': 5918}},
#    'len': {'short': {'max': 1198,
#      'average': 338,
#      'total': 28986,
#      'won': {'total': 20478, 'average': 360, 'min': 16, 'max': 1198},
#      'min': 16,
#      'lost': {'total': 8508, 'average': 294, 'min': 84, 'max': 966}},
#     'total': 29434,
#     'average': 242,
#     'won': {'average': 226, 'total': 20926, 'max': 1198, 'min': 4},
#     'min': 4,
#     'long': {'max': 48,
#      'average': 12,
#      'total': 448,
#      'won': {'total': 448, 'average': 12, 'min': 4, 'max': 48},
#      'min': 4,
#      'lost': {'total': 0, 'average': 0, 'min': 0, 'max': 0}},
#     'max': 1198,
#     'lost': {'average': 294, 'total': 8508, 'max': 966, 'min': 84}},
#    'long': {'total': 36,
#     'pnl': {'average': 676,
#      'total': 24346,
#      'won': {'total': 24346, 'average': 676, 'max': 1690},
#      'lost': {'total': 0, 'average': 0, 'max': 0}},
#     'won': 36,
#     'lost': 0},
#    'pnl': {'gross': {'average': 546, 'total': 66460},
#     'net': {'average': 536, 'total': 65242}},
#    'streak': {'won': {'longest': 12, 'current': 2},
#     'lost': {'longest': 2, 'current': 0}},
#    'lost': {'total': 30,
#     'pnl': {'average': -1076, 'total': -31246, 'max': -3736}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2021, 2, 16, 14, 45, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.4,
#   'train_loss': 0.2532379627227783,
#   'start_date': '01-01-2017',
#   'final_portfolio_value': 75273.42693208072,
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2019_31-12-2023_09e4f70d.h5',
#   'val_mae': 0.40847355127334595,
#   'training_data_end_date': DatetimeWithNanoseconds(2022, 12, 31, 19, 45, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.6,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 0},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 10,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 14, 42, 25, 718415, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_1',
#   'train_mae': 0.4116671085357666,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_1_15m_01-01-2019_31-12-2023_09e4f70d',
#   'test_data_end_date': DatetimeWithNanoseconds(2023, 12, 30, 17, 30, tzinfo=datetime.timezone.utc),
#   'final_epoch': 6,
#   'val_loss': 0.24270614981651306,
#   'drawdown_analysis': {'len': 2098,
#    'drawdown': 2,
#    'max': {'len': 9094, 'drawdown': 16, 'moneydown': 2174},
#    'moneydown': 426},
#   'end_date': '31-12-2023',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 6,
#     'pnl': {'average': 338,
#      'total': 2026,
#      'won': {'total': 2026, 'average': 338, 'max': 688},
#      'lost': {'total': 0, 'average': 0, 'max': 0}},
#     'won': 6,
#     'lost': 0},
#    'total': {'total': 22, 'open': 0, 'closed': 22},
#    'won': {'total': 18, 'pnl': {'average': 972, 'total': 17480, 'max': 4054}},
#    'len': {'short': {'max': 92,
#      'average': 64,
#      'total': 380,
#      'won': {'total': 380, 'average': 64, 'min': 12, 'max': 92},
#      'min': 12,
#      'lost': {'total': 0, 'average': 0, 'min': 0, 'max': 0}},
#     'total': 31732,
#     'average': 1512,
#     'won': {'average': 1236, 'total': 22254, 'max': 4448, 'min': 12},
#     'min': 12,
#     'long': {'max': 7990,
#      'average': 2090,
#      'total': 31352,
#      'won': {'total': 21876, 'average': 1824, 'min': 16, 'max': 4448},
#      'min': 16,
#      'lost': {'total': 9478, 'average': 3160, 'min': 436, 'max': 7990}},
#     'max': 7990,
#     'lost': {'average': 3160, 'total': 9478, 'max': 7990, 'min': 436}},
#    'long': {'total': 16,
#     'pnl': {'average': 868,
#      'total': 13018,
#      'won': {'total': 15454, 'average': 1288, 'max': 4054},
#      'lost': {'total': -2436, 'average': -812, 'max': -1290}},
#     'won': 12,
#     'lost': 4},
#    'pnl': {'gross': {'average': 720, 'total': 15130},
#     'net': {'average': 716, 'total': 15044}},
#    'streak': {'won': {'longest': 6, 'current': 6},
#     'lost': {'longest': 2, 'current': 0}},
#    'lost': {'total': 4,
#     'pnl': {'average': -812, 'total': -2436, 'max': -1290}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 1, 1, 21, 0, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.7,
#   'train_loss': 0.2505199909210205,
#   'start_date': '01-01-2019',
#   'final_portfolio_value': 25043.498831206598,
#   'training_data_start_date': DatetimeWithNanoseconds(2019, 1, 4, 8, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2019_31-12-2023_09e4f70d.h5',
#   'val_mae': 0.40847355127334595,
#   'training_data_end_date': DatetimeWithNanoseconds(2022, 12, 31, 19, 45, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.6,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 0},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 15,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 14, 41, 53, 54613, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_1',
#   'train_mae': 0.4116671085357666,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_1_15m_01-01-2019_31-12-2023_09e4f70d',
#   'test_data_end_date': DatetimeWithNanoseconds(2023, 12, 30, 17, 30, tzinfo=datetime.timezone.utc),
#   'final_epoch': 6,
#   'val_loss': 0.24270614981651306,
#   'drawdown_analysis': {'len': 32,
#    'drawdown': 2,
#    'max': {'len': 2756, 'drawdown': 12, 'moneydown': 2022},
#    'moneydown': 328},
#   'end_date': '31-12-2023',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 54,
#     'pnl': {'average': 282,
#      'total': 14894,
#      'won': {'total': 15914, 'average': 332, 'max': 1014},
#      'lost': {'total': -1020, 'average': -204, 'max': -636}},
#     'won': 48,
#     'lost': 6},
#    'total': {'total': 98, 'open': 2, 'closed': 96},
#    'won': {'total': 84, 'pnl': {'average': 440, 'total': 36916, 'max': 3520}},
#    'len': {'short': {'max': 432,
#      'average': 120,
#      'total': 6328,
#      'won': {'total': 5616, 'average': 118, 'min': 8, 'max': 432},
#      'min': 8,
#      'lost': {'total': 714, 'average': 144, 'min': 38, 'max': 256}},
#     'total': 24694,
#     'average': 258,
#     'won': {'average': 236, 'total': 19786, 'max': 1550, 'min': 8},
#     'min': 8,
#     'long': {'max': 1814,
#      'average': 428,
#      'total': 18366,
#      'won': {'total': 14170, 'average': 394, 'min': 16, 'max': 1550},
#      'min': 16,
#      'lost': {'total': 4196, 'average': 600, 'min': 238, 'max': 1814}},
#     'max': 1814,
#     'lost': {'average': 410, 'total': 4908, 'max': 1814, 'min': 38}},
#    'long': {'total': 44,
#     'pnl': {'average': 448,
#      'total': 19220,
#      'won': {'total': 21002, 'average': 584, 'max': 3520},
#      'lost': {'total': -1782, 'average': -254, 'max': -502}},
#     'won': 36,
#     'lost': 8},
#    'pnl': {'gross': {'average': 362, 'total': 34690},
#     'net': {'average': 356, 'total': 34112}},
#    'streak': {'won': {'longest': 24, 'current': 2},
#     'lost': {'longest': 2, 'current': 0}},
#    'lost': {'total': 12,
#     'pnl': {'average': -234, 'total': -2802, 'max': -636}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 1, 1, 21, 0, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.6,
#   'train_loss': 0.2505199909210205,
#   'start_date': '01-01-2019',
#   'final_portfolio_value': 44301.29116421396,
#   'training_data_start_date': DatetimeWithNanoseconds(2019, 1, 4, 8, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2020_30-12-2024_4cc8bc32.h5',
#   'val_mae': 0.4036828577518463,
#   'training_data_end_date': DatetimeWithNanoseconds(2023, 12, 31, 19, 0, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.3,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 0},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 30,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 15, 0, 56, 754826, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_1',
#   'train_mae': 0.3972854018211365,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_1_15m_01-01-2020_30-12-2024_4cc8bc32',
#   'test_data_end_date': DatetimeWithNanoseconds(2024, 12, 29, 21, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24077270925045013,
#   'drawdown_analysis': {'len': 54,
#    'drawdown': 0,
#    'max': {'len': 1172, 'drawdown': 12, 'moneydown': 3906},
#    'moneydown': 482},
#   'end_date': '30-12-2024',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 694,
#     'pnl': {'average': 168,
#      'total': 115820,
#      'won': {'total': 148326, 'average': 262, 'max': 1706},
#      'lost': {'total': -32506, 'average': -258, 'max': -1836}},
#     'won': 568,
#     'lost': 126},
#    'total': {'total': 1274, 'open': 2, 'closed': 1272},
#    'won': {'total': 1036,
#     'pnl': {'average': 284, 'total': 293176, 'max': 1912}},
#    'len': {'short': {'max': 120,
#      'average': 20,
#      'total': 13078,
#      'won': {'total': 8760, 'average': 16, 'min': 2, 'max': 92},
#      'min': 2,
#      'lost': {'total': 4318, 'average': 34, 'min': 2, 'max': 120}},
#     'total': 28186,
#     'average': 22,
#     'won': {'average': 18, 'total': 18768, 'max': 158, 'min': 2},
#     'min': 2,
#     'long': {'max': 260,
#      'average': 26,
#      'total': 15110,
#      'won': {'total': 10010, 'average': 22, 'min': 2, 'max': 158},
#      'min': 2,
#      'lost': {'total': 5100, 'average': 46, 'min': 2, 'max': 260}},
#     'max': 260,
#     'lost': {'average': 40, 'total': 9418, 'max': 260, 'min': 2}},
#    'long': {'total': 578,
#     'pnl': {'average': 198,
#      'total': 113800,
# ...
#      'min': 16,
#      'lost': {'total': 8962, 'average': 310, 'min': 22, 'max': 1112}},
#     'max': 1134,
#     'lost': {'average': 310, 'total': 8962, 'max': 1112, 'min': 22}},
#    'long': {'total': 94,
#     'pnl': {'average': 238,
#      'total': 22132,
#      'won': {'total': 35034, 'average': 548, 'max': 3522},
#      'lost': {'total': -12902, 'average': -444, 'max': -1468}},
#     'won': 64,
#     'lost': 30},
#    'pnl': {'gross': {'average': 244, 'total': 36092},
#     'net': {'average': 240, 'total': 35500}},
#    'streak': {'won': {'longest': 18, 'current': 8},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 30,
#     'pnl': {'average': -444, 'total': -12902, 'max': -1468}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2021, 2, 16, 14, 45, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.7,
#   'train_loss': 0.2532379627227783,
#   'start_date': '01-01-2017',
#   'final_portfolio_value': 44811.379571904865,
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2020_30-12-2024_4cc8bc32.h5',
#   'val_mae': 0.4036828577518463,
#   'training_data_end_date': DatetimeWithNanoseconds(2023, 12, 31, 19, 0, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.6,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 0},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 10,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 15, 11, 53, 623844, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_1',
#   'train_mae': 0.3972854018211365,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_1_15m_01-01-2020_30-12-2024_4cc8bc32',
#   'test_data_end_date': DatetimeWithNanoseconds(2024, 12, 29, 21, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24077270925045013,
#   'drawdown_analysis': {'len': 26,
#    'drawdown': 0,
#    'max': {'len': 1194, 'drawdown': 8, 'moneydown': 1748},
#    'moneydown': 40},
#   'end_date': '30-12-2024',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 272,
#     'pnl': {'average': 108,
#      'total': 29210,
#      'won': {'total': 44150, 'average': 214, 'max': 1490},
#      'lost': {'total': -14940, 'average': -230, 'max': -1058}},
#     'won': 206,
#     'lost': 66},
#    'total': {'total': 486, 'open': 2, 'closed': 486},
#    'won': {'total': 404, 'pnl': {'average': 192, 'total': 77012, 'max': 1490}},
#    'len': {'short': {'max': 418,
#      'average': 92,
#      'total': 24648,
#      'won': {'total': 15510, 'average': 76, 'min': 6, 'max': 354},
#      'min': 6,
#      'lost': {'total': 9138, 'average': 142, 'min': 14, 'max': 418}},
#     'total': 31012,
#     'average': 64,
#     'won': {'average': 52, 'total': 20834, 'max': 354, 'min': 4},
#     'min': 4,
#     'long': {'max': 242,
#      'average': 30,
#      'total': 6366,
#      'won': {'total': 5324, 'average': 28, 'min': 4, 'max': 242},
#      'min': 4,
#      'lost': {'total': 1042, 'average': 66, 'min': 12, 'max': 206}},
#     'max': 418,
#     'lost': {'average': 126, 'total': 10180, 'max': 418, 'min': 12}},
#    'long': {'total': 214,
#     'pnl': {'average': 148,
#      'total': 31546,
#      'won': {'total': 32862, 'average': 166, 'max': 774},
#      'lost': {'total': -1316, 'average': -82, 'max': -238}},
#     'won': 198,
#     'lost': 16},
#    'pnl': {'gross': {'average': 130, 'total': 62694},
#     'net': {'average': 126, 'total': 60754}},
#    'streak': {'won': {'longest': 18, 'current': 0},
#     'lost': {'longest': 4, 'current': 2}},
#    'lost': {'total': 82,
#     'pnl': {'average': -200, 'total': -16258, 'max': -1058}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2024, 1, 1, 20, 15, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.5,
#   'train_loss': 0.236819788813591,
#   'start_date': '01-01-2020',
#   'final_portfolio_value': 70753.92048848742,
#   'training_data_start_date': DatetimeWithNanoseconds(2020, 1, 4, 8, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2019_31-12-2023_09e4f70d.h5',
#   'val_mae': 0.40847355127334595,
#   'training_data_end_date': DatetimeWithNanoseconds(2022, 12, 31, 19, 45, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.7,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 0},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 20,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 14, 45, 25, 216393, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_1',
#   'train_mae': 0.4116671085357666,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_1_15m_01-01-2019_31-12-2023_09e4f70d',
#   'test_data_end_date': DatetimeWithNanoseconds(2023, 12, 30, 17, 30, tzinfo=datetime.timezone.utc),
#   'final_epoch': 6,
#   'val_loss': 0.24270614981651306,
#   'drawdown_analysis': {'len': 2098,
#    'drawdown': 2,
#    'max': {'len': 3190, 'drawdown': 26, 'moneydown': 2642},
#    'moneydown': 882},
#   'end_date': '31-12-2023',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 44,
#     'pnl': {'average': 392,
#      'total': 16862,
#      'won': {'total': 20368, 'average': 550, 'max': 2286},
#      'lost': {'total': -3506, 'average': -584, 'max': -1166}},
#     'won': 38,
#     'lost': 6},
#    'total': {'total': 62, 'open': 2, 'closed': 60},
#    'won': {'total': 54, 'pnl': {'average': 686, 'total': 36318, 'max': 4690}},
#    'len': {'short': {'max': 1132,
#      'average': 326,
#      'total': 13980,
#      'won': {'total': 11388, 'average': 308, 'min': 12, 'max': 1132},
#      'min': 12,
#      'lost': {'total': 2592, 'average': 432, 'min': 38, 'max': 624}},
#     'total': 22028,
#     'average': 368,
#     'won': {'average': 354, 'total': 18786, 'max': 1490, 'min': 12},
#     'min': 12,
#     'long': {'max': 1490,
#      'average': 474,
#      'total': 8050,
#      'won': {'total': 7398, 'average': 462, 'min': 24, 'max': 1490},
#      'min': 24,
#      'lost': {'total': 652, 'average': 652, 'min': 652, 'max': 652}},
#     'max': 1490,
#     'lost': {'average': 464, 'total': 3244, 'max': 652, 'min': 38}},
#    'long': {'total': 18,
#     'pnl': {'average': 912,
#      'total': 15510,
#      'won': {'total': 15950, 'average': 998, 'max': 4690},
#      'lost': {'total': -440, 'average': -440, 'max': -440}},
#     'won': 16,
#     'lost': 2},
#    'pnl': {'gross': {'average': 548, 'total': 32850},
#     'net': {'average': 540, 'total': 32372}},
#    'streak': {'won': {'longest': 16, 'current': 8},
#     'lost': {'longest': 2, 'current': 0}},
#    'lost': {'total': 8,
#     'pnl': {'average': -564, 'total': -3946, 'max': -1166}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 1, 1, 21, 0, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.6,
#   'train_loss': 0.2505199909210205,
#   'start_date': '01-01-2019',
#   'final_portfolio_value': 42418.23084002749,
#   'training_data_start_date': DatetimeWithNanoseconds(2019, 1, 4, 8, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2019_31-12-2023_09e4f70d.h5',
#   'val_mae': 0.40847355127334595,
#   'training_data_end_date': DatetimeWithNanoseconds(2022, 12, 31, 19, 45, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.7,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 0},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 10,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 14, 43, 6, 191499, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_1',
#   'train_mae': 0.4116671085357666,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_1_15m_01-01-2019_31-12-2023_09e4f70d',
#   'test_data_end_date': DatetimeWithNanoseconds(2023, 12, 30, 17, 30, tzinfo=datetime.timezone.utc),
#   'final_epoch': 6,
#   'val_loss': 0.24270614981651306,
#   'drawdown_analysis': {'len': 7586,
#    'drawdown': 8,
#    'max': {'len': 7586, 'drawdown': 22, 'moneydown': 2634},
#    'moneydown': 1628},
#   'end_date': '31-12-2023',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 82,
#     'pnl': {'average': 48,
#      'total': 3804,
#      'won': {'total': 14434, 'average': 278, 'max': 1150},
#      'lost': {'total': -10628, 'average': -366, 'max': -1548}},
#     'won': 52,
#     'lost': 30},
#    'total': {'total': 126, 'open': 2, 'closed': 124},
#    'won': {'total': 96, 'pnl': {'average': 234, 'total': 22142, 'max': 1150}},
#    'len': {'short': {'max': 1344,
#      'average': 392,
#      'total': 31778,
#      'won': {'total': 20942, 'average': 404, 'min': 6, 'max': 1344},
#      'min': 6,
#      'lost': {'total': 10838, 'average': 374, 'min': 56, 'max': 1280}},
#     'total': 32590,
#     'average': 264,
#     'won': {'average': 230, 'total': 21752, 'max': 1344, 'min': 6},
#     'min': 6,
#     'long': {'max': 174,
#      'average': 20,
#      'total': 812,
#      'won': {'total': 812, 'average': 20, 'min': 6, 'max': 174},
#      'min': 6,
#      'lost': {'total': 0, 'average': 0, 'min': 0, 'max': 0}},
#     'max': 1344,
#     'lost': {'average': 374, 'total': 10838, 'max': 1280, 'min': 56}},
#    'long': {'total': 44,
#     'pnl': {'average': 180,
#      'total': 7708,
#      'won': {'total': 7708, 'average': 180, 'max': 712},
#      'lost': {'total': 0, 'average': 0, 'max': 0}},
#     'won': 44,
#     'lost': 0},
#    'pnl': {'gross': {'average': 98, 'total': 12010},
#     'net': {'average': 94, 'total': 11512}},
#    'streak': {'won': {'longest': 18, 'current': 2},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 30,
#     'pnl': {'average': -366, 'total': -10628, 'max': -1548}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 1, 1, 21, 0, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.3,
#   'train_loss': 0.2505199909210205,
#   'start_date': '01-01-2019',
#   'final_portfolio_value': 21448.326447089545,
#   'training_data_start_date': DatetimeWithNanoseconds(2019, 1, 4, 8, 0, tzinfo=datetime.timezone.utc)},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2020_30-12-2024_4cc8bc32.h5',
#   'val_mae': 0.4036828577518463,
#   'training_data_end_date': DatetimeWithNanoseconds(2023, 12, 31, 19, 0, tzinfo=datetime.timezone.utc),
#   'trade_buy_threshold': 0.6,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 0},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'trade_leverage': 30,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 15, 13, 50, 70828, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1_0_1',
#   'train_mae': 0.3972854018211365,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_0_1_15m_01-01-2020_30-12-2024_4cc8bc32',
#   'test_data_end_date': DatetimeWithNanoseconds(2024, 12, 29, 21, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24077270925045013,
#   'drawdown_analysis': {'len': 372,
#    'drawdown': 0,
#    'max': {'len': 1104, 'drawdown': 28, 'moneydown': 5144},
#    'moneydown': 576},
#   'end_date': '30-12-2024',
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 118,
#     'pnl': {'average': 612,
#      'total': 72138,
#      'won': {'total': 83728, 'average': 768, 'max': 3176},
#      'lost': {'total': -11590, 'average': -1288, 'max': -3012}},
#     'won': 110,
#     'lost': 10},
#    'total': {'total': 212, 'open': 2, 'closed': 212},
#    'won': {'total': 186,
#     'pnl': {'average': 910, 'total': 168270, 'max': 4492}},
#    'len': {'short': {'max': 392,
#      'average': 72,
#      'total': 8428,
#      'won': {'total': 6840, 'average': 64, 'min': 4, 'max': 282},
#      'min': 4,
#      'lost': {'total': 1590, 'average': 178, 'min': 28, 'max': 392}},
#     'total': 24066,
#     'average': 114,
#     'won': {'average': 100, 'total': 18376, 'max': 966, 'min': 4},
#     'min': 4,
#     'long': {'max': 966,
#      'average': 168,
#      'total': 15638,
#      'won': {'total': 11538, 'average': 152, 'min': 12, 'max': 966},
#      'min': 12,
#      'lost': {'total': 4102, 'average': 242, 'min': 60, 'max': 706}},
#     'max': 966,
#     'lost': {'average': 220, 'total': 5690, 'max': 706, 'min': 28}},
#    'long': {'total': 94,
#     'pnl': {'average': 800,
#      'total': 74424,
#      'won': {'total': 84542, 'average': 1112, 'max': 4492},
#      'lost': {'total': -10118, 'average': -594, 'max': -2350}},
#     'won': 76,
#     'lost': 18},
#    'pnl': {'gross': {'average': 708, 'total': 149092},
#     'net': {'average': 696, 'total': 146560}},
#    'streak': {'won': {'longest': 18, 'current': 2},
#     'lost': {'longest': 2, 'current': 0}},
#    'lost': {'total': 26,
#     'pnl': {'average': -834, 'total': -21710, 'max': -3012}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2024, 1, 1, 20, 15, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.7,
#   'train_loss': 0.236819788813591,
#   'start_date': '01-01-2020',
#   'final_portfolio_value': 156421.12341455475,
#   'training_data_start_date': DatetimeWithNanoseconds(2020, 1, 4, 8, 0, tzinfo=datetime.timezone.utc)}]

# %%
data = pd.DataFrame(trade_models)
data
# Out:
#                                             model_path   val_mae  \
# 0    gs://ife-storage/trade/models/binance_mtf_v1_0...  0.408474
# 1    gs://ife-storage/trade/models/binance_mtf_v1_0...  0.403683
# 2    gs://ife-storage/trade/models/binance_mtf_v1_0...  0.404591
# 3    gs://ife-storage/trade/models/binance_mtf_v1_0...  0.404591
# 4    gs://ife-storage/trade/models/binance_mtf_v1_0...  0.404591
# ..                                                 ...       ...
# 495  gs://ife-storage/trade/models/binance_mtf_v1_0...  0.404591
# 496  gs://ife-storage/trade/models/binance_mtf_v1_0...  0.403683
# 497  gs://ife-storage/trade/models/binance_mtf_v1_0...  0.408474
# 498  gs://ife-storage/trade/models/binance_mtf_v1_0...  0.408474
# 499  gs://ife-storage/trade/models/binance_mtf_v1_0...  0.403683
#
#        training_data_end_date  trade_buy_threshold  \
# 0   2022-12-31 19:45:00+00:00                  0.6
# 1   2023-12-31 19:00:00+00:00                  0.7
# 2   2021-02-15 13:30:00+00:00                  0.6
# 3   2021-02-15 13:30:00+00:00                  0.6
# 4   2021-02-15 13:30:00+00:00                  0.6
# ..                        ...                  ...
# 495 2021-02-15 13:30:00+00:00                  0.4
# 496 2023-12-31 19:00:00+00:00                  0.6
# 497 2022-12-31 19:45:00+00:00                  0.7
# 498 2022-12-31 19:45:00+00:00                  0.7
# 499 2023-12-31 19:00:00+00:00                  0.6
#
#                                       features_columns  training_data_ratio  \
# 0    _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 1    _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 2    _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 3    _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 4    _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# ..                                                 ...                  ...
# 495  _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 496  _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 497  _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 498  _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 499  _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
#
#         sharpe_analysis model_input_shape  epochs  trade_leverage  ...  \
# 0    {'sharperatio': 0}         [100, 29]      20              20  ...
# 1    {'sharperatio': 0}         [100, 29]      20              25  ...
# 2    {'sharperatio': 0}         [100, 29]      20              25  ...
# 3    {'sharperatio': 0}         [100, 29]      20              10  ...
# 4    {'sharperatio': 0}         [100, 29]      20              25  ...
# ..                  ...               ...     ...             ...  ...
# 495  {'sharperatio': 0}         [100, 29]      20              10  ...
# 496  {'sharperatio': 0}         [100, 29]      20              10  ...
# 497  {'sharperatio': 0}         [100, 29]      20              20  ...
# 498  {'sharperatio': 0}         [100, 29]      20              10  ...
# 499  {'sharperatio': 0}         [100, 29]      20              30  ...
#
#     exchange starting_portfolio_value   symbol      test_data_start_date  \
# 0    binance                  10000.0  BTCUSDT 2023-01-01 21:00:00+00:00
# 1    binance                  10000.0  BTCUSDT 2024-01-01 20:15:00+00:00
# 2    binance                  10000.0  BTCUSDT 2021-02-16 14:45:00+00:00
# 3    binance                  10000.0  BTCUSDT 2021-02-16 14:45:00+00:00
# 4    binance                  10000.0  BTCUSDT 2021-02-16 14:45:00+00:00
# ..       ...                      ...      ...                       ...
# 495  binance                  10000.0  BTCUSDT 2021-02-16 14:45:00+00:00
# 496  binance                  10000.0  BTCUSDT 2024-01-01 20:15:00+00:00
# 497  binance                  10000.0  BTCUSDT 2023-01-01 21:00:00+00:00
# 498  binance                  10000.0  BTCUSDT 2023-01-01 21:00:00+00:00
# 499  binance                  10000.0  BTCUSDT 2024-01-01 20:15:00+00:00
#
#     middle_timeframe  trade_sell_threshold train_loss  start_date  \
# 0                 1h                  -0.5   0.250520  01-01-2019
# 1                 1h                  -0.4   0.236820  01-01-2020
# 2                 1h                  -0.5   0.253238  01-01-2017
# 3                 1h                  -0.4   0.253238  01-01-2017
# 4                 1h                  -0.4   0.253238  01-01-2017
# ..               ...                   ...        ...         ...
# 495               1h                  -0.7   0.253238  01-01-2017
# 496               1h                  -0.5   0.236820  01-01-2020
# 497               1h                  -0.6   0.250520  01-01-2019
# 498               1h                  -0.3   0.250520  01-01-2019
# 499               1h                  -0.7   0.236820  01-01-2020
#
#     final_portfolio_value  training_data_start_date
# 0            76166.752963 2019-01-04 08:00:00+00:00
# 1            37899.475059 2020-01-04 08:00:00+00:00
# 2           175261.684363 2017-08-20 12:00:00+00:00
# 3            78813.933113 2017-08-20 12:00:00+00:00
# 4           161189.036751 2017-08-20 12:00:00+00:00
# ..                    ...                       ...
# 495          44811.379572 2017-08-20 12:00:00+00:00
# 496          70753.920488 2020-01-04 08:00:00+00:00
# 497          42418.230840 2019-01-04 08:00:00+00:00
# 498          21448.326447 2019-01-04 08:00:00+00:00
# 499         156421.123415 2020-01-04 08:00:00+00:00
#
# [500 rows x 36 columns]

# %%
sorted(data.columns)
# Out:
# ['broker_commision',
#  'created_at',
#  'drawdown_analysis',
#  'end_date',
#  'epochs',
#  'exchange',
#  'features_columns',
#  'final_epoch',
#  'final_portfolio_value',
#  'higher_timeframe',
#  'lower_timeframe',
#  'middle_timeframe',
#  'model_input_shape',
#  'model_name',
#  'model_path',
#  'seq_length',
#  'sharpe_analysis',
#  'start_date',
#  'starting_portfolio_value',
#  'symbol',
#  'test_data_end_date',
#  'test_data_start_date',
#  'timeframe',
#  'trade_analysis',
#  'trade_buy_threshold',
#  'trade_leverage',
#  'trade_margin',
#  'trade_sell_threshold',
#  'train_loss',
#  'train_mae',
#  'training_data_end_date',
#  'training_data_ratio',
#  'training_data_start_date',
#  'val_loss',
#  'val_mae',
#  'version']

# %%
performing_model = data[['start_date', 'end_date', 'final_portfolio_value', 'trade_buy_threshold', 'trade_sell_threshold', 'trade_leverage', 'val_loss', 'val_mae', 'test_data_start_date', 'test_data_end_date']].sort_values(by='final_portfolio_value', ascending=False).head(20)
performing_model
# Out:
#      start_date    end_date  final_portfolio_value  trade_buy_threshold  \
# 58   01-01-2017  31-12-2021          311840.504217                  0.4
# 432  01-01-2018  31-12-2022          301929.699513                  0.3
# 485  01-01-2017  31-12-2021          301691.760036                  0.3
# 193  01-01-2018  31-12-2022          299590.981454                  0.4
# 390  01-01-2017  31-12-2021          290713.266129                  0.4
# 167  01-01-2017  31-12-2021          288834.521563                  0.4
# 251  01-01-2017  31-12-2021          279156.804376                  0.5
# 195  01-01-2018  31-12-2022          276187.687585                  0.5
# 188  01-01-2017  31-12-2021          276069.785129                  0.5
# 248  01-01-2018  31-12-2022          274910.544671                  0.4
# 151  01-01-2017  31-12-2021          272901.719943                  0.3
# 268  01-01-2017  31-12-2021          271783.648056                  0.3
# 391  01-01-2018  31-12-2022          271562.587850                  0.3
# 111  01-01-2018  31-12-2022          264706.100229                  0.5
# 288  01-01-2017  31-12-2021          262016.738270                  0.4
# 314  01-01-2017  31-12-2021          254469.797638                  0.5
# 155  01-01-2018  31-12-2022          253443.574495                  0.4
# 260  01-01-2018  31-12-2022          252729.140951                  0.3
# 32   01-01-2017  31-12-2021          252443.789834                  0.3
# 234  01-01-2017  31-12-2021          244908.000142                  0.4
#
#      trade_sell_threshold  trade_leverage  val_loss   val_mae  \
# 58                   -0.4              30  0.241528  0.404591
# 432                  -0.3              30  0.234278  0.399637
# 485                  -0.4              30  0.241528  0.404591
# 193                  -0.3              30  0.234278  0.399637
# 390                  -0.3              30  0.241528  0.404591
# 167                  -0.5              30  0.241528  0.404591
# 251                  -0.4              30  0.241528  0.404591
# 195                  -0.3              30  0.234278  0.399637
# 188                  -0.5              30  0.241528  0.404591
# 248                  -0.4              30  0.234278  0.399637
# 151                  -0.5              30  0.241528  0.404591
# 268                  -0.3              30  0.241528  0.404591
# 391                  -0.4              30  0.234278  0.399637
# 111                  -0.4              30  0.234278  0.399637
# 288                  -0.4              25  0.241528  0.404591
# 314                  -0.3              30  0.241528  0.404591
# 155                  -0.3              25  0.234278  0.399637
# 260                  -0.3              25  0.234278  0.399637
# 32                   -0.4              25  0.241528  0.404591
# 234                  -0.5              25  0.241528  0.404591
#
#          test_data_start_date        test_data_end_date
# 58  2021-02-16 14:45:00+00:00 2021-12-30 19:30:00+00:00
# 432 2022-01-02 10:00:00+00:00 2022-12-30 21:00:00+00:00
# 485 2021-02-16 14:45:00+00:00 2021-12-30 19:30:00+00:00
# 193 2022-01-02 10:00:00+00:00 2022-12-30 21:00:00+00:00
# 390 2021-02-16 14:45:00+00:00 2021-12-30 19:30:00+00:00
# 167 2021-02-16 14:45:00+00:00 2021-12-30 19:30:00+00:00
# 251 2021-02-16 14:45:00+00:00 2021-12-30 19:30:00+00:00
# 195 2022-01-02 10:00:00+00:00 2022-12-30 21:00:00+00:00
# 188 2021-02-16 14:45:00+00:00 2021-12-30 19:30:00+00:00
# 248 2022-01-02 10:00:00+00:00 2022-12-30 21:00:00+00:00
# 151 2021-02-16 14:45:00+00:00 2021-12-30 19:30:00+00:00
# 268 2021-02-16 14:45:00+00:00 2021-12-30 19:30:00+00:00
# 391 2022-01-02 10:00:00+00:00 2022-12-30 21:00:00+00:00
# 111 2022-01-02 10:00:00+00:00 2022-12-30 21:00:00+00:00
# 288 2021-02-16 14:45:00+00:00 2021-12-30 19:30:00+00:00
# 314 2021-02-16 14:45:00+00:00 2021-12-30 19:30:00+00:00
# 155 2022-01-02 10:00:00+00:00 2022-12-30 21:00:00+00:00
# 260 2022-01-02 10:00:00+00:00 2022-12-30 21:00:00+00:00
# 32  2021-02-16 14:45:00+00:00 2021-12-30 19:30:00+00:00
# 234 2021-02-16 14:45:00+00:00 2021-12-30 19:30:00+00:00

# %%
data.loc[58]['sharpe_analysis']
# Out:
# {'sharperatio': 0}

# %%
get_nested_value(data.loc[334]['trade_analysis'], ['streak', 'won', 'longest'])
# Out:
# 20

# %%
def get_trade_analysis_overview(df):
  selected_columns = [
      'start_date', 'end_date', 'final_portfolio_value', 'trade_buy_threshold',
      'trade_sell_threshold', 'trade_leverage', 'val_loss', 'val_mae',
      'test_data_start_date', 'test_data_end_date', 'trade_analysis', 'drawdown_analysis'
  ]
  df = df[selected_columns].copy().sort_values(by='final_portfolio_value', ascending=False)
  df['total_trade'] = df['trade_analysis'].apply(lambda x: x['total']['total'])
  df['longest_won_streak'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['streak', 'won', 'longest']))
  df['longest_lost_streak'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['streak', 'lost', 'longest']))
  df['total_pnl'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['pnl', 'net', 'total']))
  df['avg_pnl'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['pnl', 'net', 'average']))
  df['total_win_trade'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['won', 'total']))
  df['total_won_amount'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['won', 'pnl', 'total']))
  df['max_won_amount'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['won', 'pnl', 'max']))
  df['avg_won_amount'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['won', 'pnl', 'average']))
  df['total_loss_trade'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['lost', 'total']))
  df['total_lost_amount'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['lost', 'pnl', 'total']))
  df['max_lost_amount'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['lost', 'pnl', 'max']))
  df['avg_lost_amount'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['lost', 'pnl', 'average']))
  df['max_drawdown_percent'] = df['drawdown_analysis'].apply(lambda x: get_nested_value(x, ['max', 'drawdown']))
  df['max_drawdown_value'] = df['drawdown_analysis'].apply(lambda x: get_nested_value(x, ['max', 'moneydown']))
  df['max_drawdown_len'] = df['drawdown_analysis'].apply(lambda x: get_nested_value(x, ['max', 'len']))
  del df['trade_analysis']
  del df['drawdown_analysis']
  return df

# %%
trade_data = get_trade_analysis_overview(data)
trade_data
# Out:
#      start_date    end_date  final_portfolio_value  trade_buy_threshold  \
# 58   01-01-2017  31-12-2021          311840.504217                  0.4
# 432  01-01-2018  31-12-2022          301929.699513                  0.3
# 485  01-01-2017  31-12-2021          301691.760036                  0.3
# 193  01-01-2018  31-12-2022          299590.981454                  0.4
# 390  01-01-2017  31-12-2021          290713.266129                  0.4
# ..          ...         ...                    ...                  ...
# 393  01-01-2018  31-12-2022           10738.446121                  0.4
# 312  01-01-2018  31-12-2022            9821.912480                  0.7
# 348  01-01-2018  31-12-2022            9805.742091                  0.3
# 419  01-01-2018  31-12-2022            9497.453249                  0.5
# 194  01-01-2018  31-12-2022            9448.571586                  0.6
#
#      trade_sell_threshold  trade_leverage  val_loss   val_mae  \
# 58                   -0.4              30  0.241528  0.404591
# 432                  -0.3              30  0.234278  0.399637
# 485                  -0.4              30  0.241528  0.404591
# 193                  -0.3              30  0.234278  0.399637
# 390                  -0.3              30  0.241528  0.404591
# ..                    ...             ...       ...       ...
# 393                  -0.7              10  0.234278  0.399637
# 312                  -0.7              10  0.234278  0.399637
# 348                  -0.7              10  0.234278  0.399637
# 419                  -0.7              10  0.234278  0.399637
# 194                  -0.7              10  0.234278  0.399637
#
#          test_data_start_date        test_data_end_date  ...  \
# 58  2021-02-16 14:45:00+00:00 2021-12-30 19:30:00+00:00  ...
# 432 2022-01-02 10:00:00+00:00 2022-12-30 21:00:00+00:00  ...
# 485 2021-02-16 14:45:00+00:00 2021-12-30 19:30:00+00:00  ...
# 193 2022-01-02 10:00:00+00:00 2022-12-30 21:00:00+00:00  ...
# 390 2021-02-16 14:45:00+00:00 2021-12-30 19:30:00+00:00  ...
# ..                        ...                       ...  ...
# 393 2022-01-02 10:00:00+00:00 2022-12-30 21:00:00+00:00  ...
# 312 2022-01-02 10:00:00+00:00 2022-12-30 21:00:00+00:00  ...
# 348 2022-01-02 10:00:00+00:00 2022-12-30 21:00:00+00:00  ...
# 419 2022-01-02 10:00:00+00:00 2022-12-30 21:00:00+00:00  ...
# 194 2022-01-02 10:00:00+00:00 2022-12-30 21:00:00+00:00  ...
#
#      total_won_amount  max_won_amount  avg_won_amount  total_loss_trade  \
# 58             410076            2986             458               202
# 432            367636            2646             334               236
# 485            409550            2374             404               264
# 193            356732            2858             384               186
# 390            400124            2986             406               224
# ..                ...             ...             ...               ...
# 393              1826             718             262                 2
# 312               946             384             236                 2
# 348              1038             686             208                 2
# 419              1442             698             288                 4
# 194              1522             950             304                 2
#
#      total_lost_amount  max_lost_amount  avg_lost_amount  \
# 58             -108110            -4346             -534
# 432             -75764            -3864             -320
# 485            -117882            -4626             -446
# 193             -67008            -3864             -360
# 390            -119280            -4350             -532
# ..                 ...              ...              ...
# 393              -1130            -1130            -1130
# 312              -1200            -1042             -600
# 348              -1232            -1158             -616
# 419              -1944             -994             -648
# 194              -2152            -1160            -1076
#
#      max_drawdown_percent  max_drawdown_value  max_drawdown_len
# 58                     20                5462               916
# 432                    12                5168               642
# 485                    16                6162               620
# 193                    12                5132               740
# 390                    22                5712              1542
# ..                    ...                 ...               ...
# 393                    18                1740             23048
# 312                    18                1866             25860
# 348                    18                1734             26010
# 419                    28                3160             16906
# 194                    28                3160             16296
#
# [500 rows x 26 columns]

# %%
trade_data.columns
# Out:
# Index(['start_date', 'end_date', 'final_portfolio_value',
#        'trade_buy_threshold', 'trade_sell_threshold', 'trade_leverage',
#        'val_loss', 'val_mae', 'test_data_start_date', 'test_data_end_date',
#        'total_trade', 'longest_won_streak', 'longest_lost_streak', 'total_pnl',
#        'avg_pnl', 'total_win_trade', 'total_won_amount', 'max_won_amount',
#        'avg_won_amount', 'total_loss_trade', 'total_lost_amount',
#        'max_lost_amount', 'avg_lost_amount', 'max_drawdown_percent',
#        'max_drawdown_value', 'max_drawdown_len'],
#       dtype='object')

# %%
trade_data.query('max_drawdown_percent < 20 and final_portfolio_value > 50000')
# Out:
#      start_date    end_date  final_portfolio_value  trade_buy_threshold  \
# 432  01-01-2018  31-12-2022          301929.699513                  0.3
# 485  01-01-2017  31-12-2021          301691.760036                  0.3
# 193  01-01-2018  31-12-2022          299590.981454                  0.4
# 167  01-01-2017  31-12-2021          288834.521563                  0.4
# 195  01-01-2018  31-12-2022          276187.687585                  0.5
# ..          ...         ...                    ...                  ...
# 102  01-01-2018  31-12-2022           52765.173152                  0.6
# 293  01-01-2018  31-12-2022           51706.277652                  0.7
# 190  01-01-2018  31-12-2022           51589.305020                  0.7
# 93   01-01-2019  31-12-2023           51503.742865                  0.6
# 78   01-01-2017  31-12-2021           50667.091065                  0.7
#
#      trade_sell_threshold  trade_leverage  val_loss   val_mae  \
# 432                  -0.3              30  0.234278  0.399637
# 485                  -0.4              30  0.241528  0.404591
# 193                  -0.3              30  0.234278  0.399637
# 167                  -0.5              30  0.241528  0.404591
# 195                  -0.3              30  0.234278  0.399637
# ..                    ...             ...       ...       ...
# 102                  -0.6              15  0.234278  0.399637
# 293                  -0.6              15  0.234278  0.399637
# 190                  -0.3              10  0.234278  0.399637
# 93                   -0.4              10  0.242706  0.408474
# 78                   -0.6              10  0.241528  0.404591
#
#          test_data_start_date        test_data_end_date  ...  \
# 432 2022-01-02 10:00:00+00:00 2022-12-30 21:00:00+00:00  ...
# 485 2021-02-16 14:45:00+00:00 2021-12-30 19:30:00+00:00  ...
# 193 2022-01-02 10:00:00+00:00 2022-12-30 21:00:00+00:00  ...
# 167 2021-02-16 14:45:00+00:00 2021-12-30 19:30:00+00:00  ...
# 195 2022-01-02 10:00:00+00:00 2022-12-30 21:00:00+00:00  ...
# ..                        ...                       ...  ...
# 102 2022-01-02 10:00:00+00:00 2022-12-30 21:00:00+00:00  ...
# 293 2022-01-02 10:00:00+00:00 2022-12-30 21:00:00+00:00  ...
# 190 2022-01-02 10:00:00+00:00 2022-12-30 21:00:00+00:00  ...
# 93  2023-01-01 21:00:00+00:00 2023-12-30 17:30:00+00:00  ...
# 78  2021-02-16 14:45:00+00:00 2021-12-30 19:30:00+00:00  ...
#
#      total_won_amount  max_won_amount  avg_won_amount  total_loss_trade  \
# 432            367636            2646             334               236
# 485            409550            2374             404               264
# 193            356732            2858             384               186
# 167            370026            3026             524               158
# 195            327324            4142             500               134
# ..                ...             ...             ...               ...
# 102             60130            2306             608                24
# 293             52194            3504             932                12
# 190             48438            2526             414                32
# 93              50208             984             178                44
# 78              49854            2308             494                20
#
#      total_lost_amount  max_lost_amount  avg_lost_amount  \
# 432             -75764            -3864             -320
# 485            -117882            -4626             -446
# 193             -67008            -3864             -360
# 167             -91226            -3798             -576
# 195             -61180            -3864             -456
# ..                 ...              ...              ...
# 102             -17480            -3768             -760
# 293             -10604            -3632             -884
# 190              -6996            -1026             -226
# 93               -8782             -920             -204
# 78               -9138            -1434             -456
#
#      max_drawdown_percent  max_drawdown_value  max_drawdown_len
# 432                    12                5168               642
# 485                    16                6162               620
# 193                    12                5132               740
# 167                    18                5772              1216
# 195                    14                5132               942
# ..                    ...                 ...               ...
# 102                    18                6100              5348
# 293                    16                6338              7520
# 190                    10                1914              2654
# 93                     10                1382               940
# 78                     14                2676              5256
#
# [236 rows x 26 columns]

# %%
top_performing_param = trade_data.groupby(['trade_buy_threshold', 'trade_sell_threshold', 'trade_leverage']).agg({
    'final_portfolio_value': 'mean',
    'total_trade': 'mean',
    'total_pnl': 'sum',
    'longest_won_streak': 'mean',
    'longest_lost_streak': 'max',
    'max_drawdown_percent': 'max',
    'max_drawdown_value': 'max',
    'max_drawdown_len': 'max',
    'avg_lost_amount': 'mean',
    'max_lost_amount': 'max'
}).sort_values(by='final_portfolio_value', ascending=False).head(30)
top_performing_param
# Out:
#                                                          final_portfolio_value  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.4                 30                      253127.115805
#                     -0.3                 30                      251127.478716
# 0.3                 -0.3                 30                      248893.578402
#                     -0.4                 30                      247610.185347
# 0.5                 -0.4                 30                      226995.008096
# 0.4                 -0.4                 25                      215461.794103
# 0.5                 -0.3                 30                      214604.736977
# 0.4                 -0.5                 30                      213514.126841
#                     -0.3                 25                      212326.479799
# 0.3                 -0.3                 25                      210989.867231
#                     -0.4                 25                      208320.806627
# 0.5                 -0.5                 30                      207400.957563
# 0.3                 -0.5                 30                      198781.242030
# 0.5                 -0.4                 25                      190601.256780
#                     -0.3                 25                      182195.838610
# 0.4                 -0.5                 25                      180540.095156
#                     -0.4                 20                      178017.632292
# 0.5                 -0.5                 25                      177657.735025
# 0.4                 -0.3                 20                      177562.298342
# 0.3                 -0.3                 20                      177068.935376
#                     -0.4                 20                      174176.812894
# 0.6                 -0.5                 30                      170357.723204
# 0.3                 -0.5                 25                      168156.608597
# 0.6                 -0.4                 30                      167934.609514
# 0.5                 -0.4                 20                      160213.255984
# 0.6                 -0.3                 30                      152824.225650
# 0.5                 -0.3                 20                      150630.770316
# 0.4                 -0.5                 20                      149685.363968
# 0.5                 -0.5                 20                      147986.757069
# 0.4                 -0.6                 30                      146218.990091
#
#                                                          total_trade  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.4                 30                    932.0
#                     -0.3                 30                   1120.5
# 0.3                 -0.3                 30                   1356.5
#                     -0.4                 30                   1073.0
# 0.5                 -0.4                 30                    693.0
# 0.4                 -0.4                 25                    939.5
# 0.5                 -0.3                 30                    779.5
# 0.4                 -0.5                 30                    644.0
#                     -0.3                 25                   1128.0
# 0.3                 -0.3                 25                   1368.0
#                     -0.4                 25                   1077.5
# 0.5                 -0.5                 30                    527.5
# 0.3                 -0.5                 30                    703.5
# 0.5                 -0.4                 25                    696.5
#                     -0.3                 25                    786.5
# 0.4                 -0.5                 25                    648.0
#                     -0.4                 20                    958.0
# 0.5                 -0.5                 25                    532.5
# 0.4                 -0.3                 20                   1153.5
# 0.3                 -0.3                 20                   1397.5
#                     -0.4                 20                   1100.5
# 0.6                 -0.5                 30                    330.5
# 0.3                 -0.5                 25                    708.0
# 0.6                 -0.4                 30                    382.5
# 0.5                 -0.4                 20                    714.0
# 0.6                 -0.3                 30                    409.0
# 0.5                 -0.3                 20                    799.0
# 0.4                 -0.5                 20                    662.0
# 0.5                 -0.5                 20                    544.0
# 0.4                 -0.6                 30                    333.0
#
#                                                          total_pnl  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.4                 30                 973184
#                     -0.3                 30                 965080
# 0.3                 -0.3                 30                 955946
#                     -0.4                 30                 950796
# 0.5                 -0.4                 30                 868580
# 0.4                 -0.4                 25                 822412
# 0.5                 -0.3                 30                 819370
# 0.4                 -0.5                 30                 813868
#                     -0.3                 25                 809780
# 0.3                 -0.3                 25                 804270
#                     -0.4                 25                 793580
# 0.5                 -0.5                 30                 789582
# 0.3                 -0.5                 30                 754852
# 0.5                 -0.4                 25                 722906
#                     -0.3                 25                 689576
# 0.4                 -0.5                 25                 682004
#                     -0.4                 20                 672522
# 0.5                 -0.5                 25                 670614
# 0.4                 -0.3                 20                 670628
# 0.3                 -0.3                 20                 668526
#                     -0.4                 20                 656946
# 0.6                 -0.5                 30                 641626
# 0.3                 -0.5                 25                 632400
# 0.6                 -0.4                 30                 630914
# 0.5                 -0.4                 20                 601256
# 0.6                 -0.3                 30                 570618
# 0.5                 -0.3                 20                 563158
# 0.4                 -0.5                 20                 558616
# 0.5                 -0.5                 20                 551932
# 0.4                 -0.6                 30                 544560
#
#                                                          longest_won_streak  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.4                 30                            26.0
#                     -0.3                 30                            27.0
# 0.3                 -0.3                 30                            30.0
#                     -0.4                 30                            22.0
# 0.5                 -0.4                 30                            30.5
# 0.4                 -0.4                 25                            26.0
# 0.5                 -0.3                 30                            24.5
# 0.4                 -0.5                 30                            25.0
#                     -0.3                 25                            27.0
# 0.3                 -0.3                 25                            30.0
#                     -0.4                 25                            21.0
# 0.5                 -0.5                 30                            30.5
# 0.3                 -0.5                 30                            25.0
# 0.5                 -0.4                 25                            30.5
#                     -0.3                 25                            24.5
# 0.4                 -0.5                 25                            25.0
#                     -0.4                 20                            26.0
# 0.5                 -0.5                 25                            30.0
# 0.4                 -0.3                 20                            27.0
# 0.3                 -0.3                 20                            30.5
#                     -0.4                 20                            21.0
# 0.6                 -0.5                 30                            26.0
# 0.3                 -0.5                 25                            25.0
# 0.6                 -0.4                 30                            22.5
# 0.5                 -0.4                 20                            30.5
# 0.6                 -0.3                 30                            20.5
# 0.5                 -0.3                 20                            24.5
# 0.4                 -0.5                 20                            25.0
# 0.5                 -0.5                 20                            30.0
# 0.4                 -0.6                 30                            24.0
#
#                                                          longest_lost_streak  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.4                 30                                4
#                     -0.3                 30                                4
# 0.3                 -0.3                 30                                6
#                     -0.4                 30                                4
# 0.5                 -0.4                 30                                4
# 0.4                 -0.4                 25                                4
# 0.5                 -0.3                 30                                4
# 0.4                 -0.5                 30                                6
#                     -0.3                 25                                4
# 0.3                 -0.3                 25                                6
#                     -0.4                 25                                4
# 0.5                 -0.5                 30                                4
# 0.3                 -0.5                 30                                4
# 0.5                 -0.4                 25                                4
#                     -0.3                 25                                4
# 0.4                 -0.5                 25                                6
#                     -0.4                 20                                4
# 0.5                 -0.5                 25                                4
# 0.4                 -0.3                 20                                4
# 0.3                 -0.3                 20                                4
#                     -0.4                 20                                4
# 0.6                 -0.5                 30                                4
# 0.3                 -0.5                 25                                4
# 0.6                 -0.4                 30                                4
# 0.5                 -0.4                 20                                4
# 0.6                 -0.3                 30                                4
# 0.5                 -0.3                 20                                4
# 0.4                 -0.5                 20                                6
# 0.5                 -0.5                 20                                4
# 0.4                 -0.6                 30                                4
#
#                                                          max_drawdown_percent  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.4                 30                                30
#                     -0.3                 30                                40
# 0.3                 -0.3                 30                                32
#                     -0.4                 30                                28
# 0.5                 -0.4                 30                                28
# 0.4                 -0.4                 25                                26
# 0.5                 -0.3                 30                                32
# 0.4                 -0.5                 30                                22
#                     -0.3                 25                                34
# 0.3                 -0.3                 25                                26
#                     -0.4                 25                                24
# 0.5                 -0.5                 30                                24
# 0.3                 -0.5                 30                                24
# 0.5                 -0.4                 25                                24
#                     -0.3                 25                                28
# 0.4                 -0.5                 25                                20
#                     -0.4                 20                                22
# 0.5                 -0.5                 25                                20
# 0.4                 -0.3                 20                                28
# 0.3                 -0.3                 20                                22
#                     -0.4                 20                                20
# 0.6                 -0.5                 30                                36
# 0.3                 -0.5                 25                                20
# 0.6                 -0.4                 30                                40
# 0.5                 -0.4                 20                                20
# 0.6                 -0.3                 30                                44
# 0.5                 -0.3                 20                                22
# 0.4                 -0.5                 20                                16
# 0.5                 -0.5                 20                                18
# 0.4                 -0.6                 30                                30
#
#                                                          max_drawdown_value  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.4                 30                            5462
#                     -0.3                 30                            5712
# 0.3                 -0.3                 30                            6008
#                     -0.4                 30                            6162
# 0.5                 -0.4                 30                            6164
# 0.4                 -0.4                 25                            4552
# 0.5                 -0.3                 30                            5886
# 0.4                 -0.5                 30                            7508
#                     -0.3                 25                            4760
# 0.3                 -0.3                 25                            5006
#                     -0.4                 25                            5136
# 0.5                 -0.5                 30                            7482
# 0.3                 -0.5                 30                            8576
# 0.5                 -0.4                 25                            5136
#                     -0.3                 25                            4906
# 0.4                 -0.5                 25                            6258
#                     -0.4                 20                            3640
# 0.5                 -0.5                 25                            6234
# 0.4                 -0.3                 20                            3808
# 0.3                 -0.3                 20                            4004
#                     -0.4                 20                            4108
# 0.6                 -0.5                 30                            7384
# 0.3                 -0.5                 25                            7148
# 0.6                 -0.4                 30                            6814
# 0.5                 -0.4                 20                            4108
# 0.6                 -0.3                 30                            7464
# 0.5                 -0.3                 20                            3990
# 0.4                 -0.5                 20                            5006
# 0.5                 -0.5                 20                            4988
# 0.4                 -0.6                 30                           13334
#
#                                                          max_drawdown_len  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.4                 30                          1994
#                     -0.3                 30                          1668
# 0.3                 -0.3                 30                          1376
#                     -0.4                 30                          1172
# 0.5                 -0.4                 30                          1690
# 0.4                 -0.4                 25                          1994
# 0.5                 -0.3                 30                          1826
# 0.4                 -0.5                 30                          1902
#                     -0.3                 25                          1668
# 0.3                 -0.3                 25                          1376
#                     -0.4                 25                          1172
# 0.5                 -0.5                 30                          1898
# 0.3                 -0.5                 30                          1408
# 0.5                 -0.4                 25                          1690
#                     -0.3                 25                          1826
# 0.4                 -0.5                 25                          1902
#                     -0.4                 20                          1260
# 0.5                 -0.5                 25                          1726
# 0.4                 -0.3                 20                          1542
# 0.3                 -0.3                 20                          1376
#                     -0.4                 20                           918
# 0.6                 -0.5                 30                          3550
# 0.3                 -0.5                 25                          1408
# 0.6                 -0.4                 30                          3550
# 0.5                 -0.4                 20                          1444
# 0.6                 -0.3                 30                          3572
# 0.5                 -0.3                 20                          1832
# 0.4                 -0.5                 20                          1504
# 0.5                 -0.5                 20                          1332
# 0.4                 -0.6                 30                          4016
#
#                                                          avg_lost_amount  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.4                 30                       -395.0
#                     -0.3                 30                       -373.0
# 0.3                 -0.3                 30                       -317.0
#                     -0.4                 30                       -360.5
# 0.5                 -0.4                 30                       -476.5
# 0.4                 -0.4                 25                       -329.0
# 0.5                 -0.3                 30                       -455.5
# 0.4                 -0.5                 30                       -463.5
#                     -0.3                 25                       -310.5
# 0.3                 -0.3                 25                       -263.5
#                     -0.4                 25                       -303.0
# 0.5                 -0.5                 30                       -544.5
# 0.3                 -0.5                 30                       -464.0
# 0.5                 -0.4                 25                       -401.5
#                     -0.3                 25                       -376.0
# 0.4                 -0.5                 25                       -388.5
#                     -0.4                 20                       -265.0
# 0.5                 -0.5                 25                       -448.5
# 0.4                 -0.3                 20                       -247.5
# 0.3                 -0.3                 20                       -212.0
#                     -0.4                 20                       -242.5
# 0.6                 -0.5                 30                       -716.0
# 0.3                 -0.5                 25                       -390.5
# 0.6                 -0.4                 30                       -661.5
# 0.5                 -0.4                 20                       -319.0
# 0.6                 -0.3                 30                       -662.5
# 0.5                 -0.3                 20                       -301.0
# 0.4                 -0.5                 20                       -314.5
# 0.5                 -0.5                 20                       -357.5
# 0.4                 -0.6                 30                       -726.5
#
#                                                          max_lost_amount
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.4                 30                        -2262
#                     -0.3                 30                        -2364
# 0.3                 -0.3                 30                        -2640
#                     -0.4                 30                        -2668
# 0.5                 -0.4                 30                        -2534
# 0.4                 -0.4                 25                        -1886
# 0.5                 -0.3                 30                        -2776
# 0.4                 -0.5                 30                        -2410
#                     -0.3                 25                        -1970
# 0.3                 -0.3                 25                        -2200
#                     -0.4                 25                        -2224
# 0.5                 -0.5                 30                        -2304
# 0.3                 -0.5                 30                        -1792
# 0.5                 -0.4                 25                        -2110
#                     -0.3                 25                        -2314
# 0.4                 -0.5                 25                        -2008
#                     -0.4                 20                        -1508
# 0.5                 -0.5                 25                        -1920
# 0.4                 -0.3                 20                        -1576
# 0.3                 -0.3                 20                        -1760
#                     -0.4                 20                        -1778
# 0.6                 -0.5                 30                        -2764
# 0.3                 -0.5                 25                        -1492
# 0.6                 -0.4                 30                        -2798
# 0.5                 -0.4                 20                        -1688
# 0.6                 -0.3                 30                        -3208
# 0.5                 -0.3                 20                        -1850
# 0.4                 -0.5                 20                        -1606
# 0.5                 -0.5                 20                        -1536
# 0.4                 -0.6                 30                        -2358

# %%
top_performing_param.sort_values(by='max_drawdown_value', ascending=True) # lesser drawdown
# Out:
#                                                          final_portfolio_value  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.4                 20                      178017.632292
#                     -0.3                 20                      177562.298342
# 0.5                 -0.3                 20                      150630.770316
# 0.3                 -0.3                 20                      177068.935376
# 0.5                 -0.4                 20                      160213.255984
# 0.3                 -0.4                 20                      174176.812894
# 0.4                 -0.4                 25                      215461.794103
#                     -0.3                 25                      212326.479799
# 0.5                 -0.3                 25                      182195.838610
#                     -0.5                 20                      147986.757069
# 0.4                 -0.5                 20                      149685.363968
# 0.3                 -0.3                 25                      210989.867231
#                     -0.4                 25                      208320.806627
# 0.5                 -0.4                 25                      190601.256780
# 0.4                 -0.4                 30                      253127.115805
#                     -0.3                 30                      251127.478716
# 0.5                 -0.3                 30                      214604.736977
# 0.3                 -0.3                 30                      248893.578402
#                     -0.4                 30                      247610.185347
# 0.5                 -0.4                 30                      226995.008096
#                     -0.5                 25                      177657.735025
# 0.4                 -0.5                 25                      180540.095156
# 0.6                 -0.4                 30                      167934.609514
# 0.3                 -0.5                 25                      168156.608597
# 0.6                 -0.5                 30                      170357.723204
#                     -0.3                 30                      152824.225650
# 0.5                 -0.5                 30                      207400.957563
# 0.4                 -0.5                 30                      213514.126841
# 0.3                 -0.5                 30                      198781.242030
# 0.4                 -0.6                 30                      146218.990091
#
#                                                          total_trade  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.4                 20                    958.0
#                     -0.3                 20                   1153.5
# 0.5                 -0.3                 20                    799.0
# 0.3                 -0.3                 20                   1397.5
# 0.5                 -0.4                 20                    714.0
# 0.3                 -0.4                 20                   1100.5
# 0.4                 -0.4                 25                    939.5
#                     -0.3                 25                   1128.0
# 0.5                 -0.3                 25                    786.5
#                     -0.5                 20                    544.0
# 0.4                 -0.5                 20                    662.0
# 0.3                 -0.3                 25                   1368.0
#                     -0.4                 25                   1077.5
# 0.5                 -0.4                 25                    696.5
# 0.4                 -0.4                 30                    932.0
#                     -0.3                 30                   1120.5
# 0.5                 -0.3                 30                    779.5
# 0.3                 -0.3                 30                   1356.5
#                     -0.4                 30                   1073.0
# 0.5                 -0.4                 30                    693.0
#                     -0.5                 25                    532.5
# 0.4                 -0.5                 25                    648.0
# 0.6                 -0.4                 30                    382.5
# 0.3                 -0.5                 25                    708.0
# 0.6                 -0.5                 30                    330.5
#                     -0.3                 30                    409.0
# 0.5                 -0.5                 30                    527.5
# 0.4                 -0.5                 30                    644.0
# 0.3                 -0.5                 30                    703.5
# 0.4                 -0.6                 30                    333.0
#
#                                                          total_pnl  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.4                 20                 672522
#                     -0.3                 20                 670628
# 0.5                 -0.3                 20                 563158
# 0.3                 -0.3                 20                 668526
# 0.5                 -0.4                 20                 601256
# 0.3                 -0.4                 20                 656946
# 0.4                 -0.4                 25                 822412
#                     -0.3                 25                 809780
# 0.5                 -0.3                 25                 689576
#                     -0.5                 20                 551932
# 0.4                 -0.5                 20                 558616
# 0.3                 -0.3                 25                 804270
#                     -0.4                 25                 793580
# 0.5                 -0.4                 25                 722906
# 0.4                 -0.4                 30                 973184
#                     -0.3                 30                 965080
# 0.5                 -0.3                 30                 819370
# 0.3                 -0.3                 30                 955946
#                     -0.4                 30                 950796
# 0.5                 -0.4                 30                 868580
#                     -0.5                 25                 670614
# 0.4                 -0.5                 25                 682004
# 0.6                 -0.4                 30                 630914
# 0.3                 -0.5                 25                 632400
# 0.6                 -0.5                 30                 641626
#                     -0.3                 30                 570618
# 0.5                 -0.5                 30                 789582
# 0.4                 -0.5                 30                 813868
# 0.3                 -0.5                 30                 754852
# 0.4                 -0.6                 30                 544560
#
#                                                          longest_won_streak  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.4                 20                            26.0
#                     -0.3                 20                            27.0
# 0.5                 -0.3                 20                            24.5
# 0.3                 -0.3                 20                            30.5
# 0.5                 -0.4                 20                            30.5
# 0.3                 -0.4                 20                            21.0
# 0.4                 -0.4                 25                            26.0
#                     -0.3                 25                            27.0
# 0.5                 -0.3                 25                            24.5
#                     -0.5                 20                            30.0
# 0.4                 -0.5                 20                            25.0
# 0.3                 -0.3                 25                            30.0
#                     -0.4                 25                            21.0
# 0.5                 -0.4                 25                            30.5
# 0.4                 -0.4                 30                            26.0
#                     -0.3                 30                            27.0
# 0.5                 -0.3                 30                            24.5
# 0.3                 -0.3                 30                            30.0
#                     -0.4                 30                            22.0
# 0.5                 -0.4                 30                            30.5
#                     -0.5                 25                            30.0
# 0.4                 -0.5                 25                            25.0
# 0.6                 -0.4                 30                            22.5
# 0.3                 -0.5                 25                            25.0
# 0.6                 -0.5                 30                            26.0
#                     -0.3                 30                            20.5
# 0.5                 -0.5                 30                            30.5
# 0.4                 -0.5                 30                            25.0
# 0.3                 -0.5                 30                            25.0
# 0.4                 -0.6                 30                            24.0
#
#                                                          longest_lost_streak  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.4                 20                                4
#                     -0.3                 20                                4
# 0.5                 -0.3                 20                                4
# 0.3                 -0.3                 20                                4
# 0.5                 -0.4                 20                                4
# 0.3                 -0.4                 20                                4
# 0.4                 -0.4                 25                                4
#                     -0.3                 25                                4
# 0.5                 -0.3                 25                                4
#                     -0.5                 20                                4
# 0.4                 -0.5                 20                                6
# 0.3                 -0.3                 25                                6
#                     -0.4                 25                                4
# 0.5                 -0.4                 25                                4
# 0.4                 -0.4                 30                                4
#                     -0.3                 30                                4
# 0.5                 -0.3                 30                                4
# 0.3                 -0.3                 30                                6
#                     -0.4                 30                                4
# 0.5                 -0.4                 30                                4
#                     -0.5                 25                                4
# 0.4                 -0.5                 25                                6
# 0.6                 -0.4                 30                                4
# 0.3                 -0.5                 25                                4
# 0.6                 -0.5                 30                                4
#                     -0.3                 30                                4
# 0.5                 -0.5                 30                                4
# 0.4                 -0.5                 30                                6
# 0.3                 -0.5                 30                                4
# 0.4                 -0.6                 30                                4
#
#                                                          max_drawdown_percent  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.4                 20                                22
#                     -0.3                 20                                28
# 0.5                 -0.3                 20                                22
# 0.3                 -0.3                 20                                22
# 0.5                 -0.4                 20                                20
# 0.3                 -0.4                 20                                20
# 0.4                 -0.4                 25                                26
#                     -0.3                 25                                34
# 0.5                 -0.3                 25                                28
#                     -0.5                 20                                18
# 0.4                 -0.5                 20                                16
# 0.3                 -0.3                 25                                26
#                     -0.4                 25                                24
# 0.5                 -0.4                 25                                24
# 0.4                 -0.4                 30                                30
#                     -0.3                 30                                40
# 0.5                 -0.3                 30                                32
# 0.3                 -0.3                 30                                32
#                     -0.4                 30                                28
# 0.5                 -0.4                 30                                28
#                     -0.5                 25                                20
# 0.4                 -0.5                 25                                20
# 0.6                 -0.4                 30                                40
# 0.3                 -0.5                 25                                20
# 0.6                 -0.5                 30                                36
#                     -0.3                 30                                44
# 0.5                 -0.5                 30                                24
# 0.4                 -0.5                 30                                22
# 0.3                 -0.5                 30                                24
# 0.4                 -0.6                 30                                30
#
#                                                          max_drawdown_value  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.4                 20                            3640
#                     -0.3                 20                            3808
# 0.5                 -0.3                 20                            3990
# 0.3                 -0.3                 20                            4004
# 0.5                 -0.4                 20                            4108
# 0.3                 -0.4                 20                            4108
# 0.4                 -0.4                 25                            4552
#                     -0.3                 25                            4760
# 0.5                 -0.3                 25                            4906
#                     -0.5                 20                            4988
# 0.4                 -0.5                 20                            5006
# 0.3                 -0.3                 25                            5006
#                     -0.4                 25                            5136
# 0.5                 -0.4                 25                            5136
# 0.4                 -0.4                 30                            5462
#                     -0.3                 30                            5712
# 0.5                 -0.3                 30                            5886
# 0.3                 -0.3                 30                            6008
#                     -0.4                 30                            6162
# 0.5                 -0.4                 30                            6164
#                     -0.5                 25                            6234
# 0.4                 -0.5                 25                            6258
# 0.6                 -0.4                 30                            6814
# 0.3                 -0.5                 25                            7148
# 0.6                 -0.5                 30                            7384
#                     -0.3                 30                            7464
# 0.5                 -0.5                 30                            7482
# 0.4                 -0.5                 30                            7508
# 0.3                 -0.5                 30                            8576
# 0.4                 -0.6                 30                           13334
#
#                                                          max_drawdown_len  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.4                 20                          1260
#                     -0.3                 20                          1542
# 0.5                 -0.3                 20                          1832
# 0.3                 -0.3                 20                          1376
# 0.5                 -0.4                 20                          1444
# 0.3                 -0.4                 20                           918
# 0.4                 -0.4                 25                          1994
#                     -0.3                 25                          1668
# 0.5                 -0.3                 25                          1826
#                     -0.5                 20                          1332
# 0.4                 -0.5                 20                          1504
# 0.3                 -0.3                 25                          1376
#                     -0.4                 25                          1172
# 0.5                 -0.4                 25                          1690
# 0.4                 -0.4                 30                          1994
#                     -0.3                 30                          1668
# 0.5                 -0.3                 30                          1826
# 0.3                 -0.3                 30                          1376
#                     -0.4                 30                          1172
# 0.5                 -0.4                 30                          1690
#                     -0.5                 25                          1726
# 0.4                 -0.5                 25                          1902
# 0.6                 -0.4                 30                          3550
# 0.3                 -0.5                 25                          1408
# 0.6                 -0.5                 30                          3550
#                     -0.3                 30                          3572
# 0.5                 -0.5                 30                          1898
# 0.4                 -0.5                 30                          1902
# 0.3                 -0.5                 30                          1408
# 0.4                 -0.6                 30                          4016
#
#                                                          avg_lost_amount  \
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.4                 20                       -265.0
#                     -0.3                 20                       -247.5
# 0.5                 -0.3                 20                       -301.0
# 0.3                 -0.3                 20                       -212.0
# 0.5                 -0.4                 20                       -319.0
# 0.3                 -0.4                 20                       -242.5
# 0.4                 -0.4                 25                       -329.0
#                     -0.3                 25                       -310.5
# 0.5                 -0.3                 25                       -376.0
#                     -0.5                 20                       -357.5
# 0.4                 -0.5                 20                       -314.5
# 0.3                 -0.3                 25                       -263.5
#                     -0.4                 25                       -303.0
# 0.5                 -0.4                 25                       -401.5
# 0.4                 -0.4                 30                       -395.0
#                     -0.3                 30                       -373.0
# 0.5                 -0.3                 30                       -455.5
# 0.3                 -0.3                 30                       -317.0
#                     -0.4                 30                       -360.5
# 0.5                 -0.4                 30                       -476.5
#                     -0.5                 25                       -448.5
# 0.4                 -0.5                 25                       -388.5
# 0.6                 -0.4                 30                       -661.5
# 0.3                 -0.5                 25                       -390.5
# 0.6                 -0.5                 30                       -716.0
#                     -0.3                 30                       -662.5
# 0.5                 -0.5                 30                       -544.5
# 0.4                 -0.5                 30                       -463.5
# 0.3                 -0.5                 30                       -464.0
# 0.4                 -0.6                 30                       -726.5
#
#                                                          max_lost_amount
# trade_buy_threshold trade_sell_threshold trade_leverage
# 0.4                 -0.4                 20                        -1508
#                     -0.3                 20                        -1576
# 0.5                 -0.3                 20                        -1850
# 0.3                 -0.3                 20                        -1760
# 0.5                 -0.4                 20                        -1688
# 0.3                 -0.4                 20                        -1778
# 0.4                 -0.4                 25                        -1886
#                     -0.3                 25                        -1970
# 0.5                 -0.3                 25                        -2314
#                     -0.5                 20                        -1536
# 0.4                 -0.5                 20                        -1606
# 0.3                 -0.3                 25                        -2200
#                     -0.4                 25                        -2224
# 0.5                 -0.4                 25                        -2110
# 0.4                 -0.4                 30                        -2262
#                     -0.3                 30                        -2364
# 0.5                 -0.3                 30                        -2776
# 0.3                 -0.3                 30                        -2640
#                     -0.4                 30                        -2668
# 0.5                 -0.4                 30                        -2534
#                     -0.5                 25                        -1920
# 0.4                 -0.5                 25                        -2008
# 0.6                 -0.4                 30                        -2798
# 0.3                 -0.5                 25                        -1492
# 0.6                 -0.5                 30                        -2764
#                     -0.3                 30                        -3208
# 0.5                 -0.5                 30                        -2304
# 0.4                 -0.5                 30                        -2410
# 0.3                 -0.5                 30                        -1792
# 0.4                 -0.6                 30                        -2358

# %%
top_performing_param.reset_index()
# Out:
#     trade_buy_threshold  trade_sell_threshold  trade_leverage  \
# 0                   0.4                  -0.4              30
# 1                   0.4                  -0.3              30
# 2                   0.3                  -0.3              30
# 3                   0.3                  -0.4              30
# 4                   0.5                  -0.4              30
# 5                   0.4                  -0.4              25
# 6                   0.5                  -0.3              30
# 7                   0.4                  -0.5              30
# 8                   0.4                  -0.3              25
# 9                   0.3                  -0.3              25
# 10                  0.3                  -0.4              25
# 11                  0.5                  -0.5              30
# 12                  0.3                  -0.5              30
# 13                  0.5                  -0.4              25
# 14                  0.5                  -0.3              25
# 15                  0.4                  -0.5              25
# 16                  0.4                  -0.4              20
# 17                  0.5                  -0.5              25
# 18                  0.4                  -0.3              20
# 19                  0.3                  -0.3              20
# 20                  0.3                  -0.4              20
# 21                  0.6                  -0.5              30
# 22                  0.3                  -0.5              25
# 23                  0.6                  -0.4              30
# 24                  0.5                  -0.4              20
# 25                  0.6                  -0.3              30
# 26                  0.5                  -0.3              20
# 27                  0.4                  -0.5              20
# 28                  0.5                  -0.5              20
# 29                  0.4                  -0.6              30
#
#     final_portfolio_value  total_trade  total_pnl  longest_won_streak  \
# 0           253127.115805        932.0     973184                26.0
# 1           251127.478716       1120.5     965080                27.0
# 2           248893.578402       1356.5     955946                30.0
# 3           247610.185347       1073.0     950796                22.0
# 4           226995.008096        693.0     868580                30.5
# 5           215461.794103        939.5     822412                26.0
# 6           214604.736977        779.5     819370                24.5
# 7           213514.126841        644.0     813868                25.0
# 8           212326.479799       1128.0     809780                27.0
# 9           210989.867231       1368.0     804270                30.0
# 10          208320.806627       1077.5     793580                21.0
# 11          207400.957563        527.5     789582                30.5
# 12          198781.242030        703.5     754852                25.0
# 13          190601.256780        696.5     722906                30.5
# 14          182195.838610        786.5     689576                24.5
# 15          180540.095156        648.0     682004                25.0
# 16          178017.632292        958.0     672522                26.0
# 17          177657.735025        532.5     670614                30.0
# 18          177562.298342       1153.5     670628                27.0
# 19          177068.935376       1397.5     668526                30.5
# 20          174176.812894       1100.5     656946                21.0
# 21          170357.723204        330.5     641626                26.0
# 22          168156.608597        708.0     632400                25.0
# 23          167934.609514        382.5     630914                22.5
# 24          160213.255984        714.0     601256                30.5
# 25          152824.225650        409.0     570618                20.5
# 26          150630.770316        799.0     563158                24.5
# 27          149685.363968        662.0     558616                25.0
# 28          147986.757069        544.0     551932                30.0
# 29          146218.990091        333.0     544560                24.0
#
#     longest_lost_streak  max_drawdown_percent  max_drawdown_value  \
# 0                     4                    30                5462
# 1                     4                    40                5712
# 2                     6                    32                6008
# 3                     4                    28                6162
# 4                     4                    28                6164
# 5                     4                    26                4552
# 6                     4                    32                5886
# 7                     6                    22                7508
# 8                     4                    34                4760
# 9                     6                    26                5006
# 10                    4                    24                5136
# 11                    4                    24                7482
# 12                    4                    24                8576
# 13                    4                    24                5136
# 14                    4                    28                4906
# 15                    6                    20                6258
# 16                    4                    22                3640
# 17                    4                    20                6234
# 18                    4                    28                3808
# 19                    4                    22                4004
# 20                    4                    20                4108
# 21                    4                    36                7384
# 22                    4                    20                7148
# 23                    4                    40                6814
# 24                    4                    20                4108
# 25                    4                    44                7464
# 26                    4                    22                3990
# 27                    6                    16                5006
# 28                    4                    18                4988
# 29                    4                    30               13334
#
#     max_drawdown_len  avg_lost_amount  max_lost_amount
# 0               1994           -395.0            -2262
# 1               1668           -373.0            -2364
# 2               1376           -317.0            -2640
# 3               1172           -360.5            -2668
# 4               1690           -476.5            -2534
# 5               1994           -329.0            -1886
# 6               1826           -455.5            -2776
# 7               1902           -463.5            -2410
# 8               1668           -310.5            -1970
# 9               1376           -263.5            -2200
# 10              1172           -303.0            -2224
# 11              1898           -544.5            -2304
# 12              1408           -464.0            -1792
# 13              1690           -401.5            -2110
# 14              1826           -376.0            -2314
# 15              1902           -388.5            -2008
# 16              1260           -265.0            -1508
# 17              1726           -448.5            -1920
# 18              1542           -247.5            -1576
# 19              1376           -212.0            -1760
# 20               918           -242.5            -1778
# 21              3550           -716.0            -2764
# 22              1408           -390.5            -1492
# 23              3550           -661.5            -2798
# 24              1444           -319.0            -1688
# 25              3572           -662.5            -3208
# 26              1832           -301.0            -1850
# 27              1504           -314.5            -1606
# 28              1332           -357.5            -1536
# 29              4016           -726.5            -2358
