# %% [markdown]
# <a href="https://colab.research.google.com/github/ifeLight/ml-bot/blob/main/binance-multi-timeframe-grade-review_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas-ta
# !pip install backtrader[plotting]
# !pip install plotly
# !pip install --upgrade firebase-admin
# Out:
# Collecting pandas-ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from pandas-ta) (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas-ta) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas-ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas-ta) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas-ta) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->pandas-ta) (1.17.0)
# Building wheels for collected packages: pandas-ta
#   Building wheel for pandas-ta (setup.py) ... done
#   Created wheel for pandas-ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218909 sha256=02a67964035498e0390dac2955a7b2c9c83aee4fbfdb112c5242a12de51ab5e4
#   Stored in directory: /root/.cache/pip/wheels/7f/33/8b/50b245c5c65433cd8f5cb24ac15d97e5a3db2d41a8b6ae957d
# Successfully built pandas-ta
# Installing collected packages: pandas-ta
# Successfully installed pandas-ta-0.3.14b0
# Collecting backtrader[plotting]
#   Downloading backtrader-1.9.78.123-py2.py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from backtrader[plotting]) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->backtrader[plotting]) (1.17.0)
# Downloading backtrader-1.9.78.123-py2.py3-none-any.whl (419 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 5.4 MB/s eta 0:00:00
# Installing collected packages: backtrader
# Successfully installed backtrader-1.9.78.123
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)
# Requirement already satisfied: firebase-admin in /usr/local/lib/python3.11/dist-packages (6.6.0)
# Requirement already satisfied: cachecontrol>=0.12.14 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (0.14.2)
# Requirement already satisfied: google-api-python-client>=1.7.8 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (2.160.0)
# Requirement already satisfied: google-cloud-storage>=1.37.1 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (2.19.0)
# Requirement already satisfied: pyjwt>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (2.10.1)
# Requirement already satisfied: google-api-core<3.0.0dev,>=1.22.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.24.1)
# Requirement already satisfied: google-cloud-firestore>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (2.20.1)
# Requirement already satisfied: requests>=2.16.0 in /usr/local/lib/python3.11/dist-packages (from cachecontrol>=0.12.14->firebase-admin) (2.32.3)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in /usr/local/lib/python3.11/dist-packages (from cachecontrol>=0.12.14->firebase-admin) (1.1.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.69.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (4.25.6)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.26.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.38.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.62.3)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (4.1.1)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from google-cloud-firestore>=2.19.0->firebase-admin) (2.4.2)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage>=1.37.1->firebase-admin) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage>=1.37.1->firebase-admin) (1.6.0)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (1.17.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client>=1.7.8->firebase-admin) (3.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (2025.1.31)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.6.1)

# %%
import numpy as np
import pandas as pd
import datetime
import requests
import json
import os
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import backtrader as bt
import pandas_ta as ta
from imblearn.over_sampling import SMOTE
import subprocess
import firebase_admin
from firebase_admin import firestore
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
from google.colab import auth
import google.auth
import itertools
import hashlib

# %%
auth.authenticate_user()
#Configure Google cloud project
project_id = 'ifelight'
# !gcloud config set project {project_id}
# Out:
# Updated property [core/project].

# %%
# Working GCP Bucket name
bucket_name = 'ife-storage'
# Working on Firestore name
firestore_collection_name = 'trade-models'

# %%
binance_base_url = 'https://52on3577u3.execute-api.eu-central-1.amazonaws.com'

def get_binance_candles(symbol: str, interval='1h', limit: int = 50, **kwargs):
    url = f'{binance_base_url}/api/v3/uiKlines?symbol={symbol}&interval={interval}&limit={limit}'
    for key, value in kwargs.items():
        url += f'&{key}={value}'
    response = requests.get(url)
    result = json.loads(response.text)
    # print(result)
    def map_result(x):
        return {
            'Date': x[0],
            'Open': x[1],
            'High': x[2],
            'Low': x[3],
            'Close': x[4],
            'Volume': x[5],
        }
    mappeded_result = []
    for x in result:
        mappeded_result.append(map_result(x))
    return mappeded_result


def candles_to_df(data):
    df =  pd.DataFrame(data)
    df['Date'] = pd.to_datetime(df['Date'], unit='ms')
    df['Open'] = df['Open'].astype(float)
    df['High'] = df['High'].astype(float)
    df['Low'] = df['Low'].astype(float)
    df['Close'] = df['Close'].astype(float)
    df['Volume'] = df['Volume'].astype(float)
    df.set_index('Date', inplace=True)
    return df

def get_all_binance_candles(symbol: str, interval='1h', start_date=None, end_date=None, limit=1000):
  try:
    return load_candles_from_cloud_storage(symbol, interval, start_date, end_date)
  except FileNotFoundError:
    pass
  result = []
  raw_start_date = start_date
  raw_end_date = end_date
  start_date = pd.to_datetime(start_date) if start_date else pd.to_datetime('2015-01-01')
  end_date = pd.to_datetime(end_date) if end_date else pd.to_datetime('today')
  while True:
    candles = get_binance_candles(symbol, interval, limit, startTime=int(start_date.timestamp() * 1000), endTime=int(end_date.timestamp() * 1000))
    if len(candles) <= 1:
      break;
    result += candles
    start_date = pd.to_datetime(datetime.datetime.fromtimestamp(candles[-1]['Date'] / 1000))
  candles_df = candles_to_df(result)
  save_candles_to_cloud_storage(candles_df, symbol, interval, raw_start_date, raw_end_date)
  return candles_df

def candles_storage_file_name(symbol: str, interval='1h', start_date=None, end_date=None):
  file_name = f'binance_{symbol}_{interval}_{start_date}_{end_date}.csv'
  return file_name

def load_candles_from_cloud_storage(symbol: str, interval: str, start_date=None, end_date=None):
  file_name = candles_storage_file_name(symbol, interval, start_date, end_date)
  try:
    # Download the file from cloud storage.
    subprocess.run(['gsutil', 'cp', f'gs://{bucket_name}/trade/candles/{file_name}', f'/tmp/{file_name}'], check=True)

    # Load the data into a Pandas DataFrame.
    with open(f'/tmp/{file_name}', 'r') as f:
      return pd.read_csv(f, index_col=0, parse_dates=True)
  except subprocess.CalledProcessError:
    # Raise a FileNotFoundError if the file is not found in cloud storage.
    raise FileNotFoundError(f"File not found: gs://{bucket_name}/trade/candles/{file_name}")

def save_candles_to_cloud_storage(df: pd.DataFrame, symbol: str, interval: str, start_date, end_date):
  file_name = candles_storage_file_name(symbol, interval, start_date, end_date)
  df.to_csv(f'/tmp/{file_name}')
  # !gsutil cp /tmp/{file_name} gs://{bucket_name}/trade/candles/{file_name}

# %%
def add_scaled_rsi(df, window=14, prefix = '', features_columns=[]):
  series = ta.rsi(df['Close'], length=window)
  column_name = f"{prefix}RSI_{window}"
  df[column_name] = series / 100
  if(column_name not in features_columns):
    features_columns.append(column_name)
  return df

def add_scaled_ema(df, window=50, prefix = '', features_columns=[]):
  series = ta.ema(df['Close'], length=window)
  column_name = f"{prefix}EMA_{window}"
  df[column_name] = series / df['Close']
  if column_name not in features_columns:
    features_columns.append(column_name)
  return df

def add_scaled_sma(df, window=50, prefix = '', features_columns=[]):
  series = ta.sma(df['Close'], length=window)
  column_name = f"{prefix}SMA_{window}"
  df[column_name] = series / df['Close']
  if column_name not in features_columns:
    features_columns.append(column_name)
  return df

def add_scaled_macd(df, prefix= '', features_columns=[], fast = 12, slow = 26, signal=9):
  macd_df = ta.macd(df['Close'], fast=fast, slow=slow, signal=signal)
  suffix = f"{fast}_{slow}_{signal}"
  macd_column_name = f"{prefix}MACD_{suffix}"
  macds_column_name = f"{prefix}MACDs_{suffix}"
  macdh_column_name = f"{prefix}MACDh_{suffix}"
  df[macd_column_name] = macd_df[macd_df.columns[0]] / df['Close']
  df[macds_column_name] = macd_df[macd_df.columns[2]] / df['Close']
  df[macdh_column_name] = macd_df[macd_df.columns[1]] / df['Close']
  if macd_column_name not in features_columns:
    features_columns.append(macd_column_name)
  if macds_column_name not in features_columns:
    features_columns.append(macds_column_name)
  if macdh_column_name not in features_columns:
    features_columns.append(macdh_column_name)
  return df

def add_scaled_bbands(df, window=20, std=2.0, prefix= '', features_columns=[]):
  bbands_df = ta.bbands(df['Close'], length=window, std=std)
  suffix = f"{window}_{std}"
  bbl_column_name = f"{prefix}BBL_{suffix}"
  bbm_column_name = f"{prefix}BBM_{suffix}"
  bbu_column_name = f"{prefix}BBU_{suffix}"
  bbb_column_name = f"{prefix}BBB_{suffix}"
  bbp_column_name = f"{prefix}BBP_{suffix}"
  df[bbl_column_name] = bbands_df[bbands_df.columns[0]] / df['Close']
  df[bbm_column_name] = bbands_df[bbands_df.columns[1]] / df['Close']
  df[bbu_column_name] = bbands_df[bbands_df.columns[2]] / df['Close']
  df[bbb_column_name] = bbands_df[bbands_df.columns[3]]
  df[bbp_column_name] = bbands_df[bbands_df.columns[4]]
  if bbl_column_name not in features_columns: features_columns.append(bbl_column_name)
  if bbm_column_name not in features_columns: features_columns.append(bbm_column_name)
  if bbu_column_name not in features_columns: features_columns.append(bbu_column_name)
  if bbb_column_name not in features_columns: features_columns.append(bbb_column_name)
  if bbp_column_name not in features_columns: features_columns.append(bbp_column_name)
  return df

# %%
def merge_candlesticks_data(df1, df2):
  """
  Merges two candlestick DataFrames with forward fill, handling different timeframes,
  and prevents duplicate OHLCV columns.
  Ensure both DataFrames have a datetime index.
  And ensure the second DataFrame is the larger timeframe

  Args:
      df1: First candlestick DataFrame with datetime index.
      df2: Second candlestick DataFrame with datetime index.

  Returns:
      Merged DataFrame with forward-filled values, and no duplicate OHLCV columns.
  """
  # Ensure both DataFrames have a datetime index
  if not isinstance(df1.index, pd.DatetimeIndex) or not isinstance(df2.index, pd.DatetimeIndex):
      raise ValueError("DataFrames must have a datetime index.")
  # Identify OHLCV columns
  ohlcv_cols = ['open', 'high', 'low', 'close', 'volume']

  # Rename columns in df2 that conflict with df1's OHLCV columns
  for col in df2.columns:
    if col.lower() in ohlcv_cols and col.lower() in df1.columns.str.lower():
      del df2[col]

  # Merge the DataFrames using outer join, which preserves all dates
  merged_df = pd.merge(df1, df2, how='outer', left_index=True, right_index=True, suffixes=('_df1', '_df2'))

  # Forward fill the missing values for each column
  for col in merged_df.columns:
    merged_df[col] = merged_df[col].ffill()

  return merged_df

# %%
def resample_candles(df, interval='1h'):
    return df.resample(interval).agg({'Open': 'first', 'High': 'max', 'Low': 'min', 'Close': 'last', 'Volume': 'sum'}).ffill()

# %%
def predict_in_batches(model, test_data, features_columns, seq_length, batch_size=128):
    """
    Predicts in batches to speed up inference.
    """
    num_samples = len(test_data) - seq_length
    feature_array = test_data[features_columns].values
    predicted_values = np.full(len(test_data), np.nan)

    for start_idx in range(0, num_samples, batch_size):
        end_idx = min(start_idx + batch_size, num_samples)
        batch_indices = range(start_idx + seq_length, end_idx + seq_length)
        batch_input = np.array([feature_array[i - seq_length:i] for i in batch_indices])

        if len(batch_input) > 0 :
            predictions = model.predict(batch_input, verbose=0)
            predicted_values[batch_indices] = predictions.flatten() #Flatten to 1d array.

    test_data['Predicted_Value'] = predicted_values
    return test_data

# %%
class PredictedValueStrategy(bt.Strategy):
    params = (
        ('buy_threshold', 0.6),
        ('sell_threshold', 0.6),
        ('leverage', 1),  # Leverage ratio
        ('margin', 1000),
        ('log', True)
    )

    def __init__(self):
        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None

        # Add the Predicted_Value as a data feed
        self.predicted_value = self.datas[0].predicted_value

    def next(self):
        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return
         # # Check if we are in the market
        if not self.position:
          cash = self.broker.getcash()
          position_size = (self.params.margin * self.params.leverage) / self.data.close[0]
          # Long signal
          if self.predicted_value[0] > self.params.buy_threshold:
            self.log('LONG POSITION CREATED, %.2f' % self.datas[0].close[0])
            self.order = self.buy(size=position_size)

          # Short signal
          elif self.predicted_value[0] < self.params.sell_threshold:
            self.log('SHORT POSITION CREATED, %.2f' % self.datas[0].close[0])
            self.order = self.sell(size=position_size)

        else:
          if self.predicted_value[0] > self.params.buy_threshold and self.position.size < 0:
            self.log('CLOSE SHORT POSITION CREATED, %.2f' % self.datas[0].close[0])
            self.order = self.close()
          elif self.predicted_value[0] < self.params.sell_threshold and self.position.size > 0:
            self.log('CLOSE LONG POSITION CREATED, %.2f' % self.datas[0].close[0])
            self.order = self.close()

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return
        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY EXECUTED, %.2f' % order.executed.price)
            elif order.issell():
                self.log('SELL EXECUTED, %.2f' % order.executed.price)
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            if order.status == order.Canceled:
                self.log('Order Canceled')
            elif order.status == order.Margin:
                self.log(f'Order Margin Not Enough - Available cash: {self.broker.getcash()}')
            elif order.status == order.Rejected:
                self.log('Order Rejected')

        # Write down: no pending order
        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        self.log(f'TRADE COMPLETED, GROSS {trade.pnl:.2f}, NET {trade.pnlcomm:.2f}, Available Cash {self.broker.getcash():.2f}')

    def log(self, txt, dt=None):
        if not self.params.log:
          return
        dt = dt or self.datas[0].datetime.date(0)
        time = self.datas[0].datetime.time()
        print(f'{dt.isoformat()} {time.isoformat()}, {txt}')

# %%
# Extend PandasData to include the custom column
class CustomPandasData(bt.feeds.PandasData):
    # Add custom columns
    lines = ('predicted_value',)  # Add the custom line
    params = (
        ('predicted_value', 'Predicted_Value'),  # Map the column name
    )

# %%
def get_model_cloud_storage_path(bucket_name, local_file_name):
    """
    Returns the cloud storage path for a given model name.

    Parameters:
        local_file_name (str): The name of the model.

    Returns:
        str: The cloud storage path. (e.g., gs://<bucket_name>/trade/models/<model_name>.h5).
    """
    return f'gs://{bucket_name}/trade/models/{local_file_name}'

def save_model_to_cloud_storage(model: tf.keras.Model, model_name: str, bucket_name: str):
    """
    Saves a TensorFlow model to Google Cloud Storage and returns the cloud storage file path.

    Parameters:
        model (tf.keras.Model): The TensorFlow model to save.
        model_name (str): The name of the model (used to create the file name).
        bucket_name (str): The name of the Google Cloud Storage bucket.

    Returns:
        str: The cloud storage file path (e.g., gs://<bucket_name>/trade/models/<model_name>.h5).
    """
    # Define the local and cloud storage file paths
    local_file_name = f'{model_name}.h5'
    local_file_path = f'/tmp/{local_file_name}'
    cloud_file_path = get_model_cloud_storage_path(bucket_name, local_file_name)

    # Save the model locally
    model.save(local_file_path)

    try:
        # Upload the model to Google Cloud Storage
        subprocess.run(['gsutil', 'cp', local_file_path, cloud_file_path], check=True)
        print(f"Model saved to {cloud_file_path}")
    except subprocess.CalledProcessError as e:
        # Handle errors during the upload process
        raise RuntimeError(f"Failed to upload model to Google Cloud Storage: {e}")
    finally:
        # Clean up the local file
        if os.path.exists(local_file_path):
            os.remove(local_file_path)
    return cloud_file_path

def load_model_from_cloud_storage(model_name: str, bucket_name: str):
    """
    Loads a TensorFlow model from Google Cloud Storage.

    Parameters:
        model_name (str): The name of the model (used to create the file name).
        bucket_name (str): The name of the Google Cloud Storage bucket.

    Returns:
        tf.keras.Model: The loaded TensorFlow model.
    """
    # Define the local and cloud storage file paths
    local_file_name = f'{model_name}.h5'
    local_file_path = f'/tmp/{local_file_name}'
    cloud_file_path = get_model_cloud_storage_path(bucket_name, local_file_name)

    try:
        # Download the model from Google Cloud Storage
        subprocess.run(['gsutil', 'cp', cloud_file_path, local_file_path], check=True)

        # Load the model
        model = tf.keras.models.load_model(local_file_path)
        print(f"Model loaded from {cloud_file_path}")
        return model
    except subprocess.CalledProcessError as e:
        raise FileNotFoundError(f"Model not found in Google Cloud Storage: {e}")
    finally:
        # Clean up the local file
        if os.path.exists(local_file_path):
            os.remove(local_file_path)

# %%
def initialize_firestore(project_id):
    """
    Initialize the Firestore client using the service account key.

    Parameters:
        project_id (str): The Google Cloud project ID.

    Returns:
        firestore.Client: Initialized Firestore client.
    """
    if not firebase_admin._apps:
        # cred = credentials.Certificate(service_account_key_path)
        cred = firebase_admin.credentials.ApplicationDefault()
        cred._project_id = project_id  # Add this line
        os.environ["GOOGLE_CLOUD_PROJECT"] = project_id
        firebase_admin.initialize_app(cred, {'projectId': project_id})
    return firestore.client()


def save_to_firestore(project_id, collection_name, data):
    """
    Save data to a Firestore collection.

    Parameters:
        project_id (str): The Google Cloud project ID.
        service_account_key_path (str): Path to the Firebase service account key JSON file.
        collection_name (str): Name of the Firestore collection.
        data (dict): Data to save in the document.

    Returns:
        None
    """
    # Initialize Firestore client
    db = initialize_firestore(project_id)

    # Save data to Firestore
    doc_ref = db.collection(collection_name).document()
    doc_ref.set(data)
    print(f"Data saved to Firestore: Collection={collection_name}, Document ID={doc_ref.id}")

# %%
def get_nested_value(data, keys):
    """
    Retrieves a deeply nested value from a dictionary or list.

    Args:
        data: The dictionary or list to traverse.
        keys: A list of keys or indices to access the nested value.

    Returns:
        The nested value if found, otherwise None.
    """
    try:
        current_value = data
        for key in keys:
            if isinstance(current_value, dict):
                current_value = current_value.get(key)
            elif isinstance(current_value, list):
                if isinstance(key, int) and 0 <= key < len(current_value):
                    current_value = current_value[key]
                else:
                    return None #invalid index
            else:
                return None #not a dict or list
            if current_value is None:
                return None  # Early exit if any key is missing
        return current_value
    except (TypeError, IndexError, AttributeError, KeyError):
        return None

# %%
trade_models = []
db = initialize_firestore(project_id)
trade_moldel_ref = db.collection('trade-models')
trade_models_stream = (
    trade_moldel_ref.where('version', '==', 'v1')
    .where('symbol', '==', 'BTCUSDT')
    .where('exchange', '==', 'binance')
    .where('timeframe', '==', '15m')
    .stream()
)
for model in trade_models_stream:
    trade_models.append(model.to_dict())
trade_models
# Out:
# /usr/local/lib/python3.11/dist-packages/google/cloud/firestore_v1/base_collection.py:303: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   return query.where(field_path, op_string, value)
# <ipython-input-14-039c559c4f85>:6: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   .where('symbol', '==', 'BTCUSDT')
# <ipython-input-14-039c559c4f85>:7: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   .where('exchange', '==', 'binance')
# <ipython-input-14-039c559c4f85>:8: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   .where('timeframe', '==', '15m')
# [{'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_15m_01-01-2021_01-01-2024_ca605b32.h5',
#   'val_mae': 0.42670920491218567,
#   'train_candles_length': 66944,
#   'trade_buy_threshold': 0.5,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': None},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'training_data_end_date': DatetimeWithNanoseconds(2023, 5, 27, 14, 0, tzinfo=datetime.timezone.utc),
#   'training_data_start_date': DatetimeWithNanoseconds(2021, 1, 4, 8, 0, tzinfo=datetime.timezone.utc),
#   'val_candles_length': 16737,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 2, 57, 47, 71481, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1',
#   'train_mae': 0.38837358355522156,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_15m_01-01-2021_01-01-2024_ca605b32',
#   'test_data_end_date': DatetimeWithNanoseconds(2023, 12, 31, 18, 30, tzinfo=datetime.timezone.utc),
#   'final_epoch': 10,
#   'val_loss': 0.2748824656009674,
#   'drawdown_analysis': {'len': 24,
#    'drawdown': 0,
#    'max': {'len': 2790, 'drawdown': 24, 'moneydown': 3132},
#    'moneydown': 126},
#   'end_date': '01-01-2024',
#   'test_candles_length': 20846,
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 282,
#     'pnl': {'average': 72,
#      'total': 20442,
#      'won': {'total': 35552, 'average': 162, 'max': 896},
#      'lost': {'total': -15110, 'average': -248, 'max': -2102}},
#     'won': 222,
#     'lost': 62},
#    'total': {'total': 416, 'open': 2, 'closed': 414},
#    'won': {'total': 346, 'pnl': {'average': 160, 'total': 54742, 'max': 896}},
#    'len': {'short': {'max': 172,
#      'average': 46,
#      'total': 12742,
#      'won': {'total': 8342, 'average': 38, 'min': 2, 'max': 156},
#      'min': 2,
#      'lost': {'total': 4400, 'average': 72, 'min': 10, 'max': 172}},
#     'total': 15804,
#     'average': 38,
#     'won': {'average': 32, 'total': 11024, 'max': 156, 'min': 2},
#     'min': 2,
#     'long': {'max': 106,
#      'average': 24,
#      'total': 3062,
#      'won': {'total': 2684, 'average': 22, 'min': 6, 'max': 86},
#      'min': 6,
#      'lost': {'total': 380, 'average': 48, 'min': 10, 'max': 106}},
#     'max': 172,
#     'lost': {'average': 70, 'total': 4780, 'max': 172, 'min': 10}},
#    'long': {'total': 132,
#     'pnl': {'average': 140,
#      'total': 18310,
#      'won': {'total': 19190, 'average': 156, 'max': 744},
#      'lost': {'total': -880, 'average': -110, 'max': -320}},
#     'won': 124,
#     'lost': 8},
#    'pnl': {'gross': {'average': 102, 'total': 42062},
#     'net': {'average': 94, 'total': 38750}},
#    'streak': {'won': {'longest': 30, 'current': 8},
#     'lost': {'longest': 2, 'current': 0}},
#    'lost': {'total': 70,
#     'pnl': {'average': -232, 'total': -15990, 'max': -2102}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2023, 5, 28, 15, 15, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.5,
#   'train_loss': 0.22801391780376434,
#   'trade_leverage': 20,
#   'final_portfolio_value': 48801.28462062088,
#   'start_date': '01-01-2021'},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_15m_01-01-2023_31-12-2025_f61cdbdc.h5',
#   'val_mae': 0.4217982590198517,
#   'train_candles_length': 48737,
#   'trade_buy_threshold': 0.8,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 0},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'training_data_end_date': DatetimeWithNanoseconds(2024, 10, 1, 0, 15, tzinfo=datetime.timezone.utc),
#   'training_data_start_date': DatetimeWithNanoseconds(2023, 1, 4, 8, 0, tzinfo=datetime.timezone.utc),
#   'val_candles_length': 12185,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 3, 31, 33, 466711, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1',
#   'train_mae': 0.40471068024635315,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_15m_01-01-2023_31-12-2025_f61cdbdc',
#   'test_data_end_date': DatetimeWithNanoseconds(2025, 3, 8, 22, 15, tzinfo=datetime.timezone.utc),
#   'final_epoch': 7,
#   'val_loss': 0.2523728907108307,
#   'drawdown_analysis': {'len': 14320,
#    'drawdown': 60,
#    'max': {'len': 14320, 'drawdown': 92, 'moneydown': 9802},
#    'moneydown': 6256},
#   'end_date': '31-12-2025',
#   'test_candles_length': 15156,
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 2,
#     'pnl': {'average': -8080,
#      'total': -8080,
#      'won': {'total': 0, 'average': 0, 'max': 0},
#      'lost': {'total': -8080, 'average': -8080, 'max': -8080}},
#     'won': 0,
#     'lost': 2},
#    'total': {'total': 2, 'open': 2, 'closed': 2},
#    'won': {'total': 0, 'pnl': {'average': 0, 'total': 0, 'max': 0}},
#    'len': {'short': {'max': 6106,
#      'average': 6106,
#      'total': 6106,
#      'won': {'total': 0, 'average': 0, 'min': 0, 'max': 0},
#      'min': 6106,
#      'lost': {'total': 6106, 'average': 6106, 'min': 6106, 'max': 6106}},
#     'total': 6106,
#     'average': 6106,
#     'won': {'average': 0, 'total': 0, 'max': 0},
#     'min': 6106,
#     'long': {'max': 0,
#      'average': 0,
#      'total': 0,
#      'won': {'total': 0, 'average': 0, 'min': 0, 'max': 0},
#      'min': 0,
#      'lost': {'total': 0, 'average': 0, 'min': 0, 'max': 0}},
#     'max': 6106,
#     'lost': {'average': 6106, 'total': 6106, 'max': 6106, 'min': 6106}},
#    'long': {'total': 0,
#     'pnl': {'average': 0,
#      'total': 0,
#      'won': {'total': 0, 'average': 0, 'max': 0},
#      'lost': {'total': 0, 'average': 0, 'max': 0}},
#     'won': 0,
#     'lost': 0},
#    'pnl': {'gross': {'average': -8072, 'total': -8072},
#     'net': {'average': -8080, 'total': -8080}},
#    'streak': {'won': {'longest': 0, 'current': 0},
#     'lost': {'longest': 2, 'current': 2}},
#    'lost': {'total': 2,
#     'pnl': {'average': -8080, 'total': -8080, 'max': -8080}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2024, 10, 2, 1, 30, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.5,
#   'train_loss': 0.24440884590148926,
#   'trade_leverage': 15,
#   'final_portfolio_value': 4369.235279258652,
#   'start_date': '01-01-2023'},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_15m_01-01-2022_31-12-2024_0edf6da3.h5',
#   'val_mae': 0.3997677266597748,
#   'train_candles_length': 66980,
#   'trade_buy_threshold': 0.8,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': None},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'training_data_end_date': DatetimeWithNanoseconds(2024, 5, 26, 13, 0, tzinfo=datetime.timezone.utc),
#   'training_data_start_date': DatetimeWithNanoseconds(2022, 1, 4, 8, 0, tzinfo=datetime.timezone.utc),
#   'val_candles_length': 16745,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 3, 20, 39, 257285, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1',
#   'train_mae': 0.3948995769023895,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_15m_01-01-2022_31-12-2024_0edf6da3',
#   'test_data_end_date': DatetimeWithNanoseconds(2024, 12, 30, 20, 15, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24148191511631012,
#   'drawdown_analysis': {'len': 11038,
#    'drawdown': 2,
#    'max': {'len': 11038, 'drawdown': 24, 'moneydown': 3868},
#    'moneydown': 384},
#   'end_date': '31-12-2024',
#   'test_candles_length': 20857,
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 16,
#     'pnl': {'average': 170,
#      'total': 2554,
#      'won': {'total': 5440, 'average': 604, 'max': 1386},
#      'lost': {'total': -2886, 'average': -480, 'max': -1408}},
#     'won': 10,
#     'lost': 6},
#    'total': {'total': 22, 'open': 2, 'closed': 22},
#    'won': {'total': 14, 'pnl': {'average': 634, 'total': 8866, 'max': 1386}},
#    'len': {'short': {'max': 3556,
#      'average': 1012,
#      'total': 15166,
#      'won': {'total': 8114, 'average': 902, 'min': 104, 'max': 3556},
#      'min': 104,
#      'lost': {'total': 7052, 'average': 1176, 'min': 548, 'max': 2714}},
#     'total': 16214,
#     'average': 772,
#     'won': {'average': 648, 'total': 9062, 'max': 3556, 'min': 20},
#     'min': 20,
#     'long': {'max': 470,
#      'average': 176,
#      'total': 1050,
#      'won': {'total': 948, 'average': 190, 'min': 20, 'max': 470},
#      'min': 20,
#      'lost': {'total': 102, 'average': 102, 'min': 102, 'max': 102}},
#     'max': 3556,
#     'lost': {'average': 1022, 'total': 7154, 'max': 2714, 'min': 102}},
#    'long': {'total': 6,
#     'pnl': {'average': 558,
#      'total': 3350,
#      'won': {'total': 3428, 'average': 686, 'max': 1356},
#      'lost': {'total': -78, 'average': -78, 'max': -78}},
#     'won': 6,
#     'lost': 2},
#    'pnl': {'gross': {'average': 286, 'total': 5986},
#     'net': {'average': 282, 'total': 5902}},
#    'streak': {'won': {'longest': 8, 'current': 2},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 8,
#     'pnl': {'average': -422, 'total': -2962, 'max': -1408}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2024, 5, 27, 14, 15, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.7,
#   'train_loss': 0.23400862514972687,
#   'trade_leverage': 10,
#   'final_portfolio_value': 16087.619855154671,
#   'start_date': '01-01-2022'},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_15m_01-01-2018_31-12-2020_9ce822a6.h5',
#   'val_mae': 0.4253034293651581,
#   'train_candles_length': 66767,
#   'trade_buy_threshold': 0.5,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': None},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'training_data_end_date': DatetimeWithNanoseconds(2020, 5, 26, 23, 15, tzinfo=datetime.timezone.utc),
#   'training_data_start_date': DatetimeWithNanoseconds(2018, 1, 4, 8, 0, tzinfo=datetime.timezone.utc),
#   'val_candles_length': 16692,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 2, 11, 55, 923585, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1',
#   'train_mae': 0.402366042137146,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_15m_01-01-2018_31-12-2020_9ce822a6',
#   'test_data_end_date': DatetimeWithNanoseconds(2020, 12, 30, 20, 45, tzinfo=datetime.timezone.utc),
#   'final_epoch': 12,
#   'val_loss': 0.26657888293266296,
#   'drawdown_analysis': {'len': 48,
#    'drawdown': 2,
#    'max': {'len': 616, 'drawdown': 6, 'moneydown': 856},
#    'moneydown': 282},
#   'end_date': '31-12-2020',
#   'test_candles_length': 20790,
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 118,
#     'pnl': {'average': 80,
#      'total': 9352,
#      'won': {'total': 10990, 'average': 110, 'max': 458},
#      'lost': {'total': -1638, 'average': -102, 'max': -436}},
#     'won': 102,
#     'lost': 16},
#    'total': {'total': 256, 'open': 2, 'closed': 256},
#    'won': {'total': 218, 'pnl': {'average': 142, 'total': 30752, 'max': 982}},
#    'len': {'short': {'max': 150,
#      'average': 34,
#      'total': 3970,
#      'won': {'total': 2912, 'average': 30, 'min': 4, 'max': 150},
#      'min': 4,
#      'lost': {'total': 1058, 'average': 66, 'min': 4, 'max': 116}},
#     'total': 18560,
#     'average': 74,
#     'won': {'average': 68, 'total': 14596, 'max': 494, 'min': 4},
#     'min': 4,
#     'long': {'max': 494,
#      'average': 106,
#      'total': 14592,
#      'won': {'total': 11684, 'average': 102, 'min': 12, 'max': 494},
#      'min': 12,
#      'lost': {'total': 2908, 'average': 132, 'min': 32, 'max': 396}},
#     'max': 494,
#     'lost': {'average': 104, 'total': 3966, 'max': 396, 'min': 4}},
#    'long': {'total': 138,
#     'pnl': {'average': 128,
#      'total': 17672,
#      'won': {'total': 19764, 'average': 170, 'max': 982},
#      'lost': {'total': -2090, 'average': -94, 'max': -338}},
#     'won': 116,
#     'lost': 22},
#    'pnl': {'gross': {'average': 110, 'total': 27738},
#     'net': {'average': 106, 'total': 27022}},
#    'streak': {'won': {'longest': 26, 'current': 4},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 38,
#     'pnl': {'average': -98, 'total': -3728, 'max': -436}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2020, 5, 28, 0, 30, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.6,
#   'train_loss': 0.24198581278324127,
#   'trade_leverage': 7,
#   'final_portfolio_value': 36824.672360666955,
#   'start_date': '01-01-2018'},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_15m_01-01-2022_31-12-2024_0edf6da3.h5',
#   'val_mae': 0.3997677266597748,
#   'train_candles_length': 66980,
#   'trade_buy_threshold': 0.6,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': None},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'training_data_end_date': DatetimeWithNanoseconds(2024, 5, 26, 13, 0, tzinfo=datetime.timezone.utc),
#   'training_data_start_date': DatetimeWithNanoseconds(2022, 1, 4, 8, 0, tzinfo=datetime.timezone.utc),
#   'val_candles_length': 16745,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 3, 17, 34, 217015, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1',
#   'train_mae': 0.3948995769023895,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_15m_01-01-2022_31-12-2024_0edf6da3',
#   'test_data_end_date': DatetimeWithNanoseconds(2024, 12, 30, 20, 15, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24148191511631012,
#   'drawdown_analysis': {'len': 2,
#    'drawdown': 0,
#    'max': {'len': 974, 'drawdown': 12, 'moneydown': 2466},
#    'moneydown': 24},
#   'end_date': '31-12-2024',
#   'test_candles_length': 20857,
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 62,
#     'pnl': {'average': 252,
#      'total': 15610,
#      'won': {'total': 16906, 'average': 302, 'max': 904},
#      'lost': {'total': -1294, 'average': -216, 'max': -622}},
#     'won': 56,
#     'lost': 6},
#    'total': {'total': 130, 'open': 2, 'closed': 130},
#    'won': {'total': 112, 'pnl': {'average': 408, 'total': 45260, 'max': 3324}},
#    'len': {'short': {'max': 164,
#      'average': 26,
#      'total': 1642,
#      'won': {'total': 1028, 'average': 18, 'min': 6, 'max': 112},
#      'min': 6,
#      'lost': {'total': 616, 'average': 102, 'min': 60, 'max': 164}},
#     'total': 16118,
#     'average': 126,
#     'won': {'average': 118, 'total': 12958, 'max': 976, 'min': 6},
#     'min': 6,
#     'long': {'max': 976,
#      'average': 216,
#      'total': 14476,
#      'won': {'total': 11930, 'average': 218, 'min': 12, 'max': 976},
#      'min': 12,
#      'lost': {'total': 2546, 'average': 212, 'min': 68, 'max': 530}},
#     'max': 976,
#     'lost': {'average': 176, 'total': 3160, 'max': 530, 'min': 60}},
#    'long': {'total': 68,
#     'pnl': {'average': 372,
#      'total': 24842,
#      'won': {'total': 28356, 'average': 516, 'max': 3324},
#      'lost': {'total': -3512, 'average': -292, 'max': -918}},
#     'won': 56,
#     'lost': 12},
#    'pnl': {'gross': {'average': 320, 'total': 41228},
#     'net': {'average': 314, 'total': 40452}},
#    'streak': {'won': {'longest': 28, 'current': 0},
#     'lost': {'longest': 2, 'current': 2}},
#    'lost': {'total': 18,
#     'pnl': {'average': -266, 'total': -4808, 'max': -918}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2024, 5, 27, 14, 15, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.7,
#   'train_loss': 0.23400862514972687,
#   'trade_leverage': 15,
#   'final_portfolio_value': 50920.10969542733,
#   'start_date': '01-01-2022'},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_15m_01-01-2017_01-01-2020_ec50b973.h5',
#   'val_mae': 0.4235987067222595,
#   'train_candles_length': 52760,
#   'trade_buy_threshold': 0.6,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': None},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'training_data_end_date': DatetimeWithNanoseconds(2019, 7, 12, 8, 45, tzinfo=datetime.timezone.utc),
#   'training_data_start_date': DatetimeWithNanoseconds(2017, 8, 20, 12, 0, tzinfo=datetime.timezone.utc),
#   'val_candles_length': 13190,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 1, 56, 36, 964888, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1',
#   'train_mae': 0.3878595232963562,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_15m_01-01-2017_01-01-2020_ec50b973',
#   'test_data_end_date': DatetimeWithNanoseconds(2019, 12, 31, 18, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 14,
#   'val_loss': 0.2594665288925171,
#   'drawdown_analysis': {'len': 0,
#    'drawdown': 0,
#    'max': {'len': 3362, 'drawdown': 18, 'moneydown': 3992},
#    'moneydown': 0},
#   'end_date': '01-01-2020',
#   'test_candles_length': 16413,
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 58,
#     'pnl': {'average': 172,
#      'total': 9936,
#      'won': {'total': 15444, 'average': 344, 'max': 1154},
#      'lost': {'total': -5508, 'average': -424, 'max': -2504}},
#     'won': 46,
#     'lost': 14},
#    'total': {'total': 102, 'open': 2, 'closed': 102},
#    'won': {'total': 84, 'pnl': {'average': 286, 'total': 23658, 'max': 1186}},
#    'len': {'short': {'max': 750,
#      'average': 224,
#      'total': 12948,
#      'won': {'total': 8932, 'average': 198, 'min': 20, 'max': 750},
#      'min': 20,
#      'lost': {'total': 4016, 'average': 310, 'min': 84, 'max': 614}},
#     'total': 15058,
#     'average': 150,
#     'won': {'average': 126, 'total': 10392, 'max': 750, 'min': 10},
#     'min': 10,
#     'long': {'max': 324,
#      'average': 50,
#      'total': 2110,
#      'won': {'total': 1460, 'average': 38, 'min': 10, 'max': 128},
#      'min': 10,
#      'lost': {'total': 650, 'average': 130, 'min': 42, 'max': 324}},
#     'max': 750,
#     'lost': {'average': 260, 'total': 4666, 'max': 614, 'min': 42}},
#    'long': {'total': 44,
#     'pnl': {'average': 148,
#      'total': 6358,
#      'won': {'total': 8214, 'average': 216, 'max': 1186},
#      'lost': {'total': -1856, 'average': -370, 'max': -1522}},
#     'won': 38,
#     'lost': 6},
#    'pnl': {'gross': {'average': 166, 'total': 16696},
#     'net': {'average': 162, 'total': 16294}},
#    'streak': {'won': {'longest': 24, 'current': 8},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 18,
#     'pnl': {'average': -408, 'total': -7364, 'max': -2504}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2019, 7, 13, 10, 0, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.5,
#   'train_loss': 0.22800233960151672,
#   'trade_leverage': 10,
#   'final_portfolio_value': 26453.637022496434,
#   'start_date': '01-01-2017'},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_15m_01-01-2019_31-12-2021_292f9b18.h5',
#   'val_mae': 0.3873039484024048,
#   'train_candles_length': 66855,
#   'trade_buy_threshold': 0.8,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': None},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'training_data_end_date': DatetimeWithNanoseconds(2021, 5, 26, 17, 15, tzinfo=datetime.timezone.utc),
#   'training_data_start_date': DatetimeWithNanoseconds(2019, 1, 4, 8, 0, tzinfo=datetime.timezone.utc),
#   'val_candles_length': 16714,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 2, 31, 5, 991062, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1',
#   'train_mae': 0.4248599708080292,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_15m_01-01-2019_31-12-2021_292f9b18',
#   'test_data_end_date': DatetimeWithNanoseconds(2021, 12, 30, 19, 30, tzinfo=datetime.timezone.utc),
#   'final_epoch': 7,
#   'val_loss': 0.224314883351326,
#   'drawdown_analysis': {'len': 15668,
#    'drawdown': 80,
#    'max': {'len': 15668, 'drawdown': 168, 'moneydown': 28236},
#    'moneydown': 13212},
#   'end_date': '31-12-2021',
#   'test_candles_length': 20818,
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 2,
#     'pnl': {'average': 2910,
#      'total': 2910,
#      'won': {'total': 2910, 'average': 2910, 'max': 2910},
#      'lost': {'total': 0, 'average': 0, 'max': 0}},
#     'won': 2,
#     'lost': 0},
#    'total': {'total': 2, 'open': 2, 'closed': 2},
#    'won': {'total': 2, 'pnl': {'average': 2910, 'total': 2910, 'max': 2910}},
#    'len': {'short': {'max': 2846,
#      'average': 2846,
#      'total': 2846,
#      'won': {'total': 2846, 'average': 2846, 'min': 2846, 'max': 2846},
#      'min': 2846,
#      'lost': {'total': 0, 'average': 0, 'min': 0, 'max': 0}},
#     'total': 2846,
#     'average': 2846,
#     'won': {'average': 2846, 'total': 2846, 'max': 2846, 'min': 2846},
#     'min': 2846,
#     'long': {'max': 0,
#      'average': 0,
#      'total': 0,
#      'won': {'total': 0, 'average': 0, 'min': 0, 'max': 0},
#      'min': 0,
#      'lost': {'total': 0, 'average': 0, 'min': 0, 'max': 0}},
#     'max': 2846,
#     'lost': {'average': 0, 'total': 0, 'max': 0}},
#    'long': {'total': 0,
#     'pnl': {'average': 0,
#      'total': 0,
#      'won': {'total': 0, 'average': 0, 'max': 0},
#      'lost': {'total': 0, 'average': 0, 'max': 0}},
#     'won': 0,
#     'lost': 0},
#    'pnl': {'gross': {'average': 2920, 'total': 2920},
#     'net': {'average': 2910, 'total': 2910}},
#    'streak': {'won': {'longest': 2, 'current': 2},
#     'lost': {'longest': 0, 'current': 0}},
#    'lost': {'total': 0, 'pnl': {'average': 0, 'total': 0, 'max': 0}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2021, 5, 27, 18, 30, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.6,
#   'train_loss': 0.2636461555957794,
#   'trade_leverage': 25,
#   'final_portfolio_value': 3554.921916191197,
#   'start_date': '01-01-2019'},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_15m_01-01-2020_31-12-2022_c514f0a4.h5',
#   'val_mae': 0.4048410654067993,
#   'train_candles_length': 66915,
#   'trade_buy_threshold': 0.8,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': None},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'training_data_end_date': DatetimeWithNanoseconds(2022, 5, 26, 19, 0, tzinfo=datetime.timezone.utc),
#   'training_data_start_date': DatetimeWithNanoseconds(2020, 1, 4, 8, 0, tzinfo=datetime.timezone.utc),
#   'val_candles_length': 16729,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 2, 45, 51, 490378, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1',
#   'train_mae': 0.4030745327472687,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_15m_01-01-2020_31-12-2022_c514f0a4',
#   'test_data_end_date': DatetimeWithNanoseconds(2022, 12, 30, 21, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 9,
#   'val_loss': 0.24267169833183289,
#   'drawdown_analysis': {'len': 3742,
#    'drawdown': 2,
#    'max': {'len': 3742, 'drawdown': 14, 'moneydown': 2782},
#    'moneydown': 448},
#   'end_date': '31-12-2022',
#   'test_candles_length': 20836,
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 30,
#     'pnl': {'average': 602,
#      'total': 18062,
#      'won': {'total': 22336, 'average': 1176, 'max': 4088},
#      'lost': {'total': -4274, 'average': -388, 'max': -1584}},
#     'won': 20,
#     'lost': 12},
#    'total': {'total': 44, 'open': 0, 'closed': 44},
#    'won': {'total': 32, 'pnl': {'average': 956, 'total': 30578, 'max': 4088}},
#    'len': {'short': {'max': 4152,
#      'average': 638,
#      'total': 19154,
#      'won': {'total': 15708, 'average': 828, 'min': 14, 'max': 4152},
#      'min': 14,
#      'lost': {'total': 3446, 'average': 314, 'min': 98, 'max': 864}},
#     'total': 19578,
#     'average': 456,
#     'won': {'average': 504, 'total': 16132, 'max': 4152, 'min': 8},
#     'min': 8,
#     'long': {'max': 92,
#      'average': 34,
#      'total': 424,
#      'won': {'total': 424, 'average': 34, 'min': 8, 'max': 92},
#      'min': 8,
#      'lost': {'total': 0, 'average': 0, 'min': 0, 'max': 0}},
#     'max': 4152,
#     'lost': {'average': 314, 'total': 3446, 'max': 864, 'min': 98}},
#    'long': {'total': 14,
#     'pnl': {'average': 634,
#      'total': 8242,
#      'won': {'total': 8242, 'average': 634, 'max': 1232},
#      'lost': {'total': 0, 'average': 0, 'max': 0}},
#     'won': 14,
#     'lost': 0},
#    'pnl': {'gross': {'average': 618, 'total': 26560},
#     'net': {'average': 612, 'total': 26304}},
#    'streak': {'won': {'longest': 8, 'current': 6},
#     'lost': {'longest': 2, 'current': 0}},
#    'lost': {'total': 12,
#     'pnl': {'average': -388, 'total': -4274, 'max': -1584}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2022, 5, 27, 20, 15, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.5,
#   'train_loss': 0.24263039231300354,
#   'trade_leverage': 15,
#   'final_portfolio_value': 36302.76151664884,
#   'start_date': '01-01-2020'},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_15m_01-01-2023_31-12-2025_f61cdbdc.h5',
#   'val_mae': 0.4217982590198517,
#   'train_candles_length': 48737,
#   'trade_buy_threshold': 0.5,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 2},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'training_data_end_date': DatetimeWithNanoseconds(2024, 10, 1, 0, 15, tzinfo=datetime.timezone.utc),
#   'training_data_start_date': DatetimeWithNanoseconds(2023, 1, 4, 8, 0, tzinfo=datetime.timezone.utc),
#   'val_candles_length': 12185,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 3, 28, 40, 823454, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1',
#   'train_mae': 0.40471068024635315,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_15m_01-01-2023_31-12-2025_f61cdbdc',
#   'test_data_end_date': DatetimeWithNanoseconds(2025, 3, 8, 22, 15, tzinfo=datetime.timezone.utc),
#   'final_epoch': 7,
#   'val_loss': 0.2523728907108307,
#   'drawdown_analysis': {'len': 4574,
#    'drawdown': 6,
#    'max': {'len': 4574, 'drawdown': 10, 'moneydown': 1410},
#    'moneydown': 686},
#   'end_date': '31-12-2025',
#   'test_candles_length': 15156,
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 4,
#     'pnl': {'average': 158,
#      'total': 634,
#      'won': {'total': 634, 'average': 158, 'max': 256},
#      'lost': {'total': 0, 'average': 0, 'max': 0}},
#     'won': 4,
#     'lost': 0},
#    'total': {'total': 12, 'open': 2, 'closed': 12},
#    'won': {'total': 10, 'pnl': {'average': 474, 'total': 4270, 'max': 1756}},
#    'len': {'short': {'max': 106,
#      'average': 42,
#      'total': 166,
#      'won': {'total': 166, 'average': 42, 'min': 10, 'max': 106},
#      'min': 10,
#      'lost': {'total': 0, 'average': 0, 'min': 0, 'max': 0}},
#     'total': 14524,
#     'average': 1320,
#     'won': {'average': 1172, 'total': 10544, 'max': 3938, 'min': 10},
#     'min': 10,
#     'long': {'max': 3938,
#      'average': 2052,
#      'total': 14358,
#      'won': {'total': 10378, 'average': 2076, 'min': 502, 'max': 3938},
#      'min': 502,
#      'lost': {'total': 3982, 'average': 1990, 'min': 1300, 'max': 2682}},
#     'max': 3938,
#     'lost': {'average': 1990, 'total': 3982, 'max': 2682, 'min': 1300}},
#    'long': {'total': 8,
#     'pnl': {'average': 476,
#      'total': 3326,
#      'won': {'total': 3636, 'average': 728, 'max': 1756},
#      'lost': {'total': -310, 'average': -156, 'max': -202}},
#     'won': 6,
#     'lost': 2},
#    'pnl': {'gross': {'average': 362, 'total': 3982},
#     'net': {'average': 360, 'total': 3958}},
#    'streak': {'won': {'longest': 8, 'current': 0},
#     'lost': {'longest': 2, 'current': 2}},
#    'lost': {'total': 2, 'pnl': {'average': -156, 'total': -310, 'max': -202}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2024, 10, 2, 1, 30, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.7,
#   'train_loss': 0.24440884590148926,
#   'trade_leverage': 5,
#   'final_portfolio_value': 13894.122536325493,
#   'start_date': '01-01-2023'},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_15m_01-01-2023_31-12-2025_f61cdbdc.h5',
#   'val_mae': 0.4217982590198517,
#   'train_candles_length': 48737,
#   'trade_buy_threshold': 0.5,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 2},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'training_data_end_date': DatetimeWithNanoseconds(2024, 10, 1, 0, 15, tzinfo=datetime.timezone.utc),
#   'training_data_start_date': DatetimeWithNanoseconds(2023, 1, 4, 8, 0, tzinfo=datetime.timezone.utc),
#   'val_candles_length': 12185,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 3, 27, 58, 226137, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1',
#   'train_mae': 0.40471068024635315,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_15m_01-01-2023_31-12-2025_f61cdbdc',
#   'test_data_end_date': DatetimeWithNanoseconds(2025, 3, 8, 22, 15, tzinfo=datetime.timezone.utc),
#   'final_epoch': 7,
#   'val_loss': 0.2523728907108307,
#   'drawdown_analysis': {'len': 110,
#    'drawdown': 2,
#    'max': {'len': 492, 'drawdown': 4, 'moneydown': 688},
#    'moneydown': 206},
#   'end_date': '31-12-2025',
#   'test_candles_length': 15156,
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 70,
#     'pnl': {'average': 142,
#      'total': 9862,
#      'won': {'total': 10330, 'average': 160, 'max': 440},
#      'lost': {'total': -468, 'average': -94, 'max': -350}},
#     'won': 66,
#     'lost': 6},
#    'total': {'total': 154, 'open': 2, 'closed': 154},
#    'won': {'total': 132, 'pnl': {'average': 194, 'total': 25290, 'max': 1518}},
#    'len': {'short': {'max': 118,
#      'average': 32,
#      'total': 2202,
#      'won': {'total': 1838, 'average': 28, 'min': 4, 'max': 118},
#      'min': 4,
#      'lost': {'total': 364, 'average': 74, 'min': 16, 'max': 104}},
#     'total': 13456,
#     'average': 88,
#     'won': {'average': 86, 'total': 11176, 'max': 786, 'min': 4},
#     'min': 4,
#     'long': {'max': 786,
#      'average': 136,
#      'total': 11254,
#      'won': {'total': 9338, 'average': 142, 'min': 10, 'max': 786},
#      'min': 10,
#      'lost': {'total': 1916, 'average': 114, 'min': 38, 'max': 320}},
#     'max': 786,
#     'lost': {'average': 104, 'total': 2280, 'max': 320, 'min': 16}},
#    'long': {'total': 84,
#     'pnl': {'average': 166,
#      'total': 13818,
#      'won': {'total': 14960, 'average': 228, 'max': 1518},
#      'lost': {'total': -1142, 'average': -66, 'max': -206}},
#     'won': 66,
#     'lost': 18},
#    'pnl': {'gross': {'average': 158, 'total': 24110},
#     'net': {'average': 156, 'total': 23680}},
#    'streak': {'won': {'longest': 30, 'current': 6},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 22,
#     'pnl': {'average': -72, 'total': -1610, 'max': -350}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2024, 10, 2, 1, 30, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.5,
#   'train_loss': 0.24440884590148926,
#   'trade_leverage': 7,
#   'final_portfolio_value': 33581.37105888699,
#   'start_date': '01-01-2023'},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_15m_01-01-2022_31-12-2024_0edf6da3.h5',
#   'val_mae': 0.3997677266597748,
#   'train_candles_length': 66980,
#   'trade_buy_threshold': 0.7,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': None},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'training_data_end_date': DatetimeWithNanoseconds(2024, 5, 26, 13, 0, tzinfo=datetime.timezone.utc),
#   'training_data_start_date': DatetimeWithNanoseconds(2022, 1, 4, 8, 0, tzinfo=datetime.timezone.utc),
#   'val_candles_length': 16745,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 3, 19, 20, 918976, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1',
#   'train_mae': 0.3948995769023895,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_15m_01-01-2022_31-12-2024_0edf6da3',
#   'test_data_end_date': DatetimeWithNanoseconds(2024, 12, 30, 20, 15, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24148191511631012,
#   'drawdown_analysis': {'len': 2,
#    'drawdown': 0,
#    'max': {'len': 988, 'drawdown': 16, 'moneydown': 4132},
#    'moneydown': 40},
#   'end_date': '31-12-2024',
#   'test_candles_length': 20857,
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 56,
#     'pnl': {'average': 530,
#      'total': 29106,
#      'won': {'total': 32176, 'average': 686, 'max': 1734},
#      'lost': {'total': -3070, 'average': -384, 'max': -1606}},
#     'won': 48,
#     'lost': 8},
#    'total': {'total': 100, 'open': 2, 'closed': 100},
#    'won': {'total': 84, 'pnl': {'average': 770, 'total': 63808, 'max': 4440}},
#    'len': {'short': {'max': 352,
#      'average': 88,
#      'total': 4814,
#      'won': {'total': 3518, 'average': 76, 'min': 10, 'max': 352},
#      'min': 10,
#      'lost': {'total': 1296, 'average': 162, 'min': 90, 'max': 216}},
#     'total': 14026,
#     'average': 142,
#     'won': {'average': 138, 'total': 11366, 'max': 948, 'min': 10},
#     'min': 10,
#     'long': {'max': 948,
#      'average': 210,
#      'total': 9212,
#      'won': {'total': 7848, 'average': 218, 'min': 16, 'max': 948},
#      'min': 16,
#      'lost': {'total': 1364, 'average': 170, 'min': 58, 'max': 440}},
#     'max': 948,
#     'lost': {'average': 166, 'total': 2660, 'max': 440, 'min': 58}},
#    'long': {'total': 44,
#     'pnl': {'average': 636,
#      'total': 28000,
#      'won': {'total': 31632, 'average': 880, 'max': 4440},
#      'lost': {'total': -3632, 'average': -454, 'max': -1402}},
#     'won': 36,
#     'lost': 8},
#    'pnl': {'gross': {'average': 588, 'total': 58094},
#     'net': {'average': 578, 'total': 57104}},
#    'streak': {'won': {'longest': 20, 'current': 0},
#     'lost': {'longest': 2, 'current': 2}},
#    'lost': {'total': 16,
#     'pnl': {'average': -418, 'total': -6702, 'max': -1606}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2024, 5, 27, 14, 15, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.7,
#   'train_loss': 0.23400862514972687,
#   'trade_leverage': 25,
#   'final_portfolio_value': 67816.42491030696,
#   'start_date': '01-01-2022'},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_15m_01-01-2022_31-12-2024_0edf6da3.h5',
#   'val_mae': 0.3997677266597748,
#   'train_candles_length': 66980,
#   'trade_buy_threshold': 0.6,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': None},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'training_data_end_date': DatetimeWithNanoseconds(2024, 5, 26, 13, 0, tzinfo=datetime.timezone.utc),
#   'training_data_start_date': DatetimeWithNanoseconds(2022, 1, 4, 8, 0, tzinfo=datetime.timezone.utc),
#   'val_candles_length': 16745,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 3, 17, 44, 681989, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1',
#   'train_mae': 0.3948995769023895,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_15m_01-01-2022_31-12-2024_0edf6da3',
#   'test_data_end_date': DatetimeWithNanoseconds(2024, 12, 30, 20, 15, tzinfo=datetime.timezone.utc),
#   'final_epoch': 11,
#   'val_loss': 0.24148191511631012,
#   'drawdown_analysis': {'len': 2,
#    'drawdown': 0,
#    'max': {'len': 974, 'drawdown': 8, 'moneydown': 2516},
#    'moneydown': 40},
#   'end_date': '31-12-2024',
#   'test_candles_length': 20857,
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 66,
#     'pnl': {'average': 410,
#      'total': 26568,
#      'won': {'total': 28762, 'average': 488, 'max': 1506},
#      'lost': {'total': -2194, 'average': -366, 'max': -1038}},
#     'won': 60,
#     'lost': 6},
#    'total': {'total': 118, 'open': 2, 'closed': 116},
#    'won': {'total': 100, 'pnl': {'average': 658, 'total': 65802, 'max': 5538}},
#    'len': {'short': {'max': 166,
#      'average': 26,
#      'total': 1712,
#      'won': {'total': 1096, 'average': 20, 'min': 6, 'max': 112},
#      'min': 6,
#      'lost': {'total': 616, 'average': 104, 'min': 60, 'max': 166}},
#     'total': 12908,
#     'average': 112,
#     'won': {'average': 100, 'total': 10014, 'max': 976, 'min': 6},
#     'min': 6,
#     'long': {'max': 976,
#      'average': 220,
#      'total': 11196,
#      'won': {'total': 8920, 'average': 218, 'min': 12, 'max': 976},
#      'min': 12,
#      'lost': {'total': 2278, 'average': 228, 'min': 78, 'max': 530}},
#     'max': 976,
#     'lost': {'average': 182, 'total': 2894, 'max': 530, 'min': 60}},
#    'long': {'total': 52,
#     'pnl': {'average': 624,
#      'total': 31846,
#      'won': {'total': 37040, 'average': 904, 'max': 5538},
#      'lost': {'total': -5194, 'average': -518, 'max': -1530}},
#     'won': 42,
#     'lost': 10},
#    'pnl': {'gross': {'average': 514, 'total': 59576},
#     'net': {'average': 504, 'total': 58414}},
#    'streak': {'won': {'longest': 28, 'current': 0},
#     'lost': {'longest': 2, 'current': 2}},
#    'lost': {'total': 16,
#     'pnl': {'average': -462, 'total': -7388, 'max': -1530}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2024, 5, 27, 14, 15, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.7,
#   'train_loss': 0.23400862514972687,
#   'trade_leverage': 25,
#   'final_portfolio_value': 69194.15193739183,
#   'start_date': '01-01-2022'},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_15m_01-01-2021_01-01-2024_ca605b32.h5',
#   'val_mae': 0.42670920491218567,
#   'train_candles_length': 66944,
#   'trade_buy_threshold': 0.7,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': None},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'training_data_end_date': DatetimeWithNanoseconds(2023, 5, 27, 14, 0, tzinfo=datetime.timezone.utc),
#   'training_data_start_date': DatetimeWithNanoseconds(2021, 1, 4, 8, 0, tzinfo=datetime.timezone.utc),
#   'val_candles_length': 16737,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 3, 1, 1, 527537, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1',
#   'train_mae': 0.38837358355522156,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_15m_01-01-2021_01-01-2024_ca605b32',
#   'test_data_end_date': DatetimeWithNanoseconds(2023, 12, 31, 18, 30, tzinfo=datetime.timezone.utc),
#   'final_epoch': 10,
#   'val_loss': 0.2748824656009674,
#   'drawdown_analysis': {'len': 7686,
#    'drawdown': 8,
#    'max': {'len': 7686, 'drawdown': 34, 'moneydown': 4958},
#    'moneydown': 1526},
#   'end_date': '01-01-2024',
#   'test_candles_length': 20846,
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 112,
#     'pnl': {'average': 64,
#      'total': 7132,
#      'won': {'total': 20750, 'average': 270, 'max': 1152},
#      'lost': {'total': -13618, 'average': -400, 'max': -3188}},
# ...
#     'pnl': {'average': 334,
#      'total': 9350,
#      'won': {'total': 10204, 'average': 426, 'max': 1628},
#      'lost': {'total': -852, 'average': -212, 'max': -440}},
#     'won': 24,
#     'lost': 4},
#    'pnl': {'gross': {'average': 334, 'total': 29316},
#     'net': {'average': 328, 'total': 28790}},
#    'streak': {'won': {'longest': 20, 'current': 0},
#     'lost': {'longest': 2, 'current': 2}},
#    'lost': {'total': 12,
#     'pnl': {'average': -346, 'total': -4166, 'max': -968}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2024, 10, 2, 1, 30, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.5,
#   'train_loss': 0.24440884590148926,
#   'trade_leverage': 15,
#   'final_portfolio_value': 39518.43519043403,
#   'start_date': '01-01-2023'},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_15m_01-01-2019_31-12-2021_292f9b18.h5',
#   'val_mae': 0.3873039484024048,
#   'train_candles_length': 66855,
#   'trade_buy_threshold': 0.7,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': None},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'training_data_end_date': DatetimeWithNanoseconds(2021, 5, 26, 17, 15, tzinfo=datetime.timezone.utc),
#   'training_data_start_date': DatetimeWithNanoseconds(2019, 1, 4, 8, 0, tzinfo=datetime.timezone.utc),
#   'val_candles_length': 16714,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 2, 29, 33, 290184, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1',
#   'train_mae': 0.4248599708080292,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_15m_01-01-2019_31-12-2021_292f9b18',
#   'test_data_end_date': DatetimeWithNanoseconds(2021, 12, 30, 19, 30, tzinfo=datetime.timezone.utc),
#   'final_epoch': 7,
#   'val_loss': 0.224314883351326,
#   'drawdown_analysis': {'len': 982,
#    'drawdown': 4,
#    'max': {'len': 11042, 'drawdown': 42, 'moneydown': 9308},
#    'moneydown': 1154},
#   'end_date': '31-12-2021',
#   'test_candles_length': 20818,
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 38,
#     'pnl': {'average': 608,
#      'total': 23066,
#      'won': {'total': 38234, 'average': 1416, 'max': 5318},
#      'lost': {'total': -15166, 'average': -1378, 'max': -3736}},
#     'won': 28,
#     'lost': 12},
#    'total': {'total': 44, 'open': 2, 'closed': 42},
#    'won': {'total': 30, 'pnl': {'average': 1348, 'total': 40414, 'max': 5318}},
#    'len': {'short': {'max': 1778,
#      'average': 442,
#      'total': 16760,
#      'won': {'total': 11844, 'average': 440, 'min': 48, 'max': 1778},
#      'min': 48,
#      'lost': {'total': 4916, 'average': 448, 'min': 76, 'max': 1586}},
#     'total': 17104,
#     'average': 408,
#     'won': {'average': 398, 'total': 11946, 'max': 1778, 'min': 12},
#     'min': 12,
#     'long': {'max': 244,
#      'average': 86,
#      'total': 344,
#      'won': {'total': 102, 'average': 34, 'min': 12, 'max': 60},
#      'min': 12,
#      'lost': {'total': 244, 'average': 244, 'min': 244, 'max': 244}},
#     'max': 1778,
#     'lost': {'average': 430, 'total': 5158, 'max': 1586, 'min': 76}},
#    'long': {'total': 4,
#     'pnl': {'average': 506,
#      'total': 2026,
#      'won': {'total': 2182, 'average': 728, 'max': 774},
#      'lost': {'total': -156, 'average': -156, 'max': -156}},
#     'won': 4,
#     'lost': 2},
#    'pnl': {'gross': {'average': 608, 'total': 25506},
#     'net': {'average': 598, 'total': 25092}},
#    'streak': {'won': {'longest': 10, 'current': 2},
#     'lost': {'longest': 2, 'current': 0}},
#    'lost': {'total': 12,
#     'pnl': {'average': -1276, 'total': -15322, 'max': -3736}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2021, 5, 27, 18, 30, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.6,
#   'train_loss': 0.2636461555957794,
#   'trade_leverage': 25,
#   'final_portfolio_value': 34754.31653082801,
#   'start_date': '01-01-2019'},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_15m_01-01-2023_31-12-2025_f61cdbdc.h5',
#   'val_mae': 0.4217982590198517,
#   'train_candles_length': 48737,
#   'trade_buy_threshold': 0.7,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': 2},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'training_data_end_date': DatetimeWithNanoseconds(2024, 10, 1, 0, 15, tzinfo=datetime.timezone.utc),
#   'training_data_start_date': DatetimeWithNanoseconds(2023, 1, 4, 8, 0, tzinfo=datetime.timezone.utc),
#   'val_candles_length': 12185,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 3, 30, 32, 499083, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1',
#   'train_mae': 0.40471068024635315,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_15m_01-01-2023_31-12-2025_f61cdbdc',
#   'test_data_end_date': DatetimeWithNanoseconds(2025, 3, 8, 22, 15, tzinfo=datetime.timezone.utc),
#   'final_epoch': 7,
#   'val_loss': 0.2523728907108307,
#   'drawdown_analysis': {'len': 182,
#    'drawdown': 2,
#    'max': {'len': 8732, 'drawdown': 58, 'moneydown': 6636},
#    'moneydown': 140},
#   'end_date': '31-12-2025',
#   'test_candles_length': 15156,
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 20,
#     'pnl': {'average': 508,
#      'total': 9642,
#      'won': {'total': 17074, 'average': 1424, 'max': 3116},
#      'lost': {'total': -7432, 'average': -1062, 'max': -4066}},
#     'won': 12,
#     'lost': 8},
#    'total': {'total': 20, 'open': 2, 'closed': 20},
#    'won': {'total': 12, 'pnl': {'average': 1424, 'total': 17074, 'max': 3116}},
#    'len': {'short': {'max': 1918,
#      'average': 646,
#      'total': 12256,
#      'won': {'total': 7106, 'average': 592, 'min': 32, 'max': 1918},
#      'min': 32,
#      'lost': {'total': 5150, 'average': 736, 'min': 80, 'max': 1568}},
#     'total': 12256,
#     'average': 646,
#     'won': {'average': 592, 'total': 7106, 'max': 1918, 'min': 32},
#     'min': 32,
#     'long': {'max': 0,
#      'average': 0,
#      'total': 0,
#      'won': {'total': 0, 'average': 0, 'min': 0, 'max': 0},
#      'min': 0,
#      'lost': {'total': 0, 'average': 0, 'min': 0, 'max': 0}},
#     'max': 1918,
#     'lost': {'average': 736, 'total': 5150, 'max': 1568, 'min': 80}},
#    'long': {'total': 0,
#     'pnl': {'average': 0,
#      'total': 0,
#      'won': {'total': 0, 'average': 0, 'max': 0},
#      'lost': {'total': 0, 'average': 0, 'max': 0}},
#     'won': 0,
#     'lost': 0},
#    'pnl': {'gross': {'average': 518, 'total': 9830},
#     'net': {'average': 508, 'total': 9642}},
#    'streak': {'won': {'longest': 4, 'current': 4},
#     'lost': {'longest': 4, 'current': 0}},
#    'lost': {'total': 8,
#     'pnl': {'average': -1062, 'total': -7432, 'max': -4066}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2024, 10, 2, 1, 30, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.5,
#   'train_loss': 0.24440884590148926,
#   'trade_leverage': 25,
#   'final_portfolio_value': 20733.499547585583,
#   'start_date': '01-01-2023'},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_15m_01-01-2020_31-12-2022_c514f0a4.h5',
#   'val_mae': 0.4048410654067993,
#   'train_candles_length': 66915,
#   'trade_buy_threshold': 0.6,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': None},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'training_data_end_date': DatetimeWithNanoseconds(2022, 5, 26, 19, 0, tzinfo=datetime.timezone.utc),
#   'training_data_start_date': DatetimeWithNanoseconds(2020, 1, 4, 8, 0, tzinfo=datetime.timezone.utc),
#   'val_candles_length': 16729,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 2, 42, 37, 418548, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1',
#   'train_mae': 0.4030745327472687,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_15m_01-01-2020_31-12-2022_c514f0a4',
#   'test_data_end_date': DatetimeWithNanoseconds(2022, 12, 30, 21, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 9,
#   'val_loss': 0.24267169833183289,
#   'drawdown_analysis': {'len': 0,
#    'drawdown': 0,
#    'max': {'len': 604, 'drawdown': 20, 'moneydown': 2660},
#    'moneydown': 0},
#   'end_date': '31-12-2022',
#   'test_candles_length': 20836,
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 136,
#     'pnl': {'average': 188,
#      'total': 25618,
#      'won': {'total': 27632, 'average': 224, 'max': 1644},
#      'lost': {'total': -2014, 'average': -168, 'max': -744}},
#     'won': 124,
#     'lost': 12},
#    'total': {'total': 274, 'open': 2, 'closed': 272},
#    'won': {'total': 236, 'pnl': {'average': 232, 'total': 54186, 'max': 1644}},
#    'len': {'short': {'max': 298,
#      'average': 60,
#      'total': 8146,
#      'won': {'total': 7012, 'average': 58, 'min': 6, 'max': 298},
#      'min': 6,
#      'lost': {'total': 1134, 'average': 94, 'min': 24, 'max': 256}},
#     'total': 17824,
#     'average': 66,
#     'won': {'average': 60, 'total': 14158, 'max': 472, 'min': 6},
#     'min': 6,
#     'long': {'max': 472,
#      'average': 72,
#      'total': 9678,
#      'won': {'total': 7146, 'average': 64, 'min': 10, 'max': 472},
#      'min': 10,
#      'lost': {'total': 2532, 'average': 102, 'min': 26, 'max': 192}},
#     'max': 472,
#     'lost': {'average': 100, 'total': 3666, 'max': 256, 'min': 24}},
#    'long': {'total': 136,
#     'pnl': {'average': 158,
#      'total': 21372,
#      'won': {'total': 26554, 'average': 240, 'max': 1094},
#      'lost': {'total': -5182, 'average': -206, 'max': -1722}},
#     'won': 112,
#     'lost': 26},
#    'pnl': {'gross': {'average': 178, 'total': 48076},
#     'net': {'average': 174, 'total': 46988}},
#    'streak': {'won': {'longest': 20, 'current': 2},
#     'lost': {'longest': 2, 'current': 0}},
#    'lost': {'total': 38,
#     'pnl': {'average': -194, 'total': -7196, 'max': -1722}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2022, 5, 27, 20, 15, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.5,
#   'train_loss': 0.24263039231300354,
#   'trade_leverage': 10,
#   'final_portfolio_value': 57054.17892666893,
#   'start_date': '01-01-2020'},
#  {'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_15m_01-01-2020_31-12-2022_c514f0a4.h5',
#   'val_mae': 0.4048410654067993,
#   'train_candles_length': 66915,
#   'trade_buy_threshold': 0.7,
#   'features_columns': ['15m_RSI_14',
#    '15m_RSI_6',
#    '15m_EMA_5',
#    '15m_EMA_21',
#    '15m_SMA_50',
#    '15m_MACD_12_26_9',
#    '15m_MACDs_12_26_9',
#    '15m_MACDh_12_26_9',
#    '15m_BBL_20_2.0',
#    '15m_BBM_20_2.0',
#    '15m_BBU_20_2.0',
#    '15m_BBB_20_2.0',
#    '15m_BBP_20_2.0',
#    '1h_RSI_14',
#    '1h_RSI_6',
#    '1h_EMA_5',
#    '1h_EMA_21',
#    '1h_MACD_12_26_9',
#    '1h_MACDs_12_26_9',
#    '1h_MACDh_12_26_9',
#    '1h_BBL_20_2.0',
#    '1h_BBM_20_2.0',
#    '1h_BBU_20_2.0',
#    '1h_BBB_20_2.0',
#    '1h_BBP_20_2.0',
#    '4h_RSI_14',
#    '4h_RSI_6',
#    '4h_EMA_5',
#    '4h_EMA_21'],
#   'training_data_ratio': 0.8,
#   'sharpe_analysis': {'sharperatio': None},
#   'model_input_shape': [100, 29],
#   'epochs': 20,
#   'training_data_end_date': DatetimeWithNanoseconds(2022, 5, 26, 19, 0, tzinfo=datetime.timezone.utc),
#   'training_data_start_date': DatetimeWithNanoseconds(2020, 1, 4, 8, 0, tzinfo=datetime.timezone.utc),
#   'val_candles_length': 16729,
#   'created_at': DatetimeWithNanoseconds(2025, 3, 9, 2, 45, 25, 962204, tzinfo=datetime.timezone.utc),
#   'lower_timeframe': '15m',
#   'version': 'v1',
#   'train_mae': 0.4030745327472687,
#   'timeframe': '15m',
#   'seq_length': 100,
#   'higher_timeframe': '4h',
#   'model_name': 'binance_mtf_v1_15m_01-01-2020_31-12-2022_c514f0a4',
#   'test_data_end_date': DatetimeWithNanoseconds(2022, 12, 30, 21, 0, tzinfo=datetime.timezone.utc),
#   'final_epoch': 9,
#   'val_loss': 0.24267169833183289,
#   'drawdown_analysis': {'len': 1478,
#    'drawdown': 2,
#    'max': {'len': 3138, 'drawdown': 16, 'moneydown': 3172},
#    'moneydown': 624},
#   'end_date': '31-12-2022',
#   'test_candles_length': 20836,
#   'trade_margin': 1000,
#   'trade_analysis': {'short': {'total': 20,
#     'pnl': {'average': 852,
#      'total': 17042,
#      'won': {'total': 18910, 'average': 1182, 'max': 3692},
#      'lost': {'total': -1868, 'average': -466, 'max': -676}},
#     'won': 16,
#     'lost': 4},
#    'total': {'total': 34, 'open': 2, 'closed': 34},
#    'won': {'total': 28, 'pnl': {'average': 1148, 'total': 30988, 'max': 3692}},
#    'len': {'short': {'max': 874,
#      'average': 180,
#      'total': 3586,
#      'won': {'total': 2076, 'average': 130, 'min': 14, 'max': 368},
#      'min': 14,
#      'lost': {'total': 1510, 'average': 378, 'min': 124, 'max': 874}},
#     'total': 12360,
#     'average': 376,
#     'won': {'average': 342, 'total': 9228, 'max': 1438, 'min': 14},
#     'min': 14,
#     'long': {'max': 1438,
#      'average': 676,
#      'total': 8774,
#      'won': {'total': 7152, 'average': 650, 'min': 144, 'max': 1438},
#      'min': 144,
#      'lost': {'total': 1622, 'average': 812, 'min': 352, 'max': 1272}},
#     'max': 1438,
#     'lost': {'average': 522, 'total': 3132, 'max': 1272, 'min': 124}},
#    'long': {'total': 14,
#     'pnl': {'average': 688,
#      'total': 8948,
#      'won': {'total': 12080, 'average': 1098, 'max': 2796},
#      'lost': {'total': -3132, 'average': -1566, 'max': -2094}},
#     'won': 12,
#     'lost': 2},
#    'pnl': {'gross': {'average': 796, 'total': 26250},
#     'net': {'average': 788, 'total': 25988}},
#    'streak': {'won': {'longest': 14, 'current': 2},
#     'lost': {'longest': 2, 'current': 0}},
#    'lost': {'total': 6,
#     'pnl': {'average': -832, 'total': -5000, 'max': -2094}}},
#   'broker_commision': 0.02,
#   'exchange': 'binance',
#   'starting_portfolio_value': 10000.0,
#   'symbol': 'BTCUSDT',
#   'test_data_start_date': DatetimeWithNanoseconds(2022, 5, 27, 20, 15, tzinfo=datetime.timezone.utc),
#   'middle_timeframe': '1h',
#   'trade_sell_threshold': -0.7,
#   'train_loss': 0.24263039231300354,
#   'trade_leverage': 20,
#   'final_portfolio_value': 36153.85949135184,
#   'start_date': '01-01-2020'}]

# %%
data = pd.DataFrame(trade_models)
data
# Out:
#                                             model_path   val_mae  \
# 0    gs://ife-storage/trade/models/binance_mtf_v1_1...  0.426709
# 1    gs://ife-storage/trade/models/binance_mtf_v1_1...  0.421798
# 2    gs://ife-storage/trade/models/binance_mtf_v1_1...  0.399768
# 3    gs://ife-storage/trade/models/binance_mtf_v1_1...  0.425303
# 4    gs://ife-storage/trade/models/binance_mtf_v1_1...  0.399768
# ..                                                 ...       ...
# 499  gs://ife-storage/trade/models/binance_mtf_v1_1...  0.421798
# 500  gs://ife-storage/trade/models/binance_mtf_v1_1...  0.387304
# 501  gs://ife-storage/trade/models/binance_mtf_v1_1...  0.421798
# 502  gs://ife-storage/trade/models/binance_mtf_v1_1...  0.404841
# 503  gs://ife-storage/trade/models/binance_mtf_v1_1...  0.404841
#
#      train_candles_length  trade_buy_threshold  \
# 0                   66944                  0.5
# 1                   48737                  0.8
# 2                   66980                  0.8
# 3                   66767                  0.5
# 4                   66980                  0.6
# ..                    ...                  ...
# 499                 48737                  0.6
# 500                 66855                  0.7
# 501                 48737                  0.7
# 502                 66915                  0.6
# 503                 66915                  0.7
#
#                                       features_columns  training_data_ratio  \
# 0    _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 1    _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 2    _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 3    _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 4    _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# ..                                                 ...                  ...
# 499  _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 500  _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 501  _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 502  _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
# 503  _RSI_14, 15m_RSI_6, 15m_EMA_5, 15m_EMA_21,...                  0.8
#
#            sharpe_analysis model_input_shape  epochs  \
# 0    {'sharperatio': None}         [100, 29]      20
# 1       {'sharperatio': 0}         [100, 29]      20
# 2    {'sharperatio': None}         [100, 29]      20
# 3    {'sharperatio': None}         [100, 29]      20
# 4    {'sharperatio': None}         [100, 29]      20
# ..                     ...               ...     ...
# 499    {'sharperatio': 14}         [100, 29]      20
# 500  {'sharperatio': None}         [100, 29]      20
# 501     {'sharperatio': 2}         [100, 29]      20
# 502  {'sharperatio': None}         [100, 29]      20
# 503  {'sharperatio': None}         [100, 29]      20
#
#        training_data_end_date  ... exchange  starting_portfolio_value  \
# 0   2023-05-27 14:00:00+00:00  ...  binance                   10000.0
# 1   2024-10-01 00:15:00+00:00  ...  binance                   10000.0
# 2   2024-05-26 13:00:00+00:00  ...  binance                   10000.0
# 3   2020-05-26 23:15:00+00:00  ...  binance                   10000.0
# 4   2024-05-26 13:00:00+00:00  ...  binance                   10000.0
# ..                        ...  ...      ...                       ...
# 499 2024-10-01 00:15:00+00:00  ...  binance                   10000.0
# 500 2021-05-26 17:15:00+00:00  ...  binance                   10000.0
# 501 2024-10-01 00:15:00+00:00  ...  binance                   10000.0
# 502 2022-05-26 19:00:00+00:00  ...  binance                   10000.0
# 503 2022-05-26 19:00:00+00:00  ...  binance                   10000.0
#
#       symbol      test_data_start_date middle_timeframe  trade_sell_threshold  \
# 0    BTCUSDT 2023-05-28 15:15:00+00:00               1h                  -0.5
# 1    BTCUSDT 2024-10-02 01:30:00+00:00               1h                  -0.5
# 2    BTCUSDT 2024-05-27 14:15:00+00:00               1h                  -0.7
# 3    BTCUSDT 2020-05-28 00:30:00+00:00               1h                  -0.6
# 4    BTCUSDT 2024-05-27 14:15:00+00:00               1h                  -0.7
# ..       ...                       ...              ...                   ...
# 499  BTCUSDT 2024-10-02 01:30:00+00:00               1h                  -0.5
# 500  BTCUSDT 2021-05-27 18:30:00+00:00               1h                  -0.6
# 501  BTCUSDT 2024-10-02 01:30:00+00:00               1h                  -0.5
# 502  BTCUSDT 2022-05-27 20:15:00+00:00               1h                  -0.5
# 503  BTCUSDT 2022-05-27 20:15:00+00:00               1h                  -0.7
#
#     train_loss  trade_leverage final_portfolio_value  start_date
# 0     0.228014              20          48801.284621  01-01-2021
# 1     0.244409              15           4369.235279  01-01-2023
# 2     0.234009              10          16087.619855  01-01-2022
# 3     0.241986               7          36824.672361  01-01-2018
# 4     0.234009              15          50920.109695  01-01-2022
# ..         ...             ...                   ...         ...
# 499   0.244409              15          39518.435190  01-01-2023
# 500   0.263646              25          34754.316531  01-01-2019
# 501   0.244409              25          20733.499548  01-01-2023
# 502   0.242630              10          57054.178927  01-01-2020
# 503   0.242630              20          36153.859491  01-01-2020
#
# [504 rows x 39 columns]

# %%
sorted(data.columns)
# Out:
# ['broker_commision',
#  'created_at',
#  'drawdown_analysis',
#  'end_date',
#  'epochs',
#  'exchange',
#  'features_columns',
#  'final_epoch',
#  'final_portfolio_value',
#  'higher_timeframe',
#  'lower_timeframe',
#  'middle_timeframe',
#  'model_input_shape',
#  'model_name',
#  'model_path',
#  'seq_length',
#  'sharpe_analysis',
#  'start_date',
#  'starting_portfolio_value',
#  'symbol',
#  'test_candles_length',
#  'test_data_end_date',
#  'test_data_start_date',
#  'timeframe',
#  'trade_analysis',
#  'trade_buy_threshold',
#  'trade_leverage',
#  'trade_margin',
#  'trade_sell_threshold',
#  'train_candles_length',
#  'train_loss',
#  'train_mae',
#  'training_data_end_date',
#  'training_data_ratio',
#  'training_data_start_date',
#  'val_candles_length',
#  'val_loss',
#  'val_mae',
#  'version']

# %%
performing_model = data[['start_date', 'end_date', 'final_portfolio_value', 'trade_buy_threshold', 'trade_sell_threshold', 'trade_leverage', 'val_loss', 'val_mae', 'test_data_start_date', 'test_data_end_date']].sort_values(by='final_portfolio_value', ascending=False).head(20)
performing_model
# Out:
#      start_date    end_date  final_portfolio_value  trade_buy_threshold  \
# 334  01-01-2019  31-12-2021          136371.757700                  0.5
# 124  01-01-2020  31-12-2022          124316.117028                  0.5
# 362  01-01-2020  31-12-2022          122611.538572                  0.6
# 343  01-01-2019  31-12-2021          114265.077466                  0.5
# 331  01-01-2019  31-12-2021          109128.855969                  0.5
# 412  01-01-2022  31-12-2024          107671.489501                  0.5
# 417  01-01-2020  31-12-2022          104617.752425                  0.5
# 374  01-01-2020  31-12-2022          101699.383001                  0.6
# 198  01-01-2020  31-12-2022           99460.295528                  0.7
# 218  01-01-2022  31-12-2024           98868.281067                  0.5
# 94   01-01-2022  31-12-2024           96479.198636                  0.6
# 469  01-01-2018  31-12-2020           94019.575364                  0.5
# 59   01-01-2022  31-12-2024           93503.508516                  0.6
# 316  01-01-2019  31-12-2021           90632.927371                  0.5
# 116  01-01-2018  31-12-2020           90314.749251                  0.5
# 317  01-01-2019  31-12-2021           88718.853187                  0.5
# 83   01-01-2022  31-12-2024           88417.986005                  0.5
# 376  01-01-2020  31-12-2022           86672.279203                  0.7
# 386  01-01-2020  31-12-2022           84265.803722                  0.7
# 488  01-01-2020  31-12-2022           83824.358184                  0.5
#
#      trade_sell_threshold  trade_leverage  val_loss   val_mae  \
# 334                  -0.5              25  0.224315  0.387304
# 124                  -0.5              25  0.242672  0.404841
# 362                  -0.5              25  0.242672  0.404841
# 343                  -0.5              20  0.224315  0.387304
# 331                  -0.6              25  0.224315  0.387304
# 412                  -0.5              25  0.241482  0.399768
# 417                  -0.5              20  0.242672  0.404841
# 374                  -0.5              20  0.242672  0.404841
# 198                  -0.5              25  0.242672  0.404841
# 218                  -0.6              25  0.241482  0.399768
# 94                   -0.5              25  0.241482  0.399768
# 469                  -0.5              25  0.266579  0.425303
# 59                   -0.6              25  0.241482  0.399768
# 316                  -0.6              20  0.224315  0.387304
# 116                  -0.6              25  0.266579  0.425303
# 317                  -0.5              15  0.224315  0.387304
# 83                   -0.5              20  0.241482  0.399768
# 376                  -0.6              25  0.242672  0.404841
# 386                  -0.5              20  0.242672  0.404841
# 488                  -0.5              15  0.242672  0.404841
#
#          test_data_start_date        test_data_end_date
# 334 2021-05-27 18:30:00+00:00 2021-12-30 19:30:00+00:00
# 124 2022-05-27 20:15:00+00:00 2022-12-30 21:00:00+00:00
# 362 2022-05-27 20:15:00+00:00 2022-12-30 21:00:00+00:00
# 343 2021-05-27 18:30:00+00:00 2021-12-30 19:30:00+00:00
# 331 2021-05-27 18:30:00+00:00 2021-12-30 19:30:00+00:00
# 412 2024-05-27 14:15:00+00:00 2024-12-30 20:15:00+00:00
# 417 2022-05-27 20:15:00+00:00 2022-12-30 21:00:00+00:00
# 374 2022-05-27 20:15:00+00:00 2022-12-30 21:00:00+00:00
# 198 2022-05-27 20:15:00+00:00 2022-12-30 21:00:00+00:00
# 218 2024-05-27 14:15:00+00:00 2024-12-30 20:15:00+00:00
# 94  2024-05-27 14:15:00+00:00 2024-12-30 20:15:00+00:00
# 469 2020-05-28 00:30:00+00:00 2020-12-30 20:45:00+00:00
# 59  2024-05-27 14:15:00+00:00 2024-12-30 20:15:00+00:00
# 316 2021-05-27 18:30:00+00:00 2021-12-30 19:30:00+00:00
# 116 2020-05-28 00:30:00+00:00 2020-12-30 20:45:00+00:00
# 317 2021-05-27 18:30:00+00:00 2021-12-30 19:30:00+00:00
# 83  2024-05-27 14:15:00+00:00 2024-12-30 20:15:00+00:00
# 376 2022-05-27 20:15:00+00:00 2022-12-30 21:00:00+00:00
# 386 2022-05-27 20:15:00+00:00 2022-12-30 21:00:00+00:00
# 488 2022-05-27 20:15:00+00:00 2022-12-30 21:00:00+00:00

# %%
data.loc[334]['trade_analysis']['won']
# Out:
# {'total': 334, 'pnl': {'average': 506, 'total': 168564, 'max': 2852}}

# %%
get_nested_value(data.loc[334]['trade_analysis'], ['streak', 'won', 'longest'])
# Out:
# 20

# %%
def get_trade_analysis_overview(df):
  selected_columns = [
      'start_date', 'end_date', 'final_portfolio_value', 'trade_buy_threshold',
      'trade_sell_threshold', 'trade_leverage', 'val_loss', 'val_mae',
      'test_data_start_date', 'test_data_end_date', 'trade_analysis', 'drawdown_analysis'
  ]
  df = df[selected_columns].copy().sort_values(by='final_portfolio_value', ascending=False)
  df['total_trade'] = df['trade_analysis'].apply(lambda x: x['total']['total'])
  df['longest_won_streak'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['streak', 'won', 'longest']))
  df['longest_lost_streak'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['streak', 'lost', 'longest']))
  df['total_pnl'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['pnl', 'net', 'total']))
  df['avg_pnl'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['pnl', 'net', 'average']))
  df['total_win_trade'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['won', 'total']))
  df['total_won_amount'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['won', 'pnl', 'total']))
  df['max_won_amount'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['won', 'pnl', 'max']))
  df['avg_won_amount'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['won', 'pnl', 'average']))
  df['total_loss_trade'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['lost', 'total']))
  df['total_lost_amount'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['lost', 'pnl', 'total']))
  df['max_lost_amount'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['lost', 'pnl', 'max']))
  df['avg_lost_amount'] = df['trade_analysis'].apply(lambda x: get_nested_value(x, ['lost', 'pnl', 'average']))
  df['max_drawdown_percent'] = df['drawdown_analysis'].apply(lambda x: get_nested_value(x, ['max', 'drawdown']))
  df['max_drawdown_value'] = df['drawdown_analysis'].apply(lambda x: get_nested_value(x, ['max', 'moneydown']))
  df['max_drawdown_len'] = df['drawdown_analysis'].apply(lambda x: get_nested_value(x, ['max', 'len']))
  del df['trade_analysis']
  del df['drawdown_analysis']
  return df

# %%
trade_data = get_trade_analysis_overview(data)
trade_data
# Out:
#      start_date    end_date  final_portfolio_value  trade_buy_threshold  \
# 334  01-01-2019  31-12-2021          136371.757700                  0.5
# 124  01-01-2020  31-12-2022          124316.117028                  0.5
# 362  01-01-2020  31-12-2022          122611.538572                  0.6
# 343  01-01-2019  31-12-2021          114265.077466                  0.5
# 331  01-01-2019  31-12-2021          109128.855969                  0.5
# ..          ...         ...                    ...                  ...
# 192  01-01-2018  31-12-2020          -14389.286926                  0.8
# 232  01-01-2018  31-12-2020          -15364.986535                  0.8
# 268  01-01-2018  31-12-2020          -19401.430975                  0.8
# 498  01-01-2018  31-12-2020          -20486.608657                  0.8
# 250  01-01-2018  31-12-2020          -25485.114834                  0.8
#
#      trade_sell_threshold  trade_leverage  val_loss   val_mae  \
# 334                  -0.5              25  0.224315  0.387304
# 124                  -0.5              25  0.242672  0.404841
# 362                  -0.5              25  0.242672  0.404841
# 343                  -0.5              20  0.224315  0.387304
# 331                  -0.6              25  0.224315  0.387304
# ..                    ...             ...       ...       ...
# 192                  -0.6              20  0.266579  0.425303
# 232                  -0.5              20  0.266579  0.425303
# 268                  -0.7              25  0.266579  0.425303
# 498                  -0.6              25  0.266579  0.425303
# 250                  -0.5              25  0.266579  0.425303
#
#          test_data_start_date        test_data_end_date  ...  \
# 334 2021-05-27 18:30:00+00:00 2021-12-30 19:30:00+00:00  ...
# 124 2022-05-27 20:15:00+00:00 2022-12-30 21:00:00+00:00  ...
# 362 2022-05-27 20:15:00+00:00 2022-12-30 21:00:00+00:00  ...
# 343 2021-05-27 18:30:00+00:00 2021-12-30 19:30:00+00:00  ...
# 331 2021-05-27 18:30:00+00:00 2021-12-30 19:30:00+00:00  ...
# ..                        ...                       ...  ...
# 192 2020-05-28 00:30:00+00:00 2020-12-30 20:45:00+00:00  ...
# 232 2020-05-28 00:30:00+00:00 2020-12-30 20:45:00+00:00  ...
# 268 2020-05-28 00:30:00+00:00 2020-12-30 20:45:00+00:00  ...
# 498 2020-05-28 00:30:00+00:00 2020-12-30 20:45:00+00:00  ...
# 250 2020-05-28 00:30:00+00:00 2020-12-30 20:45:00+00:00  ...
#
#      total_won_amount  max_won_amount  avg_won_amount  total_loss_trade  \
# 334          168564.0          2852.0           506.0              68.0
# 124          127752.0          2970.0           494.0              42.0
# 362          124380.0          4108.0           558.0              32.0
# 343          140056.0          2282.0           408.0              72.0
# 331          129570.0          2656.0           632.0              52.0
# ..                ...             ...             ...               ...
# 192            2744.0          1946.0           550.0               4.0
# 232            2608.0          2368.0          1304.0               8.0
# 268            3162.0          1596.0           790.0               4.0
# 498            3432.0          2432.0           686.0               4.0
# 250            3260.0          2960.0          1630.0               6.0
#
#      total_lost_amount  max_lost_amount  avg_lost_amount  \
# 334           -42032.0          -2864.0           -618.0
# 124           -13600.0          -2432.0           -324.0
# 362           -11932.0          -2152.0           -372.0
# 343           -35662.0          -2292.0           -494.0
# 331           -30278.0          -2694.0           -582.0
# ..                 ...              ...              ...
# 192           -10142.0          -4172.0          -2536.0
# 232           -11090.0          -4172.0          -1584.0
# 268           -12716.0          -5176.0          -3178.0
# 498           -12678.0          -5214.0          -3170.0
# 250           -10604.0          -5214.0          -1766.0
#
#      max_drawdown_percent  max_drawdown_value  max_drawdown_len
# 334                    20                4610               852
# 124                    10                4062               790
# 362                     8                3306               604
# 343                    18                3688               770
# 331                    22                3856               788
# ..                    ...                 ...               ...
# 192                   226               25892             17832
# 232                   242               26236             17832
# 268                   252               32382             17832
# 498                   274               32364             17832
# 250                   332               36582             17832
#
# [504 rows x 26 columns]

# %%
trade_data.columns
# Out:
# Index(['start_date', 'end_date', 'final_portfolio_value',
#        'trade_buy_threshold', 'trade_sell_threshold', 'trade_leverage',
#        'val_loss', 'val_mae', 'test_data_start_date', 'test_data_end_date',
#        'total_trade', 'longest_won_streak', 'longest_lost_streak', 'total_pnl',
#        'avg_pnl', 'total_win_trade', 'total_won_amount', 'max_won_amount',
#        'avg_won_amount', 'total_loss_trade', 'total_lost_amount',
#        'max_lost_amount', 'avg_lost_amount', 'max_drawdown_percent',
#        'max_drawdown_value', 'max_drawdown_len'],
#       dtype='object')

# %%
trade_data.query('max_drawdown_percent < 20 and final_portfolio_value > 50000')
# Out:
#      start_date    end_date  final_portfolio_value  trade_buy_threshold  \
# 124  01-01-2020  31-12-2022          124316.117028                  0.5
# 362  01-01-2020  31-12-2022          122611.538572                  0.6
# 343  01-01-2019  31-12-2021          114265.077466                  0.5
# 412  01-01-2022  31-12-2024          107671.489501                  0.5
# 417  01-01-2020  31-12-2022          104617.752425                  0.5
# ..          ...         ...                    ...                  ...
# 201  01-01-2018  31-12-2020           51419.982532                  0.5
# 328  01-01-2017  01-01-2020           50971.335708                  0.5
# 4    01-01-2022  31-12-2024           50920.109695                  0.6
# 43   01-01-2023  31-12-2025           50749.959564                  0.5
# 299  01-01-2022  31-12-2024           50647.629427                  0.7
#
#      trade_sell_threshold  trade_leverage  val_loss   val_mae  \
# 124                  -0.5              25  0.242672  0.404841
# 362                  -0.5              25  0.242672  0.404841
# 343                  -0.5              20  0.224315  0.387304
# 412                  -0.5              25  0.241482  0.399768
# 417                  -0.5              20  0.242672  0.404841
# ..                    ...             ...       ...       ...
# 201                  -0.5              10  0.266579  0.425303
# 328                  -0.5              20  0.259467  0.423599
# 4                    -0.7              15  0.241482  0.399768
# 43                   -0.5              15  0.252373  0.421798
# 299                  -0.6              15  0.241482  0.399768
#
#          test_data_start_date        test_data_end_date  ...  \
# 124 2022-05-27 20:15:00+00:00 2022-12-30 21:00:00+00:00  ...
# 362 2022-05-27 20:15:00+00:00 2022-12-30 21:00:00+00:00  ...
# 343 2021-05-27 18:30:00+00:00 2021-12-30 19:30:00+00:00  ...
# 412 2024-05-27 14:15:00+00:00 2024-12-30 20:15:00+00:00  ...
# 417 2022-05-27 20:15:00+00:00 2022-12-30 21:00:00+00:00  ...
# ..                        ...                       ...  ...
# 201 2020-05-28 00:30:00+00:00 2020-12-30 20:45:00+00:00  ...
# 328 2019-07-13 10:00:00+00:00 2019-12-31 18:00:00+00:00  ...
# 4   2024-05-27 14:15:00+00:00 2024-12-30 20:15:00+00:00  ...
# 43  2024-10-02 01:30:00+00:00 2025-03-08 22:15:00+00:00  ...
# 299 2024-05-27 14:15:00+00:00 2024-12-30 20:15:00+00:00  ...
#
#      total_won_amount  max_won_amount  avg_won_amount  total_loss_trade  \
# 124          127752.0          2970.0           494.0              42.0
# 362          124380.0          4108.0           558.0              32.0
# 343          140056.0          2282.0           408.0              72.0
# 412          117414.0          1722.0           320.0              82.0
# 417          105306.0          2376.0           398.0              44.0
# ..                ...             ...             ...               ...
# 201           52358.0           800.0           140.0              76.0
# 328           58370.0          1696.0           394.0              40.0
# 4             45260.0          3324.0           408.0              18.0
# 43            44312.0          1682.0           372.0              20.0
# 299           51356.0          1898.0           358.0              32.0
#
#      total_lost_amount  max_lost_amount  avg_lost_amount  \
# 124           -13600.0          -2432.0           -324.0
# 362           -11932.0          -2152.0           -372.0
# 343           -35662.0          -2292.0           -494.0
# 412           -19742.0           -976.0           -244.0
# 417           -10820.0          -1946.0           -252.0
# ..                 ...              ...              ...
# 201           -10200.0           -754.0           -134.0
# 328           -17682.0          -3006.0           -452.0
# 4              -4808.0           -918.0           -266.0
# 43             -3350.0           -748.0           -176.0
# 299           -11108.0          -1240.0           -346.0
#
#      max_drawdown_percent  max_drawdown_value  max_drawdown_len
# 124                    10                4062               790
# 362                     8                3306               604
# 343                    18                3688               770
# 412                    12                2398               848
# 417                     8                3250               790
# ..                    ...                 ...               ...
# 201                     6                1162               796
# 328                    18                4620              2706
# 4                      12                2466               974
# 43                      8                1474               580
# 299                     6                2092              1720
#
# [62 rows x 26 columns]
