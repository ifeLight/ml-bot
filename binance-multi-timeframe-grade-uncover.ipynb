# %% [markdown]
# <a href="https://colab.research.google.com/github/ifeLight/ml-bot/blob/main/binance-multi-timeframe-grade-uncover.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas-ta
# !pip install backtrader[plotting]
# !pip install plotly
# !pip install --upgrade firebase-admin
# Out:
# Collecting pandas-ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from pandas-ta) (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas-ta) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas-ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas-ta) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas-ta) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->pandas-ta) (1.17.0)
# Building wheels for collected packages: pandas-ta
#   Building wheel for pandas-ta (setup.py) ... done
#   Created wheel for pandas-ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218909 sha256=96171799b1aae162918c4843515e3e0f6986274cee3e6dd81584ae8203e67082
#   Stored in directory: /root/.cache/pip/wheels/7f/33/8b/50b245c5c65433cd8f5cb24ac15d97e5a3db2d41a8b6ae957d
# Successfully built pandas-ta
# Installing collected packages: pandas-ta
# Successfully installed pandas-ta-0.3.14b0
# Collecting backtrader[plotting]
#   Downloading backtrader-1.9.78.123-py2.py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from backtrader[plotting]) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->backtrader[plotting]) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->backtrader[plotting]) (1.17.0)
# Downloading backtrader-1.9.78.123-py2.py3-none-any.whl (419 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 25.4 MB/s eta 0:00:00
# Installing collected packages: backtrader
# Successfully installed backtrader-1.9.78.123
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)
# Requirement already satisfied: firebase-admin in /usr/local/lib/python3.11/dist-packages (6.6.0)
# Requirement already satisfied: cachecontrol>=0.12.14 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (0.14.2)
# Requirement already satisfied: google-api-python-client>=1.7.8 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (2.160.0)
# Requirement already satisfied: google-cloud-storage>=1.37.1 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (2.19.0)
# Requirement already satisfied: pyjwt>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (2.10.1)
# Requirement already satisfied: google-api-core<3.0.0dev,>=1.22.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.24.1)
# Requirement already satisfied: google-cloud-firestore>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (2.20.1)
# Requirement already satisfied: requests>=2.16.0 in /usr/local/lib/python3.11/dist-packages (from cachecontrol>=0.12.14->firebase-admin) (2.32.3)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in /usr/local/lib/python3.11/dist-packages (from cachecontrol>=0.12.14->firebase-admin) (1.1.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.69.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (4.25.6)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.26.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.38.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.62.3)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (4.1.1)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from google-cloud-firestore>=2.19.0->firebase-admin) (2.4.2)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage>=1.37.1->firebase-admin) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage>=1.37.1->firebase-admin) (1.6.0)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (1.17.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client>=1.7.8->firebase-admin) (3.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (2025.1.31)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.6.1)

# %%
import numpy as np
import pandas as pd
import datetime
import requests
import json
import os
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import backtrader as bt
import pandas_ta as ta
from imblearn.over_sampling import SMOTE
import subprocess
import firebase_admin
from firebase_admin import firestore
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
from google.colab import auth
import google.auth
import itertools
import hashlib

# %%
auth.authenticate_user()
#Configure Google cloud project
project_id = 'ifelight'
# !gcloud config set project {project_id}
# Out:
# Updated property [core/project].

# %%
# Working GCP Bucket name
bucket_name = 'ife-storage'
# Working on Firestore name
firestore_collection_name = 'trade-models'

# %%
binance_base_url = 'https://52on3577u3.execute-api.eu-central-1.amazonaws.com'

def get_binance_candles(symbol: str, interval='1h', limit: int = 50, **kwargs):
    url = f'{binance_base_url}/api/v3/uiKlines?symbol={symbol}&interval={interval}&limit={limit}'
    for key, value in kwargs.items():
        url += f'&{key}={value}'
    response = requests.get(url)
    result = json.loads(response.text)
    # print(result)
    def map_result(x):
        return {
            'Date': x[0],
            'Open': x[1],
            'High': x[2],
            'Low': x[3],
            'Close': x[4],
            'Volume': x[5],
        }
    mappeded_result = []
    for x in result:
        mappeded_result.append(map_result(x))
    return mappeded_result


def candles_to_df(data):
    df =  pd.DataFrame(data)
    df['Date'] = pd.to_datetime(df['Date'], unit='ms')
    df['Open'] = df['Open'].astype(float)
    df['High'] = df['High'].astype(float)
    df['Low'] = df['Low'].astype(float)
    df['Close'] = df['Close'].astype(float)
    df['Volume'] = df['Volume'].astype(float)
    df.set_index('Date', inplace=True)
    return df

def get_all_binance_candles(symbol: str, interval='1h', start_date=None, end_date=None, limit=1000):
  try:
    return load_candles_from_cloud_storage(symbol, interval, start_date, end_date)
  except FileNotFoundError:
    pass
  result = []
  raw_start_date = start_date
  raw_end_date = end_date
  start_date = pd.to_datetime(start_date) if start_date else pd.to_datetime('2015-01-01')
  end_date = pd.to_datetime(end_date) if end_date else pd.to_datetime('today')
  while True:
    candles = get_binance_candles(symbol, interval, limit, startTime=int(start_date.timestamp() * 1000), endTime=int(end_date.timestamp() * 1000))
    if len(candles) <= 1:
      break;
    result += candles
    start_date = pd.to_datetime(datetime.datetime.fromtimestamp(candles[-1]['Date'] / 1000))
  candles_df = candles_to_df(result)
  save_candles_to_cloud_storage(candles_df, symbol, interval, raw_start_date, raw_end_date)
  return candles_df

def candles_storage_file_name(symbol: str, interval='1h', start_date=None, end_date=None):
  file_name = f'binance_{symbol}_{interval}_{start_date}_{end_date}.csv'
  return file_name

def load_candles_from_cloud_storage(symbol: str, interval: str, start_date=None, end_date=None):
  file_name = candles_storage_file_name(symbol, interval, start_date, end_date)
  try:
    # Download the file from cloud storage.
    subprocess.run(['gsutil', 'cp', f'gs://{bucket_name}/trade/candles/{file_name}', f'/tmp/{file_name}'], check=True)

    # Load the data into a Pandas DataFrame.
    with open(f'/tmp/{file_name}', 'r') as f:
      return pd.read_csv(f, index_col=0, parse_dates=True)
  except subprocess.CalledProcessError:
    # Raise a FileNotFoundError if the file is not found in cloud storage.
    raise FileNotFoundError(f"File not found: gs://{bucket_name}/trade/candles/{file_name}")

def save_candles_to_cloud_storage(df: pd.DataFrame, symbol: str, interval: str, start_date, end_date):
  file_name = candles_storage_file_name(symbol, interval, start_date, end_date)
  df.to_csv(f'/tmp/{file_name}')
  # !gsutil cp /tmp/{file_name} gs://{bucket_name}/trade/candles/{file_name}

# %%
def generate_random_hash(max_length=8):
    """
    Generate a random hash of a maximum length.

    Args:
        max_length (int): Maximum length of the hash (default is 8).

    Returns:
        str: A random hash of the specified maximum length.
    """
    # Generate a random byte sequence
    random_bytes = os.urandom(16)  # 16 bytes of random data
    # Create a SHA-256 hash of the random bytes
    hash_object = hashlib.sha256(random_bytes)
    # Get the hexadecimal representation of the hash
    hex_hash = hash_object.hexdigest()
    # Truncate the hash to the desired maximum length
    return hex_hash[:max_length]

# %%
def add_pivots(df, window=5):
    """
    Calculate the probability of price going up and down based on higher and lower pivots.
    """
    df['Higher_Pivot'] = df['High'].rolling(window=2 * window + 1, center=True).apply(
        lambda x: 1 if x.iloc[window] == x.max() else 0, raw=False
    )
    df['Lower_Pivot'] = df['Low'].rolling(window=2 * window + 1, center=True).apply(
        lambda x: 1 if x.iloc[window] == x.min() else 0, raw=False
    )

    # Step 2: Ensure no two successive pivots of the same type
    pivot_type = None  # Tracks the type of the last pivot
    last_pivot_index = None  # Tracks the index of the last pivot

    # Remove duplicated index
    df = df[~df.index.duplicated(keep='first')]

    for i in range(len(df.index)):
      if df.loc[df.index[i], 'Higher_Pivot'].item() == 1:
          if pivot_type == 'higher':
              # Compare current higher pivot with the last higher pivot
              if df.loc[df.index[i], 'High'].item() > df.loc[df.index[last_pivot_index], 'High'].item():
                  # Remove the last higher pivot
                  df.loc[df.index[last_pivot_index], 'Higher_Pivot'] = 0
                  # Update the last pivot
                  last_pivot_index = i
              else:
                  # Remove the current higher pivot
                  df.loc[df.index[i], 'Higher_Pivot'] = 0
          else:
              # Update pivot type and index
              pivot_type = 'higher'
              last_pivot_index = i

      elif df.loc[df.index[i], 'Lower_Pivot'].item() == 1:
          if pivot_type == 'lower':
              # Compare current lower pivot with the last lower pivot
              if df.loc[df.index[i], 'Low'].item() < df.loc[df.index[last_pivot_index], 'Low'].item():
                  # Remove the last lower pivot
                  df.loc[df.index[last_pivot_index], 'Lower_Pivot'] = 0
                  # Update the last pivot
                  last_pivot_index = i
              else:
                  # Remove the current lower pivot
                  df.loc[df.index[i], 'Lower_Pivot'] = 0
          else:
              # Update pivot type and index
              pivot_type = 'lower'
              last_pivot_index = i
    return df

# %%
def calculate_pivot_proximity(df):
    """
    Calculates the pivot proximity using a loop-based approach, finding the closest
    previous and next pivots without generating intermediate lists of all pivots.

    Args:
        df (pd.DataFrame): DataFrame with 'Pivot' and 'Close' columns.

    Returns:
        pd.DataFrame: DataFrame with 'Pivot_Proximity' column added.
    """
    df = df.copy()

    pivot_values = df['Pivot'].values
    close_values = df['Close'].values
    proximity_values = [0.0] * len(df)

    for i in range(len(df)):
      pivot = pivot_values[i]
      if pivot == -1:
        proximity_values[i] = -1.0
      elif pivot == 1:
        proximity_values[i] = 1.0
      else:
        closest_previous_pivot_index = None
        for j in range(i - 1, -1, -1):
          if pivot_values[j] != 0:
            closest_previous_pivot_index = j
            break

        if closest_previous_pivot_index is not None:
          closest_previous_pivot_value = pivot_values[closest_previous_pivot_index]
          closest_previous_close = close_values[closest_previous_pivot_index]

          closest_next_pivot_index = None
          if closest_previous_pivot_value == -1:
            for j in range(i + 1, len(df)):
              if pivot_values[j] == 1:
                closest_next_pivot_index = j
                break
          else:
            for j in range(i + 1, len(df)):
              if pivot_values[j] == -1:
                closest_next_pivot_index = j
                break

          if closest_next_pivot_index is not None:
            closest_next_close = close_values[closest_next_pivot_index]

            distance_to_previous = abs(close_values[i] - closest_previous_close)
            distance_to_next = abs(close_values[i] - closest_next_close)

            if distance_to_previous + distance_to_next != 0:
              if closest_previous_pivot_value == -1:
                proximity_values[i] = (distance_to_previous - distance_to_next) / (distance_to_previous + distance_to_next)
              else:
                proximity_values[i] = (distance_to_next - distance_to_previous) / (distance_to_previous + distance_to_next)

    df['Pivot_Proximity'] = proximity_values
    return df

# %%
def add_scaled_rsi(df, window=14, prefix = '', features_columns=[]):
  series = ta.rsi(df['Close'], length=window)
  column_name = f"{prefix}RSI_{window}"
  df[column_name] = series / 100
  if(column_name not in features_columns):
    features_columns.append(column_name)
  return df

def add_scaled_ema(df, window=50, prefix = '', features_columns=[]):
  series = ta.ema(df['Close'], length=window)
  column_name = f"{prefix}EMA_{window}"
  df[column_name] = series / df['Close']
  if column_name not in features_columns:
    features_columns.append(column_name)
  return df

def add_scaled_sma(df, window=50, prefix = '', features_columns=[]):
  series = ta.sma(df['Close'], length=window)
  column_name = f"{prefix}SMA_{window}"
  df[column_name] = series / df['Close']
  if column_name not in features_columns:
    features_columns.append(column_name)
  return df

def add_scaled_macd(df, prefix= '', features_columns=[], fast = 12, slow = 26, signal=9):
  macd_df = ta.macd(df['Close'], fast=fast, slow=slow, signal=signal)
  suffix = f"{fast}_{slow}_{signal}"
  macd_column_name = f"{prefix}MACD_{suffix}"
  macds_column_name = f"{prefix}MACDs_{suffix}"
  macdh_column_name = f"{prefix}MACDh_{suffix}"
  df[macd_column_name] = macd_df[macd_df.columns[0]] / df['Close']
  df[macds_column_name] = macd_df[macd_df.columns[2]] / df['Close']
  df[macdh_column_name] = macd_df[macd_df.columns[1]] / df['Close']
  if macd_column_name not in features_columns:
    features_columns.append(macd_column_name)
  if macds_column_name not in features_columns:
    features_columns.append(macds_column_name)
  if macdh_column_name not in features_columns:
    features_columns.append(macdh_column_name)
  return df

def add_scaled_bbands(df, window=20, std=2.0, prefix= '', features_columns=[]):
  bbands_df = ta.bbands(df['Close'], length=window, std=std)
  suffix = f"{window}_{std}"
  bbl_column_name = f"{prefix}BBL_{suffix}"
  bbm_column_name = f"{prefix}BBM_{suffix}"
  bbu_column_name = f"{prefix}BBU_{suffix}"
  bbb_column_name = f"{prefix}BBB_{suffix}"
  bbp_column_name = f"{prefix}BBP_{suffix}"
  df[bbl_column_name] = bbands_df[bbands_df.columns[0]] / df['Close']
  df[bbm_column_name] = bbands_df[bbands_df.columns[1]] / df['Close']
  df[bbu_column_name] = bbands_df[bbands_df.columns[2]] / df['Close']
  df[bbb_column_name] = bbands_df[bbands_df.columns[3]]
  df[bbp_column_name] = bbands_df[bbands_df.columns[4]]
  if bbl_column_name not in features_columns: features_columns.append(bbl_column_name)
  if bbm_column_name not in features_columns: features_columns.append(bbm_column_name)
  if bbu_column_name not in features_columns: features_columns.append(bbu_column_name)
  if bbb_column_name not in features_columns: features_columns.append(bbb_column_name)
  if bbp_column_name not in features_columns: features_columns.append(bbp_column_name)
  return df

# %%
def merge_candlesticks_data(df1, df2):
  """
  Merges two candlestick DataFrames with forward fill, handling different timeframes,
  and prevents duplicate OHLCV columns.
  Ensure both DataFrames have a datetime index.
  And ensure the second DataFrame is the larger timeframe

  Args:
      df1: First candlestick DataFrame with datetime index.
      df2: Second candlestick DataFrame with datetime index.

  Returns:
      Merged DataFrame with forward-filled values, and no duplicate OHLCV columns.
  """
  # Ensure both DataFrames have a datetime index
  if not isinstance(df1.index, pd.DatetimeIndex) or not isinstance(df2.index, pd.DatetimeIndex):
      raise ValueError("DataFrames must have a datetime index.")
  # Identify OHLCV columns
  ohlcv_cols = ['open', 'high', 'low', 'close', 'volume']

  # Rename columns in df2 that conflict with df1's OHLCV columns
  for col in df2.columns:
    if col.lower() in ohlcv_cols and col.lower() in df1.columns.str.lower():
      del df2[col]

  # Merge the DataFrames using outer join, which preserves all dates
  merged_df = pd.merge(df1, df2, how='outer', left_index=True, right_index=True, suffixes=('_df1', '_df2'))

  # Forward fill the missing values for each column
  for col in merged_df.columns:
    merged_df[col] = merged_df[col].ffill()

  return merged_df

# %%
def resample_candles(df, interval='1h'):
    return df.resample(interval).agg({'Open': 'first', 'High': 'max', 'Low': 'min', 'Close': 'last', 'Volume': 'sum'}).ffill()

# %%
def create_sequences(data, features_columns, target_col, seq_length):
    """
    Create sequences of `seq_length` time steps for LSTM input, optimized for performance.
    """
    num_samples = len(data) - seq_length
    num_features = len(features_columns)

    X = np.zeros((num_samples, seq_length, num_features))
    y = np.zeros(num_samples)

    features_data = data[features_columns].values
    target_data = data[target_col].values

    for i in range(num_samples):
        X[i] = features_data[i:i + seq_length]
        y[i] = target_data[i + seq_length]

    return X, y

# %%
class CustomEarlyStopping(tf.keras.callbacks.Callback):
    def __init__(self, patience=2):
        super(CustomEarlyStopping, self).__init__()
        self.patience = patience  # Number of consecutive increases allowed
        self.best_val_mae = float('inf')  # Track the best validation MAE
        self.increase_count = 0  # Counter for consecutive increases

    def on_epoch_end(self, epoch, logs=None):
        current_val_mae = logs.get('val_mae')  # Get validation MAE for the current epoch

        if current_val_mae < self.best_val_mae:
            # If validation MAE improves, reset the counter
            self.best_val_mae = current_val_mae
            self.increase_count = 0
        else:
            # If validation MAE increases, increment the counter
            self.increase_count += 1

        # Stop training if validation MAE increases consecutively for 'patience' epochs
        if self.increase_count >= self.patience:
            print(f"\nEarly stopping: Validation MAE increased {self.patience} times in a row.")
            self.model.stop_training = True

# %%
def predict_in_batches(model, test_data, features_columns, seq_length, batch_size=128):
    """
    Predicts in batches to speed up inference.
    """
    num_samples = len(test_data) - seq_length
    feature_array = test_data[features_columns].values
    predicted_values = np.full(len(test_data), np.nan)

    for start_idx in range(0, num_samples, batch_size):
        end_idx = min(start_idx + batch_size, num_samples)
        batch_indices = range(start_idx + seq_length, end_idx + seq_length)
        batch_input = np.array([feature_array[i - seq_length:i] for i in batch_indices])

        if len(batch_input) > 0 :
            predictions = model.predict(batch_input, verbose=0)
            predicted_values[batch_indices] = predictions.flatten() #Flatten to 1d array.

    test_data['Predicted_Value'] = predicted_values
    return test_data

# %%
class PredictedValueStrategy(bt.Strategy):
    params = (
        ('buy_threshold', 0.6),
        ('sell_threshold', 0.6),
        ('leverage', 1),  # Leverage ratio
        ('margin', 1000),
        ('log', True)
    )

    def __init__(self):
        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None

        # Add the Predicted_Value as a data feed
        self.predicted_value = self.datas[0].predicted_value

    def next(self):
        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return
         # # Check if we are in the market
        if not self.position:
          cash = self.broker.getcash()
          position_size = (self.params.margin * self.params.leverage) / self.data.close[0]
          # Long signal
          if self.predicted_value[0] > self.params.buy_threshold:
            self.log('LONG POSITION CREATED, %.2f' % self.datas[0].close[0])
            self.order = self.buy(size=position_size)

          # Short signal
          elif self.predicted_value[0] < self.params.sell_threshold:
            self.log('SHORT POSITION CREATED, %.2f' % self.datas[0].close[0])
            self.order = self.sell(size=position_size)

        else:
          if self.predicted_value[0] > self.params.buy_threshold and self.position.size < 0:
            self.log('CLOSE SHORT POSITION CREATED, %.2f' % self.datas[0].close[0])
            self.order = self.close()
          elif self.predicted_value[0] < self.params.sell_threshold and self.position.size > 0:
            self.log('CLOSE LONG POSITION CREATED, %.2f' % self.datas[0].close[0])
            self.order = self.close()

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return
        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY EXECUTED, %.2f' % order.executed.price)
            elif order.issell():
                self.log('SELL EXECUTED, %.2f' % order.executed.price)
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            if order.status == order.Canceled:
                self.log('Order Canceled')
            elif order.status == order.Margin:
                self.log(f'Order Margin Not Enough - Available cash: {self.broker.getcash()}')
            elif order.status == order.Rejected:
                self.log('Order Rejected')

        # Write down: no pending order
        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        self.log(f'TRADE COMPLETED, GROSS {trade.pnl:.2f}, NET {trade.pnlcomm:.2f}, Available Cash {self.broker.getcash():.2f}')

    def log(self, txt, dt=None):
        if not self.params.log:
          return
        dt = dt or self.datas[0].datetime.date(0)
        time = self.datas[0].datetime.time()
        print(f'{dt.isoformat()} {time.isoformat()}, {txt}')

# %%
# Extend PandasData to include the custom column
class CustomPandasData(bt.feeds.PandasData):
    # Add custom columns
    lines = ('predicted_value',)  # Add the custom line
    params = (
        ('predicted_value', 'Predicted_Value'),  # Map the column name
    )

# %%
def make_dict_even(data):
    """
    Recursively makes all numeric values in a dictionary even.

    Args:
        data (dict): The input dictionary (can have nested dictionaries or lists).

    Returns:
        dict: A new dictionary with all numeric values made even.
    """
    if isinstance(data, dict):
        new_dict = {}
        for key, value in data.items():
            new_dict[key] = make_dict_even(value)
        return new_dict
    elif isinstance(data, list):
        return [make_dict_even(item) for item in data]
    elif isinstance(data, (int, float)):
        if isinstance(data, int):
            return data if data % 2 == 0 else data + 1
        else: # float. We will round to an int, and then make even.
            int_value = round(data)
            return int_value if int_value % 2 == 0 else int_value + 1

    else:
        return data  # Return non-numeric values as they are

# %%
def get_model_cloud_storage_path(bucket_name, local_file_name):
    """
    Returns the cloud storage path for a given model name.

    Parameters:
        local_file_name (str): The name of the model.

    Returns:
        str: The cloud storage path. (e.g., gs://<bucket_name>/trade/models/<model_name>.h5).
    """
    return f'gs://{bucket_name}/trade/models/{local_file_name}'

def save_model_to_cloud_storage(model: tf.keras.Model, model_name: str, bucket_name: str):
    """
    Saves a TensorFlow model to Google Cloud Storage and returns the cloud storage file path.

    Parameters:
        model (tf.keras.Model): The TensorFlow model to save.
        model_name (str): The name of the model (used to create the file name).
        bucket_name (str): The name of the Google Cloud Storage bucket.

    Returns:
        str: The cloud storage file path (e.g., gs://<bucket_name>/trade/models/<model_name>.h5).
    """
    # Define the local and cloud storage file paths
    local_file_name = f'{model_name}.h5'
    local_file_path = f'/tmp/{local_file_name}'
    cloud_file_path = get_model_cloud_storage_path(bucket_name, local_file_name)

    # Save the model locally
    model.save(local_file_path)

    try:
        # Upload the model to Google Cloud Storage
        subprocess.run(['gsutil', 'cp', local_file_path, cloud_file_path], check=True)
        print(f"Model saved to {cloud_file_path}")
    except subprocess.CalledProcessError as e:
        # Handle errors during the upload process
        raise RuntimeError(f"Failed to upload model to Google Cloud Storage: {e}")
    finally:
        # Clean up the local file
        if os.path.exists(local_file_path):
            os.remove(local_file_path)
    return cloud_file_path

def load_model_from_cloud_storage(model_name: str, bucket_name: str):
    """
    Loads a TensorFlow model from Google Cloud Storage.

    Parameters:
        model_name (str): The name of the model (used to create the file name).
        bucket_name (str): The name of the Google Cloud Storage bucket.

    Returns:
        tf.keras.Model: The loaded TensorFlow model.
    """
    # Define the local and cloud storage file paths
    local_file_name = f'{model_name}.h5'
    local_file_path = f'/tmp/{local_file_name}'
    cloud_file_path = get_model_cloud_storage_path(bucket_name, local_file_name)

    try:
        # Download the model from Google Cloud Storage
        subprocess.run(['gsutil', 'cp', cloud_file_path, local_file_path], check=True)

        # Load the model
        model = tf.keras.models.load_model(local_file_path)
        print(f"Model loaded from {cloud_file_path}")
        return model
    except subprocess.CalledProcessError as e:
        raise FileNotFoundError(f"Model not found in Google Cloud Storage: {e}")
    finally:
        # Clean up the local file
        if os.path.exists(local_file_path):
            os.remove(local_file_path)

# %%
def initialize_firestore(project_id):
    """
    Initialize the Firestore client using the service account key.

    Parameters:
        project_id (str): The Google Cloud project ID.

    Returns:
        firestore.Client: Initialized Firestore client.
    """
    if not firebase_admin._apps:
        # cred = credentials.Certificate(service_account_key_path)
        cred = firebase_admin.credentials.ApplicationDefault()
        cred._project_id = project_id  # Add this line
        os.environ["GOOGLE_CLOUD_PROJECT"] = project_id
        firebase_admin.initialize_app(cred, {'projectId': project_id})
    return firestore.client()


def save_to_firestore(project_id, collection_name, data):
    """
    Save data to a Firestore collection.

    Parameters:
        project_id (str): The Google Cloud project ID.
        service_account_key_path (str): Path to the Firebase service account key JSON file.
        collection_name (str): Name of the Firestore collection.
        data (dict): Data to save in the document.

    Returns:
        None
    """
    # Initialize Firestore client
    db = initialize_firestore(project_id)

    # Save data to Firestore
    doc_ref = db.collection(collection_name).document()
    doc_ref.set(data)
    print(f"Data saved to Firestore: Collection={collection_name}, Document ID={doc_ref.id}")


def delete_documents_by_field(project_id, collection_name, field_name, field_value, batch_size=500):
  """
  Deletes documents in a Firestore collection where a specific field matches a value.

  Args:
      collection_name: The name of the Firestore collection.
      field_name: The name of the field to filter by.
      field_value: The value to filter the field against.
      batch_size: The number of documents to delete in each batch.
  """
  db = initialize_firestore(project_id)
  collection_ref = db.collection(collection_name)

  try:
      while True:
          query = collection_ref.where(field_name, '==', field_value).limit(batch_size)
          docs = query.stream()

          deleted_count = 0
          batch = db.batch()

          for doc in docs:
              batch.delete(doc.reference)
              deleted_count += 1

          if deleted_count == 0:
              print(f"No documents found with {field_name} == {field_value} in {collection_name}.")
              break

          batch.commit()
          print(f"Deleted {deleted_count} documents from {collection_name} where {field_name} == {field_value}.")
          if deleted_count < batch_size: # if less than batch size deleted, then there are no more documents matching.
              break

  except Exception as e:
      print(f"An error occurred: {e}")

# %%
def generate_param_grid(params):
    """
    Generate a grid of all possible hyperparameter combinations.

    Args:
        params (dict): A dictionary where keys are hyperparameter names and values are lists of possible values.

    Returns:
        list: A list of dictionaries, where each dictionary represents a unique combination of hyperparameters.
    """
    keys = params.keys()
    values = params.values()

    # Generate all possible combinations of hyperparameters
    param_grid = [dict(zip(keys, combination)) for combination in itertools.product(*values)]

    return param_grid

# %%
def fix_out_of_range_values(obj):
    """
    Recursively traverse a nested object and convert out-of-range values to zero.

    Args:
        obj: The input object (can be a dictionary, list, or other nested structure).

    Returns:
        The same object with out-of-range values replaced by zero.
    """
    if isinstance(obj, dict):
        # If the object is a dictionary, recursively process its values
        for key, value in obj.items():
            obj[key] = fix_out_of_range_values(value)
    elif isinstance(obj, list):
        # If the object is a list, recursively process its elements
        for i in range(len(obj)):
            obj[i] = fix_out_of_range_values(obj[i])
    else:
        # If the object is a value, check if it's out of range
        try:
            # Attempt to perform a numeric operation to check if the value is valid
            # For example, check if the value can be compared to a range
            if not (-1e15 < obj < 1e14):  # Adjust the range as needed
                obj = 0
        except (TypeError, ValueError):
            # If the value is not numeric or causes an error, replace it with zero
            obj = 0
    return obj

# %%
options = {
  'timeframe': '15m',
  'symbol': 'BTCUSDT',
  'exchange': 'binance',
  'start_date': '01-01-2024',
  'end_date': '28-02-2025' ,
  'pivot_windows': 10,
  'version': 'v1_0_1',
  'middle_timeframe': '1h',
  'higher_timeframe': '4h',
  'seq_length': 100
}

# %%
def generate_model(**options):
  # Extract options
  timeframe = options['timeframe'] if 'timeframe' in options else '15m'
  symbol = options['symbol'] if 'symbol' in options else 'BTCUSDT'
  exchange = options['exchange'] if 'exchange' in options else 'binance'
  start_date = options['start_date'] if 'start_date' in options else '01-01-2024'
  end_date = options['end_date'] if 'end_date' in options else '28-02-2025'
  pivot_windows = options['pivot_windows'] if 'pivot_windows' in options else 10
  version = options['version'] if 'version' in options else 'v1'
  middle_timeframe = options['middle_timeframe'] if 'middle_timeframe' in options else '1h'
  higher_timeframe = options['higher_timeframe'] if 'higher_timeframe' in options else '4h'
  seq_length = options['seq_length'] if 'seq_length' in options else 100

  # Get raw candles
  data = get_all_binance_candles(symbol, timeframe, start_date, end_date)
  # Add pivots
  data = add_pivots(data, int(pivot_windows))
  data['Pivot'] = np.where(data['Higher_Pivot'] == 1, -1, np.where(data['Lower_Pivot'] == 1, 1, 0))
  del data['Higher_Pivot']
  del data['Lower_Pivot']
  # Calculate pivot proximity
  data = calculate_pivot_proximity(data)
  # Declare feature columns
  features_columns = []

  # # Add technical indicators on lower timeframe
  lower_timeframe = timeframe
  lower_timeframe_prefix = f"{lower_timeframe}_"
  add_scaled_rsi(data, 14, prefix=lower_timeframe_prefix, features_columns=features_columns)
  add_scaled_rsi(data, 6, prefix=lower_timeframe_prefix, features_columns=features_columns)
  add_scaled_ema(data, 5, prefix=lower_timeframe_prefix, features_columns=features_columns)
  add_scaled_ema(data, 21, prefix=lower_timeframe_prefix, features_columns=features_columns)
  add_scaled_sma(data, 50, prefix=lower_timeframe_prefix, features_columns=features_columns)
  add_scaled_macd(data, prefix=lower_timeframe_prefix, features_columns=features_columns)
  add_scaled_bbands(data, prefix=lower_timeframe_prefix, features_columns=features_columns)

  # Add technical indicators on middle timeframe
  middle_timeframe_prefix = f"{middle_timeframe}_"
  middle_data = resample_candles(data, middle_timeframe)
  add_scaled_rsi(middle_data, 14, prefix=middle_timeframe_prefix, features_columns=features_columns)
  add_scaled_rsi(middle_data, 6, prefix=middle_timeframe_prefix, features_columns=features_columns)
  add_scaled_ema(middle_data, 5, prefix=middle_timeframe_prefix, features_columns=features_columns)
  add_scaled_ema(middle_data, 21, prefix=middle_timeframe_prefix, features_columns=features_columns)
  add_scaled_macd(middle_data, prefix=middle_timeframe_prefix, features_columns=features_columns)
  add_scaled_bbands(middle_data, prefix=middle_timeframe_prefix, features_columns=features_columns)

  # Add technical indicators on higher timeframe
  higher_timeframe_prefix = f"{higher_timeframe}_"
  higher_data = resample_candles(data, higher_timeframe)
  add_scaled_rsi(higher_data, 14, prefix=higher_timeframe_prefix, features_columns=features_columns)
  add_scaled_rsi(higher_data, 6, prefix=higher_timeframe_prefix, features_columns=features_columns)
  add_scaled_ema(higher_data, 5, prefix=higher_timeframe_prefix, features_columns=features_columns)
  add_scaled_ema(higher_data, 21, prefix=higher_timeframe_prefix, features_columns=features_columns)

  # Merge middle and higher timeframe data to lower timeframe data
  data = merge_candlesticks_data(data, middle_data)
  data = merge_candlesticks_data(data, higher_data)

  # Drop rows with NaN values (due to rolling calculations)
  data.dropna(inplace=True)

  # delete Pivot_Porximity that have zero at the beginning and ending of the dataframe
  non_zero_indices = data[data['Pivot_Proximity'] != 0].index
  non_zero_at_begining = non_zero_indices[0]
  non_zero_at_end = non_zero_indices[-1]
  data = data.loc[non_zero_at_begining:non_zero_at_end]

  # select only first 80 % of the data
  training_data_ratio = 0.8 # 80%
  training_data = data[:int(len(data) * training_data_ratio)]
  training_data_start_date = training_data.index[0]
  training_data_end_date = training_data.index[-1]

  # Create training sequences
  target_col = 'Pivot_Proximity'
  X, y = create_sequences(training_data, features_columns, target_col, seq_length)

  # Split into training and testing sets
  train_validate_split_ratio = 0.2
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=train_validate_split_ratio, shuffle=False)
  train_candles_length = len(X_train)
  val_candles_length = len(X_test)

  # Build the LSTM model
  model_input_shape = (X_train.shape[1], X_train.shape[2])
  model = Sequential([
      LSTM(100, return_sequences=True, input_shape=model_input_shape),
      Dropout(0.2),
      LSTM(50, return_sequences=False),
      Dropout(0.2),
      Dense(50, activation='relu'),
      Dropout(0.2),
      Dense(25, activation='relu'),
      Dropout(0.2),
      Dense(10, activation='relu'),
      Dropout(0.2),
      Dense(1, activation='tanh')
  ])
  model.compile(optimizer='adam', loss='mse', metrics=['mae'])

  # Define early stopping
  custom_early_stopping = CustomEarlyStopping(patience=3)

  # Step 5: Train the model
  train_epochs = 20
  history = model.fit(
      X_train, y_train,
      epochs=train_epochs,
      batch_size=32,
      validation_data=(X_test, y_test),
      verbose=1,
      callbacks=[custom_early_stopping]
  )
  final_epoch = len(history.history['loss'])
  train_loss = history.history['loss'][-1]
  train_mae = history.history['mae'][-1]
  val_loss = history.history['val_loss'][-1]
  val_mae = history.history['val_mae'][-1]

  # Save model to cloud storage
  # Save the model
  random_hash = generate_random_hash()
  model_name = f"binance_mtf_{version}_{timeframe}_{start_date}_{end_date}_{random_hash}"
  model_path = save_model_to_cloud_storage(model, model_name, bucket_name)

  # test data
  test_data = data[int(len(data) * training_data_ratio):]

  # Predict in batches
  batch_size = 128
  predict_in_batches(model, test_data, features_columns, seq_length, batch_size)
  test_data.dropna(inplace=True) # Early predicted values wont be availble due to sequencing
  test_data_start_date = test_data.index[0]
  test_data_end_date = test_data.index[-1]

  # Load data into a Pandas DataFrame
  backtest_data = CustomPandasData(
      dataname=test_data,
      datetime=None,  # Use the index as the datetime
      open='Open',         # Column index for Open
      high='High',         # Column index for High
      low='Low',          # Column index for Low
      close='Close',        # Column index for Close
      volume='Volume',       # Column index for Volume
      openinterest=None,# No open interest column
      predicted_value='Predicted_Value'  # Column index for Predicted_Value
  )

  bactest_grid_params = generate_param_grid({
      'buy_threshold': [0.3, 0.4, 0.5, 0.6, 0.7,],
      'sell_threshold': [-0.3, -0.4, -0.5, -0.6, -0.7],
      'leverage': [10, 15, 20, 25, 30],
  })

  for param in bactest_grid_params:
    # Grid trade params
    trade_buy_threshold = param['buy_threshold']
    trade_sell_threshold = param['sell_threshold']
    trade_leverage = param['leverage']
    print(f"Backtesting- Buy Threshold: {trade_buy_threshold}, Sell Threshold: {trade_sell_threshold}, leverage: {trade_leverage}")

    # backtest configuration
    trade_margin = 1000
    broker_commision = 0.02 # In percentage

    # Create a Cerebro engine instance
    cerebro = bt.Cerebro()

    # Add the strategy
    cerebro.addstrategy(
        PredictedValueStrategy,
        buy_threshold=trade_buy_threshold,
        sell_threshold=trade_sell_threshold,
        leverage=trade_leverage,
        margin=trade_margin,
        log=False
    )

    # Add the data feed
    cerebro.adddata(backtest_data)

    # Set the initial cash
    cerebro.broker.set_cash(10000.0)

    # Set the commission
    cerebro.broker.setcommission(commission=broker_commision / 100)

    # Add analyzers
    cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='sharpe')
    cerebro.addanalyzer(bt.analyzers.DrawDown, _name='drawdown')
    cerebro.addanalyzer(bt.analyzers.TradeAnalyzer, _name='tradeanalyzer')
    cerebro.addanalyzer(bt.analyzers.Returns, _name='returns')

    # Run the backtest
    starting_portfolio_value = cerebro.broker.getvalue()
    print('Starting Portfolio Value: %.2f' % starting_portfolio_value)
    backtest_result = cerebro.run()
    final_portfolio_value = cerebro.broker.getvalue()
    print('Final Portfolio Value: %.2f' % final_portfolio_value)

    # Capture analysis
    strat = backtest_result[0]

    trade_analysis = make_dict_even(strat.analyzers.tradeanalyzer.get_analysis())
    trade_analysis = fix_out_of_range_values(trade_analysis)

    drawdown_analysis = make_dict_even(strat.analyzers.drawdown.get_analysis())
    drawdown_analysis = fix_out_of_range_values(drawdown_analysis)
    sharpe_analysis = make_dict_even(strat.analyzers.sharpe.get_analysis())
    sharpe_analysis = fix_out_of_range_values(sharpe_analysis)

    analysis_result = {
        'timeframe': timeframe,
        'start_date': start_date,
        'end_date': end_date,
        'symbol': symbol,
        'exchange': exchange,
        'features_columns': features_columns,
        'lower_timeframe': lower_timeframe,
        'middle_timeframe': middle_timeframe,
        'higher_timeframe': higher_timeframe,
        'seq_length': seq_length,
        'training_data_ratio': training_data_ratio,
        'epochs': train_epochs,
        'model_input_shape': model_input_shape,
        'model_name': model_name,
        'model_path': model_path,
        'train_loss': train_loss,
        'train_mae': train_mae,
        'val_loss': val_loss,
        'val_mae': val_mae,
        'final_epoch': final_epoch,
        'training_data_start_date': training_data_start_date,
        'training_data_end_date': training_data_end_date,
        'test_data_start_date': test_data_start_date,
        'test_data_end_date': test_data_end_date,
        'trade_leverage': trade_leverage,
        'trade_margin': trade_margin,
        'trade_buy_threshold': trade_buy_threshold,
        'trade_sell_threshold': trade_sell_threshold,
        'starting_portfolio_value': starting_portfolio_value,
        'final_portfolio_value': final_portfolio_value,
        'broker_commision': broker_commision,
        'trade_analysis': trade_analysis,
        'drawdown_analysis': drawdown_analysis,
        'sharpe_analysis': sharpe_analysis,
        'version': version,
        'created_at': datetime.datetime.now()
    }
    save_to_firestore(project_id, firestore_collection_name, analysis_result)
    print(analysis_result)

# %%
evaluate_periods =  [(datetime.datetime(x,1,1), datetime.datetime(x,1,1) + datetime.timedelta(days=365*5)) for x in range(2017,2021)]
for start_date, end_date in evaluate_periods:
  options['start_date'] = start_date.strftime('%d-%m-%Y')
  options['end_date'] = end_date.strftime('%d-%m-%Y')
  print(f"Evaluating from {start_date} to {end_date}")
  generate_model(**options)
# Out:
# Evaluating from 2017-01-01 00:00:00 to 2021-12-31 00:00:00
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 3049/3049 ━━━━━━━━━━━━━━━━━━━━ 42s 13ms/step - loss: 0.3256 - mae: 0.4872 - val_loss: 0.2829 - val_mae: 0.4501
# Epoch 2/20
# 3049/3049 ━━━━━━━━━━━━━━━━━━━━ 37s 12ms/step - loss: 0.2826 - mae: 0.4454 - val_loss: 0.2508 - val_mae: 0.4180
# Epoch 3/20
# 3049/3049 ━━━━━━━━━━━━━━━━━━━━ 37s 12ms/step - loss: 0.2655 - mae: 0.4275 - val_loss: 0.2494 - val_mae: 0.4102
# Epoch 4/20
# 3049/3049 ━━━━━━━━━━━━━━━━━━━━ 37s 12ms/step - loss: 0.2613 - mae: 0.4225 - val_loss: 0.2443 - val_mae: 0.4043
# Epoch 5/20
# 3049/3049 ━━━━━━━━━━━━━━━━━━━━ 37s 12ms/step - loss: 0.2574 - mae: 0.4186 - val_loss: 0.2464 - val_mae: 0.4103
# Epoch 6/20
# 3049/3049 ━━━━━━━━━━━━━━━━━━━━ 37s 12ms/step - loss: 0.2570 - mae: 0.4180 - val_loss: 0.2445 - val_mae: 0.4119
# Epoch 7/20
# 3048/3049 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2531 - mae: 0.4141
# Early stopping: Validation MAE increased 3 times in a row.
# 3049/3049 ━━━━━━━━━━━━━━━━━━━━ 37s 12ms/step - loss: 0.2531 - mae: 0.4141 - val_loss: 0.2415 - val_mae: 0.4046
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved to gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d.h5
# <ipython-input-14-54e86c8c4e9a>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['Predicted_Value'] = predicted_values
# <ipython-input-28-3df4ec991660>:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data.dropna(inplace=True) # Early predicted values wont be availble due to sequencing
# Backtesting- Buy Threshold: 0.3, Sell Threshold: -0.3, leverage: 10
# Starting Portfolio Value: 10000.00
# Final Portfolio Value: 106362.51
# Data saved to Firestore: Collection=trade-models, Document ID=7C97HeoLXDUidSWutawZ
# {'timeframe': '15m', 'start_date': '01-01-2017', 'end_date': '31-12-2021', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'features_columns': ['15m_RSI_14', '15m_RSI_6', '15m_EMA_5', '15m_EMA_21', '15m_SMA_50', '15m_MACD_12_26_9', '15m_MACDs_12_26_9', '15m_MACDh_12_26_9', '15m_BBL_20_2.0', '15m_BBM_20_2.0', '15m_BBU_20_2.0', '15m_BBB_20_2.0', '15m_BBP_20_2.0', '1h_RSI_14', '1h_RSI_6', '1h_EMA_5', '1h_EMA_21', '1h_MACD_12_26_9', '1h_MACDs_12_26_9', '1h_MACDh_12_26_9', '1h_BBL_20_2.0', '1h_BBM_20_2.0', '1h_BBU_20_2.0', '1h_BBB_20_2.0', '1h_BBP_20_2.0', '4h_RSI_14', '4h_RSI_6', '4h_EMA_5', '4h_EMA_21'], 'lower_timeframe': '15m', 'middle_timeframe': '1h', 'higher_timeframe': '4h', 'seq_length': 100, 'training_data_ratio': 0.8, 'epochs': 20, 'model_input_shape': (100, 29), 'model_name': 'binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d', 'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d.h5', 'train_loss': 0.2532379627227783, 'train_mae': 0.41433656215667725, 'val_loss': 0.24152757227420807, 'val_mae': 0.4045906066894531, 'final_epoch': 7, 'training_data_start_date': Timestamp('2017-08-20 12:00:00'), 'training_data_end_date': Timestamp('2021-02-15 13:30:00'), 'test_data_start_date': Timestamp('2021-02-16 14:45:00'), 'test_data_end_date': Timestamp('2021-12-30 19:30:00'), 'trade_leverage': 10, 'trade_margin': 1000, 'trade_buy_threshold': 0.3, 'trade_sell_threshold': -0.3, 'starting_portfolio_value': 10000.0, 'final_portfolio_value': 106362.50626254406, 'broker_commision': 0.02, 'trade_analysis': {'total': {'total': 1564, 'open': 2, 'closed': 1562}, 'streak': {'won': {'current': 4, 'longest': 22}, 'lost': {'current': 0, 'longest': 4}}, 'pnl': {'gross': {'total': 102644, 'average': 66}, 'net': {'total': 96396, 'average': 62}}, 'won': {'total': 1240, 'pnl': {'total': 144152, 'average': 116, 'max': 792}}, 'lost': {'total': 324, 'pnl': {'total': -47756, 'average': -148, 'max': -1542}}, 'long': {'total': 762, 'pnl': {'total': 46936, 'average': 62, 'won': {'total': 70740, 'average': 118, 'max': 792}, 'lost': {'total': -23802, 'average': -152, 'max': -1542}}, 'won': 606, 'lost': 156}, 'short': {'total': 800, 'pnl': {'total': 49460, 'average': 62, 'won': {'total': 73412, 'average': 116, 'max': 720}, 'lost': {'total': -23952, 'average': -142, 'max': -818}}, 'won': 634, 'lost': 168}, 'len': {'total': 27160, 'average': 18, 'max': 94, 'min': 2, 'won': {'total': 16978, 'average': 14, 'max': 52, 'min': 2}, 'lost': {'total': 10182, 'average': 32, 'max': 94, 'min': 2}, 'long': {'total': 13552, 'average': 18, 'max': 94, 'min': 2, 'won': {'total': 8608, 'average': 14, 'max': 50, 'min': 2}, 'lost': {'total': 4944, 'average': 32, 'max': 94, 'min': 2}}, 'short': {'total': 13608, 'average': 18, 'max': 78, 'min': 2, 'won': {'total': 8370, 'average': 14, 'max': 52, 'min': 2}, 'lost': {'total': 5238, 'average': 32, 'max': 78, 'min': 4}}}}, 'drawdown_analysis': {'len': 6, 'drawdown': 0, 'moneydown': 58, 'max': {'len': 554, 'drawdown': 16, 'moneydown': 2002}}, 'sharpe_analysis': {'sharperatio': 0}, 'version': 'v1_0_1', 'created_at': datetime.datetime(2025, 3, 9, 13, 32, 48, 484554)}
# Backtesting- Buy Threshold: 0.3, Sell Threshold: -0.3, leverage: 15
# Starting Portfolio Value: 10000.00
# Final Portfolio Value: 152271.76
# Data saved to Firestore: Collection=trade-models, Document ID=FyaXXEcT2xfjiALBNz0O
# {'timeframe': '15m', 'start_date': '01-01-2017', 'end_date': '31-12-2021', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'features_columns': ['15m_RSI_14', '15m_RSI_6', '15m_EMA_5', '15m_EMA_21', '15m_SMA_50', '15m_MACD_12_26_9', '15m_MACDs_12_26_9', '15m_MACDh_12_26_9', '15m_BBL_20_2.0', '15m_BBM_20_2.0', '15m_BBU_20_2.0', '15m_BBB_20_2.0', '15m_BBP_20_2.0', '1h_RSI_14', '1h_RSI_6', '1h_EMA_5', '1h_EMA_21', '1h_MACD_12_26_9', '1h_MACDs_12_26_9', '1h_MACDh_12_26_9', '1h_BBL_20_2.0', '1h_BBM_20_2.0', '1h_BBU_20_2.0', '1h_BBB_20_2.0', '1h_BBP_20_2.0', '4h_RSI_14', '4h_RSI_6', '4h_EMA_5', '4h_EMA_21'], 'lower_timeframe': '15m', 'middle_timeframe': '1h', 'higher_timeframe': '4h', 'seq_length': 100, 'training_data_ratio': 0.8, 'epochs': 20, 'model_input_shape': (100, 29), 'model_name': 'binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d', 'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d.h5', 'train_loss': 0.2532379627227783, 'train_mae': 0.41433656215667725, 'val_loss': 0.24152757227420807, 'val_mae': 0.4045906066894531, 'final_epoch': 7, 'training_data_start_date': Timestamp('2017-08-20 12:00:00'), 'training_data_end_date': Timestamp('2021-02-15 13:30:00'), 'test_data_start_date': Timestamp('2021-02-16 14:45:00'), 'test_data_end_date': Timestamp('2021-12-30 19:30:00'), 'trade_leverage': 15, 'trade_margin': 1000, 'trade_buy_threshold': 0.3, 'trade_sell_threshold': -0.3, 'starting_portfolio_value': 10000.0, 'final_portfolio_value': 152271.7634555224, 'broker_commision': 0.02, 'trade_analysis': {'total': {'total': 1538, 'open': 2, 'closed': 1536}, 'streak': {'won': {'current': 4, 'longest': 22}, 'lost': {'current': 0, 'longest': 4}}, 'pnl': {'gross': {'total': 151536, 'average': 100}, 'net': {'total': 142322, 'average': 94}}, 'won': {'total': 1220, 'pnl': {'total': 211698, 'average': 174, 'max': 1188}}, 'lost': {'total': 318, 'pnl': {'total': -69376, 'average': -218, 'max': -2314}}, 'long': {'total': 736, 'pnl': {'total': 68176, 'average': 94, 'won': {'total': 101538, 'average': 174, 'max': 1188}, 'lost': {'total': -33360, 'average': -222, 'max': -2314}}, 'won': 586, 'lost': 150}, 'short': {'total': 802, 'pnl': {'total': 74146, 'average': 94, 'won': {'total': 110162, 'average': 174, 'max': 1078}, 'lost': {'total': -36016, 'average': -216, 'max': -1228}}, 'won': 634, 'lost': 168}, 'len': {'total': 26692, 'average': 18, 'max': 94, 'min': 2, 'won': {'total': 16692, 'average': 14, 'max': 52, 'min': 2}, 'lost': {'total': 10002, 'average': 32, 'max': 94, 'min': 2}, 'long': {'total': 13050, 'average': 18, 'max': 94, 'min': 2, 'won': {'total': 8292, 'average': 14, 'max': 50, 'min': 2}, 'lost': {'total': 4760, 'average': 32, 'max': 94, 'min': 2}}, 'short': {'total': 13642, 'average': 18, 'max': 78, 'min': 2, 'won': {'total': 8400, 'average': 14, 'max': 52, 'min': 2}, 'lost': {'total': 5242, 'average': 32, 'max': 78, 'min': 4}}}}, 'drawdown_analysis': {'len': 6, 'drawdown': 0, 'moneydown': 86, 'max': {'len': 554, 'drawdown': 12, 'moneydown': 3004}}, 'sharpe_analysis': {'sharperatio': 0}, 'version': 'v1_0_1', 'created_at': datetime.datetime(2025, 3, 9, 13, 32, 57, 612608)}
# Backtesting- Buy Threshold: 0.3, Sell Threshold: -0.3, leverage: 20
# Starting Portfolio Value: 10000.00
# Final Portfolio Value: 193127.18
# Data saved to Firestore: Collection=trade-models, Document ID=Bkd9loUBcJsP0FmDmIbR
# {'timeframe': '15m', 'start_date': '01-01-2017', 'end_date': '31-12-2021', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'features_columns': ['15m_RSI_14', '15m_RSI_6', '15m_EMA_5', '15m_EMA_21', '15m_SMA_50', '15m_MACD_12_26_9', '15m_MACDs_12_26_9', '15m_MACDh_12_26_9', '15m_BBL_20_2.0', '15m_BBM_20_2.0', '15m_BBU_20_2.0', '15m_BBB_20_2.0', '15m_BBP_20_2.0', '1h_RSI_14', '1h_RSI_6', '1h_EMA_5', '1h_EMA_21', '1h_MACD_12_26_9', '1h_MACDs_12_26_9', '1h_MACDh_12_26_9', '1h_BBL_20_2.0', '1h_BBM_20_2.0', '1h_BBU_20_2.0', '1h_BBB_20_2.0', '1h_BBP_20_2.0', '4h_RSI_14', '4h_RSI_6', '4h_EMA_5', '4h_EMA_21'], 'lower_timeframe': '15m', 'middle_timeframe': '1h', 'higher_timeframe': '4h', 'seq_length': 100, 'training_data_ratio': 0.8, 'epochs': 20, 'model_input_shape': (100, 29), 'model_name': 'binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d', 'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d.h5', 'train_loss': 0.2532379627227783, 'train_mae': 0.41433656215667725, 'val_loss': 0.24152757227420807, 'val_mae': 0.4045906066894531, 'final_epoch': 7, 'training_data_start_date': Timestamp('2017-08-20 12:00:00'), 'training_data_end_date': Timestamp('2021-02-15 13:30:00'), 'test_data_start_date': Timestamp('2021-02-16 14:45:00'), 'test_data_end_date': Timestamp('2021-12-30 19:30:00'), 'trade_leverage': 20, 'trade_margin': 1000, 'trade_buy_threshold': 0.3, 'trade_sell_threshold': -0.3, 'starting_portfolio_value': 10000.0, 'final_portfolio_value': 193127.18014930104, 'broker_commision': 0.02, 'trade_analysis': {'total': {'total': 1492, 'open': 2, 'closed': 1492}, 'streak': {'won': {'current': 4, 'longest': 22}, 'lost': {'current': 0, 'longest': 4}}, 'pnl': {'gross': {'total': 195118, 'average': 132}, 'net': {'total': 183194, 'average': 124}}, 'won': {'total': 1184, 'pnl': {'total': 273988, 'average': 232, 'max': 1584}}, 'lost': {'total': 308, 'pnl': {'total': -90794, 'average': -294, 'max': -3084}}, 'long': {'total': 688, 'pnl': {'total': 86030, 'average': 126, 'won': {'total': 127418, 'average': 232, 'max': 1584}, 'lost': {'total': -41386, 'average': -302, 'max': -3084}}, 'won': 550, 'lost': 138}, 'short': {'total': 804, 'pnl': {'total': 97164, 'average': 122, 'won': {'total': 146570, 'average': 232, 'max': 1438}, 'lost': {'total': -49406, 'average': -288, 'max': -1636}}, 'won': 634, 'lost': 172}, 'len': {'total': 25870, 'average': 18, 'max': 94, 'min': 2, 'won': {'total': 16128, 'average': 14, 'max': 52, 'min': 2}, 'lost': {'total': 9742, 'average': 32, 'max': 94, 'min': 2}, 'long': {'total': 12156, 'average': 18, 'max': 94, 'min': 2, 'won': {'total': 7746, 'average': 14, 'max': 50, 'min': 2}, 'lost': {'total': 4412, 'average': 32, 'max': 94, 'min': 2}}, 'short': {'total': 13714, 'average': 18, 'max': 78, 'min': 2, 'won': {'total': 8382, 'average': 14, 'max': 52, 'min': 2}, 'lost': {'total': 5332, 'average': 32, 'max': 78, 'min': 4}}}}, 'drawdown_analysis': {'len': 6, 'drawdown': 0, 'moneydown': 114, 'max': {'len': 850, 'drawdown': 14, 'moneydown': 4004}}, 'sharpe_analysis': {'sharperatio': 0}, 'version': 'v1_0_1', 'created_at': datetime.datetime(2025, 3, 9, 13, 33, 6, 171000)}
# Backtesting- Buy Threshold: 0.3, Sell Threshold: -0.3, leverage: 25
# Starting Portfolio Value: 10000.00
# Final Portfolio Value: 233272.06
# Data saved to Firestore: Collection=trade-models, Document ID=ZKur3jBESOsJHhzwgIhc
# {'timeframe': '15m', 'start_date': '01-01-2017', 'end_date': '31-12-2021', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'features_columns': ['15m_RSI_14', '15m_RSI_6', '15m_EMA_5', '15m_EMA_21', '15m_SMA_50', '15m_MACD_12_26_9', '15m_MACDs_12_26_9', '15m_MACDh_12_26_9', '15m_BBL_20_2.0', '15m_BBM_20_2.0', '15m_BBU_20_2.0', '15m_BBB_20_2.0', '15m_BBP_20_2.0', '1h_RSI_14', '1h_RSI_6', '1h_EMA_5', '1h_EMA_21', '1h_MACD_12_26_9', '1h_MACDs_12_26_9', '1h_MACDh_12_26_9', '1h_BBL_20_2.0', '1h_BBM_20_2.0', '1h_BBU_20_2.0', '1h_BBB_20_2.0', '1h_BBP_20_2.0', '4h_RSI_14', '4h_RSI_6', '4h_EMA_5', '4h_EMA_21'], 'lower_timeframe': '15m', 'middle_timeframe': '1h', 'higher_timeframe': '4h', 'seq_length': 100, 'training_data_ratio': 0.8, 'epochs': 20, 'model_input_shape': (100, 29), 'model_name': 'binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d', 'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d.h5', 'train_loss': 0.2532379627227783, 'train_mae': 0.41433656215667725, 'val_loss': 0.24152757227420807, 'val_mae': 0.4045906066894531, 'final_epoch': 7, 'training_data_start_date': Timestamp('2017-08-20 12:00:00'), 'training_data_end_date': Timestamp('2021-02-15 13:30:00'), 'test_data_start_date': Timestamp('2021-02-16 14:45:00'), 'test_data_end_date': Timestamp('2021-12-30 19:30:00'), 'trade_leverage': 25, 'trade_margin': 1000, 'trade_buy_threshold': 0.3, 'trade_sell_threshold': -0.3, 'starting_portfolio_value': 10000.0, 'final_portfolio_value': 233272.0606162647, 'broker_commision': 0.02, 'trade_analysis': {'total': {'total': 1462, 'open': 2, 'closed': 1462}, 'streak': {'won': {'current': 4, 'longest': 20}, 'lost': {'current': 0, 'longest': 4}}, 'pnl': {'gross': {'total': 237960, 'average': 164}, 'net': {'total': 223354, 'average': 154}}, 'won': {'total': 1156, 'pnl': {'total': 336656, 'average': 292, 'max': 1978}}, 'lost': {'total': 306, 'pnl': {'total': -113300, 'average': -370, 'max': -3856}}, 'long': {'total': 654, 'pnl': {'total': 102526, 'average': 158, 'won': {'total': 153820, 'average': 296, 'max': 1978}, 'lost': {'total': -51292, 'average': -382, 'max': -3856}}, 'won': 520, 'lost': 134}, 'short': {'total': 808, 'pnl': {'total': 120828, 'average': 150, 'won': {'total': 182836, 'average': 288, 'max': 1798}, 'lost': {'total': -62008, 'average': -362, 'max': -2046}}, 'won': 636, 'lost': 172}, 'len': {'total': 25430, 'average': 18, 'max': 94, 'min': 2, 'won': {'total': 15782, 'average': 14, 'max': 52, 'min': 2}, 'lost': {'total': 9648, 'average': 32, 'max': 94, 'min': 2}, 'long': {'total': 11644, 'average': 18, 'max': 94, 'min': 2, 'won': {'total': 7314, 'average': 14, 'max': 50, 'min': 2}, 'lost': {'total': 4332, 'average': 32, 'max': 94, 'min': 2}}, 'short': {'total': 13786, 'average': 18, 'max': 80, 'min': 2, 'won': {'total': 8468, 'average': 14, 'max': 52, 'min': 2}, 'lost': {'total': 5318, 'average': 32, 'max': 80, 'min': 4}}}}, 'drawdown_analysis': {'len': 6, 'drawdown': 0, 'moneydown': 144, 'max': {'len': 850, 'drawdown': 18, 'moneydown': 5006}}, 'sharpe_analysis': {'sharperatio': 0}, 'version': 'v1_0_1', 'created_at': datetime.datetime(2025, 3, 9, 13, 33, 14, 745082)}
# Backtesting- Buy Threshold: 0.3, Sell Threshold: -0.3, leverage: 30
# Starting Portfolio Value: 10000.00
# Final Portfolio Value: 271783.65
# Data saved to Firestore: Collection=trade-models, Document ID=abPDUS3lcHqGg2uNu9mm
# {'timeframe': '15m', 'start_date': '01-01-2017', 'end_date': '31-12-2021', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'features_columns': ['15m_RSI_14', '15m_RSI_6', '15m_EMA_5', '15m_EMA_21', '15m_SMA_50', '15m_MACD_12_26_9', '15m_MACDs_12_26_9', '15m_MACDh_12_26_9', '15m_BBL_20_2.0', '15m_BBM_20_2.0', '15m_BBU_20_2.0', '15m_BBB_20_2.0', '15m_BBP_20_2.0', '1h_RSI_14', '1h_RSI_6', '1h_EMA_5', '1h_EMA_21', '1h_MACD_12_26_9', '1h_MACDs_12_26_9', '1h_MACDh_12_26_9', '1h_BBL_20_2.0', '1h_BBM_20_2.0', '1h_BBU_20_2.0', '1h_BBB_20_2.0', '1h_BBP_20_2.0', '4h_RSI_14', '4h_RSI_6', '4h_EMA_5', '4h_EMA_21'], 'lower_timeframe': '15m', 'middle_timeframe': '1h', 'higher_timeframe': '4h', 'seq_length': 100, 'training_data_ratio': 0.8, 'epochs': 20, 'model_input_shape': (100, 29), 'model_name': 'binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d', 'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d.h5', 'train_loss': 0.2532379627227783, 'train_mae': 0.41433656215667725, 'val_loss': 0.24152757227420807, 'val_mae': 0.4045906066894531, 'final_epoch': 7, 'training_data_start_date': Timestamp('2017-08-20 12:00:00'), 'training_data_end_date': Timestamp('2021-02-15 13:30:00'), 'test_data_start_date': Timestamp('2021-02-16 14:45:00'), 'test_data_end_date': Timestamp('2021-12-30 19:30:00'), 'trade_leverage': 30, 'trade_margin': 1000, 'trade_buy_threshold': 0.3, 'trade_sell_threshold': -0.3, 'starting_portfolio_value': 10000.0, 'final_portfolio_value': 271783.6480557097, 'broker_commision': 0.02, 'trade_analysis': {'total': {'total': 1442, 'open': 2, 'closed': 1442}, 'streak': {'won': {'current': 4, 'longest': 20}, 'lost': {'current': 0, 'longest': 4}}, 'pnl': {'gross': {'total': 279168, 'average': 194}, 'net': {'total': 261882, 'average': 182}}, 'won': {'total': 1138, 'pnl': {'total': 397956, 'average': 350, 'max': 2374}}, 'lost': {'total': 304, 'pnl': {'total': -136074, 'average': -448, 'max': -4628}}, 'long': {'total': 634, 'pnl': {'total': 117612, 'average': 186, 'won': {'total': 178990, 'average': 358, 'max': 2374}, 'lost': {'total': -61378, 'average': -464, 'max': -4628}}, 'won': 502, 'lost': 132}, 'short': {'total': 808, 'pnl': {'total': 144270, 'average': 180, 'won': {'total': 218966, 'average': 346, 'max': 2158}, 'lost': {'total': -74694, 'average': -434, 'max': -2456}}, 'won': 636, 'lost': 172}, 'len': {'total': 25150, 'average': 18, 'max': 94, 'min': 2, 'won': {'total': 15520, 'average': 14, 'max': 52, 'min': 2}, 'lost': {'total': 9632, 'average': 32, 'max': 94, 'min': 2}, 'long': {'total': 11332, 'average': 18, 'max': 94, 'min': 2, 'won': {'total': 7038, 'average': 14, 'max': 50, 'min': 2}, 'lost': {'total': 4294, 'average': 34, 'max': 94, 'min': 2}}, 'short': {'total': 13818, 'average': 18, 'max': 80, 'min': 2, 'won': {'total': 8482, 'average': 14, 'max': 52, 'min': 2}, 'lost': {'total': 5338, 'average': 32, 'max': 80, 'min': 4}}}}, 'drawdown_analysis': {'len': 6, 'drawdown': 0, 'moneydown': 172, 'max': {'len': 850, 'drawdown': 22, 'moneydown': 6008}}, 'sharpe_analysis': {'sharperatio': 0}, 'version': 'v1_0_1', 'created_at': datetime.datetime(2025, 3, 9, 13, 33, 22, 881494)}
# Backtesting- Buy Threshold: 0.3, Sell Threshold: -0.4, leverage: 10
# Starting Portfolio Value: 10000.00
# Final Portfolio Value: 113218.76
# Data saved to Firestore: Collection=trade-models, Document ID=s59jREmME3gIYA2ovEeA
# {'timeframe': '15m', 'start_date': '01-01-2017', 'end_date': '31-12-2021', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'features_columns': ['15m_RSI_14', '15m_RSI_6', '15m_EMA_5', '15m_EMA_21', '15m_SMA_50', '15m_MACD_12_26_9', '15m_MACDs_12_26_9', '15m_MACDh_12_26_9', '15m_BBL_20_2.0', '15m_BBM_20_2.0', '15m_BBU_20_2.0', '15m_BBB_20_2.0', '15m_BBP_20_2.0', '1h_RSI_14', '1h_RSI_6', '1h_EMA_5', '1h_EMA_21', '1h_MACD_12_26_9', '1h_MACDs_12_26_9', '1h_MACDh_12_26_9', '1h_BBL_20_2.0', '1h_BBM_20_2.0', '1h_BBU_20_2.0', '1h_BBB_20_2.0', '1h_BBP_20_2.0', '4h_RSI_14', '4h_RSI_6', '4h_EMA_5', '4h_EMA_21'], 'lower_timeframe': '15m', 'middle_timeframe': '1h', 'higher_timeframe': '4h', 'seq_length': 100, 'training_data_ratio': 0.8, 'epochs': 20, 'model_input_shape': (100, 29), 'model_name': 'binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d', 'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d.h5', 'train_loss': 0.2532379627227783, 'train_mae': 0.41433656215667725, 'val_loss': 0.24152757227420807, 'val_mae': 0.4045906066894531, 'final_epoch': 7, 'training_data_start_date': Timestamp('2017-08-20 12:00:00'), 'training_data_end_date': Timestamp('2021-02-15 13:30:00'), 'test_data_start_date': Timestamp('2021-02-16 14:45:00'), 'test_data_end_date': Timestamp('2021-12-30 19:30:00'), 'trade_leverage': 10, 'trade_margin': 1000, 'trade_buy_threshold': 0.3, 'trade_sell_threshold': -0.4, 'starting_portfolio_value': 10000.0, 'final_portfolio_value': 113218.76498632267, 'broker_commision': 0.02, 'trade_analysis': {'total': {'total': 1352, 'open': 2, 'closed': 1352}, 'streak': {'won': {'current': 4, 'longest': 18}, 'lost': {'current': 0, 'longest': 4}}, 'pnl': {'gross': {'total': 108614, 'average': 80}, 'net': {'total': 103210, 'average': 76}}, 'won': {'total': 1076, 'pnl': {'total': 145576, 'average': 136, 'max': 792}}, 'lost': {'total': 276, 'pnl': {'total': -42364, 'average': -152, 'max': -1542}}, 'long': {'total': 682, 'pnl': {'total': 51922, 'average': 76, 'won': {'total': 76022, 'average': 142, 'max': 792}, 'lost': {'total': -24100, 'average': -162, 'max': -1542}}, 'won': 534, 'lost': 148}, 'short': {'total': 670, 'pnl': {'total': 51290, 'average': 78, 'won': {'total': 69554, 'average': 130, 'max': 720}, 'lost': {'total': -18264, 'average': -142, 'max': -818}}, 'won': 542, 'lost': 128}, 'len': {'total': 27132, 'average': 20, 'max': 124, 'min': 2, 'won': {'total': 17230, 'average': 16, 'max': 100, 'min': 2}, 'lost': {'total': 9902, 'average': 36, 'max': 124, 'min': 2}, 'long': {'total': 16084, 'average': 24, 'max': 124, 'min': 2, 'won': {'total': 10220, 'average': 20, 'max': 100, 'min': 2}, 'lost': {'total': 5864, 'average': 40, 'max': 124, 'min': 6}}, 'short': {'total': 11048, 'average': 18, 'max': 72, 'min': 2, 'won': {'total': 7010, 'average': 14, 'max': 54, 'min': 2}, 'lost': {'total': 4038, 'average': 32, 'max': 72, 'min': 2}}}}, 'drawdown_analysis': {'len': 302, 'drawdown': 0, 'moneydown': 120, 'max': {'len': 476, 'drawdown': 14, 'moneydown': 2054}}, 'sharpe_analysis': {'sharperatio': 0}, 'version': 'v1_0_1', 'created_at': datetime.datetime(2025, 3, 9, 13, 33, 31, 197048)}
# Backtesting- Buy Threshold: 0.3, Sell Threshold: -0.4, leverage: 15
# Starting Portfolio Value: 10000.00
# Final Portfolio Value: 161842.95
# Data saved to Firestore: Collection=trade-models, Document ID=rr3tdFiepu5LFBDNDqw2
# {'timeframe': '15m', 'start_date': '01-01-2017', 'end_date': '31-12-2021', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'features_columns': ['15m_RSI_14', '15m_RSI_6', '15m_EMA_5', '15m_EMA_21', '15m_SMA_50', '15m_MACD_12_26_9', '15m_MACDs_12_26_9', '15m_MACDh_12_26_9', '15m_BBL_20_2.0', '15m_BBM_20_2.0', '15m_BBU_20_2.0', '15m_BBB_20_2.0', '15m_BBP_20_2.0', '1h_RSI_14', '1h_RSI_6', '1h_EMA_5', '1h_EMA_21', '1h_MACD_12_26_9', '1h_MACDs_12_26_9', '1h_MACDh_12_26_9', '1h_BBL_20_2.0', '1h_BBM_20_2.0', '1h_BBU_20_2.0', '1h_BBB_20_2.0', '1h_BBP_20_2.0', '4h_RSI_14', '4h_RSI_6', '4h_EMA_5', '4h_EMA_21'], 'lower_timeframe': '15m', 'middle_timeframe': '1h', 'higher_timeframe': '4h', 'seq_length': 100, 'training_data_ratio': 0.8, 'epochs': 20, 'model_input_shape': (100, 29), 'model_name': 'binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d', 'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d.h5', 'train_loss': 0.2532379627227783, 'train_mae': 0.41433656215667725, 'val_loss': 0.24152757227420807, 'val_mae': 0.4045906066894531, 'final_epoch': 7, 'training_data_start_date': Timestamp('2017-08-20 12:00:00'), 'training_data_end_date': Timestamp('2021-02-15 13:30:00'), 'test_data_start_date': Timestamp('2021-02-16 14:45:00'), 'test_data_end_date': Timestamp('2021-12-30 19:30:00'), 'trade_leverage': 15, 'trade_margin': 1000, 'trade_buy_threshold': 0.3, 'trade_sell_threshold': -0.4, 'starting_portfolio_value': 10000.0, 'final_portfolio_value': 161842.95155591742, 'broker_commision': 0.02, 'trade_analysis': {'total': {'total': 1330, 'open': 2, 'closed': 1328}, 'streak': {'won': {'current': 4, 'longest': 18}, 'lost': {'current': 0, 'longest': 4}}, 'pnl': {'gross': {'total': 159798, 'average': 120}, 'net': {'total': 151830, 'average': 114}}, 'won': {'total': 1056, 'pnl': {'total': 212964, 'average': 202, 'max': 1188}}, 'lost': {'total': 274, 'pnl': {'total': -61132, 'average': -224, 'max': -2312}}, 'long': {'total': 660, 'pnl': {'total': 74806, 'average': 114, 'won': {'total': 108540, 'average': 210, 'max': 1188}, 'lost': {'total': -33732, 'average': -236, 'max': -2312}}, 'won': 516, 'lost': 144}, 'short': {'total': 670, 'pnl': {'total': 77024, 'average': 116, 'won': {'total': 104424, 'average': 194, 'max': 1078}, 'lost': {'total': -27400, 'average': -210, 'max': -1228}}, 'won': 540, 'lost': 130}, 'len': {'total': 26664, 'average': 20, 'max': 124, 'min': 2, 'won': {'total': 16930, 'average': 16, 'max': 100, 'min': 2}, 'lost': {'total': 9734, 'average': 36, 'max': 124, 'min': 2}, 'long': {'total': 15582, 'average': 24, 'max': 124, 'min': 2, 'won': {'total': 9916, 'average': 20, 'max': 100, 'min': 2}, 'lost': {'total': 5666, 'average': 40, 'max': 124, 'min': 6}}, 'short': {'total': 11082, 'average': 18, 'max': 72, 'min': 2, 'won': {'total': 7014, 'average': 14, 'max': 54, 'min': 2}, 'lost': {'total': 4068, 'average': 32, 'max': 72, 'min': 2}}}}, 'drawdown_analysis': {'len': 302, 'drawdown': 0, 'moneydown': 180, 'max': {'len': 476, 'drawdown': 10, 'moneydown': 3082}}, 'sharpe_analysis': {'sharperatio': 0}, 'version': 'v1_0_1', 'created_at': datetime.datetime(2025, 3, 9, 13, 33, 39, 127769)}
# Backtesting- Buy Threshold: 0.3, Sell Threshold: -0.4, leverage: 20
# Starting Portfolio Value: 10000.00
# Final Portfolio Value: 205838.79
# Data saved to Firestore: Collection=trade-models, Document ID=PerGulxCTfMz0t8qMTU6
# {'timeframe': '15m', 'start_date': '01-01-2017', 'end_date': '31-12-2021', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'features_columns': ['15m_RSI_14', '15m_RSI_6', '15m_EMA_5', '15m_EMA_21', '15m_SMA_50', '15m_MACD_12_26_9', '15m_MACDs_12_26_9', '15m_MACDh_12_26_9', '15m_BBL_20_2.0', '15m_BBM_20_2.0', '15m_BBU_20_2.0', '15m_BBB_20_2.0', '15m_BBP_20_2.0', '1h_RSI_14', '1h_RSI_6', '1h_EMA_5', '1h_EMA_21', '1h_MACD_12_26_9', '1h_MACDs_12_26_9', '1h_MACDh_12_26_9', '1h_BBL_20_2.0', '1h_BBM_20_2.0', '1h_BBU_20_2.0', '1h_BBB_20_2.0', '1h_BBP_20_2.0', '4h_RSI_14', '4h_RSI_6', '4h_EMA_5', '4h_EMA_21'], 'lower_timeframe': '15m', 'middle_timeframe': '1h', 'higher_timeframe': '4h', 'seq_length': 100, 'training_data_ratio': 0.8, 'epochs': 20, 'model_input_shape': (100, 29), 'model_name': 'binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d', 'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d.h5', 'train_loss': 0.2532379627227783, 'train_mae': 0.41433656215667725, 'val_loss': 0.24152757227420807, 'val_mae': 0.4045906066894531, 'final_epoch': 7, 'training_data_start_date': Timestamp('2017-08-20 12:00:00'), 'training_data_end_date': Timestamp('2021-02-15 13:30:00'), 'test_data_start_date': Timestamp('2021-02-16 14:45:00'), 'test_data_end_date': Timestamp('2021-12-30 19:30:00'), 'trade_leverage': 20, 'trade_margin': 1000, 'trade_buy_threshold': 0.3, 'trade_sell_threshold': -0.4, 'starting_portfolio_value': 10000.0, 'final_portfolio_value': 205838.78941938514, 'broker_commision': 0.02, 'trade_analysis': {'total': {'total': 1298, 'open': 2, 'closed': 1298}, 'streak': {'won': {'current': 4, 'longest': 18}, 'lost': {'current': 0, 'longest': 4}}, 'pnl': {'gross': {'total': 206196, 'average': 160}, 'net': {'total': 195822, 'average': 152}}, 'won': {'total': 1028, 'pnl': {'total': 276914, 'average': 270, 'max': 1584}}, 'lost': {'total': 270, 'pnl': {'total': -81092, 'average': -300, 'max': -3084}}, 'long': {'total': 624, 'pnl': {'total': 92382, 'average': 148, 'won': {'total': 136664, 'average': 282, 'max': 1584}, 'lost': {'total': -44282, 'average': -322, 'max': -3084}}, 'won': 488, 'lost': 138}, 'short': {'total': 674, 'pnl': {'total': 103442, 'average': 154, 'won': {'total': 140252, 'average': 260, 'max': 1438}, 'lost': {'total': -36810, 'average': -278, 'max': -1636}}, 'won': 542, 'lost': 132}, 'len': {'total': 25998, 'average': 20, 'max': 124, 'min': 2, 'won': {'total': 16370, 'average': 16, 'max': 100, 'min': 2}, 'lost': {'total': 9628, 'average': 36, 'max': 124, 'min': 2}, 'long': {'total': 14860, 'average': 24, 'max': 124, 'min': 2, 'won': {'total': 9358, 'average': 20, 'max': 100, 'min': 2}, 'lost': {'total': 5502, 'average': 40, 'max': 124, 'min': 6}}, 'short': {'total': 11138, 'average': 18, 'max': 72, 'min': 2, 'won': {'total': 7014, 'average': 14, 'max': 54, 'min': 2}, 'lost': {'total': 4126, 'average': 32, 'max': 72, 'min': 2}}}}, 'drawdown_analysis': {'len': 302, 'drawdown': 0, 'moneydown': 238, 'max': {'len': 620, 'drawdown': 14, 'moneydown': 4108}}, 'sharpe_analysis': {'sharperatio': 0}, 'version': 'v1_0_1', 'created_at': datetime.datetime(2025, 3, 9, 13, 33, 47, 443629)}
# Backtesting- Buy Threshold: 0.3, Sell Threshold: -0.4, leverage: 25
# Starting Portfolio Value: 10000.00
# Final Portfolio Value: 252443.79
# Data saved to Firestore: Collection=trade-models, Document ID=46WspfTAFd24qimYoNCy
# {'timeframe': '15m', 'start_date': '01-01-2017', 'end_date': '31-12-2021', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'features_columns': ['15m_RSI_14', '15m_RSI_6', '15m_EMA_5', '15m_EMA_21', '15m_SMA_50', '15m_MACD_12_26_9', '15m_MACDs_12_26_9', '15m_MACDh_12_26_9', '15m_BBL_20_2.0', '15m_BBM_20_2.0', '15m_BBU_20_2.0', '15m_BBB_20_2.0', '15m_BBP_20_2.0', '1h_RSI_14', '1h_RSI_6', '1h_EMA_5', '1h_EMA_21', '1h_MACD_12_26_9', '1h_MACDs_12_26_9', '1h_MACDh_12_26_9', '1h_BBL_20_2.0', '1h_BBM_20_2.0', '1h_BBU_20_2.0', '1h_BBB_20_2.0', '1h_BBP_20_2.0', '4h_RSI_14', '4h_RSI_6', '4h_EMA_5', '4h_EMA_21'], 'lower_timeframe': '15m', 'middle_timeframe': '1h', 'higher_timeframe': '4h', 'seq_length': 100, 'training_data_ratio': 0.8, 'epochs': 20, 'model_input_shape': (100, 29), 'model_name': 'binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d', 'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d.h5', 'train_loss': 0.2532379627227783, 'train_mae': 0.41433656215667725, 'val_loss': 0.24152757227420807, 'val_mae': 0.4045906066894531, 'final_epoch': 7, 'training_data_start_date': Timestamp('2017-08-20 12:00:00'), 'training_data_end_date': Timestamp('2021-02-15 13:30:00'), 'test_data_start_date': Timestamp('2021-02-16 14:45:00'), 'test_data_end_date': Timestamp('2021-12-30 19:30:00'), 'trade_leverage': 25, 'trade_margin': 1000, 'trade_buy_threshold': 0.3, 'trade_sell_threshold': -0.4, 'starting_portfolio_value': 10000.0, 'final_portfolio_value': 252443.78983398146, 'broker_commision': 0.02, 'trade_analysis': {'total': {'total': 1284, 'open': 2, 'closed': 1284}, 'streak': {'won': {'current': 4, 'longest': 18}, 'lost': {'current': 0, 'longest': 4}}, 'pnl': {'gross': {'total': 255250, 'average': 200}, 'net': {'total': 242422, 'average': 190}}, 'won': {'total': 1018, 'pnl': {'total': 342420, 'average': 338, 'max': 1978}}, 'lost': {'total': 266, 'pnl': {'total': -99998, 'average': -376, 'max': -3854}}, 'long': {'total': 610, 'pnl': {'total': 113454, 'average': 186, 'won': {'total': 167112, 'average': 350, 'max': 1978}, 'lost': {'total': -53658, 'average': -402, 'max': -3854}}, 'won': 478, 'lost': 134}, 'short': {'total': 674, 'pnl': {'total': 128970, 'average': 192, 'won': {'total': 175308, 'average': 326, 'max': 1798}, 'lost': {'total': -46338, 'average': -348, 'max': -2046}}, 'won': 540, 'lost': 134}, 'len': {'total': 25662, 'average': 20, 'max': 124, 'min': 2, 'won': {'total': 16156, 'average': 16, 'max': 100, 'min': 2}, 'lost': {'total': 9508, 'average': 36, 'max': 124, 'min': 2}, 'long': {'total': 14510, 'average': 24, 'max': 124, 'min': 2, 'won': {'total': 9154, 'average': 20, 'max': 100, 'min': 2}, 'lost': {'total': 5356, 'average': 40, 'max': 124, 'min': 6}}, 'short': {'total': 11154, 'average': 18, 'max': 72, 'min': 2, 'won': {'total': 7002, 'average': 14, 'max': 54, 'min': 2}, 'lost': {'total': 4152, 'average': 32, 'max': 72, 'min': 2}}}}, 'drawdown_analysis': {'len': 302, 'drawdown': 0, 'moneydown': 298, 'max': {'len': 620, 'drawdown': 16, 'moneydown': 5136}}, 'sharpe_analysis': {'sharperatio': 0}, 'version': 'v1_0_1', 'created_at': datetime.datetime(2025, 3, 9, 13, 33, 55, 393758)}
# Backtesting- Buy Threshold: 0.3, Sell Threshold: -0.4, leverage: 30
# Starting Portfolio Value: 10000.00
# Final Portfolio Value: 301691.76
# Data saved to Firestore: Collection=trade-models, Document ID=y9SD65IVILgJHQJJaYNj
# {'timeframe': '15m', 'start_date': '01-01-2017', 'end_date': '31-12-2021', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'features_columns': ['15m_RSI_14', '15m_RSI_6', '15m_EMA_5', '15m_EMA_21', '15m_SMA_50', '15m_MACD_12_26_9', '15m_MACDs_12_26_9', '15m_MACDh_12_26_9', '15m_BBL_20_2.0', '15m_BBM_20_2.0', '15m_BBU_20_2.0', '15m_BBB_20_2.0', '15m_BBP_20_2.0', '1h_RSI_14', '1h_RSI_6', '1h_EMA_5', '1h_EMA_21', '1h_MACD_12_26_9', '1h_MACDs_12_26_9', '1h_MACDh_12_26_9', '1h_BBL_20_2.0', '1h_BBM_20_2.0', '1h_BBU_20_2.0', '1h_BBB_20_2.0', '1h_BBP_20_2.0', '4h_RSI_14', '4h_RSI_6', '4h_EMA_5', '4h_EMA_21'], 'lower_timeframe': '15m', 'middle_timeframe': '1h', 'higher_timeframe': '4h', 'seq_length': 100, 'training_data_ratio': 0.8, 'epochs': 20, 'model_input_shape': (100, 29), 'model_name': 'binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d', 'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d.h5', 'train_loss': 0.2532379627227783, 'train_mae': 0.41433656215667725, 'val_loss': 0.24152757227420807, 'val_mae': 0.4045906066894531, 'final_epoch': 7, 'training_data_start_date': Timestamp('2017-08-20 12:00:00'), 'training_data_end_date': Timestamp('2021-02-15 13:30:00'), 'test_data_start_date': Timestamp('2021-02-16 14:45:00'), 'test_data_end_date': Timestamp('2021-12-30 19:30:00'), 'trade_leverage': 30, 'trade_margin': 1000, 'trade_buy_threshold': 0.3, 'trade_sell_threshold': -0.4, 'starting_portfolio_value': 10000.0, 'final_portfolio_value': 301691.76003603585, 'broker_commision': 0.02, 'trade_analysis': {'total': {'total': 1280, 'open': 2, 'closed': 1278}, 'streak': {'won': {'current': 4, 'longest': 18}, 'lost': {'current': 0, 'longest': 4}}, 'pnl': {'gross': {'total': 306998, 'average': 240}, 'net': {'total': 291666, 'average': 228}}, 'won': {'total': 1014, 'pnl': {'total': 409550, 'average': 404, 'max': 2374}}, 'lost': {'total': 264, 'pnl': {'total': -117882, 'average': -446, 'max': -4626}}, 'long': {'total': 606, 'pnl': {'total': 136882, 'average': 226, 'won': {'total': 199100, 'average': 420, 'max': 2374}, 'lost': {'total': -62218, 'average': -474, 'max': -4626}}, 'won': 474, 'lost': 132}, 'short': {'total': 674, 'pnl': {'total': 154784, 'average': 230, 'won': {'total': 210450, 'average': 390, 'max': 2158}, 'lost': {'total': -55664, 'average': -418, 'max': -2456}}, 'won': 540, 'lost': 134}, 'len': {'total': 25508, 'average': 20, 'max': 124, 'min': 2, 'won': {'total': 16078, 'average': 16, 'max': 100, 'min': 2}, 'lost': {'total': 9430, 'average': 36, 'max': 124, 'min': 2}, 'long': {'total': 14346, 'average': 24, 'max': 124, 'min': 2, 'won': {'total': 9070, 'average': 20, 'max': 100, 'min': 2}, 'lost': {'total': 5276, 'average': 40, 'max': 124, 'min': 6}}, 'short': {'total': 11164, 'average': 18, 'max': 72, 'min': 2, 'won': {'total': 7010, 'average': 14, 'max': 54, 'min': 2}, 'lost': {'total': 4154, 'average': 32, 'max': 72, 'min': 2}}}}, 'drawdown_analysis': {'len': 302, 'drawdown': 0, 'moneydown': 358, 'max': {'len': 620, 'drawdown': 16, 'moneydown': 6162}}, 'sharpe_analysis': {'sharperatio': 0}, 'version': 'v1_0_1', 'created_at': datetime.datetime(2025, 3, 9, 13, 34, 3, 704466)}
# Backtesting- Buy Threshold: 0.3, Sell Threshold: -0.5, leverage: 10
# Starting Portfolio Value: 10000.00
# Final Portfolio Value: 105065.60
# Data saved to Firestore: Collection=trade-models, Document ID=1za7uygliFBQenHzsz0C
# {'timeframe': '15m', 'start_date': '01-01-2017', 'end_date': '31-12-2021', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'features_columns': ['15m_RSI_14', '15m_RSI_6', '15m_EMA_5', '15m_EMA_21', '15m_SMA_50', '15m_MACD_12_26_9', '15m_MACDs_12_26_9', '15m_MACDh_12_26_9', '15m_BBL_20_2.0', '15m_BBM_20_2.0', '15m_BBU_20_2.0', '15m_BBB_20_2.0', '15m_BBP_20_2.0', '1h_RSI_14', '1h_RSI_6', '1h_EMA_5', '1h_EMA_21', '1h_MACD_12_26_9', '1h_MACDs_12_26_9', '1h_MACDh_12_26_9', '1h_BBL_20_2.0', '1h_BBM_20_2.0', '1h_BBU_20_2.0', '1h_BBB_20_2.0', '1h_BBP_20_2.0', '4h_RSI_14', '4h_RSI_6', '4h_EMA_5', '4h_EMA_21'], 'lower_timeframe': '15m', 'middle_timeframe': '1h', 'higher_timeframe': '4h', 'seq_length': 100, 'training_data_ratio': 0.8, 'epochs': 20, 'model_input_shape': (100, 29), 'model_name': 'binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d', 'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d.h5', 'train_loss': 0.2532379627227783, 'train_mae': 0.41433656215667725, 'val_loss': 0.24152757227420807, 'val_mae': 0.4045906066894531, 'final_epoch': 7, 'training_data_start_date': Timestamp('2017-08-20 12:00:00'), 'training_data_end_date': Timestamp('2021-02-15 13:30:00'), 'test_data_start_date': Timestamp('2021-02-16 14:45:00'), 'test_data_end_date': Timestamp('2021-12-30 19:30:00'), 'trade_leverage': 10, 'trade_margin': 1000, 'trade_buy_threshold': 0.3, 'trade_sell_threshold': -0.5, 'starting_portfolio_value': 10000.0, 'final_portfolio_value': 105065.59672335809, 'broker_commision': 0.02, 'trade_analysis': {'total': {'total': 1040, 'open': 0, 'closed': 1040}, 'streak': {'won': {'current': 4, 'longest': 20}, 'lost': {'current': 0, 'longest': 4}}, 'pnl': {'gross': {'total': 99224, 'average': 96}, 'net': {'total': 95066, 'average': 92}}, 'won': {'total': 840, 'pnl': {'total': 131606, 'average': 158, 'max': 1002}}, 'lost': {'total': 200, 'pnl': {'total': -36540, 'average': -182, 'max': -1360}}, 'long': {'total': 552, 'pnl': {'total': 51966, 'average': 94, 'won': {'total': 75770, 'average': 176, 'max': 1002}, 'lost': {'total': -23802, 'average': -202, 'max': -1360}}, 'won': 434, 'lost': 118}, 'short': {'total': 488, 'pnl': {'total': 43100, 'average': 88, 'won': {'total': 55836, 'average': 138, 'max': 734}, 'lost': {'total': -12736, 'average': -152, 'max': -658}}, 'won': 406, 'lost': 84}, 'len': {'total': 27180, 'average': 26, 'max': 210, 'min': 2, 'won': {'total': 17820, 'average': 22, 'max': 210, 'min': 2}, 'lost': {'total': 9360, 'average': 48, 'max': 126, 'min': 2}, 'long': {'total': 19506, 'average': 36, 'max': 210, 'min': 2, 'won': {'total': 12998, 'average': 30, 'max': 210, 'min': 2}, 'lost': {'total': 6508, 'average': 56, 'max': 126, 'min': 8}}, 'short': {'total': 7676, 'average': 16, 'max': 72, 'min': 2, 'won': {'total': 4824, 'average': 12, 'max': 50, 'min': 2}, 'lost': {'total': 2852, 'average': 34, 'max': 72, 'min': 2}}}}, 'drawdown_analysis': {'len': 286, 'drawdown': 0, 'moneydown': 360, 'max': {'len': 606, 'drawdown': 14, 'moneydown': 2294}}, 'sharpe_analysis': {'sharperatio': 0}, 'version': 'v1_0_1', 'created_at': datetime.datetime(2025, 3, 9, 13, 34, 11, 359183)}
# Backtesting- Buy Threshold: 0.3, Sell Threshold: -0.5, leverage: 15
# Starting Portfolio Value: 10000.00
# Final Portfolio Value: 150724.41
# Data saved to Firestore: Collection=trade-models, Document ID=VJGh34L4lx1Rp47adlAt
# {'timeframe': '15m', 'start_date': '01-01-2017', 'end_date': '31-12-2021', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'features_columns': ['15m_RSI_14', '15m_RSI_6', '15m_EMA_5', '15m_EMA_21', '15m_SMA_50', '15m_MACD_12_26_9', '15m_MACDs_12_26_9', '15m_MACDh_12_26_9', '15m_BBL_20_2.0', '15m_BBM_20_2.0', '15m_BBU_20_2.0', '15m_BBB_20_2.0', '15m_BBP_20_2.0', '1h_RSI_14', '1h_RSI_6', '1h_EMA_5', '1h_EMA_21', '1h_MACD_12_26_9', '1h_MACDs_12_26_9', '1h_MACDh_12_26_9', '1h_BBL_20_2.0', '1h_BBM_20_2.0', '1h_BBU_20_2.0', '1h_BBB_20_2.0', '1h_BBP_20_2.0', '4h_RSI_14', '4h_RSI_6', '4h_EMA_5', '4h_EMA_21'], 'lower_timeframe': '15m', 'middle_timeframe': '1h', 'higher_timeframe': '4h', 'seq_length': 100, 'training_data_ratio': 0.8, 'epochs': 20, 'model_input_shape': (100, 29), 'model_name': 'binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d', 'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d.h5', 'train_loss': 0.2532379627227783, 'train_mae': 0.41433656215667725, 'val_loss': 0.24152757227420807, 'val_mae': 0.4045906066894531, 'final_epoch': 7, 'training_data_start_date': Timestamp('2017-08-20 12:00:00'), 'training_data_end_date': Timestamp('2021-02-15 13:30:00'), 'test_data_start_date': Timestamp('2021-02-16 14:45:00'), 'test_data_end_date': Timestamp('2021-12-30 19:30:00'), 'trade_leverage': 15, 'trade_margin': 1000, 'trade_buy_threshold': 0.3, 'trade_sell_threshold': -0.5, 'starting_portfolio_value': 10000.0, 'final_portfolio_value': 150724.4104694244, 'broker_commision': 0.02, 'trade_analysis': {'total': {'total': 1020, 'open': 0, 'closed': 1020}, 'streak': {'won': {'current': 4, 'longest': 20}, 'lost': {'current': 0, 'longest': 4}}, 'pnl': {'gross': {'total': 146846, 'average': 144}, 'net': {'total': 140724, 'average': 138}}, 'won': {'total': 826, 'pnl': {'total': 192538, 'average': 234, 'max': 1372}}, 'lost': {'total': 196, 'pnl': {'total': -51812, 'average': -266, 'max': -2042}}, 'long': {'total': 526, 'pnl': {'total': 74170, 'average': 142, 'won': {'total': 106938, 'average': 258, 'max': 1372}, 'lost': {'total': -32768, 'average': -292, 'max': -2042}}, 'won': 414, 'lost': 112}, 'short': {'total': 494, 'pnl': {'total': 66554, 'average': 136, 'won': {'total': 85600, 'average': 208, 'max': 1100}, 'lost': {'total': -19044, 'average': -228, 'max': -988}}, 'won': 412, 'lost': 84}, 'len': {'total': 26550, 'average': 26, 'max': 210, 'min': 2, 'won': {'total': 17438, 'average': 22, 'max': 210, 'min': 2}, 'lost': {'total': 9112, 'average': 48, 'max': 126, 'min': 2}, 'long': {'total': 18790, 'average': 36, 'max': 210, 'min': 2, 'won': {'total': 12520, 'average': 30, 'max': 210, 'min': 2}, 'lost': {'total': 6270, 'average': 56, 'max': 126, 'min': 8}}, 'short': {'total': 7760, 'average': 16, 'max': 72, 'min': 2, 'won': {'total': 4918, 'average': 12, 'max': 50, 'min': 2}, 'lost': {'total': 2842, 'average': 34, 'max': 72, 'min': 2}}}}, 'drawdown_analysis': {'len': 286, 'drawdown': 0, 'moneydown': 540, 'max': {'len': 606, 'drawdown': 10, 'moneydown': 3440}}, 'sharpe_analysis': {'sharperatio': 0}, 'version': 'v1_0_1', 'created_at': datetime.datetime(2025, 3, 9, 13, 34, 19, 428087)}
# Backtesting- Buy Threshold: 0.3, Sell Threshold: -0.5, leverage: 20
# Starting Portfolio Value: 10000.00
# Final Portfolio Value: 189843.41
# Data saved to Firestore: Collection=trade-models, Document ID=b0W2SwHTqn1lHpLgaoR0
# {'timeframe': '15m', 'start_date': '01-01-2017', 'end_date': '31-12-2021', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'features_columns': ['15m_RSI_14', '15m_RSI_6', '15m_EMA_5', '15m_EMA_21', '15m_SMA_50', '15m_MACD_12_26_9', '15m_MACDs_12_26_9', '15m_MACDh_12_26_9', '15m_BBL_20_2.0', '15m_BBM_20_2.0', '15m_BBU_20_2.0', '15m_BBB_20_2.0', '15m_BBP_20_2.0', '1h_RSI_14', '1h_RSI_6', '1h_EMA_5', '1h_EMA_21', '1h_MACD_12_26_9', '1h_MACDs_12_26_9', '1h_MACDh_12_26_9', '1h_BBL_20_2.0', '1h_BBM_20_2.0', '1h_BBU_20_2.0', '1h_BBB_20_2.0', '1h_BBP_20_2.0', '4h_RSI_14', '4h_RSI_6', '4h_EMA_5', '4h_EMA_21'], 'lower_timeframe': '15m', 'middle_timeframe': '1h', 'higher_timeframe': '4h', 'seq_length': 100, 'training_data_ratio': 0.8, 'epochs': 20, 'model_input_shape': (100, 29), 'model_name': 'binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d', 'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2017_31-12-2021_080dd22d.h5', 'train_loss': 0.2532379627227783, 'train_mae': 0.41433656215667725, 'val_loss': 0.24152757227420807, 'val_mae': 0.4045906066894531, 'final_epoch': 7, 'training_data_start_date': Timestamp('2017-08-20 12:00:00'), 'training_data_end_date': Timestamp('2021-02-15 13:30:00'), 'test_data_start_date': Timestamp('2021-02-16 14:45:00'), 'test_data_end_date': Timestamp('2021-12-30 19:30:00'), 'trade_leverage': 20, 'trade_margin': 1000, 'trade_buy_threshold': 0.3, 'trade_sell_threshold': -0.5, 'starting_portfolio_value': 10000.0, 'final_portfolio_value': 189843.41124086268, 'broker_commision': 0.02, 'trade_analysis': {'total': {'total': 986, 'open': 0, 'closed': 986}, 'streak': {'won': {'current': 4, 'longest': 20}, 'lost': {'current': 0, 'longest': 4}}, 'pnl': {'gross': {'total': 187724, 'average': 192}, 'net': {'total': 179844, 'average': 184}}, 'won': {'total': 798, 'pnl': {'total': 247446, 'average': 310, 'max': 1830}}, 'lost': {'total': 188, 'pnl': {'total': -67602, 'average': -362, 'max': -2722}}, 'long': {'total': 488, 'pnl': {'total': 91404, 'average': 188, 'won': {'total': 132822, 'average': 344, 'max': 1830}, 'lost': {'total': -41418, 'average': -406, 'max': -2722}}, 'won': 386, 'lost': 102}, 'short': {'total': 498, 'pnl': {'total': 88442, 'average': 178, 'won': {'total': 114624, 'average': 278, 'max': 1466}, 'lost': {'total': -26184, 'average': -308, 'max': -1318}}, 'won': 412, 'lost': 86}, 'len': {'total': 25470, 'average': 26, 'max': 210, 'min': 2, 'won': {'total': 16792, 'average': 22, 'max': 210, 'min': 2}, 'lost': {'total': 8678, 'average': 46, 'max': 126, 'min': 2}, 'long': {'total': 17604, 'average': 36, 'max': 210, 'min': 2, 'won': {'total': 11822, 'average': 32, 'max': 210, 'min': 2}, 'lost': {'total': 5782, 'average': 58, 'max': 126, 'min': 8}}, 'short': {'total': 7866, 'average': 16, 'max': 72, 'min': 2, 'won': {'total': 4970, 'average': 12, 'max': 50, 'min': 2}, 'lost': {'total': 2898, 'average': 34, 'max': 72, 'min': 2}}}}, 'drawdown_analysis': {'len': 286, 'drawdown': 0, 'moneydown': 722, 'max': {'len': 648, 'drawdown': 16, 'moneydown': 4588}}, 'sharpe_analysis': {'sharperatio': 0}, 'version': 'v1_0_1', 'created_at': datetime.datetime(2025, 3, 9, 13, 34, 27, 221110)}
# Backtesting- Buy Threshold: 0.3, Sell Threshold: -0.5, leverage: 25
# Starting Portfolio Value: 10000.00
# Final Portfolio Value: 229221.28
# Data saved to Firestore: Collection=trade-models, Document ID=o2Zy1RvFT7wxo7Ub2qdW
# ...
# Backtesting- Buy Threshold: 0.7, Sell Threshold: -0.7, leverage: 15
# Starting Portfolio Value: 10000.00
# Final Portfolio Value: 41728.21
# Data saved to Firestore: Collection=trade-models, Document ID=B6GcJ9Imwb41H6VvTX44
# {'timeframe': '15m', 'start_date': '01-01-2020', 'end_date': '30-12-2024', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'features_columns': ['15m_RSI_14', '15m_RSI_6', '15m_EMA_5', '15m_EMA_21', '15m_SMA_50', '15m_MACD_12_26_9', '15m_MACDs_12_26_9', '15m_MACDh_12_26_9', '15m_BBL_20_2.0', '15m_BBM_20_2.0', '15m_BBU_20_2.0', '15m_BBB_20_2.0', '15m_BBP_20_2.0', '1h_RSI_14', '1h_RSI_6', '1h_EMA_5', '1h_EMA_21', '1h_MACD_12_26_9', '1h_MACDs_12_26_9', '1h_MACDh_12_26_9', '1h_BBL_20_2.0', '1h_BBM_20_2.0', '1h_BBU_20_2.0', '1h_BBB_20_2.0', '1h_BBP_20_2.0', '4h_RSI_14', '4h_RSI_6', '4h_EMA_5', '4h_EMA_21'], 'lower_timeframe': '15m', 'middle_timeframe': '1h', 'higher_timeframe': '4h', 'seq_length': 100, 'training_data_ratio': 0.8, 'epochs': 20, 'model_input_shape': (100, 29), 'model_name': 'binance_mtf_v1_0_1_15m_01-01-2020_30-12-2024_4cc8bc32', 'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2020_30-12-2024_4cc8bc32.h5', 'train_loss': 0.236819788813591, 'train_mae': 0.3972854018211365, 'val_loss': 0.24077270925045013, 'val_mae': 0.4036828577518463, 'final_epoch': 11, 'training_data_start_date': Timestamp('2020-01-04 08:00:00'), 'training_data_end_date': Timestamp('2023-12-31 19:00:00'), 'test_data_start_date': Timestamp('2024-01-01 20:15:00'), 'test_data_end_date': Timestamp('2024-12-29 21:00:00'), 'trade_leverage': 15, 'trade_margin': 1000, 'trade_buy_threshold': 0.7, 'trade_sell_threshold': -0.7, 'starting_portfolio_value': 10000.0, 'final_portfolio_value': 41728.20569083602, 'broker_commision': 0.02, 'trade_analysis': {'total': {'total': 102, 'open': 2, 'closed': 100}, 'streak': {'won': {'current': 10, 'longest': 10}, 'lost': {'current': 0, 'longest': 2}}, 'pnl': {'gross': {'total': 31932, 'average': 320}, 'net': {'total': 31334, 'average': 314}}, 'won': {'total': 78, 'pnl': {'total': 46394, 'average': 604, 'max': 1920}}, 'lost': {'total': 24, 'pnl': {'total': -15060, 'average': -654, 'max': -1572}}, 'long': {'total': 36, 'pnl': {'total': 12736, 'average': 364, 'won': {'total': 14942, 'average': 516, 'max': 1920}, 'lost': {'total': -2204, 'average': -366, 'max': -954}}, 'won': 30, 'lost': 6}, 'short': {'total': 66, 'pnl': {'total': 18598, 'average': 286, 'won': {'total': 31454, 'average': 656, 'max': 1782}, 'lost': {'total': -12856, 'average': -756, 'max': -1572}}, 'won': 48, 'lost': 18}, 'len': {'total': 27256, 'average': 274, 'max': 1586, 'min': 12, 'won': {'total': 18272, 'average': 238, 'max': 1586, 'min': 12}, 'lost': {'total': 8984, 'average': 392, 'max': 1232, 'min': 38}, 'long': {'total': 6004, 'average': 172, 'max': 672, 'min': 12, 'won': {'total': 4432, 'average': 154, 'max': 672, 'min': 12}, 'lost': {'total': 1572, 'average': 262, 'max': 636, 'min': 38}}, 'short': {'total': 21252, 'average': 328, 'max': 1586, 'min': 14, 'won': {'total': 13840, 'average': 288, 'max': 1586, 'min': 14}, 'lost': {'total': 7414, 'average': 436, 'max': 1232, 'min': 108}}}}, 'drawdown_analysis': {'len': 580, 'drawdown': 0, 'moneydown': 182, 'max': {'len': 4246, 'drawdown': 30, 'moneydown': 3804}}, 'sharpe_analysis': {'sharperatio': 0}, 'version': 'v1_0_1', 'created_at': datetime.datetime(2025, 3, 9, 15, 16, 49, 53169)}
# Backtesting- Buy Threshold: 0.7, Sell Threshold: -0.7, leverage: 20
# Starting Portfolio Value: 10000.00
# Final Portfolio Value: 50964.93
# Data saved to Firestore: Collection=trade-models, Document ID=xo67ja6lzcxEhszISR6O
# {'timeframe': '15m', 'start_date': '01-01-2020', 'end_date': '30-12-2024', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'features_columns': ['15m_RSI_14', '15m_RSI_6', '15m_EMA_5', '15m_EMA_21', '15m_SMA_50', '15m_MACD_12_26_9', '15m_MACDs_12_26_9', '15m_MACDh_12_26_9', '15m_BBL_20_2.0', '15m_BBM_20_2.0', '15m_BBU_20_2.0', '15m_BBB_20_2.0', '15m_BBP_20_2.0', '1h_RSI_14', '1h_RSI_6', '1h_EMA_5', '1h_EMA_21', '1h_MACD_12_26_9', '1h_MACDs_12_26_9', '1h_MACDh_12_26_9', '1h_BBL_20_2.0', '1h_BBM_20_2.0', '1h_BBU_20_2.0', '1h_BBB_20_2.0', '1h_BBP_20_2.0', '4h_RSI_14', '4h_RSI_6', '4h_EMA_5', '4h_EMA_21'], 'lower_timeframe': '15m', 'middle_timeframe': '1h', 'higher_timeframe': '4h', 'seq_length': 100, 'training_data_ratio': 0.8, 'epochs': 20, 'model_input_shape': (100, 29), 'model_name': 'binance_mtf_v1_0_1_15m_01-01-2020_30-12-2024_4cc8bc32', 'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2020_30-12-2024_4cc8bc32.h5', 'train_loss': 0.236819788813591, 'train_mae': 0.3972854018211365, 'val_loss': 0.24077270925045013, 'val_mae': 0.4036828577518463, 'final_epoch': 11, 'training_data_start_date': Timestamp('2020-01-04 08:00:00'), 'training_data_end_date': Timestamp('2023-12-31 19:00:00'), 'test_data_start_date': Timestamp('2024-01-01 20:15:00'), 'test_data_end_date': Timestamp('2024-12-29 21:00:00'), 'trade_leverage': 20, 'trade_margin': 1000, 'trade_buy_threshold': 0.7, 'trade_sell_threshold': -0.7, 'starting_portfolio_value': 10000.0, 'final_portfolio_value': 50964.92744305742, 'broker_commision': 0.02, 'trade_analysis': {'total': {'total': 98, 'open': 2, 'closed': 98}, 'streak': {'won': {'current': 10, 'longest': 10}, 'lost': {'current': 0, 'longest': 2}}, 'pnl': {'gross': {'total': 41212, 'average': 426}, 'net': {'total': 40438, 'average': 418}}, 'won': {'total': 74, 'pnl': {'total': 60520, 'average': 818, 'max': 2560}}, 'lost': {'total': 24, 'pnl': {'total': -20080, 'average': -872, 'max': -2096}}, 'long': {'total': 32, 'pnl': {'total': 15862, 'average': 496, 'won': {'total': 18802, 'average': 724, 'max': 2560}, 'lost': {'total': -2940, 'average': -490, 'max': -1272}}, 'won': 26, 'lost': 6}, 'short': {'total': 66, 'pnl': {'total': 24576, 'average': 378, 'won': {'total': 41718, 'average': 870, 'max': 2264}, 'lost': {'total': -17140, 'average': -1008, 'max': -2096}}, 'won': 48, 'lost': 18}, 'len': {'total': 27050, 'average': 280, 'max': 1586, 'min': 12, 'won': {'total': 18066, 'average': 244, 'max': 1586, 'min': 12}, 'lost': {'total': 8984, 'average': 392, 'max': 1232, 'min': 38}, 'long': {'total': 5718, 'average': 180, 'max': 672, 'min': 12, 'won': {'total': 4148, 'average': 160, 'max': 672, 'min': 12}, 'lost': {'total': 1572, 'average': 262, 'max': 636, 'min': 38}}, 'short': {'total': 21332, 'average': 328, 'max': 1586, 'min': 14, 'won': {'total': 13920, 'average': 290, 'max': 1586, 'min': 14}, 'lost': {'total': 7414, 'average': 436, 'max': 1232, 'min': 108}}}}, 'drawdown_analysis': {'len': 580, 'drawdown': 0, 'moneydown': 242, 'max': {'len': 4246, 'drawdown': 36, 'moneydown': 5072}}, 'sharpe_analysis': {'sharperatio': 0}, 'version': 'v1_0_1', 'created_at': datetime.datetime(2025, 3, 9, 15, 16, 57, 67584)}
# Backtesting- Buy Threshold: 0.7, Sell Threshold: -0.7, leverage: 25
# Starting Portfolio Value: 10000.00
# Final Portfolio Value: 56654.71
# Data saved to Firestore: Collection=trade-models, Document ID=EMT3NVg454Pz3GLioHsP
# {'timeframe': '15m', 'start_date': '01-01-2020', 'end_date': '30-12-2024', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'features_columns': ['15m_RSI_14', '15m_RSI_6', '15m_EMA_5', '15m_EMA_21', '15m_SMA_50', '15m_MACD_12_26_9', '15m_MACDs_12_26_9', '15m_MACDh_12_26_9', '15m_BBL_20_2.0', '15m_BBM_20_2.0', '15m_BBU_20_2.0', '15m_BBB_20_2.0', '15m_BBP_20_2.0', '1h_RSI_14', '1h_RSI_6', '1h_EMA_5', '1h_EMA_21', '1h_MACD_12_26_9', '1h_MACDs_12_26_9', '1h_MACDh_12_26_9', '1h_BBL_20_2.0', '1h_BBM_20_2.0', '1h_BBU_20_2.0', '1h_BBB_20_2.0', '1h_BBP_20_2.0', '4h_RSI_14', '4h_RSI_6', '4h_EMA_5', '4h_EMA_21'], 'lower_timeframe': '15m', 'middle_timeframe': '1h', 'higher_timeframe': '4h', 'seq_length': 100, 'training_data_ratio': 0.8, 'epochs': 20, 'model_input_shape': (100, 29), 'model_name': 'binance_mtf_v1_0_1_15m_01-01-2020_30-12-2024_4cc8bc32', 'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2020_30-12-2024_4cc8bc32.h5', 'train_loss': 0.236819788813591, 'train_mae': 0.3972854018211365, 'val_loss': 0.24077270925045013, 'val_mae': 0.4036828577518463, 'final_epoch': 11, 'training_data_start_date': Timestamp('2020-01-04 08:00:00'), 'training_data_end_date': Timestamp('2023-12-31 19:00:00'), 'test_data_start_date': Timestamp('2024-01-01 20:15:00'), 'test_data_end_date': Timestamp('2024-12-29 21:00:00'), 'trade_leverage': 25, 'trade_margin': 1000, 'trade_buy_threshold': 0.7, 'trade_sell_threshold': -0.7, 'starting_portfolio_value': 10000.0, 'final_portfolio_value': 56654.7056339946, 'broker_commision': 0.02, 'trade_analysis': {'total': {'total': 94, 'open': 2, 'closed': 92}, 'streak': {'won': {'current': 10, 'longest': 10}, 'lost': {'current': 0, 'longest': 2}}, 'pnl': {'gross': {'total': 46914, 'average': 510}, 'net': {'total': 45996, 'average': 500}}, 'won': {'total': 70, 'pnl': {'total': 71208, 'average': 1018, 'max': 3200}}, 'lost': {'total': 22, 'pnl': {'total': -25210, 'average': -1146, 'max': -2620}}, 'long': {'total': 28, 'pnl': {'total': 15564, 'average': 576, 'won': {'total': 18994, 'average': 864, 'max': 3200}, 'lost': {'total': -3430, 'average': -686, 'max': -1590}}, 'won': 22, 'lost': 6}, 'short': {'total': 66, 'pnl': {'total': 30434, 'average': 468, 'won': {'total': 52216, 'average': 1088, 'max': 2830}, 'lost': {'total': -21780, 'average': -1280, 'max': -2620}}, 'won': 48, 'lost': 18}, 'len': {'total': 25286, 'average': 276, 'max': 1588, 'min': 14, 'won': {'total': 16914, 'average': 242, 'max': 1588, 'min': 14}, 'lost': {'total': 8372, 'average': 382, 'max': 1232, 'min': 38}, 'long': {'total': 3926, 'average': 146, 'max': 638, 'min': 16, 'won': {'total': 2990, 'average': 136, 'max': 638, 'min': 16}, 'lost': {'total': 936, 'average': 188, 'max': 392, 'min': 38}}, 'short': {'total': 21360, 'average': 330, 'max': 1588, 'min': 14, 'won': {'total': 13924, 'average': 290, 'max': 1588, 'min': 14}, 'lost': {'total': 7438, 'average': 438, 'max': 1232, 'min': 108}}}}, 'drawdown_analysis': {'len': 580, 'drawdown': 2, 'moneydown': 302, 'max': {'len': 4246, 'drawdown': 42, 'moneydown': 6340}}, 'sharpe_analysis': {'sharperatio': 0}, 'version': 'v1_0_1', 'created_at': datetime.datetime(2025, 3, 9, 15, 17, 4, 995368)}
# Backtesting- Buy Threshold: 0.7, Sell Threshold: -0.7, leverage: 30
# Starting Portfolio Value: 10000.00
# Final Portfolio Value: 65985.65
# Data saved to Firestore: Collection=trade-models, Document ID=6cUQkvMedpegk62LiJRj
# {'timeframe': '15m', 'start_date': '01-01-2020', 'end_date': '30-12-2024', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'features_columns': ['15m_RSI_14', '15m_RSI_6', '15m_EMA_5', '15m_EMA_21', '15m_SMA_50', '15m_MACD_12_26_9', '15m_MACDs_12_26_9', '15m_MACDh_12_26_9', '15m_BBL_20_2.0', '15m_BBM_20_2.0', '15m_BBU_20_2.0', '15m_BBB_20_2.0', '15m_BBP_20_2.0', '1h_RSI_14', '1h_RSI_6', '1h_EMA_5', '1h_EMA_21', '1h_MACD_12_26_9', '1h_MACDs_12_26_9', '1h_MACDh_12_26_9', '1h_BBL_20_2.0', '1h_BBM_20_2.0', '1h_BBU_20_2.0', '1h_BBB_20_2.0', '1h_BBP_20_2.0', '4h_RSI_14', '4h_RSI_6', '4h_EMA_5', '4h_EMA_21'], 'lower_timeframe': '15m', 'middle_timeframe': '1h', 'higher_timeframe': '4h', 'seq_length': 100, 'training_data_ratio': 0.8, 'epochs': 20, 'model_input_shape': (100, 29), 'model_name': 'binance_mtf_v1_0_1_15m_01-01-2020_30-12-2024_4cc8bc32', 'model_path': 'gs://ife-storage/trade/models/binance_mtf_v1_0_1_15m_01-01-2020_30-12-2024_4cc8bc32.h5', 'train_loss': 0.236819788813591, 'train_mae': 0.3972854018211365, 'val_loss': 0.24077270925045013, 'val_mae': 0.4036828577518463, 'final_epoch': 11, 'training_data_start_date': Timestamp('2020-01-04 08:00:00'), 'training_data_end_date': Timestamp('2023-12-31 19:00:00'), 'test_data_start_date': Timestamp('2024-01-01 20:15:00'), 'test_data_end_date': Timestamp('2024-12-29 21:00:00'), 'trade_leverage': 30, 'trade_margin': 1000, 'trade_buy_threshold': 0.7, 'trade_sell_threshold': -0.7, 'starting_portfolio_value': 10000.0, 'final_portfolio_value': 65985.6467607935, 'broker_commision': 0.02, 'trade_analysis': {'total': {'total': 94, 'open': 2, 'closed': 92}, 'streak': {'won': {'current': 10, 'longest': 10}, 'lost': {'current': 0, 'longest': 2}}, 'pnl': {'gross': {'total': 56296, 'average': 612}, 'net': {'total': 55196, 'average': 600}}, 'won': {'total': 70, 'pnl': {'total': 85450, 'average': 1222, 'max': 3838}}, 'lost': {'total': 22, 'pnl': {'total': -30254, 'average': -1374, 'max': -3144}}, 'long': {'total': 28, 'pnl': {'total': 18676, 'average': 692, 'won': {'total': 22792, 'average': 1036, 'max': 3838}, 'lost': {'total': -4116, 'average': -822, 'max': -1908}}, 'won': 22, 'lost': 6}, 'short': {'total': 66, 'pnl': {'total': 36520, 'average': 562, 'won': {'total': 62658, 'average': 1306, 'max': 3396}, 'lost': {'total': -26136, 'average': -1536, 'max': -3144}}, 'won': 48, 'lost': 18}, 'len': {'total': 25286, 'average': 276, 'max': 1588, 'min': 14, 'won': {'total': 16914, 'average': 242, 'max': 1588, 'min': 14}, 'lost': {'total': 8372, 'average': 382, 'max': 1232, 'min': 38}, 'long': {'total': 3926, 'average': 146, 'max': 638, 'min': 16, 'won': {'total': 2990, 'average': 136, 'max': 638, 'min': 16}, 'lost': {'total': 936, 'average': 188, 'max': 392, 'min': 38}}, 'short': {'total': 21360, 'average': 330, 'max': 1588, 'min': 14, 'won': {'total': 13924, 'average': 290, 'max': 1588, 'min': 14}, 'lost': {'total': 7438, 'average': 438, 'max': 1232, 'min': 108}}}}, 'drawdown_analysis': {'len': 580, 'drawdown': 2, 'moneydown': 362, 'max': {'len': 4246, 'drawdown': 48, 'moneydown': 7606}}, 'sharpe_analysis': {'sharperatio': 0}, 'version': 'v1_0_1', 'created_at': datetime.datetime(2025, 3, 9, 15, 17, 13, 118387)}
